# %% [markdown]
# # 搭建环境

# %%
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import math
import collections
import itertools
from typing import List, Tuple
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'
import tensorflow as tf

PROJECT_ROOT_DIR = "."
H5_PATH = os.path.join(PROJECT_ROOT_DIR, "model_h5", "Gomoku-v0_tf_21")
os.makedirs(H5_PATH, exist_ok=True)

SavedModel_PATH = os.path.join(PROJECT_ROOT_DIR, "saved_model", "Gomoku-v0_tf_21")
os.makedirs(SavedModel_PATH, exist_ok=True)


EMPTY = 0
BLACK = 1
WHITE = -1
render_characters='+ox'
end='\n'

def strfboard(board:np.ndarray) -> str:
    
    s = ''
    for x in range(board.shape[0]):
        for y in range(board.shape[1]):
            c = render_characters[board[x][y]]
            s += c
        s += end
    return s[:-len(end)]

def is_index(board:np.ndarray, location:np.ndarray) -> bool:
    
    x, y = location
    return x in range(board.shape[0]) and y in range(board.shape[1])

@tf.function
def extend_board(board:tf.Tensor) -> tf.Tensor:
    
    boards = tf.stack([board,
            tf.experimental.numpy.rot90(board), 
            tf.experimental.numpy.rot90(board, k=2),
            tf.experimental.numpy.rot90(board, k=3), 
            tf.transpose(board), 
            tf.experimental.numpy.rot90(tf.transpose(board)),
            tf.experimental.numpy.rot90(tf.transpose(board),k=2), 
            tf.experimental.numpy.rot90(tf.transpose(board),k=3)])
    return boards

class KInARowEnv:

    def __init__(self, board_shape:int=3, target_length:int=3):
        
        self.target_length = target_length
        self.PASS = np.array([-1, 0],dtype=np.int32)
        if isinstance(board_shape, int):
            board_shape = (board_shape, board_shape)
        self.board = np.zeros(board_shape, dtype=np.int32)

    def reset(self) -> Tuple[np.ndarray, int]:
        
        self.board = np.zeros_like(self.board, dtype=np.int32)
        self.player = BLACK
        return self.board, self.player

    def is_valid(self, state:Tuple[np.ndarray, int], action:np.ndarray) -> bool:
        
        board, _ = state
        if not is_index(board, action):
            return False
        x, y = action
        return board[x, y] == EMPTY

    def get_valid(self, state:Tuple[np.ndarray, int]) -> np.ndarray:
        
        board, _ = state
        valid = np.zeros_like(board, dtype=np.int8)
        for x in range(board.shape[0]):
            for y in range(board.shape[1]):
                valid[x, y] = self.is_valid(state, np.array([x, y]))
        return valid

    def has_valid(self, state:Tuple[np.ndarray, int]) -> bool:
        
        board = state[0]
        for x in range(board.shape[0]):
            for y in range(board.shape[1]):
                if self.is_valid(state, np.array([x, y])):
                    return True
        return False

    def get_winner(self, state:Tuple[np.ndarray, int]) -> int:
        
        board, _ = state
        for player in [BLACK, WHITE]:
            for x in range(board.shape[0]):
                for y in range(board.shape[1]):
                    for dx, dy in [(1, -1), (1, 0), (1, 1), (0, 1)]: # loop on the 8 directions
                        xx, yy = x, y
                        for count in itertools.count():
                            if not is_index(board, (xx, yy)) or board[xx, yy] != player:
                                break
                            xx, yy = xx + dx, yy + dy
                        if count >= self.target_length:
                            return player
        for player in [BLACK, WHITE]:
            if self.has_valid((board, player)):
                return None
        return 0

    def get_next_state(self, state:Tuple[np.ndarray, int], action:np.ndarray) -> Tuple[np.ndarray, int]:
        
        board, player = state
        x, y = action
        if self.is_valid(state, action):
            board = np.array(board,dtype=np.int32)
            board[x, y] = player
        return board, -player

    def next_step(self, state:Tuple[np.ndarray, int],
                  action:np.ndarray) -> Tuple[np.ndarray, int, int, int]:
        
        if not self.is_valid(state, action):
            action = self.PASS
        while True:
            state = self.get_next_state(state, action)
            winner = self.get_winner(state)
            if winner is not None:
                return state, winner, 1
            if self.has_valid(state):
                break
            action = self.PASS
        return state, 0, 0

    def step(self, action:np.ndarray) -> Tuple[np.ndarray, int, int, int]:
        
        state = (self.board, self.player)
        next_state, winner, done = self.next_step(state, action)
        self.board, self.player = next_state
        return self.board, self.player, winner, done

# %% [markdown]
# # 五子棋 Gomoku-v0

# %% [markdown]
# ## 环境实例

# %%
#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

# %% [markdown]
# ## 智能体

# %%
def residual(x:tf.Tensor, filters:list, kernel_sizes:int=3, strides:int=1, activations:str='relu',
            regularizer:tf.keras.regularizers.Regularizer=tf.keras.regularizers.l2(1e-4)) -> tf.Tensor:
    
    shortcut = x
    for i, filte in enumerate(filters):
        kernel_size = kernel_sizes if isinstance(kernel_sizes, int) \
            else kernel_sizes[i]
        stride = strides if isinstance(strides, int) else strides[i]
        activation = activations if isinstance(activations, str) \
            else activations[i]
        z = tf.keras.layers.Conv2D(filte, kernel_size, strides=stride,
                               padding='same', kernel_regularizer=regularizer,
                               bias_regularizer=regularizer)(x)
        y = tf.keras.layers.BatchNormalization()(z)
        if i == len(filters) - 1:
            y = tf.keras.layers.Add()([shortcut, y])
        x = tf.keras.layers.Activation(activation)(y)
    return x

# %%
class AlphaZeroAgent:
    def __init__(self, env:object, epoches:int=1,
                 kwargs:dict={}, load:str=None, sim_count:int=800,
                 c_init:float=1.25, c_base:int=19652,
                 prior_exploration_fraction:float=0.25):
        
        self.env = env
        self.board = np.zeros_like(env.board,dtype=np.int32)
        self.epoches = epoches
        
        # Use the central storage strategy instead:
        distribution = tf.distribute.experimental.CentralStorageStrategy()
        
        with distribution.scope():
            if load is not None:
                self.net = tf.keras.models.load_model(load,
                    custom_objects={"categorical_crossentropy_2d": categorical_crossentropy_2d})
            else:
                self.net = self.build_network(**kwargs)
        
        self.reset_mcts()
        self.sim_count = sim_count # MCTS 次数
        self.c_init = c_init # PUCT 系数
        self.c_base = c_base # PUCT 系数
        self.prior_exploration_fraction = prior_exploration_fraction
        
    def build_network(self, conv_filters:list, residual_filters:List[list],
                      policy_filters:list,learning_rate:float=0.001,
                      regularizer:tf.keras.regularizers.Regularizer
                      =tf.keras.regularizers.l2(1e-4)) -> tf.keras.Model:
        
        # 公共部分
        inputs = tf.keras.Input(shape=self.board.shape)
        x = tf.keras.layers.Reshape(self.board.shape + (1,))(inputs)
        for conv_filter in conv_filters:
            z = tf.keras.layers.Conv2D(conv_filter, 3, padding='same',
                                   kernel_regularizer=regularizer,
                                   bias_regularizer=regularizer)(x)
            y = tf.keras.layers.BatchNormalization()(z)
            x = tf.keras.layers.ReLU()(y)
        for residual_filter in residual_filters:
            x = residual(x, filters=residual_filter, regularizer=regularizer)
        intermediates = x
        
        # 概率部分
        for policy_filter in policy_filters:
            z = tf.keras.layers.Conv2D(policy_filter, 3, padding='same',
                                   kernel_regularizer=regularizer,
                                   bias_regularizer=regularizer)(x)
            y = tf.keras.layers.BatchNormalization()(z)
            x = tf.keras.layers.ReLU()(y)
        logits = tf.keras.layers.Conv2D(1, 3, padding='same',
                kernel_regularizer=regularizer, bias_regularizer=regularizer)(x)
        flattens = tf.keras.layers.Flatten()(logits)
        softmaxs = tf.keras.layers.Softmax()(flattens)
        probs = tf.keras.layers.Reshape(self.board.shape)(softmaxs)
        
        # 价值部分
        z = tf.keras.layers.Conv2D(1, 3, padding='same',
                               kernel_regularizer=regularizer,
                               bias_regularizer=regularizer)(intermediates)
        y = tf.keras.layers.BatchNormalization()(z)
        x = tf.keras.layers.ReLU()(y)
        flattens = tf.keras.layers.Flatten()(x)
        vs = tf.keras.layers.Dense(1, activation=tf.keras.activations.tanh,
                               kernel_regularizer=regularizer,
                               bias_regularizer=regularizer)(flattens)
        
        model = tf.keras.Model(inputs=inputs, outputs=[probs, vs])
        
        @tf.function
        def categorical_crossentropy_2d(y_true:tf.Tensor,
                                        y_pred:tf.Tensor) -> tf.keras.losses.Loss:
            labels = tf.reshape(y_true, [-1, self.board.size])
            preds = tf.reshape(y_pred, [-1,self.board.size])
            return tf.keras.losses.categorical_crossentropy(labels, preds)
        
        loss = [categorical_crossentropy_2d, tf.keras.losses.MSE]
        optimizer = tf.keras.optimizers.Adam(learning_rate)
        model.compile(loss=loss,optimizer=optimizer)
        return model
    
    def reset_mcts(self):
        
        def zero_board_factory() -> np.ndarray: # 用于构造 default_dict
            return np.zeros_like(self.board, dtype=float)
        
        self.q = collections.defaultdict(zero_board_factory)
        # q 值估计: board -> board
        self.count = collections.defaultdict(zero_board_factory)
        # q 值计数: board -> board
        self.policy = {} # 策略：board -> board
        self.valid = {} # 有效位置：board -> board
        self.winner = {} # 赢家：board -> None or int
        
    def decide(self, observation:Tuple[np.ndarray, int]) -> Tuple[np.ndarray, np.ndarray]:
        
        # 计算策略
        board, player = observation
        canonical_board = player * board
        s = strfboard(canonical_board)
        while self.count[s].sum() < self.sim_count: # 多次 MCTS 搜索
            self.search(canonical_board, prior_noise=True)
        prob = self.count[s] / self.count[s].sum()
        
        # 采样
        location_index = np.random.choice(prob.size, p=prob.reshape(-1))
        location = np.unravel_index(location_index, prob.shape)
        return location, prob
    
    def learn(self, train_set:tf.data.Dataset):
        
        self.net.fit(train_set, verbose=0, epochs=self.epoches) # 训练
        self.reset_mcts()
        
    def search(self, board:np.ndarray, prior_noise:bool=False) -> np.ndarray: # MCTS 搜索
        
        s = strfboard(board)        
        if s not in self.winner:
            self.winner[s] = self.env.get_winner((board, BLACK)) # 计算赢家
        if self.winner[s] is not None: # 赢家确定的情况
            return self.winner[s]
        
        if s not in self.policy: # 未计算过策略的叶子节点
            pis, vs = self.net.predict(board[np.newaxis])
            pi, v = pis[0], vs[0]
            valid = self.env.get_valid((board, BLACK))
            masked_pi = pi * valid
            total_masked_pi = np.sum(masked_pi)
            if total_masked_pi <= 0: # 所有的有效动作都没有概率， 偶尔可能发生
                masked_pi = valid # workaround
                total_masked_pi = np.sum(masked_pi)
            self.policy[s] = masked_pi / total_masked_pi
            self.valid[s] = valid
            return v
        
        # PUCT 上届计算
        count_sum = self.count[s].sum()
        coef = (self.c_init + np.log1p((1 + count_sum) / self.c_base)) * \
            math.sqrt(count_sum) / (1. + self.count[s])
        
        if prior_noise: # 先验噪声
            alpha = 1. / self.valid[s].sum()
            noise = np.random.gamma(alpha, 1., board.shape)
            noise *= self.valid[s]
            noise /= noise.sum()
            prior = (1. - self.prior_exploration_fraction) * \
                self.policy[s] + \
                self.prior_exploration_fraction * noise
        else:
            prior = self.policy[s]
        
        ub = np.where(self.valid[s], self.q[s] + coef * prior, np.nan)
        location_index = np.nanargmax(ub)
        location = np.unravel_index(location_index, board.shape)
        
        (next_board, next_player), _, _ = self.env.next_step(
            (board, BLACK), np.array(location))
        next_canonical_board = next_player * next_board
        next_v = self.search(next_canonical_board) # 递归搜索
        v = next_player * next_v
        
        self.count[s][location] += 1
        self.q[s][location] += (v - self.q[s][location]) / \
                self.count[s][location]
        return v

# %% [markdown]
# ## 训练

# %%
"""
AlphaZero 参数， 可用来求解比较大型的问题 （如五子棋）
"""
train_iterations = 700000 # 训练迭代次数
train_episodes_per_iteration = 5000 # 每次迭代自我对弈回合数
epoches = 10 # 每回合进行几次批学习
batch_size = 4096 # 批学习的批大小
sim_count = 800 # MCTS需要的计数
net_kwargs = {}
net_kwargs['conv_filters'] = [256,]
net_kwargs['residual_filters'] = [[256, 256], ] * 19
net_kwargs['policy_filters'] = [256,]
shuffle_buffer_size = 10000

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 20
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
net_kwargs = {}
net_kwargs['conv_filters'] = [32,]
net_kwargs['residual_filters'] = [[32, 32],]
net_kwargs['policy_filters'] = [64,]
shuffle_buffer_size = 512

agent = AlphaZeroAgent(env=env, kwargs=net_kwargs, sim_count=sim_count,
                       epoches=epoches)

def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 0 回合 0: 收集到 184 条经验
# 训练 0 回合 1: 收集到 224 条经验
# 训练 0 回合 2: 收集到 216 条经验
# 训练 0 回合 3: 收集到 176 条经验
# 训练 0 回合 4: 收集到 192 条经验
# 训练 0 回合 5: 收集到 392 条经验
# 训练 0 回合 6: 收集到 200 条经验
# 训练 0 回合 7: 收集到 176 条经验
# 训练 0 回合 8: 收集到 184 条经验
# 训练 0 回合 9: 收集到 176 条经验
# 训练 0 回合 10: 收集到 168 条经验
# 训练 0 回合 11: 收集到 136 条经验
# 训练 0 回合 12: 收集到 192 条经验
# 训练 0 回合 13: 收集到 216 条经验
# 训练 0 回合 14: 收集到 168 条经验
# 训练 0 回合 15: 收集到 168 条经验
# 训练 0 回合 16: 收集到 392 条经验
# 训练 0 回合 17: 收集到 240 条经验
# 训练 0 回合 18: 收集到 272 条经验
# 训练 0 回合 19: 收集到 224 条经验
# 训练 0：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0000/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 0)
# +++++++
# o++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 4)
# +++++++
# o++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++x++
# 第 2 步： 玩家 1， 动作 (2, 2)
# +++++++
# o++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# ++++x++
# 第 3 步： 玩家 -1， 动作 (6, 3)
# +++++++
# o++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# +++xx++
# 第 4 步： 玩家 1， 动作 (3, 2)
# +++++++
# o++++++
# ++o++++
# ++o++++
# +++++++
# +++++++
# +++xx++
# 第 5 步： 玩家 -1， 动作 (1, 6)
# +++++++
# o+++++x
# ++o++++
# ++o++++
# +++++++
# +++++++
# +++xx++
# 第 6 步： 玩家 1， 动作 (2, 1)
# +++++++
# o+++++x
# +oo++++
# ++o++++
# +++++++
# +++++++
# +++xx++
# 第 7 步： 玩家 -1， 动作 (4, 6)
# +++++++
# o+++++x
# +oo++++
# ++o++++
# ++++++x
# +++++++
# +++xx++
# 第 8 步： 玩家 1， 动作 (5, 5)
# +++++++
# o+++++x
# +oo++++
# ++o++++
# ++++++x
# +++++o+
# +++xx++
# 第 9 步： 玩家 -1， 动作 (6, 1)
# +++++++
# o+++++x
# +oo++++
# ++o++++
# ++++++x
# +++++o+
# +x+xx++
# 第 10 步： 玩家 1， 动作 (4, 5)
# +++++++
# o+++++x
# +oo++++
# ++o++++
# +++++ox
# +++++o+
# +x+xx++
# 第 11 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# o+++++x
# +oo++++
# ++o++++
# +++++ox
# +++++o+
# +x+xx++
# 第 12 步： 玩家 1， 动作 (0, 3)
# +++o++x
# o+++++x
# +oo++++
# ++o++++
# +++++ox
# +++++o+
# +x+xx++
# 第 13 步： 玩家 -1， 动作 (4, 4)
# +++o++x
# o+++++x
# +oo++++
# ++o++++
# ++++xox
# +++++o+
# +x+xx++
# 第 14 步： 玩家 1， 动作 (2, 4)
# +++o++x
# o+++++x
# +oo+o++
# ++o++++
# ++++xox
# +++++o+
# +x+xx++
# 第 15 步： 玩家 -1， 动作 (5, 1)
# +++o++x
# o+++++x
# +oo+o++
# ++o++++
# ++++xox
# +x+++o+
# +x+xx++
# 第 16 步： 玩家 1， 动作 (1, 4)
# +++o++x
# o+++o+x
# +oo+o++
# ++o++++
# ++++xox
# +x+++o+
# +x+xx++
# 第 17 步： 玩家 -1， 动作 (5, 3)
# +++o++x
# o+++o+x
# +oo+o++
# ++o++++
# ++++xox
# +x+x+o+
# +x+xx++
# 第 18 步： 玩家 1， 动作 (5, 4)
# +++o++x
# o+++o+x
# +oo+o++
# ++o++++
# ++++xox
# +x+xoo+
# +x+xx++
# 第 19 步： 玩家 -1， 动作 (2, 3)
# +++o++x
# o+++o+x
# +ooxo++
# ++o++++
# ++++xox
# +x+xoo+
# +x+xx++
# 第 20 步： 玩家 1， 动作 (4, 3)
# +++o++x
# o+++o+x
# +ooxo++
# ++o++++
# +++oxox
# +x+xoo+
# +x+xx++
# 赢家 1
# 训练 1 回合 0: 收集到 136 条经验
# 训练 1 回合 1: 收集到 256 条经验
# 训练 1 回合 2: 收集到 264 条经验
# 训练 1 回合 3: 收集到 392 条经验
# 训练 1 回合 4: 收集到 224 条经验
# 训练 1 回合 5: 收集到 136 条经验
# 训练 1 回合 6: 收集到 264 条经验
# 训练 1 回合 7: 收集到 232 条经验
# 训练 1 回合 8: 收集到 288 条经验
# 训练 1 回合 9: 收集到 192 条经验
# 训练 1 回合 10: 收集到 248 条经验
# 训练 1 回合 11: 收集到 240 条经验
# 训练 1 回合 12: 收集到 304 条经验
# 训练 1 回合 13: 收集到 224 条经验
# 训练 1 回合 14: 收集到 200 条经验
# 训练 1 回合 15: 收集到 168 条经验
# 训练 1 回合 16: 收集到 248 条经验
# 训练 1 回合 17: 收集到 128 条经验
# 训练 1 回合 18: 收集到 304 条经验
# 训练 1 回合 19: 收集到 392 条经验
# 训练 1：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0001/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 4)
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# x++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 2)
# +++++++
# ++++o++
# +++++++
# ++o++++
# +++++++
# x++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 2)
# +++++++
# ++x+o++
# +++++++
# ++o++++
# +++++++
# x++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 4)
# +++++++
# ++x+o++
# +++++++
# ++o+o++
# +++++++
# x++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 2)
# +++++++
# ++x+o++
# +++++++
# ++o+o++
# +++++++
# x+x++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 6)
# +++++++
# ++x+o++
# +++++++
# ++o+o+o
# +++++++
# x+x++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# ++x+o++
# +++++++
# ++o+o+o
# +++++++
# x+x++++
# +++++++
# 第 8 步： 玩家 1， 动作 (5, 1)
# +x+++++
# ++x+o++
# +++++++
# ++o+o+o
# +++++++
# xox++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (4, 3)
# +x+++++
# ++x+o++
# +++++++
# ++o+o+o
# +++x+++
# xox++++
# +++++++
# 第 10 步： 玩家 1， 动作 (4, 4)
# +x+++++
# ++x+o++
# +++++++
# ++o+o+o
# +++xo++
# xox++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (2, 0)
# +x+++++
# ++x+o++
# x++++++
# ++o+o+o
# +++xo++
# xox++++
# +++++++
# 第 12 步： 玩家 1， 动作 (0, 5)
# +x+++o+
# ++x+o++
# x++++++
# ++o+o+o
# +++xo++
# xox++++
# +++++++
# 第 13 步： 玩家 -1， 动作 (5, 6)
# +x+++o+
# ++x+o++
# x++++++
# ++o+o+o
# +++xo++
# xox+++x
# +++++++
# 第 14 步： 玩家 1， 动作 (2, 5)
# +x+++o+
# ++x+o++
# x++++o+
# ++o+o+o
# +++xo++
# xox+++x
# +++++++
# 第 15 步： 玩家 -1， 动作 (3, 3)
# +x+++o+
# ++x+o++
# x++++o+
# ++oxo+o
# +++xo++
# xox+++x
# +++++++
# 第 16 步： 玩家 1， 动作 (2, 3)
# +x+++o+
# ++x+o++
# x++o+o+
# ++oxo+o
# +++xo++
# xox+++x
# +++++++
# 第 17 步： 玩家 -1， 动作 (4, 0)
# +x+++o+
# ++x+o++
# x++o+o+
# ++oxo+o
# x++xo++
# xox+++x
# +++++++
# 第 18 步： 玩家 1， 动作 (2, 2)
# +x+++o+
# ++x+o++
# x+oo+o+
# ++oxo+o
# x++xo++
# xox+++x
# +++++++
# 第 19 步： 玩家 -1， 动作 (3, 5)
# +x+++o+
# ++x+o++
# x+oo+o+
# ++oxoxo
# x++xo++
# xox+++x
# +++++++
# 第 20 步： 玩家 1， 动作 (6, 1)
# +x+++o+
# ++x+o++
# x+oo+o+
# ++oxoxo
# x++xo++
# xox+++x
# +o+++++
# 第 21 步： 玩家 -1， 动作 (2, 4)
# +x+++o+
# ++x+o++
# x+ooxo+
# ++oxoxo
# x++xo++
# xox+++x
# +o+++++
# 第 22 步： 玩家 1， 动作 (5, 3)
# +x+++o+
# ++x+o++
# x+ooxo+
# ++oxoxo
# x++xo++
# xoxo++x
# +o+++++
# 第 23 步： 玩家 -1， 动作 (5, 4)
# +x+++o+
# ++x+o++
# x+ooxo+
# ++oxoxo
# x++xo++
# xoxox+x
# +o+++++
# 第 24 步： 玩家 1， 动作 (6, 5)
# +x+++o+
# ++x+o++
# x+ooxo+
# ++oxoxo
# x++xo++
# xoxox+x
# +o+++o+
# 第 25 步： 玩家 -1， 动作 (2, 1)
# +x+++o+
# ++x+o++
# xxooxo+
# ++oxoxo
# x++xo++
# xoxox+x
# +o+++o+
# 第 26 步： 玩家 1， 动作 (4, 1)
# +x+++o+
# ++x+o++
# xxooxo+
# ++oxoxo
# xo+xo++
# xoxox+x
# +o+++o+
# 赢家 1
# 训练 2 回合 0: 收集到 184 条经验
# 训练 2 回合 1: 收集到 336 条经验
# 训练 2 回合 2: 收集到 200 条经验
# 训练 2 回合 3: 收集到 176 条经验
# 训练 2 回合 4: 收集到 136 条经验
# 训练 2 回合 5: 收集到 288 条经验
# 训练 2 回合 6: 收集到 200 条经验
# 训练 2 回合 7: 收集到 208 条经验
# 训练 2 回合 8: 收集到 200 条经验
# 训练 2 回合 9: 收集到 192 条经验
# 训练 2 回合 10: 收集到 368 条经验
# 训练 2 回合 11: 收集到 232 条经验
# 训练 2 回合 12: 收集到 216 条经验
# 训练 2 回合 13: 收集到 184 条经验
# 训练 2 回合 14: 收集到 280 条经验
# 训练 2 回合 15: 收集到 240 条经验
# 训练 2 回合 16: 收集到 216 条经验
# 训练 2 回合 17: 收集到 392 条经验
# 训练 2 回合 18: 收集到 272 条经验
# 训练 2 回合 19: 收集到 192 条经验
# 训练 2：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0002/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 5)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++x+
# 第 2 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# ++++o++
# +++++x+
# 第 3 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# ++++o++
# +++++x+
# 第 4 步： 玩家 1， 动作 (3, 4)
# x++++++
# +++++++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# +++++x+
# 第 5 步： 玩家 -1， 动作 (6, 2)
# x++++++
# +++++++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# ++x++x+
# 第 6 步： 玩家 1， 动作 (1, 4)
# x++++++
# ++++o++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# ++x++x+
# 第 7 步： 玩家 -1， 动作 (0, 5)
# x++++x+
# ++++o++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# ++x++x+
# 第 8 步： 玩家 1， 动作 (6, 6)
# x++++x+
# ++++o++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# ++x++xo
# 第 9 步： 玩家 -1， 动作 (3, 5)
# x++++x+
# ++++o++
# +++++++
# ++++ox+
# +++++o+
# ++++o++
# ++x++xo
# 第 10 步： 玩家 1， 动作 (4, 2)
# x++++x+
# ++++o++
# +++++++
# ++++ox+
# ++o++o+
# ++++o++
# ++x++xo
# 第 11 步： 玩家 -1， 动作 (4, 1)
# x++++x+
# ++++o++
# +++++++
# ++++ox+
# +xo++o+
# ++++o++
# ++x++xo
# 第 12 步： 玩家 1， 动作 (3, 2)
# x++++x+
# ++++o++
# +++++++
# ++o+ox+
# +xo++o+
# ++++o++
# ++x++xo
# 第 13 步： 玩家 -1， 动作 (1, 0)
# x++++x+
# x+++o++
# +++++++
# ++o+ox+
# +xo++o+
# ++++o++
# ++x++xo
# 第 14 步： 玩家 1， 动作 (3, 6)
# x++++x+
# x+++o++
# +++++++
# ++o+oxo
# +xo++o+
# ++++o++
# ++x++xo
# 第 15 步： 玩家 -1， 动作 (0, 1)
# xx+++x+
# x+++o++
# +++++++
# ++o+oxo
# +xo++o+
# ++++o++
# ++x++xo
# 第 16 步： 玩家 1， 动作 (1, 2)
# xx+++x+
# x+o+o++
# +++++++
# ++o+oxo
# +xo++o+
# ++++o++
# ++x++xo
# 第 17 步： 玩家 -1， 动作 (0, 4)
# xx++xx+
# x+o+o++
# +++++++
# ++o+oxo
# +xo++o+
# ++++o++
# ++x++xo
# 第 18 步： 玩家 1， 动作 (3, 0)
# xx++xx+
# x+o+o++
# +++++++
# o+o+oxo
# +xo++o+
# ++++o++
# ++x++xo
# 第 19 步： 玩家 -1， 动作 (6, 4)
# xx++xx+
# x+o+o++
# +++++++
# o+o+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 20 步： 玩家 1， 动作 (3, 1)
# xx++xx+
# x+o+o++
# +++++++
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 21 步： 玩家 -1， 动作 (2, 5)
# xx++xx+
# x+o+o++
# +++++x+
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 22 步： 玩家 1， 动作 (0, 2)
# xxo+xx+
# x+o+o++
# +++++x+
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 23 步： 玩家 -1， 动作 (2, 2)
# xxo+xx+
# x+o+o++
# ++x++x+
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 24 步： 玩家 1， 动作 (1, 3)
# xxo+xx+
# x+ooo++
# ++x++x+
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 25 步： 玩家 -1， 动作 (2, 0)
# xxo+xx+
# x+ooo++
# x+x++x+
# ooo+oxo
# +xo++o+
# ++++o++
# ++x+xxo
# 第 26 步： 玩家 1， 动作 (6, 1)
# xxo+xx+
# x+ooo++
# x+x++x+
# ooo+oxo
# +xo++o+
# ++++o++
# +ox+xxo
# 第 27 步： 玩家 -1， 动作 (2, 6)
# xxo+xx+
# x+ooo++
# x+x++xx
# ooo+oxo
# +xo++o+
# ++++o++
# +ox+xxo
# 第 28 步： 玩家 1， 动作 (1, 6)
# xxo+xx+
# x+ooo+o
# x+x++xx
# ooo+oxo
# +xo++o+
# ++++o++
# +ox+xxo
# 第 29 步： 玩家 -1， 动作 (2, 1)
# xxo+xx+
# x+ooo+o
# xxx++xx
# ooo+oxo
# +xo++o+
# ++++o++
# +ox+xxo
# 第 30 步： 玩家 1， 动作 (4, 0)
# xxo+xx+
# x+ooo+o
# xxx++xx
# ooo+oxo
# oxo++o+
# ++++o++
# +ox+xxo
# 第 31 步： 玩家 -1， 动作 (1, 1)
# xxo+xx+
# xxooo+o
# xxx++xx
# ooo+oxo
# oxo++o+
# ++++o++
# +ox+xxo
# 第 32 步： 玩家 1， 动作 (3, 3)
# xxo+xx+
# xxooo+o
# xxx++xx
# oooooxo
# oxo++o+
# ++++o++
# +ox+xxo
# 赢家 1
# 训练 3 回合 0: 收集到 264 条经验
# 训练 3 回合 1: 收集到 296 条经验
# 训练 3 回合 2: 收集到 192 条经验
# 训练 3 回合 3: 收集到 176 条经验
# 训练 3 回合 4: 收集到 224 条经验
# 训练 3 回合 5: 收集到 232 条经验
# 训练 3 回合 6: 收集到 136 条经验
# 训练 3 回合 7: 收集到 144 条经验
# 训练 3 回合 8: 收集到 288 条经验
# 训练 3 回合 9: 收集到 184 条经验
# 训练 3 回合 10: 收集到 288 条经验
# 训练 3 回合 11: 收集到 200 条经验
# 训练 3 回合 12: 收集到 304 条经验
# 训练 3 回合 13: 收集到 192 条经验
# 训练 3 回合 14: 收集到 320 条经验
# 训练 3 回合 15: 收集到 344 条经验
# 训练 3 回合 16: 收集到 152 条经验
# 训练 3 回合 17: 收集到 232 条经验
# 训练 3 回合 18: 收集到 208 条经验
# 训练 3 回合 19: 收集到 208 条经验
# 训练 3：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0003/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++o+
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++o++o+
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (6, 4)
# +++++++
# ++o++o+
# ++++x++
# +++++++
# +++++++
# +++++++
# ++++x++
# 第 4 步： 玩家 1， 动作 (0, 5)
# +++++o+
# ++o++o+
# ++++x++
# +++++++
# +++++++
# +++++++
# ++++x++
# 第 5 步： 玩家 -1， 动作 (3, 2)
# +++++o+
# ++o++o+
# ++++x++
# ++x++++
# +++++++
# +++++++
# ++++x++
# 第 6 步： 玩家 1， 动作 (1, 0)
# +++++o+
# o+o++o+
# ++++x++
# ++x++++
# +++++++
# +++++++
# ++++x++
# 第 7 步： 玩家 -1， 动作 (6, 6)
# +++++o+
# o+o++o+
# ++++x++
# ++x++++
# +++++++
# +++++++
# ++++x+x
# 第 8 步： 玩家 1， 动作 (2, 5)
# +++++o+
# o+o++o+
# ++++xo+
# ++x++++
# +++++++
# +++++++
# ++++x+x
# 第 9 步： 玩家 -1， 动作 (2, 6)
# +++++o+
# o+o++o+
# ++++xox
# ++x++++
# +++++++
# +++++++
# ++++x+x
# 第 10 步： 玩家 1， 动作 (2, 0)
# +++++o+
# o+o++o+
# o+++xox
# ++x++++
# +++++++
# +++++++
# ++++x+x
# 第 11 步： 玩家 -1， 动作 (3, 1)
# +++++o+
# o+o++o+
# o+++xox
# +xx++++
# +++++++
# +++++++
# ++++x+x
# 第 12 步： 玩家 1， 动作 (5, 5)
# +++++o+
# o+o++o+
# o+++xox
# +xx++++
# +++++++
# +++++o+
# ++++x+x
# 第 13 步： 玩家 -1， 动作 (5, 3)
# +++++o+
# o+o++o+
# o+++xox
# +xx++++
# +++++++
# +++x+o+
# ++++x+x
# 第 14 步： 玩家 1， 动作 (6, 2)
# +++++o+
# o+o++o+
# o+++xox
# +xx++++
# +++++++
# +++x+o+
# ++o+x+x
# 第 15 步： 玩家 -1， 动作 (3, 3)
# +++++o+
# o+o++o+
# o+++xox
# +xxx+++
# +++++++
# +++x+o+
# ++o+x+x
# 第 16 步： 玩家 1， 动作 (3, 5)
# +++++o+
# o+o++o+
# o+++xox
# +xxx+o+
# +++++++
# +++x+o+
# ++o+x+x
# 第 17 步： 玩家 -1， 动作 (6, 5)
# +++++o+
# o+o++o+
# o+++xox
# +xxx+o+
# +++++++
# +++x+o+
# ++o+xxx
# 第 18 步： 玩家 1， 动作 (4, 5)
# +++++o+
# o+o++o+
# o+++xox
# +xxx+o+
# +++++o+
# +++x+o+
# ++o+xxx
# 赢家 1
# 训练 4 回合 0: 收集到 104 条经验
# 训练 4 回合 1: 收集到 168 条经验
# 训练 4 回合 2: 收集到 256 条经验
# 训练 4 回合 3: 收集到 120 条经验
# 训练 4 回合 4: 收集到 360 条经验
# 训练 4 回合 5: 收集到 296 条经验
# 训练 4 回合 6: 收集到 88 条经验
# 训练 4 回合 7: 收集到 272 条经验
# 训练 4 回合 8: 收集到 208 条经验
# 训练 4 回合 9: 收集到 288 条经验
# 训练 4 回合 10: 收集到 216 条经验
# 训练 4 回合 11: 收集到 240 条经验
# 训练 4 回合 12: 收集到 216 条经验
# 训练 4 回合 13: 收集到 176 条经验
# 训练 4 回合 14: 收集到 160 条经验
# 训练 4 回合 15: 收集到 264 条经验
# 训练 4 回合 16: 收集到 144 条经验
# 训练 4 回合 17: 收集到 264 条经验
# 训练 4 回合 18: 收集到 184 条经验
# 训练 4 回合 19: 收集到 240 条经验
# 训练 4：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0004/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 3)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++o+++
# ++o++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 4)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++o+++
# ++o+x++
# +++++++
# 第 4 步： 玩家 1， 动作 (5, 3)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++o+++
# ++oox++
# +++++++
# 第 5 步： 玩家 -1， 动作 (6, 0)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++o+++
# ++oox++
# x++++++
# 第 6 步： 玩家 1， 动作 (5, 1)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++o+++
# +ooox++
# x++++++
# 第 7 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# ++++++x
# +++++++
# +++++++
# +++o+++
# +ooox++
# x++++++
# 第 8 步： 玩家 1， 动作 (3, 0)
# ++++++x
# ++++++x
# +++++++
# o++++++
# +++o+++
# +ooox++
# x++++++
# 第 9 步： 玩家 -1， 动作 (2, 5)
# ++++++x
# ++++++x
# +++++x+
# o++++++
# +++o+++
# +ooox++
# x++++++
# 第 10 步： 玩家 1， 动作 (3, 3)
# ++++++x
# ++++++x
# +++++x+
# o++o+++
# +++o+++
# +ooox++
# x++++++
# 第 11 步： 玩家 -1， 动作 (4, 1)
# ++++++x
# ++++++x
# +++++x+
# o++o+++
# +x+o+++
# +ooox++
# x++++++
# 第 12 步： 玩家 1， 动作 (3, 5)
# ++++++x
# ++++++x
# +++++x+
# o++o+o+
# +x+o+++
# +ooox++
# x++++++
# 第 13 步： 玩家 -1， 动作 (6, 5)
# ++++++x
# ++++++x
# +++++x+
# o++o+o+
# +x+o+++
# +ooox++
# x++++x+
# 第 14 步： 玩家 1， 动作 (2, 2)
# ++++++x
# ++++++x
# ++o++x+
# o++o+o+
# +x+o+++
# +ooox++
# x++++x+
# 第 15 步： 玩家 -1， 动作 (4, 0)
# ++++++x
# ++++++x
# ++o++x+
# o++o+o+
# xx+o+++
# +ooox++
# x++++x+
# 第 16 步： 玩家 1， 动作 (3, 6)
# ++++++x
# ++++++x
# ++o++x+
# o++o+oo
# xx+o+++
# +ooox++
# x++++x+
# 第 17 步： 玩家 -1， 动作 (4, 2)
# ++++++x
# ++++++x
# ++o++x+
# o++o+oo
# xxxo+++
# +ooox++
# x++++x+
# 第 18 步： 玩家 1， 动作 (2, 3)
# ++++++x
# ++++++x
# ++oo+x+
# o++o+oo
# xxxo+++
# +ooox++
# x++++x+
# 第 19 步： 玩家 -1， 动作 (0, 0)
# x+++++x
# ++++++x
# ++oo+x+
# o++o+oo
# xxxo+++
# +ooox++
# x++++x+
# 第 20 步： 玩家 1， 动作 (6, 3)
# x+++++x
# ++++++x
# ++oo+x+
# o++o+oo
# xxxo+++
# +ooox++
# x++o+x+
# 赢家 1
# 训练 5 回合 0: 收集到 240 条经验
# 训练 5 回合 1: 收集到 144 条经验
# 训练 5 回合 2: 收集到 328 条经验
# 训练 5 回合 3: 收集到 280 条经验
# 训练 5 回合 4: 收集到 392 条经验
# 训练 5 回合 5: 收集到 152 条经验
# 训练 5 回合 6: 收集到 176 条经验
# 训练 5 回合 7: 收集到 112 条经验
# 训练 5 回合 8: 收集到 184 条经验
# 训练 5 回合 9: 收集到 256 条经验
# 训练 5 回合 10: 收集到 272 条经验
# 训练 5 回合 11: 收集到 280 条经验
# 训练 5 回合 12: 收集到 176 条经验
# 训练 5 回合 13: 收集到 192 条经验
# 训练 5 回合 14: 收集到 264 条经验
# 训练 5 回合 15: 收集到 288 条经验
# 训练 5 回合 16: 收集到 224 条经验
# 训练 5 回合 17: 收集到 208 条经验
# 训练 5 回合 18: 收集到 224 条经验
# 训练 5 回合 19: 收集到 184 条经验
# 训练 5：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0005/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++x
# o++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++o+
# +++++++
# +++++++
# ++++++x
# o++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 5)
# +++++x+
# +++++o+
# +++++++
# +++++++
# ++++++x
# o++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 5)
# +++++x+
# +++++o+
# +++++++
# +++++++
# +++++ox
# o++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 0)
# +++++x+
# +++++o+
# +++++++
# +++++++
# x++++ox
# o++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 6)
# +++++xo
# +++++o+
# +++++++
# +++++++
# x++++ox
# o++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (1, 1)
# +++++xo
# +x+++o+
# +++++++
# +++++++
# x++++ox
# o++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (5, 2)
# +++++xo
# +x+++o+
# +++++++
# +++++++
# x++++ox
# o+o++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (4, 1)
# +++++xo
# +x+++o+
# +++++++
# +++++++
# xx+++ox
# o+o++++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 3)
# +++++xo
# +x+++o+
# +++++++
# +++++++
# xx+++ox
# o+o++++
# +++o+++
# 第 11 步： 玩家 -1， 动作 (0, 4)
# ++++xxo
# +x+++o+
# +++++++
# +++++++
# xx+++ox
# o+o++++
# +++o+++
# 第 12 步： 玩家 1， 动作 (3, 1)
# ++++xxo
# +x+++o+
# +++++++
# +o+++++
# xx+++ox
# o+o++++
# +++o+++
# 第 13 步： 玩家 -1， 动作 (4, 2)
# ++++xxo
# +x+++o+
# +++++++
# +o+++++
# xxx++ox
# o+o++++
# +++o+++
# 第 14 步： 玩家 1， 动作 (6, 0)
# ++++xxo
# +x+++o+
# +++++++
# +o+++++
# xxx++ox
# o+o++++
# o++o+++
# 第 15 步： 玩家 -1， 动作 (3, 3)
# ++++xxo
# +x+++o+
# +++++++
# +o+x+++
# xxx++ox
# o+o++++
# o++o+++
# 第 16 步： 玩家 1， 动作 (2, 3)
# ++++xxo
# +x+++o+
# +++o+++
# +o+x+++
# xxx++ox
# o+o++++
# o++o+++
# 第 17 步： 玩家 -1， 动作 (3, 6)
# ++++xxo
# +x+++o+
# +++o+++
# +o+x++x
# xxx++ox
# o+o++++
# o++o+++
# 第 18 步： 玩家 1， 动作 (1, 6)
# ++++xxo
# +x+++oo
# +++o+++
# +o+x++x
# xxx++ox
# o+o++++
# o++o+++
# 第 19 步： 玩家 -1， 动作 (3, 2)
# ++++xxo
# +x+++oo
# +++o+++
# +oxx++x
# xxx++ox
# o+o++++
# o++o+++
# 第 20 步： 玩家 1， 动作 (4, 4)
# ++++xxo
# +x+++oo
# +++o+++
# +oxx++x
# xxx+oox
# o+o++++
# o++o+++
# 第 21 步： 玩家 -1， 动作 (3, 5)
# ++++xxo
# +x+++oo
# +++o+++
# +oxx+xx
# xxx+oox
# o+o++++
# o++o+++
# 第 22 步： 玩家 1， 动作 (3, 4)
# ++++xxo
# +x+++oo
# +++o+++
# +oxxoxx
# xxx+oox
# o+o++++
# o++o+++
# 第 23 步： 玩家 -1， 动作 (1, 4)
# ++++xxo
# +x++xoo
# +++o+++
# +oxxoxx
# xxx+oox
# o+o++++
# o++o+++
# 第 24 步： 玩家 1， 动作 (4, 3)
# ++++xxo
# +x++xoo
# +++o+++
# +oxxoxx
# xxxooox
# o+o++++
# o++o+++
# 第 25 步： 玩家 -1， 动作 (6, 5)
# ++++xxo
# +x++xoo
# +++o+++
# +oxxoxx
# xxxooox
# o+o++++
# o++o+x+
# 第 26 步： 玩家 1， 动作 (2, 5)
# ++++xxo
# +x++xoo
# +++o+o+
# +oxxoxx
# xxxooox
# o+o++++
# o++o+x+
# 赢家 1
# 训练 6 回合 0: 收集到 176 条经验
# 训练 6 回合 1: 收集到 240 条经验
# 训练 6 回合 2: 收集到 152 条经验
# 训练 6 回合 3: 收集到 272 条经验
# 训练 6 回合 4: 收集到 248 条经验
# 训练 6 回合 5: 收集到 208 条经验
# 训练 6 回合 6: 收集到 392 条经验
# 训练 6 回合 7: 收集到 200 条经验
# 训练 6 回合 8: 收集到 376 条经验
# 训练 6 回合 9: 收集到 304 条经验
# 训练 6 回合 10: 收集到 144 条经验
# 训练 6 回合 11: 收集到 392 条经验
# 训练 6 回合 12: 收集到 144 条经验
# 训练 6 回合 13: 收集到 296 条经验
# 训练 6 回合 14: 收集到 232 条经验
# 训练 6 回合 15: 收集到 192 条经验
# 训练 6 回合 16: 收集到 208 条经验
# 训练 6 回合 17: 收集到 224 条经验
# 训练 6 回合 18: 收集到 208 条经验
# 训练 6 回合 19: 收集到 256 条经验
# 训练 6：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0006/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 0)
# x++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 5)
# x++++o+
# +++++++
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 0)
# x++++o+
# +++++++
# x++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 3)
# x++++o+
# +++++++
# x++++++
# +++o+o+
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 3)
# x++++o+
# +++++++
# x++x+++
# +++o+o+
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 5)
# x++++o+
# +++++++
# x++x+++
# +++o+o+
# +++++o+
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (1, 0)
# x++++o+
# x++++++
# x++x+++
# +++o+o+
# +++++o+
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (2, 5)
# x++++o+
# x++++++
# x++x+o+
# +++o+o+
# +++++o+
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 1)
# x++++o+
# x++++++
# x++x+o+
# +x+o+o+
# +++++o+
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (4, 2)
# x++++o+
# x++++++
# x++x+o+
# +x+o+o+
# ++o++o+
# +++++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 3)
# x++++o+
# x++++++
# x++x+o+
# +x+o+o+
# ++o++o+
# +++++++
# +++x+++
# 第 12 步： 玩家 1， 动作 (0, 1)
# xo+++o+
# x++++++
# x++x+o+
# +x+o+o+
# ++o++o+
# +++++++
# +++x+++
# 第 13 步： 玩家 -1， 动作 (4, 3)
# xo+++o+
# x++++++
# x++x+o+
# +x+o+o+
# ++ox+o+
# +++++++
# +++x+++
# 第 14 步： 玩家 1， 动作 (2, 4)
# xo+++o+
# x++++++
# x++xoo+
# +x+o+o+
# ++ox+o+
# +++++++
# +++x+++
# 第 15 步： 玩家 -1， 动作 (5, 2)
# xo+++o+
# x++++++
# x++xoo+
# +x+o+o+
# ++ox+o+
# ++x++++
# +++x+++
# 第 16 步： 玩家 1， 动作 (5, 5)
# xo+++o+
# x++++++
# x++xoo+
# +x+o+o+
# ++ox+o+
# ++x++o+
# +++x+++
# 第 17 步： 玩家 -1， 动作 (0, 4)
# xo++xo+
# x++++++
# x++xoo+
# +x+o+o+
# ++ox+o+
# ++x++o+
# +++x+++
# 第 18 步： 玩家 1， 动作 (5, 1)
# xo++xo+
# x++++++
# x++xoo+
# +x+o+o+
# ++ox+o+
# +ox++o+
# +++x+++
# 第 19 步： 玩家 -1， 动作 (1, 6)
# xo++xo+
# x+++++x
# x++xoo+
# +x+o+o+
# ++ox+o+
# +ox++o+
# +++x+++
# 第 20 步： 玩家 1， 动作 (4, 1)
# xo++xo+
# x+++++x
# x++xoo+
# +x+o+o+
# +oox+o+
# +ox++o+
# +++x+++
# 第 21 步： 玩家 -1， 动作 (5, 3)
# xo++xo+
# x+++++x
# x++xoo+
# +x+o+o+
# +oox+o+
# +oxx+o+
# +++x+++
# 第 22 步： 玩家 1， 动作 (0, 2)
# xoo+xo+
# x+++++x
# x++xoo+
# +x+o+o+
# +oox+o+
# +oxx+o+
# +++x+++
# 第 23 步： 玩家 -1， 动作 (6, 4)
# xoo+xo+
# x+++++x
# x++xoo+
# +x+o+o+
# +oox+o+
# +oxx+o+
# +++xx++
# 第 24 步： 玩家 1， 动作 (6, 5)
# xoo+xo+
# x+++++x
# x++xoo+
# +x+o+o+
# +oox+o+
# +oxx+o+
# +++xxo+
# 赢家 1
# 训练 7 回合 0: 收集到 152 条经验
# 训练 7 回合 1: 收集到 280 条经验
# 训练 7 回合 2: 收集到 200 条经验
# 训练 7 回合 3: 收集到 176 条经验
# 训练 7 回合 4: 收集到 160 条经验
# 训练 7 回合 5: 收集到 208 条经验
# 训练 7 回合 6: 收集到 232 条经验
# 训练 7 回合 7: 收集到 168 条经验
# 训练 7 回合 8: 收集到 248 条经验
# 训练 7 回合 9: 收集到 168 条经验
# 训练 7 回合 10: 收集到 168 条经验
# 训练 7 回合 11: 收集到 256 条经验
# 训练 7 回合 12: 收集到 280 条经验
# 训练 7 回合 13: 收集到 168 条经验
# 训练 7 回合 14: 收集到 192 条经验
# 训练 7 回合 15: 收集到 152 条经验
# 训练 7 回合 16: 收集到 232 条经验
# 训练 7 回合 17: 收集到 280 条经验
# 训练 7 回合 18: 收集到 296 条经验
# 训练 7 回合 19: 收集到 184 条经验
# 训练 7：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0007/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +o+x+++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 0)
# +++++++
# +++++++
# +++++++
# o++++++
# +o+x+++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x++++
# o++++++
# +o+x+++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# ++x++++
# o++o+++
# +o+x+++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (6, 6)
# +++++++
# +++++++
# ++x++++
# o++o+++
# +o+x+++
# +++++++
# ++++++x
# 第 6 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# ++x++++
# o++o+++
# +o+x+++
# +++++++
# ++++o+x
# 第 7 步： 玩家 -1， 动作 (3, 2)
# +++++++
# +++++++
# ++x++++
# o+xo+++
# +o+x+++
# +++++++
# ++++o+x
# 第 8 步： 玩家 1， 动作 (6, 2)
# +++++++
# +++++++
# ++x++++
# o+xo+++
# +o+x+++
# +++++++
# ++o+o+x
# 第 9 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# ++x++++
# o+xo+++
# +o+x+++
# ++x++++
# ++o+o+x
# 第 10 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# ++x++++
# o+xo+++
# +o+x+++
# ++xo+++
# ++o+o+x
# 第 11 步： 玩家 -1， 动作 (5, 5)
# +++++++
# +++++++
# ++x++++
# o+xo+++
# +o+x+++
# ++xo+x+
# ++o+o+x
# 第 12 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++++++
# +ox++++
# o+xo+++
# +o+x+++
# ++xo+x+
# ++o+o+x
# 第 13 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# +ox++++
# o+xo+++
# +o+x+++
# ++xo+x+
# ++o+o+x
# 第 14 步： 玩家 1， 动作 (6, 0)
# x++++++
# +++++++
# +ox++++
# o+xo+++
# +o+x+++
# ++xo+x+
# o+o+o+x
# 第 15 步： 玩家 -1， 动作 (1, 6)
# x++++++
# ++++++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xo+x+
# o+o+o+x
# 第 16 步： 玩家 1， 动作 (5, 4)
# x++++++
# ++++++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# o+o+o+x
# 第 17 步： 玩家 -1， 动作 (0, 1)
# xx+++++
# ++++++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# o+o+o+x
# 第 18 步： 玩家 1， 动作 (0, 5)
# xx+++o+
# ++++++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# o+o+o+x
# 第 19 步： 玩家 -1， 动作 (6, 1)
# xx+++o+
# ++++++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# oxo+o+x
# 第 20 步： 玩家 1， 动作 (1, 3)
# xx+++o+
# +++o++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# oxo+o+x
# 第 21 步： 玩家 -1， 动作 (1, 2)
# xx+++o+
# ++xo++x
# +ox++++
# o+xo+++
# +o+x+++
# ++xoox+
# oxo+o+x
# 第 22 步： 玩家 1， 动作 (2, 5)
# xx+++o+
# ++xo++x
# +ox++o+
# o+xo+++
# +o+x+++
# ++xoox+
# oxo+o+x
# 第 23 步： 玩家 -1， 动作 (4, 4)
# xx+++o+
# ++xo++x
# +ox++o+
# o+xo+++
# +o+xx++
# ++xoox+
# oxo+o+x
# 第 24 步： 玩家 1， 动作 (2, 4)
# xx+++o+
# ++xo++x
# +ox+oo+
# o+xo+++
# +o+xx++
# ++xoox+
# oxo+o+x
# 第 25 步： 玩家 -1， 动作 (4, 2)
# xx+++o+
# ++xo++x
# +ox+oo+
# o+xo+++
# +oxxx++
# ++xoox+
# oxo+o+x
# 赢家 -1
# 训练 8 回合 0: 收集到 248 条经验
# 训练 8 回合 1: 收集到 208 条经验
# 训练 8 回合 2: 收集到 264 条经验
# 训练 8 回合 3: 收集到 216 条经验
# 训练 8 回合 4: 收集到 152 条经验
# 训练 8 回合 5: 收集到 184 条经验
# 训练 8 回合 6: 收集到 168 条经验
# 训练 8 回合 7: 收集到 184 条经验
# 训练 8 回合 8: 收集到 272 条经验
# 训练 8 回合 9: 收集到 232 条经验
# 训练 8 回合 10: 收集到 192 条经验
# 训练 8 回合 11: 收集到 136 条经验
# 训练 8 回合 12: 收集到 200 条经验
# 训练 8 回合 13: 收集到 192 条经验
# 训练 8 回合 14: 收集到 280 条经验
# 训练 8 回合 15: 收集到 128 条经验
# 训练 8 回合 16: 收集到 312 条经验
# 训练 8 回合 17: 收集到 200 条经验
# 训练 8 回合 18: 收集到 248 条经验
# 训练 8 回合 19: 收集到 320 条经验
# 训练 8：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0008/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 5)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# ++++++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# ++++++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 3)
# x++++++
# +++++++
# +++o++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 4)
# x++++++
# ++++x++
# +++o++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 3)
# x++++++
# ++++x++
# +++o++o
# ++++o++
# +++o+++
# +++++x+
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 2)
# x++++++
# ++++x++
# +++o++o
# ++x+o++
# +++o+++
# +++++x+
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 3)
# x++++++
# ++++x++
# +++o++o
# ++xoo++
# +++o+++
# +++++x+
# +++++++
# 第 9 步： 玩家 -1， 动作 (6, 0)
# x++++++
# ++++x++
# +++o++o
# ++xoo++
# +++o+++
# +++++x+
# x++++++
# 第 10 步： 玩家 1， 动作 (2, 5)
# x++++++
# ++++x++
# +++o+oo
# ++xoo++
# +++o+++
# +++++x+
# x++++++
# 第 11 步： 玩家 -1， 动作 (3, 6)
# x++++++
# ++++x++
# +++o+oo
# ++xoo+x
# +++o+++
# +++++x+
# x++++++
# 第 12 步： 玩家 1， 动作 (5, 2)
# x++++++
# ++++x++
# +++o+oo
# ++xoo+x
# +++o+++
# ++o++x+
# x++++++
# 第 13 步： 玩家 -1， 动作 (1, 1)
# x++++++
# +x++x++
# +++o+oo
# ++xoo+x
# +++o+++
# ++o++x+
# x++++++
# 第 14 步： 玩家 1， 动作 (1, 5)
# x++++++
# +x++xo+
# +++o+oo
# ++xoo+x
# +++o+++
# ++o++x+
# x++++++
# 第 15 步： 玩家 -1， 动作 (4, 1)
# x++++++
# +x++xo+
# +++o+oo
# ++xoo+x
# +x+o+++
# ++o++x+
# x++++++
# 第 16 步： 玩家 1， 动作 (6, 2)
# x++++++
# +x++xo+
# +++o+oo
# ++xoo+x
# +x+o+++
# ++o++x+
# x+o++++
# 第 17 步： 玩家 -1， 动作 (6, 4)
# x++++++
# +x++xo+
# +++o+oo
# ++xoo+x
# +x+o+++
# ++o++x+
# x+o+x++
# 第 18 步： 玩家 1， 动作 (2, 4)
# x++++++
# +x++xo+
# +++oooo
# ++xoo+x
# +x+o+++
# ++o++x+
# x+o+x++
# 第 19 步： 玩家 -1， 动作 (5, 0)
# x++++++
# +x++xo+
# +++oooo
# ++xoo+x
# +x+o+++
# x+o++x+
# x+o+x++
# 第 20 步： 玩家 1， 动作 (0, 1)
# xo+++++
# +x++xo+
# +++oooo
# ++xoo+x
# +x+o+++
# x+o++x+
# x+o+x++
# 第 21 步： 玩家 -1， 动作 (5, 3)
# xo+++++
# +x++xo+
# +++oooo
# ++xoo+x
# +x+o+++
# x+ox+x+
# x+o+x++
# 第 22 步： 玩家 1， 动作 (1, 3)
# xo+++++
# +x+oxo+
# +++oooo
# ++xoo+x
# +x+o+++
# x+ox+x+
# x+o+x++
# 第 23 步： 玩家 -1， 动作 (3, 0)
# xo+++++
# +x+oxo+
# +++oooo
# x+xoo+x
# +x+o+++
# x+ox+x+
# x+o+x++
# 第 24 步： 玩家 1， 动作 (0, 5)
# xo+++o+
# +x+oxo+
# +++oooo
# x+xoo+x
# +x+o+++
# x+ox+x+
# x+o+x++
# 第 25 步： 玩家 -1， 动作 (1, 6)
# xo+++o+
# +x+oxox
# +++oooo
# x+xoo+x
# +x+o+++
# x+ox+x+
# x+o+x++
# 第 26 步： 玩家 1， 动作 (6, 5)
# xo+++o+
# +x+oxox
# +++oooo
# x+xoo+x
# +x+o+++
# x+ox+x+
# x+o+xo+
# 第 27 步： 玩家 -1， 动作 (3, 1)
# xo+++o+
# +x+oxox
# +++oooo
# xxxoo+x
# +x+o+++
# x+ox+x+
# x+o+xo+
# 第 28 步： 玩家 1， 动作 (6, 6)
# xo+++o+
# +x+oxox
# +++oooo
# xxxoo+x
# +x+o+++
# x+ox+x+
# x+o+xoo
# 第 29 步： 玩家 -1， 动作 (2, 0)
# xo+++o+
# +x+oxox
# x++oooo
# xxxoo+x
# +x+o+++
# x+ox+x+
# x+o+xoo
# 第 30 步： 玩家 1， 动作 (1, 2)
# xo+++o+
# +xooxox
# x++oooo
# xxxoo+x
# +x+o+++
# x+ox+x+
# x+o+xoo
# 第 31 步： 玩家 -1， 动作 (4, 0)
# xo+++o+
# +xooxox
# x++oooo
# xxxoo+x
# xx+o+++
# x+ox+x+
# x+o+xoo
# 赢家 -1
# 训练 9 回合 0: 收集到 192 条经验
# 训练 9 回合 1: 收集到 136 条经验
# 训练 9 回合 2: 收集到 392 条经验
# 训练 9 回合 3: 收集到 168 条经验
# 训练 9 回合 4: 收集到 256 条经验
# 训练 9 回合 5: 收集到 184 条经验
# 训练 9 回合 6: 收集到 232 条经验
# 训练 9 回合 7: 收集到 216 条经验
# 训练 9 回合 8: 收集到 176 条经验
# 训练 9 回合 9: 收集到 240 条经验
# 训练 9 回合 10: 收集到 248 条经验
# 训练 9 回合 11: 收集到 248 条经验
# 训练 9 回合 12: 收集到 296 条经验
# 训练 9 回合 13: 收集到 200 条经验
# 训练 9 回合 14: 收集到 184 条经验
# 训练 9 回合 15: 收集到 168 条经验
# 训练 9 回合 16: 收集到 208 条经验
# 训练 9 回合 17: 收集到 184 条经验
# 训练 9 回合 18: 收集到 176 条经验
# 训练 9 回合 19: 收集到 208 条经验
# 训练 9：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0009/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# 第 1 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# ++++x++
# +++++++
# +++o+++
# +++++++
# +++++++
# ++++o++
# 第 3 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++++x++
# +++++++
# +++o+++
# +++++++
# x++++++
# ++++o++
# 第 4 步： 玩家 1， 动作 (4, 2)
# +++++++
# ++++x++
# +++++++
# +++o+++
# ++o++++
# x++++++
# ++++o++
# 第 5 步： 玩家 -1， 动作 (2, 3)
# +++++++
# ++++x++
# +++x+++
# +++o+++
# ++o++++
# x++++++
# ++++o++
# 第 6 步： 玩家 1， 动作 (5, 5)
# +++++++
# ++++x++
# +++x+++
# +++o+++
# ++o++++
# x++++o+
# ++++o++
# 第 7 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++xx++
# +++x+++
# +++o+++
# ++o++++
# x++++o+
# ++++o++
# 第 8 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++xx++
# +++xo++
# +++o+++
# ++o++++
# x++++o+
# ++++o++
# 第 9 步： 玩家 -1， 动作 (5, 3)
# +++++++
# +++xx++
# +++xo++
# +++o+++
# ++o++++
# x++x+o+
# ++++o++
# 第 10 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++xx++
# +++xo++
# +++o+++
# ++o++++
# x++x+oo
# ++++o++
# 第 11 步： 玩家 -1， 动作 (2, 0)
# +++++++
# +++xx++
# x++xo++
# +++o+++
# ++o++++
# x++x+oo
# ++++o++
# 第 12 步： 玩家 1， 动作 (0, 0)
# o++++++
# +++xx++
# x++xo++
# +++o+++
# ++o++++
# x++x+oo
# ++++o++
# 第 13 步： 玩家 -1， 动作 (1, 2)
# o++++++
# ++xxx++
# x++xo++
# +++o+++
# ++o++++
# x++x+oo
# ++++o++
# 第 14 步： 玩家 1， 动作 (0, 2)
# o+o++++
# ++xxx++
# x++xo++
# +++o+++
# ++o++++
# x++x+oo
# ++++o++
# 第 15 步： 玩家 -1， 动作 (4, 4)
# o+o++++
# ++xxx++
# x++xo++
# +++o+++
# ++o+x++
# x++x+oo
# ++++o++
# 第 16 步： 玩家 1， 动作 (0, 1)
# ooo++++
# ++xxx++
# x++xo++
# +++o+++
# ++o+x++
# x++x+oo
# ++++o++
# 第 17 步： 玩家 -1， 动作 (1, 1)
# ooo++++
# +xxxx++
# x++xo++
# +++o+++
# ++o+x++
# x++x+oo
# ++++o++
# 第 18 步： 玩家 1， 动作 (6, 1)
# ooo++++
# +xxxx++
# x++xo++
# +++o+++
# ++o+x++
# x++x+oo
# +o++o++
# 第 19 步： 玩家 -1， 动作 (1, 5)
# ooo++++
# +xxxxx+
# x++xo++
# +++o+++
# ++o+x++
# x++x+oo
# +o++o++
# 赢家 -1
# 训练 10 回合 0: 收集到 168 条经验
# 训练 10 回合 1: 收集到 392 条经验
# 训练 10 回合 2: 收集到 312 条经验
# 训练 10 回合 3: 收集到 288 条经验
# 训练 10 回合 4: 收集到 296 条经验
# 训练 10 回合 5: 收集到 288 条经验
# 训练 10 回合 6: 收集到 200 条经验
# 训练 10 回合 7: 收集到 184 条经验
# 训练 10 回合 8: 收集到 320 条经验
# 训练 10 回合 9: 收集到 200 条经验
# 训练 10 回合 10: 收集到 192 条经验
# 训练 10 回合 11: 收集到 232 条经验
# 训练 10 回合 12: 收集到 232 条经验
# 训练 10 回合 13: 收集到 216 条经验
# 训练 10 回合 14: 收集到 296 条经验
# 训练 10 回合 15: 收集到 144 条经验
# 训练 10 回合 16: 收集到 136 条经验
# 训练 10 回合 17: 收集到 88 条经验
# 训练 10 回合 18: 收集到 176 条经验
# 训练 10 回合 19: 收集到 136 条经验
# 训练 10：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0010/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++x++
# +o+++++
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++x++
# oo+++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# ++++x++
# +++++++
# ++++x++
# oo+++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 5)
# +++++++
# +++++++
# ++++xo+
# +++++++
# ++++x++
# oo+++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# ++++xo+
# +++++++
# ++++x++
# oo+++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 3)
# x++++++
# +++++++
# ++++xo+
# +++o+++
# ++++x++
# oo+++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 1)
# x++++++
# +++++++
# ++++xo+
# +++o+++
# +x++x++
# oo+++++
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 5)
# x++++++
# +++++++
# ++++xo+
# +++o+o+
# +x++x++
# oo+++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (5, 5)
# x++++++
# +++++++
# ++++xo+
# +++o+o+
# +x++x++
# oo+++x+
# +++++++
# 第 10 步： 玩家 1， 动作 (5, 3)
# x++++++
# +++++++
# ++++xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +++++++
# 第 11 步： 玩家 -1， 动作 (2, 2)
# x++++++
# +++++++
# ++x+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +++++++
# 第 12 步： 玩家 1， 动作 (1, 0)
# x++++++
# o++++++
# ++x+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +++++++
# 第 13 步： 玩家 -1， 动作 (6, 1)
# x++++++
# o++++++
# ++x+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +x+++++
# 第 14 步： 玩家 1， 动作 (0, 3)
# x++o+++
# o++++++
# ++x+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +x+++++
# 第 15 步： 玩家 -1， 动作 (2, 1)
# x++o+++
# o++++++
# +xx+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +x+++++
# 第 16 步： 玩家 1， 动作 (6, 2)
# x++o+++
# o++++++
# +xx+xo+
# +++o+o+
# +x++x++
# oo+o+x+
# +xo++++
# 第 17 步： 玩家 -1， 动作 (4, 5)
# x++o+++
# o++++++
# +xx+xo+
# +++o+o+
# +x++xx+
# oo+o+x+
# +xo++++
# 第 18 步： 玩家 1， 动作 (1, 6)
# x++o+++
# o+++++o
# +xx+xo+
# +++o+o+
# +x++xx+
# oo+o+x+
# +xo++++
# 第 19 步： 玩家 -1， 动作 (6, 6)
# x++o+++
# o+++++o
# +xx+xo+
# +++o+o+
# +x++xx+
# oo+o+x+
# +xo+++x
# 第 20 步： 玩家 1， 动作 (1, 4)
# x++o+++
# o+++o+o
# +xx+xo+
# +++o+o+
# +x++xx+
# oo+o+x+
# +xo+++x
# 第 21 步： 玩家 -1， 动作 (1, 5)
# x++o+++
# o+++oxo
# +xx+xo+
# +++o+o+
# +x++xx+
# oo+o+x+
# +xo+++x
# 第 22 步： 玩家 1， 动作 (4, 2)
# x++o+++
# o+++oxo
# +xx+xo+
# +++o+o+
# +xo+xx+
# oo+o+x+
# +xo+++x
# 第 23 步： 玩家 -1， 动作 (0, 6)
# x++o++x
# o+++oxo
# +xx+xo+
# +++o+o+
# +xo+xx+
# oo+o+x+
# +xo+++x
# 第 24 步： 玩家 1， 动作 (4, 3)
# x++o++x
# o+++oxo
# +xx+xo+
# +++o+o+
# +xooxx+
# oo+o+x+
# +xo+++x
# 第 25 步： 玩家 -1， 动作 (2, 6)
# x++o++x
# o+++oxo
# +xx+xox
# +++o+o+
# +xooxx+
# oo+o+x+
# +xo+++x
# 第 26 步： 玩家 1， 动作 (6, 5)
# x++o++x
# o+++oxo
# +xx+xox
# +++o+o+
# +xooxx+
# oo+o+x+
# +xo++ox
# 第 27 步： 玩家 -1， 动作 (3, 4)
# x++o++x
# o+++oxo
# +xx+xox
# +++oxo+
# +xooxx+
# oo+o+x+
# +xo++ox
# 第 28 步： 玩家 1， 动作 (3, 6)
# x++o++x
# o+++oxo
# +xx+xox
# +++oxoo
# +xooxx+
# oo+o+x+
# +xo++ox
# 第 29 步： 玩家 -1， 动作 (5, 6)
# x++o++x
# o+++oxo
# +xx+xox
# +++oxoo
# +xooxx+
# oo+o+xx
# +xo++ox
# 第 30 步： 玩家 1， 动作 (3, 2)
# x++o++x
# o+++oxo
# +xx+xox
# ++ooxoo
# +xooxx+
# oo+o+xx
# +xo++ox
# 第 31 步： 玩家 -1， 动作 (5, 4)
# x++o++x
# o+++oxo
# +xx+xox
# ++ooxoo
# +xooxx+
# oo+oxxx
# +xo++ox
# 第 32 步： 玩家 1， 动作 (4, 0)
# x++o++x
# o+++oxo
# +xx+xox
# ++ooxoo
# oxooxx+
# oo+oxxx
# +xo++ox
# 第 33 步： 玩家 -1， 动作 (6, 4)
# x++o++x
# o+++oxo
# +xx+xox
# ++ooxoo
# oxooxx+
# oo+oxxx
# +xo+xox
# 赢家 -1
# 训练 11 回合 0: 收集到 232 条经验
# 训练 11 回合 1: 收集到 208 条经验
# 训练 11 回合 2: 收集到 192 条经验
# 训练 11 回合 3: 收集到 264 条经验
# 训练 11 回合 4: 收集到 152 条经验
# 训练 11 回合 5: 收集到 224 条经验
# 训练 11 回合 6: 收集到 392 条经验
# 训练 11 回合 7: 收集到 192 条经验
# 训练 11 回合 8: 收集到 128 条经验
# 训练 11 回合 9: 收集到 120 条经验
# 训练 11 回合 10: 收集到 256 条经验
# 训练 11 回合 11: 收集到 392 条经验
# 训练 11 回合 12: 收集到 200 条经验
# 训练 11 回合 13: 收集到 320 条经验
# 训练 11 回合 14: 收集到 256 条经验
# 训练 11 回合 15: 收集到 288 条经验
# 训练 11 回合 16: 收集到 264 条经验
# 训练 11 回合 17: 收集到 256 条经验
# 训练 11 回合 18: 收集到 224 条经验
# 训练 11 回合 19: 收集到 192 条经验
# 训练 11：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0011/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 1)
# +++++++
# +++++++
# +o+++++
# +x+++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 6)
# +++++++
# ++++++o
# +o+++++
# +x+++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 3)
# +++++++
# ++++++o
# +o+++++
# +x+x+++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 0)
# o++++++
# ++++++o
# +o+++++
# +x+x+++
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 4)
# o++++++
# ++++x+o
# +o+++++
# +x+x+++
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 4)
# o+++o++
# ++++x+o
# +o+++++
# +x+x+++
# +++++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (0, 2)
# o+x+o++
# ++++x+o
# +o+++++
# +x+x+++
# +++++++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 2)
# o+x+o++
# ++++x+o
# +o+++++
# +x+x+++
# ++o++++
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (5, 3)
# o+x+o++
# ++++x+o
# +o+++++
# +x+x+++
# ++o++++
# +++x+++
# +++++++
# 第 10 步： 玩家 1， 动作 (1, 5)
# o+x+o++
# ++++xoo
# +o+++++
# +x+x+++
# ++o++++
# +++x+++
# +++++++
# 第 11 步： 玩家 -1， 动作 (2, 4)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+++
# ++o++++
# +++x+++
# +++++++
# 第 12 步： 玩家 1， 动作 (4, 3)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+++
# ++oo+++
# +++x+++
# +++++++
# 第 13 步： 玩家 -1， 动作 (5, 5)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+++
# ++oo+++
# +++x+x+
# +++++++
# 第 14 步： 玩家 1， 动作 (4, 6)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+++
# ++oo++o
# +++x+x+
# +++++++
# 第 15 步： 玩家 -1， 动作 (6, 4)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+++
# ++oo++o
# +++x+x+
# ++++x++
# 第 16 步： 玩家 1， 动作 (3, 5)
# o+x+o++
# ++++xoo
# +o++x++
# +x+x+o+
# ++oo++o
# +++x+x+
# ++++x++
# 第 17 步： 玩家 -1， 动作 (2, 6)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+x+o+
# ++oo++o
# +++x+x+
# ++++x++
# 第 18 步： 玩家 1， 动作 (6, 2)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+x+o+
# ++oo++o
# +++x+x+
# ++o+x++
# 第 19 步： 玩家 -1， 动作 (6, 1)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+x+o+
# ++oo++o
# +++x+x+
# +xo+x++
# 第 20 步： 玩家 1， 动作 (5, 2)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+x+o+
# ++oo++o
# ++ox+x+
# +xo+x++
# 第 21 步： 玩家 -1， 动作 (4, 1)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+x+o+
# +xoo++o
# ++ox+x+
# +xo+x++
# 第 22 步： 玩家 1， 动作 (3, 4)
# o+x+o++
# ++++xoo
# +o++x+x
# +x+xoo+
# +xoo++o
# ++ox+x+
# +xo+x++
# 第 23 步： 玩家 -1， 动作 (2, 5)
# o+x+o++
# ++++xoo
# +o++xxx
# +x+xoo+
# +xoo++o
# ++ox+x+
# +xo+x++
# 第 24 步： 玩家 1， 动作 (3, 6)
# o+x+o++
# ++++xoo
# +o++xxx
# +x+xooo
# +xoo++o
# ++ox+x+
# +xo+x++
# 第 25 步： 玩家 -1， 动作 (2, 2)
# o+x+o++
# ++++xoo
# +ox+xxx
# +x+xooo
# +xoo++o
# ++ox+x+
# +xo+x++
# 第 26 步： 玩家 1， 动作 (4, 4)
# o+x+o++
# ++++xoo
# +ox+xxx
# +x+xooo
# +xooo+o
# ++ox+x+
# +xo+x++
# 第 27 步： 玩家 -1， 动作 (1, 1)
# o+x+o++
# +x++xoo
# +ox+xxx
# +x+xooo
# +xooo+o
# ++ox+x+
# +xo+x++
# 第 28 步： 玩家 1， 动作 (0, 6)
# o+x+o+o
# +x++xoo
# +ox+xxx
# +x+xooo
# +xooo+o
# ++ox+x+
# +xo+x++
# 第 29 步： 玩家 -1， 动作 (2, 3)
# o+x+o+o
# +x++xoo
# +oxxxxx
# +x+xooo
# +xooo+o
# ++ox+x+
# +xo+x++
# 赢家 -1
# 训练 12 回合 0: 收集到 240 条经验
# 训练 12 回合 1: 收集到 224 条经验
# 训练 12 回合 2: 收集到 192 条经验
# 训练 12 回合 3: 收集到 288 条经验
# 训练 12 回合 4: 收集到 144 条经验
# 训练 12 回合 5: 收集到 112 条经验
# 训练 12 回合 6: 收集到 184 条经验
# 训练 12 回合 7: 收集到 144 条经验
# 训练 12 回合 8: 收集到 120 条经验
# 训练 12 回合 9: 收集到 312 条经验
# 训练 12 回合 10: 收集到 208 条经验
# 训练 12 回合 11: 收集到 104 条经验
# 训练 12 回合 12: 收集到 208 条经验
# 训练 12 回合 13: 收集到 208 条经验
# 训练 12 回合 14: 收集到 248 条经验
# 训练 12 回合 15: 收集到 216 条经验
# 训练 12 回合 16: 收集到 296 条经验
# 训练 12 回合 17: 收集到 208 条经验
# 训练 12 回合 18: 收集到 232 条经验
# 训练 12 回合 19: 收集到 296 条经验
# 训练 12：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0012/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 0)
# +++++++
# +++++++
# x++++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++o++++
# x++++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 1)
# +++++++
# ++o++++
# xx+++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (1, 4)
# +++++++
# ++o+o++
# xx+++++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 3)
# +++++++
# ++o+o++
# xx+x+++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 0)
# o++++++
# ++o+o++
# xx+x+++
# +++++++
# +++++++
# o++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 1)
# o++++++
# ++o+o++
# xx+x+++
# +++++++
# +x+++++
# o++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (6, 2)
# o++++++
# ++o+o++
# xx+x+++
# +++++++
# +x+++++
# o++++++
# ++o++++
# 第 9 步： 玩家 -1， 动作 (3, 4)
# o++++++
# ++o+o++
# xx+x+++
# ++++x++
# +x+++++
# o++++++
# ++o++++
# 第 10 步： 玩家 1， 动作 (4, 4)
# o++++++
# ++o+o++
# xx+x+++
# ++++x++
# +x++o++
# o++++++
# ++o++++
# 第 11 步： 玩家 -1， 动作 (3, 6)
# o++++++
# ++o+o++
# xx+x+++
# ++++x+x
# +x++o++
# o++++++
# ++o++++
# 第 12 步： 玩家 1， 动作 (1, 1)
# o++++++
# +oo+o++
# xx+x+++
# ++++x+x
# +x++o++
# o++++++
# ++o++++
# 第 13 步： 玩家 -1， 动作 (4, 5)
# o++++++
# +oo+o++
# xx+x+++
# ++++x+x
# +x++ox+
# o++++++
# ++o++++
# 第 14 步： 玩家 1， 动作 (4, 3)
# o++++++
# +oo+o++
# xx+x+++
# ++++x+x
# +x+oox+
# o++++++
# ++o++++
# 第 15 步： 玩家 -1， 动作 (2, 5)
# o++++++
# +oo+o++
# xx+x+x+
# ++++x+x
# +x+oox+
# o++++++
# ++o++++
# 第 16 步： 玩家 1， 动作 (5, 4)
# o++++++
# +oo+o++
# xx+x+x+
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 第 17 步： 玩家 -1， 动作 (2, 2)
# o++++++
# +oo+o++
# xxxx+x+
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 第 18 步： 玩家 1， 动作 (0, 4)
# o+++o++
# +oo+o++
# xxxx+x+
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 第 19 步： 玩家 -1， 动作 (0, 3)
# o++xo++
# +oo+o++
# xxxx+x+
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 第 20 步： 玩家 1， 动作 (2, 6)
# o++xo++
# +oo+o++
# xxxx+xo
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 第 21 步： 玩家 -1， 动作 (2, 4)
# o++xo++
# +oo+o++
# xxxxxxo
# ++++x+x
# +x+oox+
# o+++o++
# ++o++++
# 赢家 -1
# 训练 13 回合 0: 收集到 256 条经验
# 训练 13 回合 1: 收集到 144 条经验
# 训练 13 回合 2: 收集到 344 条经验
# 训练 13 回合 3: 收集到 160 条经验
# 训练 13 回合 4: 收集到 232 条经验
# 训练 13 回合 5: 收集到 208 条经验
# 训练 13 回合 6: 收集到 168 条经验
# 训练 13 回合 7: 收集到 360 条经验
# 训练 13 回合 8: 收集到 184 条经验
# 训练 13 回合 9: 收集到 208 条经验
# 训练 13 回合 10: 收集到 264 条经验
# 训练 13 回合 11: 收集到 280 条经验
# 训练 13 回合 12: 收集到 168 条经验
# 训练 13 回合 13: 收集到 288 条经验
# 训练 13 回合 14: 收集到 208 条经验
# 训练 13 回合 15: 收集到 232 条经验
# 训练 13 回合 16: 收集到 176 条经验
# 训练 13 回合 17: 收集到 280 条经验
# 训练 13 回合 18: 收集到 176 条经验
# 训练 13 回合 19: 收集到 224 条经验
# 训练 13：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0013/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 2)
# ++x++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 3)
# ++x++o+
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 2)
# ++x++o+
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 3)
# ++xo+o+
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 5)
# ++xo+o+
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++x+
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 1)
# +oxo+o+
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++x+
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 5)
# +oxo+o+
# +++++++
# +++++++
# +++++x+
# ++xo+++
# +++++x+
# +++++++
# 第 8 步： 玩家 1， 动作 (0, 6)
# +oxo+oo
# +++++++
# +++++++
# +++++x+
# ++xo+++
# +++++x+
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 5)
# +oxo+oo
# +++++x+
# +++++++
# +++++x+
# ++xo+++
# +++++x+
# +++++++
# 第 10 步： 玩家 1， 动作 (2, 5)
# +oxo+oo
# +++++x+
# +++++o+
# +++++x+
# ++xo+++
# +++++x+
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 1)
# +oxo+oo
# +++++x+
# +++++o+
# +x+++x+
# ++xo+++
# +++++x+
# +++++++
# 第 12 步： 玩家 1， 动作 (4, 1)
# +oxo+oo
# +++++x+
# +++++o+
# +x+++x+
# +oxo+++
# +++++x+
# +++++++
# 第 13 步： 玩家 -1， 动作 (0, 0)
# xoxo+oo
# +++++x+
# +++++o+
# +x+++x+
# +oxo+++
# +++++x+
# +++++++
# 第 14 步： 玩家 1， 动作 (1, 4)
# xoxo+oo
# ++++ox+
# +++++o+
# +x+++x+
# +oxo+++
# +++++x+
# +++++++
# 第 15 步： 玩家 -1， 动作 (6, 2)
# xoxo+oo
# ++++ox+
# +++++o+
# +x+++x+
# +oxo+++
# +++++x+
# ++x++++
# 第 16 步： 玩家 1， 动作 (1, 6)
# xoxo+oo
# ++++oxo
# +++++o+
# +x+++x+
# +oxo+++
# +++++x+
# ++x++++
# 第 17 步： 玩家 -1， 动作 (3, 0)
# xoxo+oo
# ++++oxo
# +++++o+
# xx+++x+
# +oxo+++
# +++++x+
# ++x++++
# 第 18 步： 玩家 1， 动作 (5, 6)
# xoxo+oo
# ++++oxo
# +++++o+
# xx+++x+
# +oxo+++
# +++++xo
# ++x++++
# 第 19 步： 玩家 -1， 动作 (4, 5)
# xoxo+oo
# ++++oxo
# +++++o+
# xx+++x+
# +oxo+x+
# +++++xo
# ++x++++
# 第 20 步： 玩家 1， 动作 (2, 1)
# xoxo+oo
# ++++oxo
# +o+++o+
# xx+++x+
# +oxo+x+
# +++++xo
# ++x++++
# 第 21 步： 玩家 -1， 动作 (4, 6)
# xoxo+oo
# ++++oxo
# +o+++o+
# xx+++x+
# +oxo+xx
# +++++xo
# ++x++++
# 第 22 步： 玩家 1， 动作 (2, 0)
# xoxo+oo
# ++++oxo
# oo+++o+
# xx+++x+
# +oxo+xx
# +++++xo
# ++x++++
# 第 23 步： 玩家 -1， 动作 (4, 4)
# xoxo+oo
# ++++oxo
# oo+++o+
# xx+++x+
# +oxoxxx
# +++++xo
# ++x++++
# 第 24 步： 玩家 1， 动作 (5, 3)
# xoxo+oo
# ++++oxo
# oo+++o+
# xx+++x+
# +oxoxxx
# +++o+xo
# ++x++++
# 第 25 步： 玩家 -1， 动作 (3, 4)
# xoxo+oo
# ++++oxo
# oo+++o+
# xx++xx+
# +oxoxxx
# +++o+xo
# ++x++++
# 第 26 步： 玩家 1， 动作 (2, 3)
# xoxo+oo
# ++++oxo
# oo+o+o+
# xx++xx+
# +oxoxxx
# +++o+xo
# ++x++++
# 第 27 步： 玩家 -1， 动作 (1, 2)
# xoxo+oo
# ++x+oxo
# oo+o+o+
# xx++xx+
# +oxoxxx
# +++o+xo
# ++x++++
# 第 28 步： 玩家 1， 动作 (3, 2)
# xoxo+oo
# ++x+oxo
# oo+o+o+
# xxo+xx+
# +oxoxxx
# +++o+xo
# ++x++++
# 赢家 1
# 训练 14 回合 0: 收集到 248 条经验
# 训练 14 回合 1: 收集到 296 条经验
# 训练 14 回合 2: 收集到 184 条经验
# 训练 14 回合 3: 收集到 144 条经验
# 训练 14 回合 4: 收集到 312 条经验
# 训练 14 回合 5: 收集到 240 条经验
# 训练 14 回合 6: 收集到 144 条经验
# 训练 14 回合 7: 收集到 216 条经验
# 训练 14 回合 8: 收集到 328 条经验
# 训练 14 回合 9: 收集到 208 条经验
# 训练 14 回合 10: 收集到 216 条经验
# 训练 14 回合 11: 收集到 256 条经验
# 训练 14 回合 12: 收集到 192 条经验
# 训练 14 回合 13: 收集到 184 条经验
# 训练 14 回合 14: 收集到 168 条经验
# 训练 14 回合 15: 收集到 168 条经验
# 训练 14 回合 16: 收集到 136 条经验
# 训练 14 回合 17: 收集到 184 条经验
# 训练 14 回合 18: 收集到 136 条经验
# 训练 14 回合 19: 收集到 184 条经验
# 训练 14：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0014/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +o+++++
# +x+++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 1)
# +o+++++
# +++++++
# +++++++
# +o+++++
# +x+++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 5)
# +o+++++
# +++++x+
# +++++++
# +o+++++
# +x+++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (5, 4)
# +o+++++
# +++++x+
# +++++++
# +o+++++
# +x+++++
# ++++o++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 1)
# +o+++++
# +++++x+
# +++++++
# +o+++++
# +x+++++
# +x++o++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 5)
# +o+++++
# +++++x+
# +++++++
# +o+++o+
# +x+++++
# +x++o++
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 3)
# +o+++++
# +++++x+
# +++++++
# +o+x+o+
# +x+++++
# +x++o++
# +++++++
# 第 8 步： 玩家 1， 动作 (0, 4)
# +o++o++
# +++++x+
# +++++++
# +o+x+o+
# +x+++++
# +x++o++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 2)
# +o++o++
# +++++x+
# +++++++
# +oxx+o+
# +x+++++
# +x++o++
# +++++++
# 第 10 步： 玩家 1， 动作 (4, 6)
# +o++o++
# +++++x+
# +++++++
# +oxx+o+
# +x++++o
# +x++o++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 6)
# +o++o++
# +++++x+
# +++++++
# +oxx+o+
# +x++++o
# +x++o++
# ++++++x
# 第 12 步： 玩家 1， 动作 (1, 0)
# +o++o++
# o++++x+
# +++++++
# +oxx+o+
# +x++++o
# +x++o++
# ++++++x
# 第 13 步： 玩家 -1， 动作 (3, 4)
# +o++o++
# o++++x+
# +++++++
# +oxxxo+
# +x++++o
# +x++o++
# ++++++x
# 第 14 步： 玩家 1， 动作 (4, 0)
# +o++o++
# o++++x+
# +++++++
# +oxxxo+
# ox++++o
# +x++o++
# ++++++x
# 第 15 步： 玩家 -1， 动作 (2, 1)
# +o++o++
# o++++x+
# +x+++++
# +oxxxo+
# ox++++o
# +x++o++
# ++++++x
# 第 16 步： 玩家 1， 动作 (3, 0)
# +o++o++
# o++++x+
# +x+++++
# ooxxxo+
# ox++++o
# +x++o++
# ++++++x
# 第 17 步： 玩家 -1， 动作 (1, 1)
# +o++o++
# ox+++x+
# +x+++++
# ooxxxo+
# ox++++o
# +x++o++
# ++++++x
# 第 18 步： 玩家 1， 动作 (2, 0)
# +o++o++
# ox+++x+
# ox+++++
# ooxxxo+
# ox++++o
# +x++o++
# ++++++x
# 第 19 步： 玩家 -1， 动作 (5, 2)
# +o++o++
# ox+++x+
# ox+++++
# ooxxxo+
# ox++++o
# +xx+o++
# ++++++x
# 第 20 步： 玩家 1， 动作 (0, 0)
# oo++o++
# ox+++x+
# ox+++++
# ooxxxo+
# ox++++o
# +xx+o++
# ++++++x
# 赢家 1
# 训练 15 回合 0: 收集到 232 条经验
# 训练 15 回合 1: 收集到 216 条经验
# 训练 15 回合 2: 收集到 200 条经验
# 训练 15 回合 3: 收集到 200 条经验
# 训练 15 回合 4: 收集到 208 条经验
# 训练 15 回合 5: 收集到 192 条经验
# 训练 15 回合 6: 收集到 280 条经验
# 训练 15 回合 7: 收集到 120 条经验
# 训练 15 回合 8: 收集到 192 条经验
# 训练 15 回合 9: 收集到 240 条经验
# 训练 15 回合 10: 收集到 256 条经验
# 训练 15 回合 11: 收集到 224 条经验
# 训练 15 回合 12: 收集到 248 条经验
# 训练 15 回合 13: 收集到 168 条经验
# 训练 15 回合 14: 收集到 288 条经验
# 训练 15 回合 15: 收集到 176 条经验
# 训练 15 回合 16: 收集到 232 条经验
# 训练 15 回合 17: 收集到 216 条经验
# 训练 15 回合 18: 收集到 256 条经验
# 训练 15 回合 19: 收集到 392 条经验
# 训练 15：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0015/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 2)
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 6)
# ++o++++
# +++++++
# ++++++x
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 2)
# ++o++++
# +++++++
# ++++++x
# +++++++
# +++++++
# ++o++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 0)
# ++o++++
# +++++++
# ++++++x
# x++++++
# +++++++
# ++o++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 4)
# ++o+o++
# +++++++
# ++++++x
# x++++++
# +++++++
# ++o++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 3)
# ++o+o++
# +++++++
# ++++++x
# x++x+++
# +++++++
# ++o++++
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 3)
# ++o+o++
# +++++++
# ++++++x
# x++x+++
# +++++++
# ++o++++
# +++o+++
# 第 7 步： 玩家 -1， 动作 (3, 1)
# ++o+o++
# +++++++
# ++++++x
# xx+x+++
# +++++++
# ++o++++
# +++o+++
# 第 8 步： 玩家 1， 动作 (4, 1)
# ++o+o++
# +++++++
# ++++++x
# xx+x+++
# +o+++++
# ++o++++
# +++o+++
# 第 9 步： 玩家 -1， 动作 (5, 6)
# ++o+o++
# +++++++
# ++++++x
# xx+x+++
# +o+++++
# ++o+++x
# +++o+++
# 第 10 步： 玩家 1， 动作 (5, 0)
# ++o+o++
# +++++++
# ++++++x
# xx+x+++
# +o+++++
# o+o+++x
# +++o+++
# 第 11 步： 玩家 -1， 动作 (4, 0)
# ++o+o++
# +++++++
# ++++++x
# xx+x+++
# xo+++++
# o+o+++x
# +++o+++
# 第 12 步： 玩家 1， 动作 (3, 2)
# ++o+o++
# +++++++
# ++++++x
# xxox+++
# xo+++++
# o+o+++x
# +++o+++
# 第 13 步： 玩家 -1， 动作 (2, 3)
# ++o+o++
# +++++++
# +++x++x
# xxox+++
# xo+++++
# o+o+++x
# +++o+++
# 第 14 步： 玩家 1， 动作 (2, 2)
# ++o+o++
# +++++++
# ++ox++x
# xxox+++
# xo+++++
# o+o+++x
# +++o+++
# 第 15 步： 玩家 -1， 动作 (3, 4)
# ++o+o++
# +++++++
# ++ox++x
# xxoxx++
# xo+++++
# o+o+++x
# +++o+++
# 第 16 步： 玩家 1， 动作 (4, 2)
# ++o+o++
# +++++++
# ++ox++x
# xxoxx++
# xoo++++
# o+o+++x
# +++o+++
# 第 17 步： 玩家 -1， 动作 (5, 4)
# ++o+o++
# +++++++
# ++ox++x
# xxoxx++
# xoo++++
# o+o+x+x
# +++o+++
# 第 18 步： 玩家 1， 动作 (1, 2)
# ++o+o++
# ++o++++
# ++ox++x
# xxoxx++
# xoo++++
# o+o+x+x
# +++o+++
# 赢家 1
# 训练 16 回合 0: 收集到 320 条经验
# 训练 16 回合 1: 收集到 280 条经验
# 训练 16 回合 2: 收集到 288 条经验
# 训练 16 回合 3: 收集到 256 条经验
# 训练 16 回合 4: 收集到 192 条经验
# 训练 16 回合 5: 收集到 128 条经验
# 训练 16 回合 6: 收集到 256 条经验
# 训练 16 回合 7: 收集到 136 条经验
# 训练 16 回合 8: 收集到 360 条经验
# 训练 16 回合 9: 收集到 240 条经验
# 训练 16 回合 10: 收集到 272 条经验
# 训练 16 回合 11: 收集到 224 条经验
# 训练 16 回合 12: 收集到 208 条经验
# 训练 16 回合 13: 收集到 192 条经验
# 训练 16 回合 14: 收集到 184 条经验
# 训练 16 回合 15: 收集到 328 条经验
# 训练 16 回合 16: 收集到 104 条经验
# 训练 16 回合 17: 收集到 272 条经验
# 训练 16 回合 18: 收集到 152 条经验
# 训练 16 回合 19: 收集到 128 条经验
# 训练 16：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0016/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 4)
# +++++++
# +++++++
# +++++++
# +++o+++
# ++++x++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++++++
# +++++++
# +++o+++
# ++++xo+
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 0)
# +++++++
# +++++++
# +++++++
# x++o+++
# ++++xo+
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++++++
# x++o+++
# ++++xo+
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 6)
# +++o+++
# +++++++
# +++++++
# x++o+++
# ++++xox
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 1)
# +o+o+++
# +++++++
# +++++++
# x++o+++
# ++++xox
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (5, 5)
# +o+o+++
# +++++++
# +++++++
# x++o+++
# ++++xox
# +++++x+
# +++++++
# 第 8 步： 玩家 1， 动作 (1, 2)
# +o+o+++
# ++o++++
# +++++++
# x++o+++
# ++++xox
# +++++x+
# +++++++
# 第 9 步： 玩家 -1， 动作 (2, 2)
# +o+o+++
# ++o++++
# ++x++++
# x++o+++
# ++++xox
# +++++x+
# +++++++
# 第 10 步： 玩家 1， 动作 (3, 4)
# +o+o+++
# ++o++++
# ++x++++
# x++oo++
# ++++xox
# +++++x+
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 1)
# +o+o+++
# ++o++++
# ++x++++
# x++oo++
# ++++xox
# +++++x+
# +x+++++
# 第 12 步： 玩家 1， 动作 (2, 3)
# +o+o+++
# ++o++++
# ++xo+++
# x++oo++
# ++++xox
# +++++x+
# +x+++++
# 赢家 1
# 训练 17 回合 0: 收集到 168 条经验
# 训练 17 回合 1: 收集到 256 条经验
# 训练 17 回合 2: 收集到 168 条经验
# 训练 17 回合 3: 收集到 256 条经验
# 训练 17 回合 4: 收集到 88 条经验
# 训练 17 回合 5: 收集到 240 条经验
# 训练 17 回合 6: 收集到 200 条经验
# 训练 17 回合 7: 收集到 224 条经验
# 训练 17 回合 8: 收集到 200 条经验
# 训练 17 回合 9: 收集到 192 条经验
# 训练 17 回合 10: 收集到 216 条经验
# 训练 17 回合 11: 收集到 224 条经验
# 训练 17 回合 12: 收集到 248 条经验
# 训练 17 回合 13: 收集到 176 条经验
# 训练 17 回合 14: 收集到 200 条经验
# 训练 17 回合 15: 收集到 168 条经验
# 训练 17 回合 16: 收集到 152 条经验
# 训练 17 回合 17: 收集到 192 条经验
# 训练 17 回合 18: 收集到 248 条经验
# 训练 17 回合 19: 收集到 392 条经验
# 训练 17：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0017/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 2)
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 1)
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +x+++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 0)
# +++++++
# o++++++
# +++++++
# ++o++++
# +++++++
# +x+++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 2)
# +++++++
# o++++++
# ++x++++
# ++o++++
# +++++++
# +x+++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 3)
# +++++++
# o++++++
# ++x++++
# ++oo+++
# +++++++
# +x+++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 6)
# +++++++
# o+++++x
# ++x++++
# ++oo+++
# +++++++
# +x+++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 0)
# +++++++
# o+++++x
# ++x++++
# o+oo+++
# +++++++
# +x+++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (6, 5)
# +++++++
# o+++++x
# ++x++++
# o+oo+++
# +++++++
# +x+++++
# +++++x+
# 第 8 步： 玩家 1， 动作 (1, 3)
# +++++++
# o++o++x
# ++x++++
# o+oo+++
# +++++++
# +x+++++
# +++++x+
# 第 9 步： 玩家 -1， 动作 (2, 6)
# +++++++
# o++o++x
# ++x+++x
# o+oo+++
# +++++++
# +x+++++
# +++++x+
# 第 10 步： 玩家 1， 动作 (5, 2)
# +++++++
# o++o++x
# ++x+++x
# o+oo+++
# +++++++
# +xo++++
# +++++x+
# 第 11 步： 玩家 -1， 动作 (2, 3)
# +++++++
# o++o++x
# ++xx++x
# o+oo+++
# +++++++
# +xo++++
# +++++x+
# 第 12 步： 玩家 1， 动作 (3, 4)
# +++++++
# o++o++x
# ++xx++x
# o+ooo++
# +++++++
# +xo++++
# +++++x+
# 第 13 步： 玩家 -1， 动作 (4, 4)
# +++++++
# o++o++x
# ++xx++x
# o+ooo++
# ++++x++
# +xo++++
# +++++x+
# 第 14 步： 玩家 1， 动作 (3, 1)
# +++++++
# o++o++x
# ++xx++x
# ooooo++
# ++++x++
# +xo++++
# +++++x+
# 赢家 1
# 训练 18 回合 0: 收集到 248 条经验
# 训练 18 回合 1: 收集到 240 条经验
# 训练 18 回合 2: 收集到 184 条经验
# 训练 18 回合 3: 收集到 176 条经验
# 训练 18 回合 4: 收集到 264 条经验
# 训练 18 回合 5: 收集到 392 条经验
# 训练 18 回合 6: 收集到 120 条经验
# 训练 18 回合 7: 收集到 328 条经验
# 训练 18 回合 8: 收集到 256 条经验
# 训练 18 回合 9: 收集到 72 条经验
# 训练 18 回合 10: 收集到 280 条经验
# 训练 18 回合 11: 收集到 152 条经验
# 训练 18 回合 12: 收集到 240 条经验
# 训练 18 回合 13: 收集到 216 条经验
# 训练 18 回合 14: 收集到 152 条经验
# 训练 18 回合 15: 收集到 176 条经验
# 训练 18 回合 16: 收集到 232 条经验
# 训练 18 回合 17: 收集到 168 条经验
# 训练 18 回合 18: 收集到 232 条经验
# 训练 18 回合 19: 收集到 136 条经验
# 训练 18：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0018/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 5)
# +++o+++
# +++++x+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 5)
# +++o+++
# +++++x+
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++o+++
# +++++x+
# ++++x++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (1, 3)
# +++o+++
# +++o+x+
# ++++x++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 5)
# +++o+++
# +++o+x+
# ++++x++
# +++++o+
# +++++x+
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 5)
# +++o+o+
# +++o+x+
# ++++x++
# +++++o+
# +++++x+
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# +++o+o+
# +++o+x+
# ++++xx+
# +++++o+
# +++++x+
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (6, 3)
# +++o+o+
# +++o+x+
# ++++xx+
# +++++o+
# +++++x+
# +++++++
# +++o+++
# 第 9 步： 玩家 -1， 动作 (2, 6)
# +++o+o+
# +++o+x+
# ++++xxx
# +++++o+
# +++++x+
# +++++++
# +++o+++
# 第 10 步： 玩家 1， 动作 (5, 2)
# +++o+o+
# +++o+x+
# ++++xxx
# +++++o+
# +++++x+
# ++o++++
# +++o+++
# 第 11 步： 玩家 -1， 动作 (3, 3)
# +++o+o+
# +++o+x+
# ++++xxx
# +++x+o+
# +++++x+
# ++o++++
# +++o+++
# 第 12 步： 玩家 1， 动作 (1, 6)
# +++o+o+
# +++o+xo
# ++++xxx
# +++x+o+
# +++++x+
# ++o++++
# +++o+++
# 第 13 步： 玩家 -1， 动作 (3, 2)
# +++o+o+
# +++o+xo
# ++++xxx
# ++xx+o+
# +++++x+
# ++o++++
# +++o+++
# 第 14 步： 玩家 1， 动作 (5, 1)
# +++o+o+
# +++o+xo
# ++++xxx
# ++xx+o+
# +++++x+
# +oo++++
# +++o+++
# 第 15 步： 玩家 -1， 动作 (4, 2)
# +++o+o+
# +++o+xo
# ++++xxx
# ++xx+o+
# ++x++x+
# +oo++++
# +++o+++
# 第 16 步： 玩家 1， 动作 (1, 0)
# +++o+o+
# o++o+xo
# ++++xxx
# ++xx+o+
# ++x++x+
# +oo++++
# +++o+++
# 第 17 步： 玩家 -1， 动作 (0, 6)
# +++o+ox
# o++o+xo
# ++++xxx
# ++xx+o+
# ++x++x+
# +oo++++
# +++o+++
# 赢家 -1
# 训练 19 回合 0: 收集到 296 条经验
# 训练 19 回合 1: 收集到 232 条经验
# 训练 19 回合 2: 收集到 144 条经验
# 训练 19 回合 3: 收集到 184 条经验
# 训练 19 回合 4: 收集到 136 条经验
# 训练 19 回合 5: 收集到 200 条经验
# 训练 19 回合 6: 收集到 184 条经验
# 训练 19 回合 7: 收集到 168 条经验
# 训练 19 回合 8: 收集到 168 条经验
# 训练 19 回合 9: 收集到 192 条经验
# 训练 19 回合 10: 收集到 232 条经验
# 训练 19 回合 11: 收集到 216 条经验
# 训练 19 回合 12: 收集到 264 条经验
# 训练 19 回合 13: 收集到 216 条经验
# 训练 19 回合 14: 收集到 224 条经验
# 训练 19 回合 15: 收集到 280 条经验
# 训练 19 回合 16: 收集到 296 条经验
# 训练 19 回合 17: 收集到 168 条经验
# 训练 19 回合 18: 收集到 168 条经验
# 训练 19 回合 19: 收集到 128 条经验
# 训练 19：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0019/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 0)
# +++++++
# x++++++
# o++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 2)
# +++++++
# x++++++
# o+x++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 1)
# +o+++++
# x++++++
# o+x++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 4)
# +o+++++
# x++++++
# o+x++++
# +++ox++
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 0)
# oo+++++
# x++++++
# o+x++++
# +++ox++
# +++++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# oo+++++
# x++++++
# o+x++x+
# +++ox++
# +++++++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (2, 4)
# oo+++++
# x++++++
# o+x+ox+
# +++ox++
# +++++++
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (0, 5)
# oo+++x+
# x++++++
# o+x+ox+
# +++ox++
# +++++++
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (4, 4)
# oo+++x+
# x++++++
# o+x+ox+
# +++ox++
# ++++o++
# +++++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (5, 3)
# oo+++x+
# x++++++
# o+x+ox+
# +++ox++
# ++++o++
# +++x+++
# +++++++
# 第 12 步： 玩家 1， 动作 (2, 3)
# oo+++x+
# x++++++
# o+xoox+
# +++ox++
# ++++o++
# +++x+++
# +++++++
# 第 13 步： 玩家 -1， 动作 (4, 0)
# oo+++x+
# x++++++
# o+xoox+
# +++ox++
# x+++o++
# +++x+++
# +++++++
# 第 14 步： 玩家 1， 动作 (6, 2)
# oo+++x+
# x++++++
# o+xoox+
# +++ox++
# x+++o++
# +++x+++
# ++o++++
# 第 15 步： 玩家 -1， 动作 (0, 4)
# oo++xx+
# x++++++
# o+xoox+
# +++ox++
# x+++o++
# +++x+++
# ++o++++
# 第 16 步： 玩家 1， 动作 (6, 5)
# oo++xx+
# x++++++
# o+xoox+
# +++ox++
# x+++o++
# +++x+++
# ++o++o+
# 第 17 步： 玩家 -1， 动作 (0, 2)
# oox+xx+
# x++++++
# o+xoox+
# +++ox++
# x+++o++
# +++x+++
# ++o++o+
# 第 18 步： 玩家 1， 动作 (3, 6)
# oox+xx+
# x++++++
# o+xoox+
# +++ox+o
# x+++o++
# +++x+++
# ++o++o+
# 第 19 步： 玩家 -1， 动作 (5, 5)
# oox+xx+
# x++++++
# o+xoox+
# +++ox+o
# x+++o++
# +++x+x+
# ++o++o+
# 第 20 步： 玩家 1， 动作 (6, 3)
# oox+xx+
# x++++++
# o+xoox+
# +++ox+o
# x+++o++
# +++x+x+
# ++oo+o+
# 第 21 步： 玩家 -1， 动作 (0, 6)
# oox+xxx
# x++++++
# o+xoox+
# +++ox+o
# x+++o++
# +++x+x+
# ++oo+o+
# 第 22 步： 玩家 1， 动作 (2, 1)
# oox+xxx
# x++++++
# ooxoox+
# +++ox+o
# x+++o++
# +++x+x+
# ++oo+o+
# 第 23 步： 玩家 -1， 动作 (0, 3)
# ooxxxxx
# x++++++
# ooxoox+
# +++ox+o
# x+++o++
# +++x+x+
# ++oo+o+
# 赢家 -1

# %% [markdown]
# ## 评估

# %%
self_play_eval(env, agent)
# Out:
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 5)
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# +++++x+
# 第 2 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++++++
# +++++++
# +o++o++
# +++++++
# +++++++
# +++++x+
# 第 3 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x++
# +++++++
# +o++o++
# +++++++
# +++++++
# +++++x+
# 第 4 步： 玩家 1， 动作 (3, 6)
# +++++++
# ++++x++
# +++++++
# +o++o+o
# +++++++
# +++++++
# +++++x+
# 第 5 步： 玩家 -1， 动作 (0, 5)
# +++++x+
# ++++x++
# +++++++
# +o++o+o
# +++++++
# +++++++
# +++++x+
# 第 6 步： 玩家 1， 动作 (5, 3)
# +++++x+
# ++++x++
# +++++++
# +o++o+o
# +++++++
# +++o+++
# +++++x+
# 第 7 步： 玩家 -1， 动作 (2, 3)
# +++++x+
# ++++x++
# +++x+++
# +o++o+o
# +++++++
# +++o+++
# +++++x+
# 第 8 步： 玩家 1， 动作 (6, 1)
# +++++x+
# ++++x++
# +++x+++
# +o++o+o
# +++++++
# +++o+++
# +o+++x+
# 第 9 步： 玩家 -1， 动作 (2, 2)
# +++++x+
# ++++x++
# ++xx+++
# +o++o+o
# +++++++
# +++o+++
# +o+++x+
# 第 10 步： 玩家 1， 动作 (0, 4)
# ++++ox+
# ++++x++
# ++xx+++
# +o++o+o
# +++++++
# +++o+++
# +o+++x+
# 第 11 步： 玩家 -1， 动作 (2, 5)
# ++++ox+
# ++++x++
# ++xx+x+
# +o++o+o
# +++++++
# +++o+++
# +o+++x+
# 第 12 步： 玩家 1， 动作 (5, 6)
# ++++ox+
# ++++x++
# ++xx+x+
# +o++o+o
# +++++++
# +++o++o
# +o+++x+
# 第 13 步： 玩家 -1， 动作 (2, 0)
# ++++ox+
# ++++x++
# x+xx+x+
# +o++o+o
# +++++++
# +++o++o
# +o+++x+
# 第 14 步： 玩家 1， 动作 (4, 1)
# ++++ox+
# ++++x++
# x+xx+x+
# +o++o+o
# +o+++++
# +++o++o
# +o+++x+
# 第 15 步： 玩家 -1， 动作 (1, 2)
# ++++ox+
# ++x+x++
# x+xx+x+
# +o++o+o
# +o+++++
# +++o++o
# +o+++x+
# 第 16 步： 玩家 1， 动作 (0, 6)
# ++++oxo
# ++x+x++
# x+xx+x+
# +o++o+o
# +o+++++
# +++o++o
# +o+++x+
# 第 17 步： 玩家 -1， 动作 (2, 6)
# ++++oxo
# ++x+x++
# x+xx+xx
# +o++o+o
# +o+++++
# +++o++o
# +o+++x+
# 第 18 步： 玩家 1， 动作 (5, 2)
# ++++oxo
# ++x+x++
# x+xx+xx
# +o++o+o
# +o+++++
# ++oo++o
# +o+++x+
# 第 19 步： 玩家 -1， 动作 (1, 1)
# ++++oxo
# +xx+x++
# x+xx+xx
# +o++o+o
# +o+++++
# ++oo++o
# +o+++x+
# 第 20 步： 玩家 1， 动作 (1, 6)
# ++++oxo
# +xx+x+o
# x+xx+xx
# +o++o+o
# +o+++++
# ++oo++o
# +o+++x+
# 第 21 步： 玩家 -1， 动作 (0, 1)
# +x++oxo
# +xx+x+o
# x+xx+xx
# +o++o+o
# +o+++++
# ++oo++o
# +o+++x+
# 第 22 步： 玩家 1， 动作 (3, 3)
# +x++oxo
# +xx+x+o
# x+xx+xx
# +o+oo+o
# +o+++++
# ++oo++o
# +o+++x+
# 第 23 步： 玩家 -1， 动作 (5, 0)
# +x++oxo
# +xx+x+o
# x+xx+xx
# +o+oo+o
# +o+++++
# x+oo++o
# +o+++x+
# 第 24 步： 玩家 1， 动作 (2, 4)
# +x++oxo
# +xx+x+o
# x+xxoxx
# +o+oo+o
# +o+++++
# x+oo++o
# +o+++x+
# 第 25 步： 玩家 -1， 动作 (1, 3)
# +x++oxo
# +xxxx+o
# x+xxoxx
# +o+oo+o
# +o+++++
# x+oo++o
# +o+++x+
# 第 26 步： 玩家 1， 动作 (0, 3)
# +x+ooxo
# +xxxx+o
# x+xxoxx
# +o+oo+o
# +o+++++
# x+oo++o
# +o+++x+
# 第 27 步： 玩家 -1， 动作 (1, 5)
# +x+ooxo
# +xxxxxo
# x+xxoxx
# +o+oo+o
# +o+++++
# x+oo++o
# +o+++x+
# 赢家 -1

# %% [markdown]
# # 应用

# %%
#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 2)
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 3)
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++x+++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++x+++
# +o+++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# ++o+x++
# +++++++
# +++++++
# +++x+++
# +o+++++
# 第 4 步： 玩家 1， 动作 (3, 0)
# +++++++
# +++++++
# ++o+x++
# o++++++
# +++++++
# +++x+++
# +o+++++
# 第 5 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+++
# ++o+x++
# o++++++
# +++++++
# +++x+++
# +o+++++
# 第 6 步： 玩家 1， 动作 (5, 2)
# +++++++
# +++x+++
# ++o+x++
# o++++++
# +++++++
# ++ox+++
# +o+++++
# 第 7 步： 玩家 -1， 动作 (3, 6)
# +++++++
# +++x+++
# ++o+x++
# o+++++x
# +++++++
# ++ox+++
# +o+++++
# 第 8 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++x+++
# ++o+x++
# oo++++x
# +++++++
# ++ox+++
# +o+++++
# 第 9 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++x+++
# +xo+x++
# oo++++x
# +++++++
# ++ox+++
# +o+++++
# 第 10 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++x+++
# +xo+x++
# oo++++x
# ++o++++
# ++ox+++
# +o+++++
# 第 11 步： 玩家 -1， 动作 (1, 5)
# +++++++
# +++x+x+
# +xo+x++
# oo++++x
# ++o++++
# ++ox+++
# +o+++++
# 第 12 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++x+x+
# +xo+x++
# oo++++x
# ++o++o+
# ++ox+++
# +o+++++
# 第 13 步： 玩家 -1， 动作 (2, 6)
# +++++++
# +++x+x+
# +xo+x+x
# oo++++x
# ++o++o+
# ++ox+++
# +o+++++
# 第 14 步： 玩家 1， 动作 (6, 6)
# +++++++
# +++x+x+
# +xo+x+x
# oo++++x
# ++o++o+
# ++ox+++
# +o++++o
# 第 15 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +++x+x+
# +xo+x+x
# oo++x+x
# ++o++o+
# ++ox+++
# +o++++o
# 第 16 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++x+x+
# +xo+x+x
# oo++x+x
# ++o+oo+
# ++ox+++
# +o++++o
# 第 17 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x++x+x+
# +xo+x+x
# oo++x+x
# ++o+oo+
# ++ox+++
# +o++++o
# 第 18 步： 玩家 1， 动作 (0, 6)
# ++++++o
# x++x+x+
# +xo+x+x
# oo++x+x
# ++o+oo+
# ++ox+++
# +o++++o
# 第 19 步： 玩家 -1， 动作 (3, 5)
# ++++++o
# x++x+x+
# +xo+x+x
# oo++xxx
# ++o+oo+
# ++ox+++
# +o++++o
# 第 20 步： 玩家 1， 动作 (4, 1)
# ++++++o
# x++x+x+
# +xo+x+x
# oo++xxx
# +oo+oo+
# ++ox+++
# +o++++o
# 第 21 步： 玩家 -1， 动作 (0, 2)
# ++x+++o
# x++x+x+
# +xo+x+x
# oo++xxx
# +oo+oo+
# ++ox+++
# +o++++o
# 第 22 步： 玩家 1， 动作 (1, 2)
# ++x+++o
# x+ox+x+
# +xo+x+x
# oo++xxx
# +oo+oo+
# ++ox+++
# +o++++o
# 第 23 步： 玩家 -1， 动作 (4, 6)
# ++x+++o
# x+ox+x+
# +xo+x+x
# oo++xxx
# +oo+oox
# ++ox+++
# +o++++o
# 赢家 -1

# %%
board = np.zeros_like(env.board, dtype=np.int32)
player = BLACK
observation = board, player

action, _ = agent.decide(observation)
action
# Out:
# (4, 1)

# %% [markdown]
# # 重复训练

# %% [markdown]
# ## 训练1 train_iterations = 10 由于之前调试代码时第20次迭代已经训练完成，因此从第21次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 21
iteration_old_save_model = 20
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 21 回合 0: 收集到 232 条经验
# 训练 21 回合 1: 收集到 264 条经验
# 训练 21 回合 2: 收集到 280 条经验
# 训练 21 回合 3: 收集到 224 条经验
# 训练 21 回合 4: 收集到 280 条经验
# 训练 21 回合 5: 收集到 176 条经验
# 训练 21 回合 6: 收集到 248 条经验
# 训练 21 回合 7: 收集到 216 条经验
# 训练 21 回合 8: 收集到 144 条经验
# 训练 21 回合 9: 收集到 256 条经验
# 训练 21 回合 10: 收集到 184 条经验
# 训练 21 回合 11: 收集到 168 条经验
# 训练 21 回合 12: 收集到 264 条经验
# 训练 21 回合 13: 收集到 288 条经验
# 训练 21 回合 14: 收集到 200 条经验
# 训练 21 回合 15: 收集到 216 条经验
# 训练 21 回合 16: 收集到 192 条经验
# 训练 21 回合 17: 收集到 168 条经验
# 训练 21 回合 18: 收集到 264 条经验
# 训练 21 回合 19: 收集到 168 条经验
# 训练 21：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0021/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# 第 1 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++++++
# +++o+++
# 第 2 步： 玩家 1， 动作 (5, 1)
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# +o+++++
# +++o+++
# 第 3 步： 玩家 -1， 动作 (6, 4)
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# +o+++++
# +++ox++
# 第 4 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# ++x+++o
# +++++++
# +++++++
# +o+++++
# +++ox++
# 第 5 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# +++++++
# ++x+++o
# +++++++
# +++++++
# +o+++++
# +++ox++
# 第 6 步： 玩家 1， 动作 (4, 3)
# ++++++x
# +++++++
# ++x+++o
# +++++++
# +++o+++
# +o+++++
# +++ox++
# 第 7 步： 玩家 -1， 动作 (1, 3)
# ++++++x
# +++x+++
# ++x+++o
# +++++++
# +++o+++
# +o+++++
# +++ox++
# 第 8 步： 玩家 1， 动作 (2, 1)
# ++++++x
# +++x+++
# +ox+++o
# +++++++
# +++o+++
# +o+++++
# +++ox++
# 第 9 步： 玩家 -1， 动作 (3, 2)
# ++++++x
# +++x+++
# +ox+++o
# ++x++++
# +++o+++
# +o+++++
# +++ox++
# 第 10 步： 玩家 1， 动作 (4, 0)
# ++++++x
# +++x+++
# +ox+++o
# ++x++++
# o++o+++
# +o+++++
# +++ox++
# 第 11 步： 玩家 -1， 动作 (6, 1)
# ++++++x
# +++x+++
# +ox+++o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 12 步： 玩家 1， 动作 (1, 0)
# ++++++x
# o++x+++
# +ox+++o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 13 步： 玩家 -1， 动作 (0, 1)
# +x++++x
# o++x+++
# +ox+++o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 14 步： 玩家 1， 动作 (2, 4)
# +x++++x
# o++x+++
# +ox+o+o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 15 步： 玩家 -1， 动作 (0, 3)
# +x+x++x
# o++x+++
# +ox+o+o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 16 步： 玩家 1， 动作 (0, 2)
# +xox++x
# o++x+++
# +ox+o+o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 17 步： 玩家 -1， 动作 (0, 0)
# xxox++x
# o++x+++
# +ox+o+o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 18 步： 玩家 1， 动作 (1, 5)
# xxox++x
# o++x+o+
# +ox+o+o
# ++x++++
# o++o+++
# +o+++++
# +x+ox++
# 第 19 步： 玩家 -1， 动作 (5, 6)
# xxox++x
# o++x+o+
# +ox+o+o
# ++x++++
# o++o+++
# +o++++x
# +x+ox++
# 第 20 步： 玩家 1， 动作 (0, 4)
# xxoxo+x
# o++x+o+
# +ox+o+o
# ++x++++
# o++o+++
# +o++++x
# +x+ox++
# 第 21 步： 玩家 -1， 动作 (5, 2)
# xxoxo+x
# o++x+o+
# +ox+o+o
# ++x++++
# o++o+++
# +ox+++x
# +x+ox++
# 第 22 步： 玩家 1， 动作 (3, 3)
# xxoxo+x
# o++x+o+
# +ox+o+o
# ++xo+++
# o++o+++
# +ox+++x
# +x+ox++
# 第 23 步： 玩家 -1， 动作 (2, 0)
# xxoxo+x
# o++x+o+
# xox+o+o
# ++xo+++
# o++o+++
# +ox+++x
# +x+ox++
# 第 24 步： 玩家 1， 动作 (2, 3)
# xxoxo+x
# o++x+o+
# xoxoo+o
# ++xo+++
# o++o+++
# +ox+++x
# +x+ox++
# 第 25 步： 玩家 -1， 动作 (4, 2)
# xxoxo+x
# o++x+o+
# xoxoo+o
# ++xo+++
# o+xo+++
# +ox+++x
# +x+ox++
# 第 26 步： 玩家 1， 动作 (4, 5)
# xxoxo+x
# o++x+o+
# xoxoo+o
# ++xo+++
# o+xo+o+
# +ox+++x
# +x+ox++
# 第 27 步： 玩家 -1， 动作 (6, 2)
# xxoxo+x
# o++x+o+
# xoxoo+o
# ++xo+++
# o+xo+o+
# +ox+++x
# +xxox++
# 赢家 -1
# 训练 22 回合 0: 收集到 112 条经验
# 训练 22 回合 1: 收集到 152 条经验
# 训练 22 回合 2: 收集到 232 条经验
# 训练 22 回合 3: 收集到 216 条经验
# 训练 22 回合 4: 收集到 168 条经验
# 训练 22 回合 5: 收集到 184 条经验
# 训练 22 回合 6: 收集到 88 条经验
# 训练 22 回合 7: 收集到 200 条经验
# 训练 22 回合 8: 收集到 192 条经验
# 训练 22 回合 9: 收集到 272 条经验
# 训练 22 回合 10: 收集到 264 条经验
# 训练 22 回合 11: 收集到 216 条经验
# 训练 22 回合 12: 收集到 208 条经验
# 训练 22 回合 13: 收集到 152 条经验
# 训练 22 回合 14: 收集到 216 条经验
# 训练 22 回合 15: 收集到 272 条经验
# 训练 22 回合 16: 收集到 200 条经验
# 训练 22 回合 17: 收集到 248 条经验
# 训练 22 回合 18: 收集到 128 条经验
# 训练 22 回合 19: 收集到 264 条经验
# 训练 22：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0022/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# ++++x++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 6)
# +++++++
# +++++++
# ++++x++
# +++++o+
# +++++++
# +++++++
# ++++++o
# 第 3 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++++
# ++++x++
# +++++o+
# +x+++++
# +++++++
# ++++++o
# 第 4 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# ++++x++
# +++++o+
# +x+++++
# ++++++o
# ++++++o
# 第 5 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +++++++
# ++++x++
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 6 步： 玩家 1， 动作 (0, 4)
# ++++o++
# +++++++
# ++++x++
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 7 步： 玩家 -1， 动作 (2, 2)
# ++++o++
# +++++++
# ++x+x++
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 8 步： 玩家 1， 动作 (1, 3)
# ++++o++
# +++o+++
# ++x+x++
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 9 步： 玩家 -1， 动作 (1, 1)
# ++++o++
# +x+o+++
# ++x+x++
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 10 步： 玩家 1， 动作 (2, 6)
# ++++o++
# +x+o+++
# ++x+x+o
# ++++xo+
# +x+++++
# ++++++o
# ++++++o
# 第 11 步： 玩家 -1， 动作 (5, 2)
# ++++o++
# +x+o+++
# ++x+x+o
# ++++xo+
# +x+++++
# ++x+++o
# ++++++o
# 第 12 步： 玩家 1， 动作 (4, 0)
# ++++o++
# +x+o+++
# ++x+x+o
# ++++xo+
# ox+++++
# ++x+++o
# ++++++o
# 第 13 步： 玩家 -1， 动作 (6, 0)
# ++++o++
# +x+o+++
# ++x+x+o
# ++++xo+
# ox+++++
# ++x+++o
# x+++++o
# 第 14 步： 玩家 1， 动作 (3, 0)
# ++++o++
# +x+o+++
# ++x+x+o
# o+++xo+
# ox+++++
# ++x+++o
# x+++++o
# 第 15 步： 玩家 -1， 动作 (2, 0)
# ++++o++
# +x+o+++
# x+x+x+o
# o+++xo+
# ox+++++
# ++x+++o
# x+++++o
# 第 16 步： 玩家 1， 动作 (4, 3)
# ++++o++
# +x+o+++
# x+x+x+o
# o+++xo+
# ox+o+++
# ++x+++o
# x+++++o
# 第 17 步： 玩家 -1， 动作 (0, 5)
# ++++ox+
# +x+o+++
# x+x+x+o
# o+++xo+
# ox+o+++
# ++x+++o
# x+++++o
# 第 18 步： 玩家 1， 动作 (2, 3)
# ++++ox+
# +x+o+++
# x+xox+o
# o+++xo+
# ox+o+++
# ++x+++o
# x+++++o
# 第 19 步： 玩家 -1， 动作 (4, 4)
# ++++ox+
# +x+o+++
# x+xox+o
# o+++xo+
# ox+ox++
# ++x+++o
# x+++++o
# 第 20 步： 玩家 1， 动作 (3, 2)
# ++++ox+
# +x+o+++
# x+xox+o
# o+o+xo+
# ox+ox++
# ++x+++o
# x+++++o
# 第 21 步： 玩家 -1， 动作 (6, 3)
# ++++ox+
# +x+o+++
# x+xox+o
# o+o+xo+
# ox+ox++
# ++x+++o
# x++x++o
# 第 22 步： 玩家 1， 动作 (3, 1)
# ++++ox+
# +x+o+++
# x+xox+o
# ooo+xo+
# ox+ox++
# ++x+++o
# x++x++o
# 第 23 步： 玩家 -1， 动作 (3, 6)
# ++++ox+
# +x+o+++
# x+xox+o
# ooo+xox
# ox+ox++
# ++x+++o
# x++x++o
# 第 24 步： 玩家 1， 动作 (0, 3)
# +++oox+
# +x+o+++
# x+xox+o
# ooo+xox
# ox+ox++
# ++x+++o
# x++x++o
# 第 25 步： 玩家 -1， 动作 (1, 4)
# +++oox+
# +x+ox++
# x+xox+o
# ooo+xox
# ox+ox++
# ++x+++o
# x++x++o
# 第 26 步： 玩家 1， 动作 (3, 3)
# +++oox+
# +x+ox++
# x+xox+o
# ooooxox
# ox+ox++
# ++x+++o
# x++x++o
# 赢家 1
# 训练 23 回合 0: 收集到 128 条经验
# 训练 23 回合 1: 收集到 232 条经验
# 训练 23 回合 2: 收集到 392 条经验
# 训练 23 回合 3: 收集到 232 条经验
# 训练 23 回合 4: 收集到 208 条经验
# 训练 23 回合 5: 收集到 248 条经验
# 训练 23 回合 6: 收集到 224 条经验
# 训练 23 回合 7: 收集到 280 条经验
# 训练 23 回合 8: 收集到 256 条经验
# 训练 23 回合 9: 收集到 160 条经验
# 训练 23 回合 10: 收集到 264 条经验
# 训练 23 回合 11: 收集到 216 条经验
# 训练 23 回合 12: 收集到 168 条经验
# 训练 23 回合 13: 收集到 144 条经验
# 训练 23 回合 14: 收集到 256 条经验
# 训练 23 回合 15: 收集到 256 条经验
# 训练 23 回合 16: 收集到 224 条经验
# 训练 23 回合 17: 收集到 184 条经验
# 训练 23 回合 18: 收集到 272 条经验
# 训练 23 回合 19: 收集到 200 条经验
# 训练 23：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0023/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 3)
# x++++++
# +++++++
# ++++o++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 3)
# x++++++
# +++++++
# ++++o++
# +++o+++
# +++++++
# +++x+++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 4)
# x++++++
# +++++++
# ++++o++
# +++oo++
# +++++++
# +++x+++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 5)
# x++++++
# +++++x+
# ++++o++
# +++oo++
# +++++++
# +++x+++
# +++++++
# 第 6 步： 玩家 1， 动作 (1, 3)
# x++++++
# +++o+x+
# ++++o++
# +++oo++
# +++++++
# +++x+++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# x++++++
# +++o+x+
# ++++ox+
# +++oo++
# +++++++
# +++x+++
# +++++++
# 第 8 步： 玩家 1， 动作 (0, 5)
# x++++o+
# +++o+x+
# ++++ox+
# +++oo++
# +++++++
# +++x+++
# +++++++
# 第 9 步： 玩家 -1， 动作 (5, 2)
# x++++o+
# +++o+x+
# ++++ox+
# +++oo++
# +++++++
# ++xx+++
# +++++++
# 第 10 步： 玩家 1， 动作 (1, 4)
# x++++o+
# +++oox+
# ++++ox+
# +++oo++
# +++++++
# ++xx+++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 3)
# x++++o+
# +++oox+
# ++++ox+
# +++oo++
# +++++++
# ++xx+++
# +++x+++
# 第 12 步： 玩家 1， 动作 (3, 1)
# x++++o+
# +++oox+
# ++++ox+
# +o+oo++
# +++++++
# ++xx+++
# +++x+++
# 第 13 步： 玩家 -1， 动作 (0, 1)
# xx+++o+
# +++oox+
# ++++ox+
# +o+oo++
# +++++++
# ++xx+++
# +++x+++
# 第 14 步： 玩家 1， 动作 (2, 2)
# xx+++o+
# +++oox+
# ++o+ox+
# +o+oo++
# +++++++
# ++xx+++
# +++x+++
# 第 15 步： 玩家 -1， 动作 (1, 2)
# xx+++o+
# ++xoox+
# ++o+ox+
# +o+oo++
# +++++++
# ++xx+++
# +++x+++
# 第 16 步： 玩家 1， 动作 (4, 4)
# xx+++o+
# ++xoox+
# ++o+ox+
# +o+oo++
# ++++o++
# ++xx+++
# +++x+++
# 第 17 步： 玩家 -1， 动作 (4, 0)
# xx+++o+
# ++xoox+
# ++o+ox+
# +o+oo++
# x+++o++
# ++xx+++
# +++x+++
# 第 18 步： 玩家 1， 动作 (5, 4)
# xx+++o+
# ++xoox+
# ++o+ox+
# +o+oo++
# x+++o++
# ++xxo++
# +++x+++
# 赢家 1
# 训练 24 回合 0: 收集到 224 条经验
# 训练 24 回合 1: 收集到 200 条经验
# 训练 24 回合 2: 收集到 208 条经验
# 训练 24 回合 3: 收集到 208 条经验
# 训练 24 回合 4: 收集到 176 条经验
# 训练 24 回合 5: 收集到 216 条经验
# 训练 24 回合 6: 收集到 152 条经验
# 训练 24 回合 7: 收集到 192 条经验
# 训练 24 回合 8: 收集到 272 条经验
# 训练 24 回合 9: 收集到 216 条经验
# 训练 24 回合 10: 收集到 224 条经验
# 训练 24 回合 11: 收集到 208 条经验
# 训练 24 回合 12: 收集到 168 条经验
# 训练 24 回合 13: 收集到 216 条经验
# 训练 24 回合 14: 收集到 192 条经验
# 训练 24 回合 15: 收集到 216 条经验
# 训练 24 回合 16: 收集到 296 条经验
# 训练 24 回合 17: 收集到 128 条经验
# 训练 24 回合 18: 收集到 264 条经验
# 训练 24 回合 19: 收集到 144 条经验
# 训练 24：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0024/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 5)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# 第 1 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# 第 2 步： 玩家 1， 动作 (4, 4)
# x++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++o+
# 第 3 步： 玩家 -1， 动作 (2, 0)
# x++++++
# +++++++
# x++++++
# +++++++
# ++++o++
# +++++++
# +++++o+
# 第 4 步： 玩家 1， 动作 (4, 2)
# x++++++
# +++++++
# x++++++
# +++++++
# ++o+o++
# +++++++
# +++++o+
# 第 5 步： 玩家 -1， 动作 (0, 5)
# x++++x+
# +++++++
# x++++++
# +++++++
# ++o+o++
# +++++++
# +++++o+
# 第 6 步： 玩家 1， 动作 (0, 4)
# x+++ox+
# +++++++
# x++++++
# +++++++
# ++o+o++
# +++++++
# +++++o+
# 第 7 步： 玩家 -1， 动作 (3, 6)
# x+++ox+
# +++++++
# x++++++
# ++++++x
# ++o+o++
# +++++++
# +++++o+
# 第 8 步： 玩家 1， 动作 (6, 4)
# x+++ox+
# +++++++
# x++++++
# ++++++x
# ++o+o++
# +++++++
# ++++oo+
# 第 9 步： 玩家 -1， 动作 (3, 5)
# x+++ox+
# +++++++
# x++++++
# +++++xx
# ++o+o++
# +++++++
# ++++oo+
# 第 10 步： 玩家 1， 动作 (0, 3)
# x++oox+
# +++++++
# x++++++
# +++++xx
# ++o+o++
# +++++++
# ++++oo+
# 第 11 步： 玩家 -1， 动作 (4, 3)
# x++oox+
# +++++++
# x++++++
# +++++xx
# ++oxo++
# +++++++
# ++++oo+
# 第 12 步： 玩家 1， 动作 (1, 3)
# x++oox+
# +++o+++
# x++++++
# +++++xx
# ++oxo++
# +++++++
# ++++oo+
# 第 13 步： 玩家 -1， 动作 (5, 2)
# x++oox+
# +++o+++
# x++++++
# +++++xx
# ++oxo++
# ++x++++
# ++++oo+
# 第 14 步： 玩家 1， 动作 (1, 2)
# x++oox+
# ++oo+++
# x++++++
# +++++xx
# ++oxo++
# ++x++++
# ++++oo+
# 第 15 步： 玩家 -1， 动作 (4, 5)
# x++oox+
# ++oo+++
# x++++++
# +++++xx
# ++oxox+
# ++x++++
# ++++oo+
# 第 16 步： 玩家 1， 动作 (3, 2)
# x++oox+
# ++oo+++
# x++++++
# ++o++xx
# ++oxox+
# ++x++++
# ++++oo+
# 第 17 步： 玩家 -1， 动作 (3, 4)
# x++oox+
# ++oo+++
# x++++++
# ++o+xxx
# ++oxox+
# ++x++++
# ++++oo+
# 第 18 步： 玩家 1， 动作 (2, 1)
# x++oox+
# ++oo+++
# xo+++++
# ++o+xxx
# ++oxox+
# ++x++++
# ++++oo+
# 第 19 步： 玩家 -1， 动作 (4, 0)
# x++oox+
# ++oo+++
# xo+++++
# ++o+xxx
# x+oxox+
# ++x++++
# ++++oo+
# 第 20 步： 玩家 1， 动作 (5, 4)
# x++oox+
# ++oo+++
# xo+++++
# ++o+xxx
# x+oxox+
# ++x+o++
# ++++oo+
# 第 21 步： 玩家 -1， 动作 (5, 6)
# x++oox+
# ++oo+++
# xo+++++
# ++o+xxx
# x+oxox+
# ++x+o+x
# ++++oo+
# 第 22 步： 玩家 1， 动作 (3, 3)
# x++oox+
# ++oo+++
# xo+++++
# ++ooxxx
# x+oxox+
# ++x+o+x
# ++++oo+
# 第 23 步： 玩家 -1， 动作 (2, 2)
# x++oox+
# ++oo+++
# xox++++
# ++ooxxx
# x+oxox+
# ++x+o+x
# ++++oo+
# 第 24 步： 玩家 1， 动作 (3, 1)
# x++oox+
# ++oo+++
# xox++++
# +oooxxx
# x+oxox+
# ++x+o+x
# ++++oo+
# 第 25 步： 玩家 -1， 动作 (5, 1)
# x++oox+
# ++oo+++
# xox++++
# +oooxxx
# x+oxox+
# +xx+o+x
# ++++oo+
# 第 26 步： 玩家 1， 动作 (2, 3)
# x++oox+
# ++oo+++
# xoxo+++
# +oooxxx
# x+oxox+
# +xx+o+x
# ++++oo+
# 第 27 步： 玩家 -1， 动作 (2, 5)
# x++oox+
# ++oo+++
# xoxo+x+
# +oooxxx
# x+oxox+
# +xx+o+x
# ++++oo+
# 第 28 步： 玩家 1， 动作 (6, 1)
# x++oox+
# ++oo+++
# xoxo+x+
# +oooxxx
# x+oxox+
# +xx+o+x
# +o++oo+
# 第 29 步： 玩家 -1， 动作 (6, 0)
# x++oox+
# ++oo+++
# xoxo+x+
# +oooxxx
# x+oxox+
# +xx+o+x
# xo++oo+
# 第 30 步： 玩家 1， 动作 (2, 4)
# x++oox+
# ++oo+++
# xoxoox+
# +oooxxx
# x+oxox+
# +xx+o+x
# xo++oo+
# 第 31 步： 玩家 -1， 动作 (6, 6)
# x++oox+
# ++oo+++
# xoxoox+
# +oooxxx
# x+oxox+
# +xx+o+x
# xo++oox
# 第 32 步： 玩家 1， 动作 (5, 5)
# x++oox+
# ++oo+++
# xoxoox+
# +oooxxx
# x+oxox+
# +xx+oox
# xo++oox
# 第 33 步： 玩家 -1， 动作 (1, 5)
# x++oox+
# ++oo+x+
# xoxoox+
# +oooxxx
# x+oxox+
# +xx+oox
# xo++oox
# 赢家 -1
# 训练 25 回合 0: 收集到 256 条经验
# 训练 25 回合 1: 收集到 176 条经验
# 训练 25 回合 2: 收集到 184 条经验
# 训练 25 回合 3: 收集到 136 条经验
# 训练 25 回合 4: 收集到 240 条经验
# 训练 25 回合 5: 收集到 240 条经验
# 训练 25 回合 6: 收集到 168 条经验
# 训练 25 回合 7: 收集到 184 条经验
# 训练 25 回合 8: 收集到 280 条经验
# 训练 25 回合 9: 收集到 216 条经验
# 训练 25 回合 10: 收集到 320 条经验
# 训练 25 回合 11: 收集到 304 条经验
# 训练 25 回合 12: 收集到 264 条经验
# 训练 25 回合 13: 收集到 144 条经验
# 训练 25 回合 14: 收集到 200 条经验
# 训练 25 回合 15: 收集到 240 条经验
# 训练 25 回合 16: 收集到 208 条经验
# 训练 25 回合 17: 收集到 160 条经验
# 训练 25 回合 18: 收集到 232 条经验
# 训练 25 回合 19: 收集到 128 条经验
# 训练 25：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0025/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# ++++++o
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 5)
# +++++++
# +++++++
# ++++++o
# +++++++
# +++++++
# +++++x+
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++++++
# ++++++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++++++
# ++++++o
# ++++o++
# +++++++
# +++++x+
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 6)
# +x+++++
# +++++++
# ++++++o
# ++++o+o
# +++++++
# +++++x+
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 5)
# +x+++++
# +++++++
# +++++xo
# ++++o+o
# +++++++
# +++++x+
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 0)
# +x+++++
# +++++++
# +++++xo
# ++++o+o
# o++++++
# +++++x+
# +++++++
# 第 7 步： 玩家 -1， 动作 (5, 1)
# +x+++++
# +++++++
# +++++xo
# ++++o+o
# o++++++
# +x+++x+
# +++++++
# 第 8 步： 玩家 1， 动作 (1, 2)
# +x+++++
# ++o++++
# +++++xo
# ++++o+o
# o++++++
# +x+++x+
# +++++++
# 第 9 步： 玩家 -1， 动作 (6, 4)
# +x+++++
# ++o++++
# +++++xo
# ++++o+o
# o++++++
# +x+++x+
# ++++x++
# 第 10 步： 玩家 1， 动作 (3, 1)
# +x+++++
# ++o++++
# +++++xo
# +o++o+o
# o++++++
# +x+++x+
# ++++x++
# 第 11 步： 玩家 -1， 动作 (4, 4)
# +x+++++
# ++o++++
# +++++xo
# +o++o+o
# o+++x++
# +x+++x+
# ++++x++
# 第 12 步： 玩家 1， 动作 (2, 2)
# +x+++++
# ++o++++
# ++o++xo
# +o++o+o
# o+++x++
# +x+++x+
# ++++x++
# 第 13 步： 玩家 -1， 动作 (1, 5)
# +x+++++
# ++o++x+
# ++o++xo
# +o++o+o
# o+++x++
# +x+++x+
# ++++x++
# 第 14 步： 玩家 1， 动作 (1, 4)
# +x+++++
# ++o+ox+
# ++o++xo
# +o++o+o
# o+++x++
# +x+++x+
# ++++x++
# 第 15 步： 玩家 -1， 动作 (2, 3)
# +x+++++
# ++o+ox+
# ++ox+xo
# +o++o+o
# o+++x++
# +x+++x+
# ++++x++
# 第 16 步： 玩家 1， 动作 (4, 6)
# +x+++++
# ++o+ox+
# ++ox+xo
# +o++o+o
# o+++x+o
# +x+++x+
# ++++x++
# 第 17 步： 玩家 -1， 动作 (6, 5)
# +x+++++
# ++o+ox+
# ++ox+xo
# +o++o+o
# o+++x+o
# +x+++x+
# ++++xx+
# 第 18 步： 玩家 1， 动作 (6, 1)
# +x+++++
# ++o+ox+
# ++ox+xo
# +o++o+o
# o+++x+o
# +x+++x+
# +o++xx+
# 第 19 步： 玩家 -1， 动作 (1, 3)
# +x+++++
# ++oxox+
# ++ox+xo
# +o++o+o
# o+++x+o
# +x+++x+
# +o++xx+
# 第 20 步： 玩家 1， 动作 (4, 1)
# +x+++++
# ++oxox+
# ++ox+xo
# +o++o+o
# oo++x+o
# +x+++x+
# +o++xx+
# 第 21 步： 玩家 -1， 动作 (2, 4)
# +x+++++
# ++oxox+
# ++oxxxo
# +o++o+o
# oo++x+o
# +x+++x+
# +o++xx+
# 第 22 步： 玩家 1， 动作 (4, 5)
# +x+++++
# ++oxox+
# ++oxxxo
# +o++o+o
# oo++xoo
# +x+++x+
# +o++xx+
# 第 23 步： 玩家 -1， 动作 (3, 2)
# +x+++++
# ++oxox+
# ++oxxxo
# +ox+o+o
# oo++xoo
# +x+++x+
# +o++xx+
# 第 24 步： 玩家 1， 动作 (3, 5)
# +x+++++
# ++oxox+
# ++oxxxo
# +ox+ooo
# oo++xoo
# +x+++x+
# +o++xx+
# 第 25 步： 玩家 -1， 动作 (4, 2)
# +x+++++
# ++oxox+
# ++oxxxo
# +ox+ooo
# oox+xoo
# +x+++x+
# +o++xx+
# 第 26 步： 玩家 1， 动作 (2, 1)
# +x+++++
# ++oxox+
# +ooxxxo
# +ox+ooo
# oox+xoo
# +x+++x+
# +o++xx+
# 第 27 步： 玩家 -1， 动作 (3, 3)
# +x+++++
# ++oxox+
# +ooxxxo
# +oxxooo
# oox+xoo
# +x+++x+
# +o++xx+
# 赢家 -1
# 训练 26 回合 0: 收集到 176 条经验
# 训练 26 回合 1: 收集到 192 条经验
# 训练 26 回合 2: 收集到 176 条经验
# 训练 26 回合 3: 收集到 240 条经验
# 训练 26 回合 4: 收集到 272 条经验
# 训练 26 回合 5: 收集到 208 条经验
# 训练 26 回合 6: 收集到 208 条经验
# 训练 26 回合 7: 收集到 392 条经验
# 训练 26 回合 8: 收集到 288 条经验
# 训练 26 回合 9: 收集到 256 条经验
# 训练 26 回合 10: 收集到 312 条经验
# 训练 26 回合 11: 收集到 184 条经验
# 训练 26 回合 12: 收集到 304 条经验
# 训练 26 回合 13: 收集到 160 条经验
# 训练 26 回合 14: 收集到 144 条经验
# 训练 26 回合 15: 收集到 320 条经验
# 训练 26 回合 16: 收集到 200 条经验
# 训练 26 回合 17: 收集到 208 条经验
# 训练 26 回合 18: 收集到 168 条经验
# 训练 26 回合 19: 收集到 184 条经验
# 训练 26：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0026/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++++++
# +o+++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 2)
# +++++++
# +++++++
# +o+++++
# ++x++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 3)
# +++++++
# +++++++
# +o+o+++
# ++x++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (6, 2)
# +++++++
# +++++++
# +o+o+++
# ++x++++
# +++++++
# +++++++
# ++x++++
# 第 4 步： 玩家 1， 动作 (2, 5)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# +++++++
# ++x++++
# 第 5 步： 玩家 -1， 动作 (5, 4)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# ++++x++
# ++x++++
# 第 6 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# ++++x+o
# ++x++++
# 第 7 步： 玩家 -1， 动作 (5, 3)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# +++xx+o
# ++x++++
# 第 8 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# +++xx+o
# ++x+o++
# 第 9 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# x++xx+o
# ++x+o++
# 第 10 步： 玩家 1， 动作 (0, 6)
# ++++++o
# +++++++
# +o+o+o+
# ++x++++
# +++++++
# x++xx+o
# ++x+o++
# 第 11 步： 玩家 -1， 动作 (4, 6)
# ++++++o
# +++++++
# +o+o+o+
# ++x++++
# ++++++x
# x++xx+o
# ++x+o++
# 第 12 步： 玩家 1， 动作 (2, 6)
# ++++++o
# +++++++
# +o+o+oo
# ++x++++
# ++++++x
# x++xx+o
# ++x+o++
# 第 13 步： 玩家 -1， 动作 (1, 4)
# ++++++o
# ++++x++
# +o+o+oo
# ++x++++
# ++++++x
# x++xx+o
# ++x+o++
# 第 14 步： 玩家 1， 动作 (5, 1)
# ++++++o
# ++++x++
# +o+o+oo
# ++x++++
# ++++++x
# xo+xx+o
# ++x+o++
# 第 15 步： 玩家 -1， 动作 (4, 1)
# ++++++o
# ++++x++
# +o+o+oo
# ++x++++
# +x++++x
# xo+xx+o
# ++x+o++
# 第 16 步： 玩家 1， 动作 (6, 1)
# ++++++o
# ++++x++
# +o+o+oo
# ++x++++
# +x++++x
# xo+xx+o
# +ox+o++
# 第 17 步： 玩家 -1， 动作 (4, 2)
# ++++++o
# ++++x++
# +o+o+oo
# ++x++++
# +xx+++x
# xo+xx+o
# +ox+o++
# 第 18 步： 玩家 1， 动作 (3, 1)
# ++++++o
# ++++x++
# +o+o+oo
# +ox++++
# +xx+++x
# xo+xx+o
# +ox+o++
# 第 19 步： 玩家 -1， 动作 (1, 1)
# ++++++o
# +x++x++
# +o+o+oo
# +ox++++
# +xx+++x
# xo+xx+o
# +ox+o++
# 第 20 步： 玩家 1， 动作 (4, 3)
# ++++++o
# +x++x++
# +o+o+oo
# +ox++++
# +xxo++x
# xo+xx+o
# +ox+o++
# 第 21 步： 玩家 -1， 动作 (5, 2)
# ++++++o
# +x++x++
# +o+o+oo
# +ox++++
# +xxo++x
# xoxxx+o
# +ox+o++
# 第 22 步： 玩家 1， 动作 (1, 5)
# ++++++o
# +x++xo+
# +o+o+oo
# +ox++++
# +xxo++x
# xoxxx+o
# +ox+o++
# 第 23 步： 玩家 -1， 动作 (1, 2)
# ++++++o
# +xx+xo+
# +o+o+oo
# +ox++++
# +xxo++x
# xoxxx+o
# +ox+o++
# 第 24 步： 玩家 1， 动作 (2, 4)
# ++++++o
# +xx+xo+
# +o+oooo
# +ox++++
# +xxo++x
# xoxxx+o
# +ox+o++
# 第 25 步： 玩家 -1， 动作 (4, 4)
# ++++++o
# +xx+xo+
# +o+oooo
# +ox++++
# +xxox+x
# xoxxx+o
# +ox+o++
# 第 26 步： 玩家 1， 动作 (2, 2)
# ++++++o
# +xx+xo+
# +oooooo
# +ox++++
# +xxox+x
# xoxxx+o
# +ox+o++
# 赢家 1
# 训练 27 回合 0: 收集到 144 条经验
# 训练 27 回合 1: 收集到 296 条经验
# 训练 27 回合 2: 收集到 208 条经验
# 训练 27 回合 3: 收集到 176 条经验
# 训练 27 回合 4: 收集到 280 条经验
# 训练 27 回合 5: 收集到 200 条经验
# 训练 27 回合 6: 收集到 304 条经验
# 训练 27 回合 7: 收集到 152 条经验
# 训练 27 回合 8: 收集到 288 条经验
# 训练 27 回合 9: 收集到 152 条经验
# 训练 27 回合 10: 收集到 240 条经验
# 训练 27 回合 11: 收集到 240 条经验
# 训练 27 回合 12: 收集到 208 条经验
# 训练 27 回合 13: 收集到 312 条经验
# 训练 27 回合 14: 收集到 168 条经验
# 训练 27 回合 15: 收集到 264 条经验
# 训练 27 回合 16: 收集到 224 条经验
# 训练 27 回合 17: 收集到 184 条经验
# 训练 27 回合 18: 收集到 248 条经验
# 训练 27 回合 19: 收集到 248 条经验
# 训练 27：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0027/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 0)
# +++++++
# +++++++
# ++++o++
# x++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# ++++o++
# x++o+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x++o++
# x++o+++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +x++o++
# x++o+o+
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# +xx+o++
# x++o+o+
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 0)
# o++++++
# +++++++
# +xx+o++
# x++o+o+
# +++++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 3)
# o++++++
# +++++++
# +xx+o++
# x++o+o+
# +++x+++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (5, 3)
# o++++++
# +++++++
# +xx+o++
# x++o+o+
# +++x+++
# +++o+++
# +++++++
# 第 9 步： 玩家 -1， 动作 (5, 2)
# o++++++
# +++++++
# +xx+o++
# x++o+o+
# +++x+++
# ++xo+++
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 5)
# o++++o+
# +++++++
# +xx+o++
# x++o+o+
# +++x+++
# ++xo+++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 1)
# o++++o+
# +++++++
# +xx+o++
# x++o+o+
# +++x+++
# ++xo+++
# +x+++++
# 第 12 步： 玩家 1， 动作 (4, 6)
# o++++o+
# +++++++
# +xx+o++
# x++o+o+
# +++x++o
# ++xo+++
# +x+++++
# 第 13 步： 玩家 -1， 动作 (0, 6)
# o++++ox
# +++++++
# +xx+o++
# x++o+o+
# +++x++o
# ++xo+++
# +x+++++
# 第 14 步： 玩家 1， 动作 (4, 2)
# o++++ox
# +++++++
# +xx+o++
# x++o+o+
# ++ox++o
# ++xo+++
# +x+++++
# 第 15 步： 玩家 -1， 动作 (6, 3)
# o++++ox
# +++++++
# +xx+o++
# x++o+o+
# ++ox++o
# ++xo+++
# +x+x+++
# 第 16 步： 玩家 1， 动作 (5, 4)
# o++++ox
# +++++++
# +xx+o++
# x++o+o+
# ++ox++o
# ++xoo++
# +x+x+++
# 第 17 步： 玩家 -1， 动作 (3, 2)
# o++++ox
# +++++++
# +xx+o++
# x+xo+o+
# ++ox++o
# ++xoo++
# +x+x+++
# 第 18 步： 玩家 1， 动作 (6, 5)
# o++++ox
# +++++++
# +xx+o++
# x+xo+o+
# ++ox++o
# ++xoo++
# +x+x+o+
# 第 19 步： 玩家 -1， 动作 (5, 1)
# o++++ox
# +++++++
# +xx+o++
# x+xo+o+
# ++ox++o
# +xxoo++
# +x+x+o+
# 第 20 步： 玩家 1， 动作 (1, 5)
# o++++ox
# +++++o+
# +xx+o++
# x+xo+o+
# ++ox++o
# +xxoo++
# +x+x+o+
# 第 21 步： 玩家 -1， 动作 (3, 4)
# o++++ox
# +++++o+
# +xx+o++
# x+xoxo+
# ++ox++o
# +xxoo++
# +x+x+o+
# 第 22 步： 玩家 1， 动作 (0, 4)
# o+++oox
# +++++o+
# +xx+o++
# x+xoxo+
# ++ox++o
# +xxoo++
# +x+x+o+
# 第 23 步： 玩家 -1， 动作 (2, 5)
# o+++oox
# +++++o+
# +xx+ox+
# x+xoxo+
# ++ox++o
# +xxoo++
# +x+x+o+
# 赢家 -1
# 训练 28 回合 0: 收集到 248 条经验
# 训练 28 回合 1: 收集到 152 条经验
# 训练 28 回合 2: 收集到 128 条经验
# 训练 28 回合 3: 收集到 248 条经验
# 训练 28 回合 4: 收集到 136 条经验
# 训练 28 回合 5: 收集到 184 条经验
# 训练 28 回合 6: 收集到 152 条经验
# 训练 28 回合 7: 收集到 168 条经验
# 训练 28 回合 8: 收集到 112 条经验
# 训练 28 回合 9: 收集到 176 条经验
# 训练 28 回合 10: 收集到 176 条经验
# 训练 28 回合 11: 收集到 208 条经验
# 训练 28 回合 12: 收集到 152 条经验
# 训练 28 回合 13: 收集到 208 条经验
# 训练 28 回合 14: 收集到 216 条经验
# 训练 28 回合 15: 收集到 216 条经验
# 训练 28 回合 16: 收集到 152 条经验
# 训练 28 回合 17: 收集到 120 条经验
# 训练 28 回合 18: 收集到 208 条经验
# 训练 28 回合 19: 收集到 152 条经验
# 训练 28：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0028/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 3)
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 6)
# +++++++
# +++++++
# +++o+++
# ++++++x
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 2)
# +++++++
# +++++++
# +++o+++
# ++o+++x
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x++
# +++o+++
# ++o+++x
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 1)
# +o+++++
# ++++x++
# +++o+++
# ++o+++x
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 4)
# +o+++++
# ++++x++
# +++o+++
# ++o+x+x
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 6)
# +o+++++
# ++++x++
# +++o+++
# ++o+x+x
# ++++++o
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (1, 5)
# +o+++++
# ++++xx+
# +++o+++
# ++o+x+x
# ++++++o
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 5)
# +o+++++
# ++++xx+
# +++o+++
# ++o+xox
# ++++++o
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (2, 6)
# +o+++++
# ++++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 0)
# oo+++++
# ++++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 3)
# oo+++++
# ++++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++++
# +++x+++
# 第 12 步： 玩家 1， 动作 (5, 5)
# oo+++++
# ++++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 13 步： 玩家 -1， 动作 (1, 1)
# oo+++++
# +x++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 14 步： 玩家 1， 动作 (0, 4)
# oo++o++
# +x++xx+
# +++o++x
# ++o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 15 步： 玩家 -1， 动作 (2, 5)
# oo++o++
# +x++xx+
# +++o+xx
# ++o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 16 步： 玩家 1， 动作 (3, 0)
# oo++o++
# +x++xx+
# +++o+xx
# o+o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 17 步： 玩家 -1， 动作 (1, 3)
# oo++o++
# +x+xxx+
# +++o+xx
# o+o+xox
# ++++++o
# +++++o+
# +++x+++
# 第 18 步： 玩家 1， 动作 (5, 1)
# oo++o++
# +x+xxx+
# +++o+xx
# o+o+xox
# ++++++o
# +o+++o+
# +++x+++
# 第 19 步： 玩家 -1， 动作 (1, 2)
# oo++o++
# +xxxxx+
# +++o+xx
# o+o+xox
# ++++++o
# +o+++o+
# +++x+++
# 赢家 -1
# 训练 29 回合 0: 收集到 256 条经验
# 训练 29 回合 1: 收集到 208 条经验
# 训练 29 回合 2: 收集到 296 条经验
# 训练 29 回合 3: 收集到 264 条经验
# 训练 29 回合 4: 收集到 160 条经验
# 训练 29 回合 5: 收集到 176 条经验
# 训练 29 回合 6: 收集到 272 条经验
# 训练 29 回合 7: 收集到 200 条经验
# 训练 29 回合 8: 收集到 200 条经验
# 训练 29 回合 9: 收集到 152 条经验
# 训练 29 回合 10: 收集到 136 条经验
# 训练 29 回合 11: 收集到 184 条经验
# 训练 29 回合 12: 收集到 136 条经验
# 训练 29 回合 13: 收集到 160 条经验
# 训练 29 回合 14: 收集到 264 条经验
# 训练 29 回合 15: 收集到 128 条经验

# %% [markdown]
# 中间电脑死机了

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# 第 1 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++++++
# +++++x+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 2 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++o+
# +++++x+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 3 步： 玩家 -1， 动作 (6, 3)
# +++++++
# +++++o+
# +++++x+
# +++++++
# +++++++
# +++++++
# o++x+++
# 第 4 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++++o+
# +++++x+
# +o+++++
# +++++++
# +++++++
# o++x+++
# 第 5 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +++++o+
# +++++x+
# +o++x++
# +++++++
# +++++++
# o++x+++
# 第 6 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++o+
# +++++x+
# +o++xo+
# +++++++
# +++++++
# o++x+++
# 第 7 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++o+
# +++++x+
# +o++xo+
# +x+++++
# +++++++
# o++x+++
# 第 8 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++o++o+
# +++++x+
# +o++xo+
# +x+++++
# +++++++
# o++x+++
# 第 9 步： 玩家 -1， 动作 (4, 2)
# +++++++
# ++o++o+
# +++++x+
# +o++xo+
# +xx++++
# +++++++
# o++x+++
# 第 10 步： 玩家 1， 动作 (5, 5)
# +++++++
# ++o++o+
# +++++x+
# +o++xo+
# +xx++++
# +++++o+
# o++x+++
# 第 11 步： 玩家 -1， 动作 (5, 2)
# +++++++
# ++o++o+
# +++++x+
# +o++xo+
# +xx++++
# ++x++o+
# o++x+++
# 第 12 步： 玩家 1， 动作 (4, 4)
# +++++++
# ++o++o+
# +++++x+
# +o++xo+
# +xx+o++
# ++x++o+
# o++x+++
# 第 13 步： 玩家 -1， 动作 (3, 6)
# +++++++
# ++o++o+
# +++++x+
# +o++xox
# +xx+o++
# ++x++o+
# o++x+++
# 第 14 步： 玩家 1， 动作 (2, 4)
# +++++++
# ++o++o+
# ++++ox+
# +o++xox
# +xx+o++
# ++x++o+
# o++x+++
# 第 15 步： 玩家 -1， 动作 (3, 2)
# +++++++
# ++o++o+
# ++++ox+
# +ox+xox
# +xx+o++
# ++x++o+
# o++x+++
# 第 16 步： 玩家 1， 动作 (5, 1)
# +++++++
# ++o++o+
# ++++ox+
# +ox+xox
# +xx+o++
# +ox++o+
# o++x+++
# 第 17 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++o++ox
# ++++ox+
# +ox+xox
# +xx+o++
# +ox++o+
# o++x+++
# 第 18 步： 玩家 1， 动作 (2, 3)
# +++++++
# ++o++ox
# +++oox+
# +ox+xox
# +xx+o++
# +ox++o+
# o++x+++
# 第 19 步： 玩家 -1， 动作 (0, 0)
# x++++++
# ++o++ox
# +++oox+
# +ox+xox
# +xx+o++
# +ox++o+
# o++x+++
# 第 20 步： 玩家 1， 动作 (5, 3)
# x++++++
# ++o++ox
# +++oox+
# +ox+xox
# +xx+o++
# +oxo+o+
# o++x+++
# 第 21 步： 玩家 -1， 动作 (4, 3)
# x++++++
# ++o++ox
# +++oox+
# +ox+xox
# +xxxo++
# +oxo+o+
# o++x+++
# 赢家 -1

# %% [markdown]
# ## 训练2 train_iterations = 10 由于之前调试代码时第28次迭代已经训练完成，因此从第29次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 29
iteration_old_save_model = 28
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 29 回合 0: 收集到 176 条经验
# 训练 29 回合 1: 收集到 240 条经验
# 训练 29 回合 2: 收集到 248 条经验
# 训练 29 回合 3: 收集到 272 条经验
# 训练 29 回合 4: 收集到 296 条经验
# 训练 29 回合 5: 收集到 152 条经验
# 训练 29 回合 6: 收集到 184 条经验
# 训练 29 回合 7: 收集到 152 条经验
# 训练 29 回合 8: 收集到 192 条经验
# 训练 29 回合 9: 收集到 200 条经验
# 训练 29 回合 10: 收集到 136 条经验
# 训练 29 回合 11: 收集到 208 条经验
# 训练 29 回合 12: 收集到 240 条经验
# 训练 29 回合 13: 收集到 152 条经验
# 训练 29 回合 14: 收集到 200 条经验
# 训练 29 回合 15: 收集到 216 条经验
# 训练 29 回合 16: 收集到 224 条经验
# 训练 29 回合 17: 收集到 232 条经验
# 训练 29 回合 18: 收集到 192 条经验
# 训练 29 回合 19: 收集到 200 条经验
# 训练 29：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0029/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 1)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +x+++++
# 第 2 步： 玩家 1， 动作 (0, 0)
# o++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +x+++++
# 第 3 步： 玩家 -1， 动作 (5, 5)
# o++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++x+
# +x+++++
# 第 4 步： 玩家 1， 动作 (4, 5)
# o++++++
# +++++++
# +++++++
# +++o+++
# +++++o+
# +++++x+
# +x+++++
# 第 5 步： 玩家 -1， 动作 (2, 1)
# o++++++
# +++++++
# +x+++++
# +++o+++
# +++++o+
# +++++x+
# +x+++++
# 第 6 步： 玩家 1， 动作 (0, 1)
# oo+++++
# +++++++
# +x+++++
# +++o+++
# +++++o+
# +++++x+
# +x+++++
# 第 7 步： 玩家 -1， 动作 (4, 2)
# oo+++++
# +++++++
# +x+++++
# +++o+++
# ++x++o+
# +++++x+
# +x+++++
# 第 8 步： 玩家 1， 动作 (5, 6)
# oo+++++
# +++++++
# +x+++++
# +++o+++
# ++x++o+
# +++++xo
# +x+++++
# 第 9 步： 玩家 -1， 动作 (3, 5)
# oo+++++
# +++++++
# +x+++++
# +++o+x+
# ++x++o+
# +++++xo
# +x+++++
# 第 10 步： 玩家 1， 动作 (5, 3)
# oo+++++
# +++++++
# +x+++++
# +++o+x+
# ++x++o+
# +++o+xo
# +x+++++
# 第 11 步： 玩家 -1， 动作 (0, 4)
# oo++x++
# +++++++
# +x+++++
# +++o+x+
# ++x++o+
# +++o+xo
# +x+++++
# 第 12 步： 玩家 1， 动作 (1, 1)
# oo++x++
# +o+++++
# +x+++++
# +++o+x+
# ++x++o+
# +++o+xo
# +x+++++
# 第 13 步： 玩家 -1， 动作 (1, 0)
# oo++x++
# xo+++++
# +x+++++
# +++o+x+
# ++x++o+
# +++o+xo
# +x+++++
# 第 14 步： 玩家 1， 动作 (6, 0)
# oo++x++
# xo+++++
# +x+++++
# +++o+x+
# ++x++o+
# +++o+xo
# ox+++++
# 第 15 步： 玩家 -1， 动作 (3, 4)
# oo++x++
# xo+++++
# +x+++++
# +++oxx+
# ++x++o+
# +++o+xo
# ox+++++
# 第 16 步： 玩家 1， 动作 (2, 2)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# ++x++o+
# +++o+xo
# ox+++++
# 第 17 步： 玩家 -1， 动作 (6, 4)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# ++x++o+
# +++o+xo
# ox++x++
# 第 18 步： 玩家 1， 动作 (4, 0)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# o+x++o+
# +++o+xo
# ox++x++
# 第 19 步： 玩家 -1， 动作 (4, 3)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# o+xx+o+
# +++o+xo
# ox++x++
# 第 20 步： 玩家 1， 动作 (5, 0)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# o+xx+o+
# o++o+xo
# ox++x++
# 第 21 步： 玩家 -1， 动作 (5, 1)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# o+xx+o+
# ox+o+xo
# ox++x++
# 第 22 步： 玩家 1， 动作 (4, 4)
# oo++x++
# xo+++++
# +xo++++
# +++oxx+
# o+xxoo+
# ox+o+xo
# ox++x++
# 赢家 1
# 训练 30 回合 0: 收集到 240 条经验
# 训练 30 回合 1: 收集到 264 条经验
# 训练 30 回合 2: 收集到 184 条经验
# 训练 30 回合 3: 收集到 216 条经验
# 训练 30 回合 4: 收集到 144 条经验
# 训练 30 回合 5: 收集到 184 条经验
# 训练 30 回合 6: 收集到 256 条经验
# 训练 30 回合 7: 收集到 200 条经验
# 训练 30 回合 8: 收集到 248 条经验
# 训练 30 回合 9: 收集到 160 条经验
# 训练 30 回合 10: 收集到 216 条经验
# 训练 30 回合 11: 收集到 392 条经验
# 训练 30 回合 12: 收集到 200 条经验
# 训练 30 回合 13: 收集到 280 条经验
# 训练 30 回合 14: 收集到 216 条经验
# 训练 30 回合 15: 收集到 168 条经验
# 训练 30 回合 16: 收集到 128 条经验
# 训练 30 回合 17: 收集到 280 条经验
# 训练 30 回合 18: 收集到 192 条经验
# 训练 30 回合 19: 收集到 264 条经验
# 训练 30：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0030/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++++++
# +++x+++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 4)
# +++++++
# ++++o++
# +++x+++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 1)
# +++++++
# ++++o++
# +x+x+++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 1)
# +++++++
# ++++o++
# +x+x+++
# +++++++
# +oo++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 1)
# +++++++
# +x++o++
# +x+x+++
# +++++++
# +oo++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 3)
# +++++++
# +x++o++
# +x+x+++
# +++o+++
# +oo++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +x++o++
# +x+x+x+
# +++o+++
# +oo++++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (5, 2)
# +++++++
# +x++o++
# +x+x+x+
# +++o+++
# +oo++++
# ++o++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 5)
# +++++++
# +x++o++
# +x+x+x+
# +++o+x+
# +oo++++
# ++o++++
# +++++++
# 第 10 步： 玩家 1， 动作 (2, 2)
# +++++++
# +x++o++
# +xox+x+
# +++o+x+
# +oo++++
# ++o++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +x++o++
# +xox+x+
# +++oxx+
# +oo++++
# ++o++++
# +++++++
# 第 12 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +x++o++
# +xox+x+
# +++oxx+
# +oo++++
# ++o++++
# +++++++
# 第 13 步： 玩家 -1， 动作 (3, 1)
# +++++o+
# +x++o++
# +xox+x+
# +x+oxx+
# +oo++++
# ++o++++
# +++++++
# 第 14 步： 玩家 1， 动作 (3, 2)
# +++++o+
# +x++o++
# +xox+x+
# +xooxx+
# +oo++++
# ++o++++
# +++++++
# 第 15 步： 玩家 -1， 动作 (5, 4)
# +++++o+
# +x++o++
# +xox+x+
# +xooxx+
# +oo++++
# ++o+x++
# +++++++
# 第 16 步： 玩家 1， 动作 (4, 5)
# +++++o+
# +x++o++
# +xox+x+
# +xooxx+
# +oo++o+
# ++o+x++
# +++++++
# 第 17 步： 玩家 -1， 动作 (6, 1)
# +++++o+
# +x++o++
# +xox+x+
# +xooxx+
# +oo++o+
# ++o+x++
# +x+++++
# 第 18 步： 玩家 1， 动作 (1, 2)
# +++++o+
# +xo+o++
# +xox+x+
# +xooxx+
# +oo++o+
# ++o+x++
# +x+++++
# 赢家 1
# 训练 31 回合 0: 收集到 184 条经验
# 训练 31 回合 1: 收集到 160 条经验
# 训练 31 回合 2: 收集到 120 条经验
# 训练 31 回合 3: 收集到 208 条经验
# 训练 31 回合 4: 收集到 104 条经验
# 训练 31 回合 5: 收集到 304 条经验
# 训练 31 回合 6: 收集到 224 条经验
# 训练 31 回合 7: 收集到 184 条经验
# 训练 31 回合 8: 收集到 296 条经验
# 训练 31 回合 9: 收集到 184 条经验
# 训练 31 回合 10: 收集到 208 条经验
# 训练 31 回合 11: 收集到 208 条经验
# 训练 31 回合 12: 收集到 248 条经验
# 训练 31 回合 13: 收集到 200 条经验
# 训练 31 回合 14: 收集到 264 条经验
# 训练 31 回合 15: 收集到 152 条经验
# 训练 31 回合 16: 收集到 200 条经验
# 训练 31 回合 17: 收集到 176 条经验
# 训练 31 回合 18: 收集到 240 条经验
# 训练 31 回合 19: 收集到 216 条经验
# 训练 31：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0031/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# x++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# ++++o++
# x++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 3)
# +++x+++
# +++++++
# ++++o++
# +++++++
# ++++o++
# x++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 5)
# +++x+++
# +++++++
# ++++o++
# +++++o+
# ++++o++
# x++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 3)
# +++x+++
# +++++++
# ++++o++
# +++x+o+
# ++++o++
# x++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 1)
# +++x+++
# +++++++
# ++++o++
# +++x+o+
# ++++o++
# x++++++
# +o+++++
# 第 7 步： 玩家 -1， 动作 (3, 6)
# +++x+++
# +++++++
# ++++o++
# +++x+ox
# ++++o++
# x++++++
# +o+++++
# 第 8 步： 玩家 1， 动作 (5, 1)
# +++x+++
# +++++++
# ++++o++
# +++x+ox
# ++++o++
# xo+++++
# +o+++++
# 第 9 步： 玩家 -1， 动作 (5, 4)
# +++x+++
# +++++++
# ++++o++
# +++x+ox
# ++++o++
# xo++x++
# +o+++++
# 第 10 步： 玩家 1， 动作 (3, 4)
# +++x+++
# +++++++
# ++++o++
# +++xoox
# ++++o++
# xo++x++
# +o+++++
# 第 11 步： 玩家 -1， 动作 (1, 2)
# +++x+++
# ++x++++
# ++++o++
# +++xoox
# ++++o++
# xo++x++
# +o+++++
# 第 12 步： 玩家 1， 动作 (0, 0)
# o++x+++
# ++x++++
# ++++o++
# +++xoox
# ++++o++
# xo++x++
# +o+++++
# 第 13 步： 玩家 -1， 动作 (2, 3)
# o++x+++
# ++x++++
# +++xo++
# +++xoox
# ++++o++
# xo++x++
# +o+++++
# 第 14 步： 玩家 1， 动作 (3, 1)
# o++x+++
# ++x++++
# +++xo++
# +o+xoox
# ++++o++
# xo++x++
# +o+++++
# 第 15 步： 玩家 -1， 动作 (4, 2)
# o++x+++
# ++x++++
# +++xo++
# +o+xoox
# ++x+o++
# xo++x++
# +o+++++
# 第 16 步： 玩家 1， 动作 (3, 2)
# o++x+++
# ++x++++
# +++xo++
# +ooxoox
# ++x+o++
# xo++x++
# +o+++++
# 第 17 步： 玩家 -1， 动作 (2, 2)
# o++x+++
# ++x++++
# ++xxo++
# +ooxoox
# ++x+o++
# xo++x++
# +o+++++
# 第 18 步： 玩家 1， 动作 (3, 0)
# o++x+++
# ++x++++
# ++xxo++
# oooxoox
# ++x+o++
# xo++x++
# +o+++++
# 第 19 步： 玩家 -1， 动作 (5, 5)
# o++x+++
# ++x++++
# ++xxo++
# oooxoox
# ++x+o++
# xo++xx+
# +o+++++
# 第 20 步： 玩家 1， 动作 (6, 3)
# o++x+++
# ++x++++
# ++xxo++
# oooxoox
# ++x+o++
# xo++xx+
# +o+o+++
# 第 21 步： 玩家 -1， 动作 (0, 4)
# o++xx++
# ++x++++
# ++xxo++
# oooxoox
# ++x+o++
# xo++xx+
# +o+o+++
# 第 22 步： 玩家 1， 动作 (2, 5)
# o++xx++
# ++x++++
# ++xxoo+
# oooxoox
# ++x+o++
# xo++xx+
# +o+o+++
# 第 23 步： 玩家 -1， 动作 (1, 5)
# o++xx++
# ++x++x+
# ++xxoo+
# oooxoox
# ++x+o++
# xo++xx+
# +o+o+++
# 第 24 步： 玩家 1， 动作 (1, 6)
# o++xx++
# ++x++xo
# ++xxoo+
# oooxoox
# ++x+o++
# xo++xx+
# +o+o+++
# 第 25 步： 玩家 -1， 动作 (6, 0)
# o++xx++
# ++x++xo
# ++xxoo+
# oooxoox
# ++x+o++
# xo++xx+
# xo+o+++
# 第 26 步： 玩家 1， 动作 (2, 1)
# o++xx++
# ++x++xo
# +oxxoo+
# oooxoox
# ++x+o++
# xo++xx+
# xo+o+++
# 第 27 步： 玩家 -1， 动作 (0, 2)
# o+xxx++
# ++x++xo
# +oxxoo+
# oooxoox
# ++x+o++
# xo++xx+
# xo+o+++
# 第 28 步： 玩家 1， 动作 (2, 6)
# o+xxx++
# ++x++xo
# +oxxooo
# oooxoox
# ++x+o++
# xo++xx+
# xo+o+++
# 第 29 步： 玩家 -1， 动作 (0, 5)
# o+xxxx+
# ++x++xo
# +oxxooo
# oooxoox
# ++x+o++
# xo++xx+
# xo+o+++
# 第 30 步： 玩家 1， 动作 (4, 1)
# o+xxxx+
# ++x++xo
# +oxxooo
# oooxoox
# +ox+o++
# xo++xx+
# xo+o+++
# 赢家 1
# 训练 32 回合 0: 收集到 248 条经验
# 训练 32 回合 1: 收集到 184 条经验
# 训练 32 回合 2: 收集到 272 条经验
# 训练 32 回合 3: 收集到 296 条经验
# 训练 32 回合 4: 收集到 248 条经验
# 训练 32 回合 5: 收集到 224 条经验
# 训练 32 回合 6: 收集到 240 条经验
# 训练 32 回合 7: 收集到 184 条经验
# 训练 32 回合 8: 收集到 192 条经验
# 训练 32 回合 9: 收集到 152 条经验
# 训练 32 回合 10: 收集到 296 条经验
# 训练 32 回合 11: 收集到 296 条经验
# 训练 32 回合 12: 收集到 280 条经验
# 训练 32 回合 13: 收集到 184 条经验
# 训练 32 回合 14: 收集到 184 条经验
# 训练 32 回合 15: 收集到 264 条经验
# 训练 32 回合 16: 收集到 152 条经验
# 训练 32 回合 17: 收集到 240 条经验
# 训练 32 回合 18: 收集到 200 条经验
# 训练 32 回合 19: 收集到 136 条经验
# 训练 32：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0032/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 2)
# +++++++
# ++x++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 1)
# +++++++
# ++x++++
# +++++++
# +++o+++
# +++++++
# +o+++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 0)
# +++++++
# ++x++++
# +++++++
# +++o+++
# x++++++
# +o+++++
# +++++++
# 第 4 步： 玩家 1， 动作 (1, 1)
# +++++++
# +ox++++
# +++++++
# +++o+++
# x++++++
# +o+++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +ox++++
# +++++++
# +++o+++
# x++++++
# +o+++++
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 1)
# x++++++
# +ox++++
# +++++++
# +++o+++
# x++++++
# +o+++++
# +o+++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# x++++++
# +ox++++
# +++++x+
# +++o+++
# x++++++
# +o+++++
# +o+++++
# 第 8 步： 玩家 1， 动作 (1, 4)
# x++++++
# +ox+o++
# +++++x+
# +++o+++
# x++++++
# +o+++++
# +o+++++
# 第 9 步： 玩家 -1， 动作 (3, 4)
# x++++++
# +ox+o++
# +++++x+
# +++ox++
# x++++++
# +o+++++
# +o+++++
# 第 10 步： 玩家 1， 动作 (5, 3)
# x++++++
# +ox+o++
# +++++x+
# +++ox++
# x++++++
# +o+o+++
# +o+++++
# 第 11 步： 玩家 -1， 动作 (4, 4)
# x++++++
# +ox+o++
# +++++x+
# +++ox++
# x+++x++
# +o+o+++
# +o+++++
# 第 12 步： 玩家 1， 动作 (4, 2)
# x++++++
# +ox+o++
# +++++x+
# +++ox++
# x+o+x++
# +o+o+++
# +o+++++
# 第 13 步： 玩家 -1， 动作 (1, 0)
# x++++++
# xox+o++
# +++++x+
# +++ox++
# x+o+x++
# +o+o+++
# +o+++++
# 第 14 步： 玩家 1， 动作 (4, 6)
# x++++++
# xox+o++
# +++++x+
# +++ox++
# x+o+x+o
# +o+o+++
# +o+++++
# 第 15 步： 玩家 -1， 动作 (3, 5)
# x++++++
# xox+o++
# +++++x+
# +++oxx+
# x+o+x+o
# +o+o+++
# +o+++++
# 第 16 步： 玩家 1， 动作 (2, 2)
# x++++++
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+o+++
# +o+++++
# 第 17 步： 玩家 -1， 动作 (6, 6)
# x++++++
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+o+++
# +o++++x
# 第 18 步： 玩家 1， 动作 (0, 5)
# x++++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+o+++
# +o++++x
# 第 19 步： 玩家 -1， 动作 (6, 4)
# x++++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+o+++
# +o++x+x
# 第 20 步： 玩家 1， 动作 (5, 4)
# x++++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+oo++
# +o++x+x
# 第 21 步： 玩家 -1， 动作 (0, 1)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+o+x+o
# +o+oo++
# +o++x+x
# 第 22 步： 玩家 1， 动作 (4, 3)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+oox+o
# +o+oo++
# +o++x+x
# 第 23 步： 玩家 -1， 动作 (5, 2)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# x+oox+o
# +oxoo++
# +o++x+x
# 第 24 步： 玩家 1， 动作 (4, 1)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# xooox+o
# +oxoo++
# +o++x+x
# 第 25 步： 玩家 -1， 动作 (6, 5)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# xooox+o
# +oxoo++
# +o++xxx
# 第 26 步： 玩家 1， 动作 (6, 0)
# xx+++o+
# xox+o++
# ++o++x+
# +++oxx+
# xooox+o
# +oxoo++
# oo++xxx
# 第 27 步： 玩家 -1， 动作 (0, 2)
# xxx++o+
# xox+o++
# ++o++x+
# +++oxx+
# xooox+o
# +oxoo++
# oo++xxx
# 第 28 步： 玩家 1， 动作 (2, 4)
# xxx++o+
# xox+o++
# ++o+ox+
# +++oxx+
# xooox+o
# +oxoo++
# oo++xxx
# 赢家 1
# 训练 33 回合 0: 收集到 152 条经验
# 训练 33 回合 1: 收集到 200 条经验
# 训练 33 回合 2: 收集到 272 条经验
# 训练 33 回合 3: 收集到 160 条经验
# 训练 33 回合 4: 收集到 216 条经验
# 训练 33 回合 5: 收集到 248 条经验
# 训练 33 回合 6: 收集到 352 条经验
# 训练 33 回合 7: 收集到 176 条经验
# 训练 33 回合 8: 收集到 392 条经验
# 训练 33 回合 9: 收集到 112 条经验
# 训练 33 回合 10: 收集到 200 条经验
# 训练 33 回合 11: 收集到 304 条经验
# 训练 33 回合 12: 收集到 224 条经验
# 训练 33 回合 13: 收集到 208 条经验
# 训练 33 回合 14: 收集到 272 条经验
# 训练 33 回合 15: 收集到 184 条经验
# 训练 33 回合 16: 收集到 168 条经验
# 训练 33 回合 17: 收集到 264 条经验
# 训练 33 回合 18: 收集到 296 条经验
# 训练 33 回合 19: 收集到 176 条经验
# 训练 33：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0033/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 6)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# ++++++x
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++o+
# ++++++x
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# ++++x++
# +++o+++
# +++++o+
# ++++++x
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 3)
# +++++++
# +++++++
# ++++x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x+x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 6 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# ++x+x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 7 步： 玩家 -1， 动作 (1, 6)
# +++++++
# +++o++x
# ++x+x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 8 步： 玩家 1， 动作 (2, 0)
# +++++++
# +++o++x
# o+x+x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 2)
# +++++++
# ++xo++x
# o+x+x++
# +++o+++
# +++o+o+
# ++++++x
# +++++++
# 第 10 步： 玩家 1， 动作 (5, 3)
# +++++++
# ++xo++x
# o+x+x++
# +++o+++
# +++o+o+
# +++o++x
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 2)
# +++++++
# ++xo++x
# o+x+x++
# ++xo+++
# +++o+o+
# +++o++x
# +++++++
# 第 12 步： 玩家 1， 动作 (2, 3)
# +++++++
# ++xo++x
# o+xox++
# ++xo+++
# +++o+o+
# +++o++x
# +++++++
# 赢家 1
# 训练 34 回合 0: 收集到 208 条经验
# 训练 34 回合 1: 收集到 264 条经验
# 训练 34 回合 2: 收集到 128 条经验
# 训练 34 回合 3: 收集到 208 条经验
# 训练 34 回合 4: 收集到 248 条经验
# 训练 34 回合 5: 收集到 256 条经验
# 训练 34 回合 6: 收集到 256 条经验
# 训练 34 回合 7: 收集到 168 条经验
# 训练 34 回合 8: 收集到 256 条经验
# 训练 34 回合 9: 收集到 120 条经验
# 训练 34 回合 10: 收集到 232 条经验
# 训练 34 回合 11: 收集到 216 条经验
# 训练 34 回合 12: 收集到 392 条经验
# 训练 34 回合 13: 收集到 272 条经验
# 训练 34 回合 14: 收集到 208 条经验
# 训练 34 回合 15: 收集到 200 条经验
# 训练 34 回合 16: 收集到 152 条经验
# 训练 34 回合 17: 收集到 168 条经验
# 训练 34 回合 18: 收集到 256 条经验
# 训练 34 回合 19: 收集到 216 条经验
# 训练 34：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0034/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 2)
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 3)
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++x+++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 2)
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++x+++
# ++o++++
# 第 3 步： 玩家 -1， 动作 (4, 4)
# ++o++++
# +++++++
# +++++++
# +++++++
# ++++x++
# +++x+++
# ++o++++
# 第 4 步： 玩家 1， 动作 (3, 3)
# ++o++++
# +++++++
# +++++++
# +++o+++
# ++++x++
# +++x+++
# ++o++++
# 第 5 步： 玩家 -1， 动作 (4, 2)
# ++o++++
# +++++++
# +++++++
# +++o+++
# ++x+x++
# +++x+++
# ++o++++
# 第 6 步： 玩家 1， 动作 (4, 5)
# ++o++++
# +++++++
# +++++++
# +++o+++
# ++x+xo+
# +++x+++
# ++o++++
# 第 7 步： 玩家 -1， 动作 (1, 3)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# ++x+xo+
# +++x+++
# ++o++++
# 第 8 步： 玩家 1， 动作 (6, 1)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# ++x+xo+
# +++x+++
# +oo++++
# 第 9 步： 玩家 -1， 动作 (5, 1)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# ++x+xo+
# +x+x+++
# +oo++++
# 第 10 步： 玩家 1， 动作 (6, 4)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# ++x+xo+
# +x+x+++
# +oo+o++
# 第 11 步： 玩家 -1， 动作 (4, 0)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# x+x+xo+
# +x+x+++
# +oo+o++
# 第 12 步： 玩家 1， 动作 (6, 3)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# x+x+xo+
# +x+x+++
# +oooo++
# 第 13 步： 玩家 -1， 动作 (4, 1)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# xxx+xo+
# +x+x+++
# +oooo++
# 第 14 步： 玩家 1， 动作 (6, 5)
# ++o++++
# +++x+++
# +++++++
# +++o+++
# xxx+xo+
# +x+x+++
# +ooooo+
# 赢家 1
# 训练 35 回合 0: 收集到 152 条经验
# 训练 35 回合 1: 收集到 224 条经验
# 训练 35 回合 2: 收集到 176 条经验
# 训练 35 回合 3: 收集到 248 条经验
# 训练 35 回合 4: 收集到 168 条经验
# 训练 35 回合 5: 收集到 208 条经验
# 训练 35 回合 6: 收集到 160 条经验
# 训练 35 回合 7: 收集到 168 条经验
# 训练 35 回合 8: 收集到 328 条经验
# 训练 35 回合 9: 收集到 104 条经验
# 训练 35 回合 10: 收集到 200 条经验
# 训练 35 回合 11: 收集到 296 条经验
# 训练 35 回合 12: 收集到 232 条经验
# 训练 35 回合 13: 收集到 232 条经验
# 训练 35 回合 14: 收集到 296 条经验
# 训练 35 回合 15: 收集到 224 条经验
# 训练 35 回合 16: 收集到 312 条经验
# 训练 35 回合 17: 收集到 192 条经验
# 训练 35 回合 18: 收集到 256 条经验
# 训练 35 回合 19: 收集到 256 条经验
# 训练 35：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0035/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 2)
# +++o+++
# +++++++
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 4)
# +++o+++
# +++++++
# +++++++
# ++++o++
# ++x++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 2)
# +++o+++
# +++++++
# +++++++
# ++++o++
# ++x++++
# ++x++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 0)
# +++o+++
# +++++++
# o++++++
# ++++o++
# ++x++++
# ++x++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 2)
# +++o+++
# +++++++
# o+x++++
# ++++o++
# ++x++++
# ++x++++
# +++++++
# 第 6 步： 玩家 1， 动作 (5, 3)
# +++o+++
# +++++++
# o+x++++
# ++++o++
# ++x++++
# ++xo+++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# +++o+++
# +++++++
# o+x++x+
# ++++o++
# ++x++++
# ++xo+++
# +++++++
# 第 8 步： 玩家 1， 动作 (0, 5)
# +++o+o+
# +++++++
# o+x++x+
# ++++o++
# ++x++++
# ++xo+++
# +++++++
# 第 9 步： 玩家 -1， 动作 (4, 4)
# +++o+o+
# +++++++
# o+x++x+
# ++++o++
# ++x+x++
# ++xo+++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 6)
# +++o+o+
# +++++++
# o+x++x+
# ++++o++
# ++x+x++
# ++xo+++
# ++++++o
# 第 11 步： 玩家 -1， 动作 (4, 5)
# +++o+o+
# +++++++
# o+x++x+
# ++++o++
# ++x+xx+
# ++xo+++
# ++++++o
# 第 12 步： 玩家 1， 动作 (4, 1)
# +++o+o+
# +++++++
# o+x++x+
# ++++o++
# +ox+xx+
# ++xo+++
# ++++++o
# 第 13 步： 玩家 -1， 动作 (3, 5)
# +++o+o+
# +++++++
# o+x++x+
# ++++ox+
# +ox+xx+
# ++xo+++
# ++++++o
# 第 14 步： 玩家 1， 动作 (4, 6)
# +++o+o+
# +++++++
# o+x++x+
# ++++ox+
# +ox+xxo
# ++xo+++
# ++++++o
# 第 15 步： 玩家 -1， 动作 (3, 1)
# +++o+o+
# +++++++
# o+x++x+
# +x++ox+
# +ox+xxo
# ++xo+++
# ++++++o
# 第 16 步： 玩家 1， 动作 (5, 0)
# +++o+o+
# +++++++
# o+x++x+
# +x++ox+
# +ox+xxo
# o+xo+++
# ++++++o
# 第 17 步： 玩家 -1， 动作 (1, 6)
# +++o+o+
# ++++++x
# o+x++x+
# +x++ox+
# +ox+xxo
# o+xo+++
# ++++++o
# 第 18 步： 玩家 1， 动作 (6, 5)
# +++o+o+
# ++++++x
# o+x++x+
# +x++ox+
# +ox+xxo
# o+xo+++
# +++++oo
# 第 19 步： 玩家 -1， 动作 (3, 2)
# +++o+o+
# ++++++x
# o+x++x+
# +xx+ox+
# +ox+xxo
# o+xo+++
# +++++oo
# 第 20 步： 玩家 1， 动作 (3, 3)
# +++o+o+
# ++++++x
# o+x++x+
# +xxoox+
# +ox+xxo
# o+xo+++
# +++++oo
# 第 21 步： 玩家 -1， 动作 (3, 0)
# +++o+o+
# ++++++x
# o+x++x+
# xxxoox+
# +ox+xxo
# o+xo+++
# +++++oo
# 第 22 步： 玩家 1， 动作 (6, 4)
# +++o+o+
# ++++++x
# o+x++x+
# xxxoox+
# +ox+xxo
# o+xo+++
# ++++ooo
# 第 23 步： 玩家 -1， 动作 (2, 4)
# +++o+o+
# ++++++x
# o+x+xx+
# xxxoox+
# +ox+xxo
# o+xo+++
# ++++ooo
# 第 24 步： 玩家 1， 动作 (5, 4)
# +++o+o+
# ++++++x
# o+x+xx+
# xxxoox+
# +ox+xxo
# o+xoo++
# ++++ooo
# 第 25 步： 玩家 -1， 动作 (1, 4)
# +++o+o+
# ++++x+x
# o+x+xx+
# xxxoox+
# +ox+xxo
# o+xoo++
# ++++ooo
# 第 26 步： 玩家 1， 动作 (5, 6)
# +++o+o+
# ++++x+x
# o+x+xx+
# xxxoox+
# +ox+xxo
# o+xoo+o
# ++++ooo
# 第 27 步： 玩家 -1， 动作 (2, 3)
# +++o+o+
# ++++x+x
# o+xxxx+
# xxxoox+
# +ox+xxo
# o+xoo+o
# ++++ooo
# 第 28 步： 玩家 1， 动作 (6, 2)
# +++o+o+
# ++++x+x
# o+xxxx+
# xxxoox+
# +ox+xxo
# o+xoo+o
# ++o+ooo
# 第 29 步： 玩家 -1， 动作 (2, 6)
# +++o+o+
# ++++x+x
# o+xxxxx
# xxxoox+
# +ox+xxo
# o+xoo+o
# ++o+ooo
# 赢家 -1
# 训练 36 回合 0: 收集到 152 条经验
# 训练 36 回合 1: 收集到 216 条经验
# 训练 36 回合 2: 收集到 144 条经验
# 训练 36 回合 3: 收集到 336 条经验
# 训练 36 回合 4: 收集到 192 条经验
# 训练 36 回合 5: 收集到 240 条经验
# 训练 36 回合 6: 收集到 272 条经验
# 训练 36 回合 7: 收集到 176 条经验
# 训练 36 回合 8: 收集到 296 条经验
# 训练 36 回合 9: 收集到 200 条经验
# 训练 36 回合 10: 收集到 160 条经验
# 训练 36 回合 11: 收集到 392 条经验
# 训练 36 回合 12: 收集到 200 条经验
# 训练 36 回合 13: 收集到 392 条经验
# 训练 36 回合 14: 收集到 216 条经验
# 训练 36 回合 15: 收集到 256 条经验
# 训练 36 回合 16: 收集到 184 条经验
# 训练 36 回合 17: 收集到 288 条经验
# 训练 36 回合 18: 收集到 144 条经验
# 训练 36 回合 19: 收集到 192 条经验
# 训练 36：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0036/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 5)
# x++++++
# +++++++
# +++++++
# ++++oo+
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 3)
# x++++++
# +++++++
# +++++++
# +++xoo+
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 5)
# x++++++
# +++++++
# +++++o+
# +++xoo+
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 6)
# x+++++x
# +++++++
# +++++o+
# +++xoo+
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (1, 5)
# x+++++x
# +++++o+
# +++++o+
# +++xoo+
# +++++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (5, 0)
# x+++++x
# +++++o+
# +++++o+
# +++xoo+
# +++++++
# x++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 6)
# x+++++x
# +++++o+
# +++++o+
# +++xoo+
# ++++++o
# x++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 4)
# x+++++x
# ++++xo+
# +++++o+
# +++xoo+
# ++++++o
# x++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (5, 4)
# x+++++x
# ++++xo+
# +++++o+
# +++xoo+
# ++++++o
# x+++o++
# +++++++
# 第 11 步： 玩家 -1， 动作 (0, 1)
# xx++++x
# ++++xo+
# +++++o+
# +++xoo+
# ++++++o
# x+++o++
# +++++++
# 第 12 步： 玩家 1， 动作 (1, 2)
# xx++++x
# ++o+xo+
# +++++o+
# +++xoo+
# ++++++o
# x+++o++
# +++++++
# 第 13 步： 玩家 -1， 动作 (6, 0)
# xx++++x
# ++o+xo+
# +++++o+
# +++xoo+
# ++++++o
# x+++o++
# x++++++
# 第 14 步： 玩家 1， 动作 (6, 4)
# xx++++x
# ++o+xo+
# +++++o+
# +++xoo+
# ++++++o
# x+++o++
# x+++o++
# 第 15 步： 玩家 -1， 动作 (3, 0)
# xx++++x
# ++o+xo+
# +++++o+
# x++xoo+
# ++++++o
# x+++o++
# x+++o++
# 第 16 步： 玩家 1， 动作 (0, 5)
# xx+++ox
# ++o+xo+
# +++++o+
# x++xoo+
# ++++++o
# x+++o++
# x+++o++
# 第 17 步： 玩家 -1， 动作 (4, 3)
# xx+++ox
# ++o+xo+
# +++++o+
# x++xoo+
# +++x++o
# x+++o++
# x+++o++
# 第 18 步： 玩家 1， 动作 (4, 5)
# xx+++ox
# ++o+xo+
# +++++o+
# x++xoo+
# +++x+oo
# x+++o++
# x+++o++
# 赢家 1
# 训练 37 回合 0: 收集到 208 条经验
# 训练 37 回合 1: 收集到 224 条经验
# 训练 37 回合 2: 收集到 240 条经验
# 训练 37 回合 3: 收集到 344 条经验
# 训练 37 回合 4: 收集到 128 条经验
# 训练 37 回合 5: 收集到 248 条经验
# 训练 37 回合 6: 收集到 296 条经验
# 训练 37 回合 7: 收集到 216 条经验
# 训练 37 回合 8: 收集到 248 条经验
# 训练 37 回合 9: 收集到 144 条经验
# 训练 37 回合 10: 收集到 192 条经验
# 训练 37 回合 11: 收集到 160 条经验
# 训练 37 回合 12: 收集到 304 条经验
# 训练 37 回合 13: 收集到 304 条经验
# 训练 37 回合 14: 收集到 256 条经验
# 训练 37 回合 15: 收集到 264 条经验
# 训练 37 回合 16: 收集到 168 条经验
# 训练 37 回合 17: 收集到 192 条经验
# 训练 37 回合 18: 收集到 256 条经验
# 训练 37 回合 19: 收集到 168 条经验
# 训练 37：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0037/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# ++++x++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# ++++x++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++o+++
# ++x+x++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 5)
# +++++++
# +++o+++
# ++x+x++
# +++o+++
# +++++++
# +++++++
# +++++o+
# 第 5 步： 玩家 -1， 动作 (4, 5)
# +++++++
# +++o+++
# ++x+x++
# +++o+++
# +++++x+
# +++++++
# +++++o+
# 第 6 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++o+++
# +ox+x++
# +++o+++
# +++++x+
# +++++++
# +++++o+
# 第 7 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++o+++
# +ox+x++
# +++o+++
# +x+++x+
# +++++++
# +++++o+
# 第 8 步： 玩家 1， 动作 (4, 6)
# +++++++
# +++o+++
# +ox+x++
# +++o+++
# +x+++xo
# +++++++
# +++++o+
# 第 9 步： 玩家 -1， 动作 (2, 0)
# +++++++
# +++o+++
# xox+x++
# +++o+++
# +x+++xo
# +++++++
# +++++o+
# 第 10 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++o+++
# xox+x++
# +++oo++
# +x+++xo
# +++++++
# +++++o+
# 第 11 步： 玩家 -1， 动作 (0, 2)
# ++x++++
# +++o+++
# xox+x++
# +++oo++
# +x+++xo
# +++++++
# +++++o+
# 第 12 步： 玩家 1， 动作 (1, 2)
# ++x++++
# ++oo+++
# xox+x++
# +++oo++
# +x+++xo
# +++++++
# +++++o+
# 第 13 步： 玩家 -1， 动作 (5, 3)
# ++x++++
# ++oo+++
# xox+x++
# +++oo++
# +x+++xo
# +++x+++
# +++++o+
# 第 14 步： 玩家 1， 动作 (5, 1)
# ++x++++
# ++oo+++
# xox+x++
# +++oo++
# +x+++xo
# +o+x+++
# +++++o+
# 第 15 步： 玩家 -1， 动作 (4, 0)
# ++x++++
# ++oo+++
# xox+x++
# +++oo++
# xx+++xo
# +o+x+++
# +++++o+
# 第 16 步： 玩家 1， 动作 (6, 2)
# ++x++++
# ++oo+++
# xox+x++
# +++oo++
# xx+++xo
# +o+x+++
# ++o++o+
# 第 17 步： 玩家 -1， 动作 (2, 3)
# ++x++++
# ++oo+++
# xoxxx++
# +++oo++
# xx+++xo
# +o+x+++
# ++o++o+
# 第 18 步： 玩家 1， 动作 (0, 1)
# +ox++++
# ++oo+++
# xoxxx++
# +++oo++
# xx+++xo
# +o+x+++
# ++o++o+
# 第 19 步： 玩家 -1， 动作 (3, 1)
# +ox++++
# ++oo+++
# xoxxx++
# +x+oo++
# xx+++xo
# +o+x+++
# ++o++o+
# 第 20 步： 玩家 1， 动作 (3, 5)
# +ox++++
# ++oo+++
# xoxxx++
# +x+ooo+
# xx+++xo
# +o+x+++
# ++o++o+
# 第 21 步： 玩家 -1， 动作 (1, 1)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx+++xo
# +o+x+++
# ++o++o+
# 第 22 步： 玩家 1， 动作 (5, 2)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx+++xo
# +oox+++
# ++o++o+
# 第 23 步： 玩家 -1， 动作 (4, 4)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx++xxo
# +oox+++
# ++o++o+
# 第 24 步： 玩家 1， 动作 (4, 3)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx+oxxo
# +oox+++
# ++o++o+
# 第 25 步： 玩家 -1， 动作 (6, 3)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx+oxxo
# +oox+++
# ++ox+o+
# 第 26 步： 玩家 1， 动作 (5, 4)
# +ox++++
# +xoo+++
# xoxxx++
# +x+ooo+
# xx+oxxo
# +ooxo++
# ++ox+o+
# 第 27 步： 玩家 -1， 动作 (3, 2)
# +ox++++
# +xoo+++
# xoxxx++
# +xxooo+
# xx+oxxo
# +ooxo++
# ++ox+o+
# 第 28 步： 玩家 1， 动作 (1, 6)
# +ox++++
# +xoo++o
# xoxxx++
# +xxooo+
# xx+oxxo
# +ooxo++
# ++ox+o+
# 第 29 步： 玩家 -1， 动作 (0, 5)
# +ox++x+
# +xoo++o
# xoxxx++
# +xxooo+
# xx+oxxo
# +ooxo++
# ++ox+o+
# 第 30 步： 玩家 1， 动作 (4, 2)
# +ox++x+
# +xoo++o
# xoxxx++
# +xxooo+
# xxooxxo
# +ooxo++
# ++ox+o+
# 第 31 步： 玩家 -1， 动作 (1, 4)
# +ox++x+
# +xoox+o
# xoxxx++
# +xxooo+
# xxooxxo
# +ooxo++
# ++ox+o+
# 赢家 -1
# 训练 38 回合 0: 收集到 224 条经验
# 训练 38 回合 1: 收集到 248 条经验
# 训练 38 回合 2: 收集到 216 条经验
# 训练 38 回合 3: 收集到 256 条经验
# 训练 38 回合 4: 收集到 248 条经验
# 训练 38 回合 5: 收集到 264 条经验
# 训练 38 回合 6: 收集到 184 条经验
# 训练 38 回合 7: 收集到 296 条经验
# 训练 38 回合 8: 收集到 232 条经验
# 训练 38 回合 9: 收集到 184 条经验
# 训练 38 回合 10: 收集到 216 条经验
# 训练 38 回合 11: 收集到 264 条经验
# 训练 38 回合 12: 收集到 184 条经验
# 训练 38 回合 13: 收集到 208 条经验
# 训练 38 回合 14: 收集到 184 条经验
# 训练 38 回合 15: 收集到 128 条经验
# 训练 38 回合 16: 收集到 256 条经验
# 训练 38 回合 17: 收集到 184 条经验
# 训练 38 回合 18: 收集到 88 条经验
# 训练 38 回合 19: 收集到 152 条经验
# 训练 38：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0038/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# x++++++
# 第 2 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +++++++
# +++++o+
# ++o++++
# +++++++
# x++++++
# 第 3 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++++++x
# +++++++
# +++++o+
# ++o++++
# +++++++
# x++++++
# 第 4 步： 玩家 1， 动作 (5, 6)
# +++++++
# ++++++x
# +++++++
# +++++o+
# ++o++++
# ++++++o
# x++++++
# 第 5 步： 玩家 -1， 动作 (6, 4)
# +++++++
# ++++++x
# +++++++
# +++++o+
# ++o++++
# ++++++o
# x+++x++
# 第 6 步： 玩家 1， 动作 (5, 1)
# +++++++
# ++++++x
# +++++++
# +++++o+
# ++o++++
# +o++++o
# x+++x++
# 第 7 步： 玩家 -1， 动作 (4, 4)
# +++++++
# ++++++x
# +++++++
# +++++o+
# ++o+x++
# +o++++o
# x+++x++
# 第 8 步： 玩家 1， 动作 (0, 2)
# ++o++++
# ++++++x
# +++++++
# +++++o+
# ++o+x++
# +o++++o
# x+++x++
# 第 9 步： 玩家 -1， 动作 (5, 3)
# ++o++++
# ++++++x
# +++++++
# +++++o+
# ++o+x++
# +o+x++o
# x+++x++
# 第 10 步： 玩家 1， 动作 (3, 1)
# ++o++++
# ++++++x
# +++++++
# +o+++o+
# ++o+x++
# +o+x++o
# x+++x++
# 第 11 步： 玩家 -1， 动作 (0, 6)
# ++o+++x
# ++++++x
# +++++++
# +o+++o+
# ++o+x++
# +o+x++o
# x+++x++
# 第 12 步： 玩家 1， 动作 (3, 2)
# ++o+++x
# ++++++x
# +++++++
# +oo++o+
# ++o+x++
# +o+x++o
# x+++x++
# 第 13 步： 玩家 -1， 动作 (3, 6)
# ++o+++x
# ++++++x
# +++++++
# +oo++ox
# ++o+x++
# +o+x++o
# x+++x++
# 第 14 步： 玩家 1， 动作 (3, 4)
# ++o+++x
# ++++++x
# +++++++
# +oo+oox
# ++o+x++
# +o+x++o
# x+++x++
# 第 15 步： 玩家 -1， 动作 (4, 6)
# ++o+++x
# ++++++x
# +++++++
# +oo+oox
# ++o+x+x
# +o+x++o
# x+++x++
# 第 16 步： 玩家 1， 动作 (3, 3)
# ++o+++x
# ++++++x
# +++++++
# +ooooox
# ++o+x+x
# +o+x++o
# x+++x++
# 赢家 1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++x++
# ++++++o
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 1)
# +o+++++
# +++++++
# +++++++
# +++++++
# ++++x++
# ++++++o
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 0)
# +o+++++
# x++++++
# +++++++
# +++++++
# ++++x++
# ++++++o
# +++++++
# 第 4 步： 玩家 1， 动作 (5, 0)
# +o+++++
# x++++++
# +++++++
# +++++++
# ++++x++
# o+++++o
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 1)
# +o+++++
# x++++++
# +++++++
# +x+++++
# ++++x++
# o+++++o
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 6)
# +o+++++
# x++++++
# +++++++
# +x++++o
# ++++x++
# o+++++o
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 1)
# +o+++++
# x++++++
# +++++++
# +x++++o
# +x++x++
# o+++++o
# +++++++
# 第 8 步： 玩家 1， 动作 (2, 4)
# +o+++++
# x++++++
# ++++o++
# +x++++o
# +x++x++
# o+++++o
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 3)
# +o+++++
# x++x+++
# ++++o++
# +x++++o
# +x++x++
# o+++++o
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 6)
# +o++++o
# x++x+++
# ++++o++
# +x++++o
# +x++x++
# o+++++o
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 1)
# +o++++o
# x++x+++
# ++++o++
# +x++++o
# +x++x++
# o+++++o
# +x+++++
# 第 12 步： 玩家 1， 动作 (0, 2)
# +oo+++o
# x++x+++
# ++++o++
# +x++++o
# +x++x++
# o+++++o
# +x+++++
# 第 13 步： 玩家 -1， 动作 (3, 5)
# +oo+++o
# x++x+++
# ++++o++
# +x+++xo
# +x++x++
# o+++++o
# +x+++++
# 第 14 步： 玩家 1， 动作 (2, 6)
# +oo+++o
# x++x+++
# ++++o+o
# +x+++xo
# +x++x++
# o+++++o
# +x+++++
# 第 15 步： 玩家 -1， 动作 (3, 2)
# +oo+++o
# x++x+++
# ++++o+o
# +xx++xo
# +x++x++
# o+++++o
# +x+++++
# 第 16 步： 玩家 1， 动作 (4, 6)
# +oo+++o
# x++x+++
# ++++o+o
# +xx++xo
# +x++x+o
# o+++++o
# +x+++++
# 第 17 步： 玩家 -1， 动作 (2, 2)
# +oo+++o
# x++x+++
# ++x+o+o
# +xx++xo
# +x++x+o
# o+++++o
# +x+++++
# 第 18 步： 玩家 1， 动作 (3, 0)
# +oo+++o
# x++x+++
# ++x+o+o
# oxx++xo
# +x++x+o
# o+++++o
# +x+++++
# 第 19 步： 玩家 -1， 动作 (0, 5)
# +oo++xo
# x++x+++
# ++x+o+o
# oxx++xo
# +x++x+o
# o+++++o
# +x+++++
# 第 20 步： 玩家 1， 动作 (1, 6)
# +oo++xo
# x++x++o
# ++x+o+o
# oxx++xo
# +x++x+o
# o+++++o
# +x+++++
# 赢家 1

# %% [markdown]
# ## 训练3 train_iterations = 10 从第39次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 39
iteration_old_save_model = 38
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 39 回合 0: 收集到 224 条经验
# 训练 39 回合 1: 收集到 224 条经验
# 训练 39 回合 2: 收集到 232 条经验
# 训练 39 回合 3: 收集到 168 条经验
# 训练 39 回合 4: 收集到 200 条经验
# 训练 39 回合 5: 收集到 176 条经验
# 训练 39 回合 6: 收集到 280 条经验
# 训练 39 回合 7: 收集到 304 条经验
# 训练 39 回合 8: 收集到 128 条经验
# 训练 39 回合 9: 收集到 152 条经验
# 训练 39 回合 10: 收集到 152 条经验
# 训练 39 回合 11: 收集到 232 条经验
# 训练 39 回合 12: 收集到 168 条经验
# 训练 39 回合 13: 收集到 208 条经验
# 训练 39 回合 14: 收集到 128 条经验
# 训练 39 回合 15: 收集到 168 条经验
# 训练 39 回合 16: 收集到 392 条经验
# 训练 39 回合 17: 收集到 200 条经验
# 训练 39 回合 18: 收集到 288 条经验
# 训练 39 回合 19: 收集到 208 条经验
# 训练 39：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0039/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 3)
# +++++++
# ++o++++
# +++++++
# +++x+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 6)
# +++++++
# ++o++++
# +++++++
# +++x++o
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 5)
# +++++++
# ++o++++
# +++++++
# +++x+xo
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 5)
# +++++++
# ++o++++
# +++++o+
# +++x+xo
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++o++++
# +++++o+
# +++x+xo
# +++++++
# x++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 4)
# +++++++
# ++o++++
# +++++o+
# +++xoxo
# +++++++
# x++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 3)
# +++++++
# ++o++++
# +++++o+
# +++xoxo
# +++x+++
# x++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 2)
# +++++++
# ++o++++
# +++++o+
# +++xoxo
# ++ox+++
# x++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 0)
# +++++++
# ++o++++
# +++++o+
# x++xoxo
# ++ox+++
# x++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (5, 3)
# +++++++
# ++o++++
# +++++o+
# x++xoxo
# ++ox+++
# x++o+++
# +++++++
# 第 11 步： 玩家 -1， 动作 (6, 0)
# +++++++
# ++o++++
# +++++o+
# x++xoxo
# ++ox+++
# x++o+++
# x++++++
# 第 12 步： 玩家 1， 动作 (2, 2)
# +++++++
# ++o++++
# ++o++o+
# x++xoxo
# ++ox+++
# x++o+++
# x++++++
# 第 13 步： 玩家 -1， 动作 (1, 3)
# +++++++
# ++ox+++
# ++o++o+
# x++xoxo
# ++ox+++
# x++o+++
# x++++++
# 第 14 步： 玩家 1， 动作 (2, 4)
# +++++++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++ox+++
# x++o+++
# x++++++
# 第 15 步： 玩家 -1， 动作 (5, 1)
# +++++++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++ox+++
# xx+o+++
# x++++++
# 第 16 步： 玩家 1， 动作 (0, 4)
# ++++o++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++ox+++
# xx+o+++
# x++++++
# 第 17 步： 玩家 -1， 动作 (6, 5)
# ++++o++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++ox+++
# xx+o+++
# x++++x+
# 第 18 步： 玩家 1， 动作 (4, 4)
# ++++o++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++oxo++
# xx+o+++
# x++++x+
# 第 19 步： 玩家 -1， 动作 (0, 1)
# +x++o++
# ++ox+++
# ++o+oo+
# x++xoxo
# ++oxo++
# xx+o+++
# x++++x+
# 第 20 步： 玩家 1， 动作 (1, 4)
# +x++o++
# ++oxo++
# ++o+oo+
# x++xoxo
# ++oxo++
# xx+o+++
# x++++x+
# 赢家 1
# 训练 40 回合 0: 收集到 232 条经验
# 训练 40 回合 1: 收集到 232 条经验
# 训练 40 回合 2: 收集到 208 条经验
# 训练 40 回合 3: 收集到 272 条经验
# 训练 40 回合 4: 收集到 240 条经验
# 训练 40 回合 5: 收集到 272 条经验
# 训练 40 回合 6: 收集到 240 条经验
# 训练 40 回合 7: 收集到 152 条经验
# 训练 40 回合 8: 收集到 280 条经验
# 训练 40 回合 9: 收集到 192 条经验
# 训练 40 回合 10: 收集到 272 条经验
# 训练 40 回合 11: 收集到 216 条经验
# 训练 40 回合 12: 收集到 120 条经验
# 训练 40 回合 13: 收集到 200 条经验
# 训练 40 回合 14: 收集到 304 条经验
# 训练 40 回合 15: 收集到 192 条经验
# 训练 40 回合 16: 收集到 224 条经验
# 训练 40 回合 17: 收集到 272 条经验
# 训练 40 回合 18: 收集到 224 条经验
# 训练 40 回合 19: 收集到 208 条经验
# 训练 40：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0040/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 5)
# +x+++o+
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 3 步： 玩家 -1， 动作 (6, 5)
# +x+++o+
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++x+
# 第 4 步： 玩家 1， 动作 (3, 0)
# +x+++o+
# +++++++
# +++++++
# o++++++
# +++++++
# ++++o++
# +++++x+
# 第 5 步： 玩家 -1， 动作 (4, 2)
# +x+++o+
# +++++++
# +++++++
# o++++++
# ++x++++
# ++++o++
# +++++x+
# 第 6 步： 玩家 1， 动作 (5, 5)
# +x+++o+
# +++++++
# +++++++
# o++++++
# ++x++++
# ++++oo+
# +++++x+
# 第 7 步： 玩家 -1， 动作 (5, 6)
# +x+++o+
# +++++++
# +++++++
# o++++++
# ++x++++
# ++++oox
# +++++x+
# 第 8 步： 玩家 1， 动作 (3, 6)
# +x+++o+
# +++++++
# +++++++
# o+++++o
# ++x++++
# ++++oox
# +++++x+
# 第 9 步： 玩家 -1， 动作 (4, 5)
# +x+++o+
# +++++++
# +++++++
# o+++++o
# ++x++x+
# ++++oox
# +++++x+
# 第 10 步： 玩家 1， 动作 (3, 2)
# +x+++o+
# +++++++
# +++++++
# o+o+++o
# ++x++x+
# ++++oox
# +++++x+
# 第 11 步： 玩家 -1， 动作 (1, 3)
# +x+++o+
# +++x+++
# +++++++
# o+o+++o
# ++x++x+
# ++++oox
# +++++x+
# 第 12 步： 玩家 1， 动作 (3, 5)
# +x+++o+
# +++x+++
# +++++++
# o+o++oo
# ++x++x+
# ++++oox
# +++++x+
# 第 13 步： 玩家 -1， 动作 (3, 3)
# +x+++o+
# +++x+++
# +++++++
# o+ox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 14 步： 玩家 1， 动作 (2, 4)
# +x+++o+
# +++x+++
# ++++o++
# o+ox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 15 步： 玩家 -1， 动作 (1, 2)
# +x+++o+
# ++xx+++
# ++++o++
# o+ox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 16 步： 玩家 1， 动作 (3, 1)
# +x+++o+
# ++xx+++
# ++++o++
# ooox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 17 步： 玩家 -1， 动作 (2, 3)
# +x+++o+
# ++xx+++
# +++xo++
# ooox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 18 步： 玩家 1， 动作 (2, 2)
# +x+++o+
# ++xx+++
# ++oxo++
# ooox+oo
# ++x++x+
# ++++oox
# +++++x+
# 第 19 步： 玩家 -1， 动作 (3, 4)
# +x+++o+
# ++xx+++
# ++oxo++
# oooxxoo
# ++x++x+
# ++++oox
# +++++x+
# 赢家 -1
# 训练 41 回合 0: 收集到 176 条经验
# 训练 41 回合 1: 收集到 200 条经验
# 训练 41 回合 2: 收集到 192 条经验
# 训练 41 回合 3: 收集到 104 条经验
# 训练 41 回合 4: 收集到 312 条经验
# 训练 41 回合 5: 收集到 256 条经验
# 训练 41 回合 6: 收集到 272 条经验
# 训练 41 回合 7: 收集到 248 条经验
# 训练 41 回合 8: 收集到 240 条经验
# 训练 41 回合 9: 收集到 176 条经验
# 训练 41 回合 10: 收集到 248 条经验
# 训练 41 回合 11: 收集到 192 条经验
# 训练 41 回合 12: 收集到 176 条经验
# 训练 41 回合 13: 收集到 224 条经验
# 训练 41 回合 14: 收集到 240 条经验
# 训练 41 回合 15: 收集到 264 条经验
# 训练 41 回合 16: 收集到 216 条经验
# 训练 41 回合 17: 收集到 280 条经验
# 训练 41 回合 18: 收集到 240 条经验
# 训练 41 回合 19: 收集到 216 条经验
# 训练 41：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0041/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# ++x++++
# 第 2 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# ++x+o++
# 第 3 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++++++x
# +++++++
# +++++++
# +++++++
# +++o+++
# ++x+o++
# 第 4 步： 玩家 1， 动作 (4, 1)
# +++++++
# ++++++x
# +++++++
# +++++++
# +o+++++
# +++o+++
# ++x+o++
# 第 5 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++++++x
# +++++++
# +++++++
# +o+++++
# x++o+++
# ++x+o++
# 第 6 步： 玩家 1， 动作 (6, 5)
# +++++++
# ++++++x
# +++++++
# +++++++
# +o+++++
# x++o+++
# ++x+oo+
# 第 7 步： 玩家 -1， 动作 (1, 1)
# +++++++
# +x++++x
# +++++++
# +++++++
# +o+++++
# x++o+++
# ++x+oo+
# 第 8 步： 玩家 1， 动作 (0, 0)
# o++++++
# +x++++x
# +++++++
# +++++++
# +o+++++
# x++o+++
# ++x+oo+
# 第 9 步： 玩家 -1， 动作 (3, 2)
# o++++++
# +x++++x
# +++++++
# ++x++++
# +o+++++
# x++o+++
# ++x+oo+
# 第 10 步： 玩家 1， 动作 (1, 3)
# o++++++
# +x+o++x
# +++++++
# ++x++++
# +o+++++
# x++o+++
# ++x+oo+
# 第 11 步： 玩家 -1， 动作 (3, 6)
# o++++++
# +x+o++x
# +++++++
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 12 步： 玩家 1， 动作 (0, 2)
# o+o++++
# +x+o++x
# +++++++
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 13 步： 玩家 -1， 动作 (2, 5)
# o+o++++
# +x+o++x
# +++++x+
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 14 步： 玩家 1， 动作 (2, 1)
# o+o++++
# +x+o++x
# +o+++x+
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 15 步： 玩家 -1， 动作 (1, 2)
# o+o++++
# +xxo++x
# +o+++x+
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 16 步： 玩家 1， 动作 (2, 3)
# o+o++++
# +xxo++x
# +o+o+x+
# ++x+++x
# +o+++++
# x++o+++
# ++x+oo+
# 第 17 步： 玩家 -1， 动作 (4, 4)
# o+o++++
# +xxo++x
# +o+o+x+
# ++x+++x
# +o++x++
# x++o+++
# ++x+oo+
# 第 18 步： 玩家 1， 动作 (6, 3)
# o+o++++
# +xxo++x
# +o+o+x+
# ++x+++x
# +o++x++
# x++o+++
# ++xooo+
# 第 19 步： 玩家 -1， 动作 (5, 4)
# o+o++++
# +xxo++x
# +o+o+x+
# ++x+++x
# +o++x++
# x++ox++
# ++xooo+
# 第 20 步： 玩家 1， 动作 (4, 5)
# o+o++++
# +xxo++x
# +o+o+x+
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 21 步： 玩家 -1， 动作 (1, 4)
# o+o++++
# +xxox+x
# +o+o+x+
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 22 步： 玩家 1， 动作 (2, 2)
# o+o++++
# +xxox+x
# +ooo+x+
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 23 步： 玩家 -1， 动作 (2, 6)
# o+o++++
# +xxox+x
# +ooo+xx
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 24 步： 玩家 1， 动作 (0, 4)
# o+o+o++
# +xxox+x
# +ooo+xx
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 25 步： 玩家 -1， 动作 (1, 5)
# o+o+o++
# +xxoxxx
# +ooo+xx
# ++x+++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 26 步： 玩家 1， 动作 (3, 3)
# o+o+o++
# +xxoxxx
# +ooo+xx
# ++xo++x
# +o++xo+
# x++ox++
# ++xooo+
# 第 27 步： 玩家 -1， 动作 (4, 2)
# o+o+o++
# +xxoxxx
# +ooo+xx
# ++xo++x
# +ox+xo+
# x++ox++
# ++xooo+
# 第 28 步： 玩家 1， 动作 (4, 3)
# o+o+o++
# +xxoxxx
# +ooo+xx
# ++xo++x
# +oxoxo+
# x++ox++
# ++xooo+
# 赢家 1
# 训练 42 回合 0: 收集到 264 条经验
# 训练 42 回合 1: 收集到 224 条经验
# 训练 42 回合 2: 收集到 224 条经验
# 训练 42 回合 3: 收集到 216 条经验
# 训练 42 回合 4: 收集到 168 条经验
# 训练 42 回合 5: 收集到 256 条经验
# 训练 42 回合 6: 收集到 344 条经验
# 训练 42 回合 7: 收集到 296 条经验
# 训练 42 回合 8: 收集到 240 条经验
# 训练 42 回合 9: 收集到 256 条经验
# 训练 42 回合 10: 收集到 192 条经验
# 训练 42 回合 11: 收集到 160 条经验
# 训练 42 回合 12: 收集到 160 条经验
# 训练 42 回合 13: 收集到 328 条经验
# 训练 42 回合 14: 收集到 184 条经验
# 训练 42 回合 15: 收集到 256 条经验
# 训练 42 回合 16: 收集到 280 条经验
# 训练 42 回合 17: 收集到 216 条经验
# 训练 42 回合 18: 收集到 168 条经验
# 训练 42 回合 19: 收集到 112 条经验
# 训练 42：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0042/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 5)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 0)
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# +++++++
# o++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 4 步： 玩家 1， 动作 (1, 5)
# ++++++x
# +++++o+
# o++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 1)
# ++++++x
# +x+++o+
# o++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 6 步： 玩家 1， 动作 (2, 2)
# ++++++x
# +x+++o+
# o+o++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# ++++++x
# +x+++o+
# o+o++x+
# +++++++
# +++++++
# +x+++o+
# +++++++
# 第 8 步： 玩家 1， 动作 (5, 4)
# ++++++x
# +x+++o+
# o+o++x+
# +++++++
# +++++++
# +x++oo+
# +++++++
# 第 9 步： 玩家 -1， 动作 (0, 1)
# +x++++x
# +x+++o+
# o+o++x+
# +++++++
# +++++++
# +x++oo+
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 4)
# +x++o+x
# +x+++o+
# o+o++x+
# +++++++
# +++++++
# +x++oo+
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 2)
# +x++o+x
# +x+++o+
# o+o++x+
# ++x++++
# +++++++
# +x++oo+
# +++++++
# 第 12 步： 玩家 1， 动作 (2, 1)
# +x++o+x
# +x+++o+
# ooo++x+
# ++x++++
# +++++++
# +x++oo+
# +++++++
# 第 13 步： 玩家 -1， 动作 (1, 3)
# +x++o+x
# +x+x+o+
# ooo++x+
# ++x++++
# +++++++
# +x++oo+
# +++++++
# 第 14 步： 玩家 1， 动作 (3, 3)
# +x++o+x
# +x+x+o+
# ooo++x+
# ++xo+++
# +++++++
# +x++oo+
# +++++++
# 第 15 步： 玩家 -1， 动作 (2, 6)
# +x++o+x
# +x+x+o+
# ooo++xx
# ++xo+++
# +++++++
# +x++oo+
# +++++++
# 第 16 步： 玩家 1， 动作 (2, 4)
# +x++o+x
# +x+x+o+
# ooo+oxx
# ++xo+++
# +++++++
# +x++oo+
# +++++++
# 第 17 步： 玩家 -1， 动作 (6, 5)
# +x++o+x
# +x+x+o+
# ooo+oxx
# ++xo+++
# +++++++
# +x++oo+
# +++++x+
# 第 18 步： 玩家 1， 动作 (2, 3)
# +x++o+x
# +x+x+o+
# oooooxx
# ++xo+++
# +++++++
# +x++oo+
# +++++x+
# 赢家 1
# 训练 43 回合 0: 收集到 192 条经验
# 训练 43 回合 1: 收集到 184 条经验
# 训练 43 回合 2: 收集到 176 条经验
# 训练 43 回合 3: 收集到 312 条经验
# 训练 43 回合 4: 收集到 200 条经验
# 训练 43 回合 5: 收集到 200 条经验
# 训练 43 回合 6: 收集到 208 条经验
# 训练 43 回合 7: 收集到 184 条经验
# 训练 43 回合 8: 收集到 240 条经验
# 训练 43 回合 9: 收集到 168 条经验
# 训练 43 回合 10: 收集到 184 条经验
# 训练 43 回合 11: 收集到 272 条经验
# 训练 43 回合 12: 收集到 280 条经验
# 训练 43 回合 13: 收集到 120 条经验
# 训练 43 回合 14: 收集到 168 条经验
# 训练 43 回合 15: 收集到 136 条经验
# 训练 43 回合 16: 收集到 184 条经验
# 训练 43 回合 17: 收集到 200 条经验
# 训练 43 回合 18: 收集到 280 条经验
# 训练 43 回合 19: 收集到 232 条经验
# 训练 43：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0043/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 2)
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++++++
# +++x+++
# ++o++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 2)
# +++++++
# +++++++
# +++x+++
# ++o++++
# +++++++
# +++++++
# ++o++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# +++xx++
# ++o++++
# +++++++
# +++++++
# ++o++++
# 第 4 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +++xx++
# ++o++o+
# +++++++
# +++++++
# ++o++++
# 第 5 步： 玩家 -1， 动作 (3, 3)
# +++++++
# +++++++
# +++xx++
# ++ox+o+
# +++++++
# +++++++
# ++o++++
# 第 6 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++xx++
# ++ox+o+
# +++++++
# +++++++
# ++o++++
# 第 7 步： 玩家 -1， 动作 (4, 4)
# +++o+++
# +++++++
# +++xx++
# ++ox+o+
# ++++x++
# +++++++
# ++o++++
# 第 8 步： 玩家 1， 动作 (0, 6)
# +++o++o
# +++++++
# +++xx++
# ++ox+o+
# ++++x++
# +++++++
# ++o++++
# 第 9 步： 玩家 -1， 动作 (5, 6)
# +++o++o
# +++++++
# +++xx++
# ++ox+o+
# ++++x++
# ++++++x
# ++o++++
# 第 10 步： 玩家 1， 动作 (1, 5)
# +++o++o
# +++++o+
# +++xx++
# ++ox+o+
# ++++x++
# ++++++x
# ++o++++
# 第 11 步： 玩家 -1， 动作 (0, 1)
# +x+o++o
# +++++o+
# +++xx++
# ++ox+o+
# ++++x++
# ++++++x
# ++o++++
# 第 12 步： 玩家 1， 动作 (6, 6)
# +x+o++o
# +++++o+
# +++xx++
# ++ox+o+
# ++++x++
# ++++++x
# ++o+++o
# 第 13 步： 玩家 -1， 动作 (5, 1)
# +x+o++o
# +++++o+
# +++xx++
# ++ox+o+
# ++++x++
# +x++++x
# ++o+++o
# 第 14 步： 玩家 1， 动作 (1, 6)
# +x+o++o
# +++++oo
# +++xx++
# ++ox+o+
# ++++x++
# +x++++x
# ++o+++o
# 第 15 步： 玩家 -1， 动作 (3, 1)
# +x+o++o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# +x++++x
# ++o+++o
# 第 16 步： 玩家 1， 动作 (0, 4)
# +x+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# +x++++x
# ++o+++o
# 第 17 步： 玩家 -1， 动作 (5, 0)
# +x+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx++++x
# ++o+++o
# 第 18 步： 玩家 1， 动作 (5, 3)
# +x+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx+o++x
# ++o+++o
# 第 19 步： 玩家 -1， 动作 (5, 5)
# +x+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx+o+xx
# ++o+++o
# 第 20 步： 玩家 1， 动作 (0, 0)
# ox+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx+o+xx
# ++o+++o
# 第 21 步： 玩家 -1， 动作 (6, 3)
# ox+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx+o+xx
# ++ox++o
# 第 22 步： 玩家 1， 动作 (6, 5)
# ox+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xx+o+xx
# ++ox+oo
# 第 23 步： 玩家 -1， 动作 (5, 2)
# ox+oo+o
# +++++oo
# +++xx++
# +xox+o+
# ++++x++
# xxxo+xx
# ++ox+oo
# 第 24 步： 玩家 1， 动作 (2, 5)
# ox+oo+o
# +++++oo
# +++xxo+
# +xox+o+
# ++++x++
# xxxo+xx
# ++ox+oo
# 第 25 步： 玩家 -1， 动作 (4, 5)
# ox+oo+o
# +++++oo
# +++xxo+
# +xox+o+
# ++++xx+
# xxxo+xx
# ++ox+oo
# 第 26 步： 玩家 1， 动作 (3, 6)
# ox+oo+o
# +++++oo
# +++xxo+
# +xox+oo
# ++++xx+
# xxxo+xx
# ++ox+oo
# 第 27 步： 玩家 -1， 动作 (2, 1)
# ox+oo+o
# +++++oo
# +x+xxo+
# +xox+oo
# ++++xx+
# xxxo+xx
# ++ox+oo
# 第 28 步： 玩家 1， 动作 (4, 1)
# ox+oo+o
# +++++oo
# +x+xxo+
# +xox+oo
# +o++xx+
# xxxo+xx
# ++ox+oo
# 第 29 步： 玩家 -1， 动作 (6, 4)
# ox+oo+o
# +++++oo
# +x+xxo+
# +xox+oo
# +o++xx+
# xxxo+xx
# ++oxxoo
# 第 30 步： 玩家 1， 动作 (4, 2)
# ox+oo+o
# +++++oo
# +x+xxo+
# +xox+oo
# +oo+xx+
# xxxo+xx
# ++oxxoo
# 第 31 步： 玩家 -1， 动作 (1, 1)
# ox+oo+o
# +x+++oo
# +x+xxo+
# +xox+oo
# +oo+xx+
# xxxo+xx
# ++oxxoo
# 第 32 步： 玩家 1， 动作 (0, 5)
# ox+oooo
# +x+++oo
# +x+xxo+
# +xox+oo
# +oo+xx+
# xxxo+xx
# ++oxxoo
# 第 33 步： 玩家 -1， 动作 (1, 3)
# ox+oooo
# +x+x+oo
# +x+xxo+
# +xox+oo
# +oo+xx+
# xxxo+xx
# ++oxxoo
# 第 34 步： 玩家 1， 动作 (0, 2)
# oxooooo
# +x+x+oo
# +x+xxo+
# +xox+oo
# +oo+xx+
# xxxo+xx
# ++oxxoo
# 赢家 1
# 训练 44 回合 0: 收集到 232 条经验
# 训练 44 回合 1: 收集到 240 条经验
# 训练 44 回合 2: 收集到 160 条经验
# 训练 44 回合 3: 收集到 208 条经验
# 训练 44 回合 4: 收集到 200 条经验
# 训练 44 回合 5: 收集到 240 条经验
# 训练 44 回合 6: 收集到 184 条经验
# 训练 44 回合 7: 收集到 200 条经验
# 训练 44 回合 8: 收集到 248 条经验
# 训练 44 回合 9: 收集到 160 条经验
# 训练 44 回合 10: 收集到 128 条经验
# 训练 44 回合 11: 收集到 144 条经验
# 训练 44 回合 12: 收集到 200 条经验
# 训练 44 回合 13: 收集到 104 条经验
# 训练 44 回合 14: 收集到 152 条经验
# 训练 44 回合 15: 收集到 224 条经验
# 训练 44 回合 16: 收集到 304 条经验
# 训练 44 回合 17: 收集到 216 条经验
# 训练 44 回合 18: 收集到 192 条经验
# 训练 44 回合 19: 收集到 264 条经验
# 训练 44：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0044/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 2)
# +++++++
# +++++++
# +++++++
# ++x++++
# +++++++
# +++o+++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 4)
# ++++o++
# +++++++
# +++++++
# ++x++++
# +++++++
# +++o+++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 2)
# ++++o++
# +++++++
# +++++++
# ++x++++
# ++x++++
# +++o+++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 4)
# ++++o++
# +++++++
# ++++o++
# ++x++++
# ++x++++
# +++o+++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 5)
# ++++o++
# +++++++
# ++++o++
# ++x++x+
# ++x++++
# +++o+++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 1)
# +o++o++
# +++++++
# ++++o++
# ++x++x+
# ++x++++
# +++o+++
# +++++++
# 第 7 步： 玩家 -1， 动作 (6, 3)
# +o++o++
# +++++++
# ++++o++
# ++x++x+
# ++x++++
# +++o+++
# +++x+++
# 第 8 步： 玩家 1， 动作 (2, 2)
# +o++o++
# +++++++
# ++o+o++
# ++x++x+
# ++x++++
# +++o+++
# +++x+++
# 第 9 步： 玩家 -1， 动作 (0, 6)
# +o++o+x
# +++++++
# ++o+o++
# ++x++x+
# ++x++++
# +++o+++
# +++x+++
# 第 10 步： 玩家 1， 动作 (1, 5)
# +o++o+x
# +++++o+
# ++o+o++
# ++x++x+
# ++x++++
# +++o+++
# +++x+++
# 第 11 步： 玩家 -1， 动作 (4, 1)
# +o++o+x
# +++++o+
# ++o+o++
# ++x++x+
# +xx++++
# +++o+++
# +++x+++
# 第 12 步： 玩家 1， 动作 (2, 0)
# +o++o+x
# +++++o+
# o+o+o++
# ++x++x+
# +xx++++
# +++o+++
# +++x+++
# 第 13 步： 玩家 -1， 动作 (3, 4)
# +o++o+x
# +++++o+
# o+o+o++
# ++x+xx+
# +xx++++
# +++o+++
# +++x+++
# 第 14 步： 玩家 1， 动作 (2, 3)
# +o++o+x
# +++++o+
# o+ooo++
# ++x+xx+
# +xx++++
# +++o+++
# +++x+++
# 第 15 步： 玩家 -1， 动作 (1, 4)
# +o++o+x
# ++++xo+
# o+ooo++
# ++x+xx+
# +xx++++
# +++o+++
# +++x+++
# 第 16 步： 玩家 1， 动作 (5, 5)
# +o++o+x
# ++++xo+
# o+ooo++
# ++x+xx+
# +xx++++
# +++o+o+
# +++x+++
# 第 17 步： 玩家 -1， 动作 (1, 1)
# +o++o+x
# +x++xo+
# o+ooo++
# ++x+xx+
# +xx++++
# +++o+o+
# +++x+++
# 第 18 步： 玩家 1， 动作 (5, 4)
# +o++o+x
# +x++xo+
# o+ooo++
# ++x+xx+
# +xx++++
# +++ooo+
# +++x+++
# 第 19 步： 玩家 -1， 动作 (3, 6)
# +o++o+x
# +x++xo+
# o+ooo++
# ++x+xxx
# +xx++++
# +++ooo+
# +++x+++
# 第 20 步： 玩家 1， 动作 (2, 1)
# +o++o+x
# +x++xo+
# ooooo++
# ++x+xxx
# +xx++++
# +++ooo+
# +++x+++
# 赢家 1
# 训练 45 回合 0: 收集到 216 条经验
# 训练 45 回合 1: 收集到 152 条经验
# 训练 45 回合 2: 收集到 248 条经验
# 训练 45 回合 3: 收集到 200 条经验
# 训练 45 回合 4: 收集到 208 条经验
# 训练 45 回合 5: 收集到 176 条经验
# 训练 45 回合 6: 收集到 160 条经验
# 训练 45 回合 7: 收集到 264 条经验
# 训练 45 回合 8: 收集到 192 条经验
# 训练 45 回合 9: 收集到 160 条经验
# 训练 45 回合 10: 收集到 128 条经验
# 训练 45 回合 11: 收集到 256 条经验
# 训练 45 回合 12: 收集到 176 条经验
# 训练 45 回合 13: 收集到 304 条经验
# 训练 45 回合 14: 收集到 296 条经验
# 训练 45 回合 15: 收集到 232 条经验
# 训练 45 回合 16: 收集到 168 条经验
# 训练 45 回合 17: 收集到 248 条经验
# 训练 45 回合 18: 收集到 232 条经验
# 训练 45 回合 19: 收集到 296 条经验
# 训练 45：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0045/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++o+
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +x+++o+
# +++++++
# +++o+++
# 第 3 步： 玩家 -1， 动作 (4, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +x+x+o+
# +++++++
# +++o+++
# 第 4 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +x+x+o+
# +++++++
# +++o+++
# 第 5 步： 玩家 -1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# +++o+++
# +x+x+o+
# ++++x++
# +++o+++
# 第 6 步： 玩家 1， 动作 (0, 1)
# +o+++++
# +++++++
# +++++++
# +++o+++
# +x+x+o+
# ++++x++
# +++o+++
# 第 7 步： 玩家 -1， 动作 (2, 6)
# +o+++++
# +++++++
# ++++++x
# +++o+++
# +x+x+o+
# ++++x++
# +++o+++
# 第 8 步： 玩家 1， 动作 (3, 0)
# +o+++++
# +++++++
# ++++++x
# o++o+++
# +x+x+o+
# ++++x++
# +++o+++
# 第 9 步： 玩家 -1， 动作 (3, 5)
# +o+++++
# +++++++
# ++++++x
# o++o+x+
# +x+x+o+
# ++++x++
# +++o+++
# 第 10 步： 玩家 1， 动作 (1, 1)
# +o+++++
# +o+++++
# ++++++x
# o++o+x+
# +x+x+o+
# ++++x++
# +++o+++
# 第 11 步： 玩家 -1， 动作 (1, 5)
# +o+++++
# +o+++x+
# ++++++x
# o++o+x+
# +x+x+o+
# ++++x++
# +++o+++
# 第 12 步： 玩家 1， 动作 (3, 1)
# +o+++++
# +o+++x+
# ++++++x
# oo+o+x+
# +x+x+o+
# ++++x++
# +++o+++
# 第 13 步： 玩家 -1， 动作 (3, 4)
# +o+++++
# +o+++x+
# ++++++x
# oo+oxx+
# +x+x+o+
# ++++x++
# +++o+++
# 第 14 步： 玩家 1， 动作 (2, 1)
# +o+++++
# +o+++x+
# +o++++x
# oo+oxx+
# +x+x+o+
# ++++x++
# +++o+++
# 第 15 步： 玩家 -1， 动作 (6, 6)
# +o+++++
# +o+++x+
# +o++++x
# oo+oxx+
# +x+x+o+
# ++++x++
# +++o++x
# 第 16 步： 玩家 1， 动作 (1, 3)
# +o+++++
# +o+o+x+
# +o++++x
# oo+oxx+
# +x+x+o+
# ++++x++
# +++o++x
# 第 17 步： 玩家 -1， 动作 (2, 0)
# +o+++++
# +o+o+x+
# xo++++x
# oo+oxx+
# +x+x+o+
# ++++x++
# +++o++x
# 第 18 步： 玩家 1， 动作 (5, 1)
# +o+++++
# +o+o+x+
# xo++++x
# oo+oxx+
# +x+x+o+
# +o++x++
# +++o++x
# 第 19 步： 玩家 -1， 动作 (6, 2)
# +o+++++
# +o+o+x+
# xo++++x
# oo+oxx+
# +x+x+o+
# +o++x++
# ++xo++x
# 第 20 步： 玩家 1， 动作 (2, 3)
# +o+++++
# +o+o+x+
# xo+o++x
# oo+oxx+
# +x+x+o+
# +o++x++
# ++xo++x
# 第 21 步： 玩家 -1， 动作 (1, 4)
# +o+++++
# +o+oxx+
# xo+o++x
# oo+oxx+
# +x+x+o+
# +o++x++
# ++xo++x
# 第 22 步： 玩家 1， 动作 (3, 2)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+x+o+
# +o++x++
# ++xo++x
# 第 23 步： 玩家 -1， 动作 (4, 4)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+xxo+
# +o++x++
# ++xo++x
# 第 24 步： 玩家 1， 动作 (5, 5)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+xxo+
# +o++xo+
# ++xo++x
# 第 25 步： 玩家 -1， 动作 (5, 6)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+xxo+
# +o++xox
# ++xo++x
# 第 26 步： 玩家 1， 动作 (6, 1)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+xxo+
# +o++xox
# +oxo++x
# 第 27 步： 玩家 -1， 动作 (5, 3)
# +o+++++
# +o+oxx+
# xo+o++x
# ooooxx+
# +x+xxo+
# +o+xxox
# +oxo++x
# 赢家 -1
# 训练 46 回合 0: 收集到 184 条经验
# 训练 46 回合 1: 收集到 160 条经验
# 训练 46 回合 2: 收集到 152 条经验
# 训练 46 回合 3: 收集到 208 条经验
# 训练 46 回合 4: 收集到 288 条经验
# 训练 46 回合 5: 收集到 168 条经验
# 训练 46 回合 6: 收集到 224 条经验
# 训练 46 回合 7: 收集到 176 条经验
# 训练 46 回合 8: 收集到 248 条经验
# 训练 46 回合 9: 收集到 264 条经验
# 训练 46 回合 10: 收集到 112 条经验
# 训练 46 回合 11: 收集到 200 条经验
# 训练 46 回合 12: 收集到 200 条经验
# 训练 46 回合 13: 收集到 152 条经验
# 训练 46 回合 14: 收集到 136 条经验
# 训练 46 回合 15: 收集到 144 条经验
# 训练 46 回合 16: 收集到 328 条经验
# 训练 46 回合 17: 收集到 200 条经验
# 训练 46 回合 18: 收集到 160 条经验
# 训练 46 回合 19: 收集到 144 条经验
# 训练 46：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0046/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 2)
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x++++
# ++o++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# ++x++++
# ++oo+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 3)
# +++x+++
# +++++++
# ++x++++
# ++oo+++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (5, 3)
# +++x+++
# +++++++
# ++x++++
# ++oo+++
# +++++++
# +++o+++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 1)
# +++x+++
# +++++++
# ++x++++
# +xoo+++
# +++++++
# +++o+++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 6)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# +++++++
# +++o+++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 2)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x++++
# +++o+++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 4)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x+o++
# +++o+++
# +++++++
# 第 9 步： 玩家 -1， 动作 (6, 1)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x+o++
# +++o+++
# +x+++++
# 第 10 步： 玩家 1， 动作 (5, 0)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x+o++
# o++o+++
# +x+++++
# 第 11 步： 玩家 -1， 动作 (6, 2)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x+o++
# o++o+++
# +xx++++
# 第 12 步： 玩家 1， 动作 (5, 1)
# +++x++o
# +++++++
# ++x++++
# +xoo+++
# ++x+o++
# oo+o+++
# +xx++++
# 第 13 步： 玩家 -1， 动作 (1, 5)
# +++x++o
# +++++x+
# ++x++++
# +xoo+++
# ++x+o++
# oo+o+++
# +xx++++
# 第 14 步： 玩家 1， 动作 (4, 5)
# +++x++o
# +++++x+
# ++x++++
# +xoo+++
# ++x+oo+
# oo+o+++
# +xx++++
# 第 15 步： 玩家 -1， 动作 (2, 4)
# +++x++o
# +++++x+
# ++x+x++
# +xoo+++
# ++x+oo+
# oo+o+++
# +xx++++
# 第 16 步： 玩家 1， 动作 (5, 2)
# +++x++o
# +++++x+
# ++x+x++
# +xoo+++
# ++x+oo+
# oooo+++
# +xx++++
# 第 17 步： 玩家 -1， 动作 (4, 3)
# +++x++o
# +++++x+
# ++x+x++
# +xoo+++
# ++xxoo+
# oooo+++
# +xx++++
# 第 18 步： 玩家 1， 动作 (5, 4)
# +++x++o
# +++++x+
# ++x+x++
# +xoo+++
# ++xxoo+
# ooooo++
# +xx++++
# 赢家 1
# 训练 47 回合 0: 收集到 248 条经验
# 训练 47 回合 1: 收集到 184 条经验
# 训练 47 回合 2: 收集到 296 条经验
# 训练 47 回合 3: 收集到 256 条经验
# 训练 47 回合 4: 收集到 288 条经验
# 训练 47 回合 5: 收集到 192 条经验
# 训练 47 回合 6: 收集到 152 条经验
# 训练 47 回合 7: 收集到 272 条经验
# 训练 47 回合 8: 收集到 224 条经验
# 训练 47 回合 9: 收集到 184 条经验
# 训练 47 回合 10: 收集到 216 条经验
# 训练 47 回合 11: 收集到 144 条经验
# 训练 47 回合 12: 收集到 184 条经验
# 训练 47 回合 13: 收集到 256 条经验
# 训练 47 回合 14: 收集到 152 条经验
# 训练 47 回合 15: 收集到 192 条经验
# 训练 47 回合 16: 收集到 248 条经验
# 训练 47 回合 17: 收集到 296 条经验
# 训练 47 回合 18: 收集到 208 条经验
# 训练 47 回合 19: 收集到 216 条经验
# 训练 47：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0047/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 1 步： 玩家 -1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# x+o++++
# 第 2 步： 玩家 1， 动作 (3, 0)
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# x+o++++
# 第 3 步： 玩家 -1， 动作 (4, 3)
# +++++++
# +++++++
# +++++++
# o++++++
# +++x+++
# +++++++
# x+o++++
# 第 4 步： 玩家 1， 动作 (1, 6)
# +++++++
# ++++++o
# +++++++
# o++++++
# +++x+++
# +++++++
# x+o++++
# 第 5 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++++++o
# +++++++
# o++++++
# +++x+++
# x++++++
# x+o++++
# 第 6 步： 玩家 1， 动作 (3, 6)
# +++++++
# ++++++o
# +++++++
# o+++++o
# +++x+++
# x++++++
# x+o++++
# 第 7 步： 玩家 -1， 动作 (5, 6)
# +++++++
# ++++++o
# +++++++
# o+++++o
# +++x+++
# x+++++x
# x+o++++
# 第 8 步： 玩家 1， 动作 (2, 3)
# +++++++
# ++++++o
# +++o+++
# o+++++o
# +++x+++
# x+++++x
# x+o++++
# 第 9 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x+o
# +++o+++
# o+++++o
# +++x+++
# x+++++x
# x+o++++
# 第 10 步： 玩家 1， 动作 (5, 1)
# +++++++
# ++++x+o
# +++o+++
# o+++++o
# +++x+++
# xo++++x
# x+o++++
# 第 11 步： 玩家 -1， 动作 (3, 5)
# +++++++
# ++++x+o
# +++o+++
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 12 步： 玩家 1， 动作 (2, 5)
# +++++++
# ++++x+o
# +++o+o+
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 13 步： 玩家 -1， 动作 (2, 1)
# +++++++
# ++++x+o
# +x+o+o+
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 14 步： 玩家 1， 动作 (0, 3)
# +++o+++
# ++++x+o
# +x+o+o+
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 15 步： 玩家 -1， 动作 (1, 0)
# +++o+++
# x+++x+o
# +x+o+o+
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 16 步： 玩家 1， 动作 (1, 5)
# +++o+++
# x+++xoo
# +x+o+o+
# o++++xo
# +++x+++
# xo++++x
# x+o++++
# 第 17 步： 玩家 -1， 动作 (4, 2)
# +++o+++
# x+++xoo
# +x+o+o+
# o++++xo
# ++xx+++
# xo++++x
# x+o++++
# 第 18 步： 玩家 1， 动作 (4, 4)
# +++o+++
# x+++xoo
# +x+o+o+
# o++++xo
# ++xxo++
# xo++++x
# x+o++++
# 第 19 步： 玩家 -1， 动作 (3, 3)
# +++o+++
# x+++xoo
# +x+o+o+
# o++x+xo
# ++xxo++
# xo++++x
# x+o++++
# 第 20 步： 玩家 1， 动作 (2, 6)
# +++o+++
# x+++xoo
# +x+o+oo
# o++x+xo
# ++xxo++
# xo++++x
# x+o++++
# 第 21 步： 玩家 -1， 动作 (6, 5)
# +++o+++
# x+++xoo
# +x+o+oo
# o++x+xo
# ++xxo++
# xo++++x
# x+o++x+
# 第 22 步： 玩家 1， 动作 (0, 4)
# +++oo++
# x+++xoo
# +x+o+oo
# o++x+xo
# ++xxo++
# xo++++x
# x+o++x+
# 第 23 步： 玩家 -1， 动作 (4, 5)
# +++oo++
# x+++xoo
# +x+o+oo
# o++x+xo
# ++xxox+
# xo++++x
# x+o++x+
# 第 24 步： 玩家 1， 动作 (3, 1)
# +++oo++
# x+++xoo
# +x+o+oo
# oo+x+xo
# ++xxox+
# xo++++x
# x+o++x+
# 第 25 步： 玩家 -1， 动作 (2, 0)
# +++oo++
# x+++xoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xo++++x
# x+o++x+
# 第 26 步： 玩家 1， 动作 (0, 1)
# +o+oo++
# x+++xoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xo++++x
# x+o++x+
# 第 27 步： 玩家 -1， 动作 (1, 3)
# +o+oo++
# x++xxoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xo++++x
# x+o++x+
# 第 28 步： 玩家 1， 动作 (5, 4)
# +o+oo++
# x++xxoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xo++o+x
# x+o++x+
# 第 29 步： 玩家 -1， 动作 (5, 2)
# +o+oo++
# x++xxoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xox+o+x
# x+o++x+
# 第 30 步： 玩家 1， 动作 (1, 2)
# +o+oo++
# x+oxxoo
# xx+o+oo
# oo+x+xo
# ++xxox+
# xox+o+x
# x+o++x+
# 第 31 步： 玩家 -1， 动作 (4, 6)
# +o+oo++
# x+oxxoo
# xx+o+oo
# oo+x+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 第 32 步： 玩家 1， 动作 (3, 2)
# +o+oo++
# x+oxxoo
# xx+o+oo
# ooox+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 第 33 步： 玩家 -1， 动作 (1, 1)
# +o+oo++
# xxoxxoo
# xx+o+oo
# ooox+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 第 34 步： 玩家 1， 动作 (2, 2)
# +o+oo++
# xxoxxoo
# xxoo+oo
# ooox+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 第 35 步： 玩家 -1， 动作 (0, 0)
# xo+oo++
# xxoxxoo
# xxoo+oo
# ooox+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 第 36 步： 玩家 1， 动作 (2, 4)
# xo+oo++
# xxoxxoo
# xxooooo
# ooox+xo
# ++xxoxx
# xox+o+x
# x+o++x+
# 赢家 1
# 训练 48 回合 0: 收集到 224 条经验
# 训练 48 回合 1: 收集到 216 条经验
# 训练 48 回合 2: 收集到 184 条经验
# 训练 48 回合 3: 收集到 320 条经验
# 训练 48 回合 4: 收集到 272 条经验
# 训练 48 回合 5: 收集到 176 条经验
# 训练 48 回合 6: 收集到 192 条经验
# 训练 48 回合 7: 收集到 208 条经验
# 训练 48 回合 8: 收集到 232 条经验
# 训练 48 回合 9: 收集到 272 条经验
# 训练 48 回合 10: 收集到 216 条经验
# 训练 48 回合 11: 收集到 120 条经验
# 训练 48 回合 12: 收集到 232 条经验
# 训练 48 回合 13: 收集到 344 条经验
# 训练 48 回合 14: 收集到 304 条经验
# 训练 48 回合 15: 收集到 192 条经验
# 训练 48 回合 16: 收集到 200 条经验
# 训练 48 回合 17: 收集到 280 条经验
# 训练 48 回合 18: 收集到 288 条经验
# 训练 48 回合 19: 收集到 232 条经验
# 训练 48：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0048/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +++o+++
# +x+++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 6)
# +++++++
# +++++++
# +++++++
# +++o+++
# +x+++++
# +++++++
# ++++++o
# 第 3 步： 玩家 -1， 动作 (3, 6)
# +++++++
# +++++++
# +++++++
# +++o++x
# +x+++++
# +++++++
# ++++++o
# 第 4 步： 玩家 1， 动作 (2, 5)
# +++++++
# +++++++
# +++++o+
# +++o++x
# +x+++++
# +++++++
# ++++++o
# 第 5 步： 玩家 -1， 动作 (1, 1)
# +++++++
# +x+++++
# +++++o+
# +++o++x
# +x+++++
# +++++++
# ++++++o
# 第 6 步： 玩家 1， 动作 (5, 5)
# +++++++
# +x+++++
# +++++o+
# +++o++x
# +x+++++
# +++++o+
# ++++++o
# 第 7 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +x+++++
# +++++o+
# +++o++x
# +x+++++
# x++++o+
# ++++++o
# 第 8 步： 玩家 1， 动作 (3, 5)
# +++++++
# +x+++++
# +++++o+
# +++o+ox
# +x+++++
# x++++o+
# ++++++o
# 第 9 步： 玩家 -1， 动作 (5, 4)
# +++++++
# +x+++++
# +++++o+
# +++o+ox
# +x+++++
# x+++xo+
# ++++++o
# 第 10 步： 玩家 1， 动作 (3, 2)
# +++++++
# +x+++++
# +++++o+
# ++oo+ox
# +x+++++
# x+++xo+
# ++++++o
# 第 11 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +x+++++
# ++x++o+
# ++oo+ox
# +x+++++
# x+++xo+
# ++++++o
# 第 12 步： 玩家 1， 动作 (6, 3)
# +++++++
# +x+++++
# ++x++o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++o++o
# 第 13 步： 玩家 -1， 动作 (6, 4)
# +++++++
# +x+++++
# ++x++o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++ox+o
# 第 14 步： 玩家 1， 动作 (2, 1)
# +++++++
# +x+++++
# +ox++o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++ox+o
# 第 15 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +x+++++
# +oxx+o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++ox+o
# 第 16 步： 玩家 1， 动作 (6, 5)
# +++++++
# +x+++++
# +oxx+o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++oxoo
# 第 17 步： 玩家 -1， 动作 (1, 5)
# +++++++
# +x+++x+
# +oxx+o+
# ++oo+ox
# +x+++++
# x+++xo+
# +++oxoo
# 第 18 步： 玩家 1， 动作 (4, 4)
# +++++++
# +x+++x+
# +oxx+o+
# ++oo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 19 步： 玩家 -1， 动作 (3, 1)
# +++++++
# +x+++x+
# +oxx+o+
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 20 步： 玩家 1， 动作 (1, 6)
# +++++++
# +x+++xo
# +oxx+o+
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 21 步： 玩家 -1， 动作 (2, 6)
# +++++++
# +x+++xo
# +oxx+ox
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 22 步： 玩家 1， 动作 (0, 0)
# o++++++
# +x+++xo
# +oxx+ox
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 23 步： 玩家 -1， 动作 (0, 5)
# o++++x+
# +x+++xo
# +oxx+ox
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 24 步： 玩家 1， 动作 (0, 1)
# oo+++x+
# +x+++xo
# +oxx+ox
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 25 步： 玩家 -1， 动作 (2, 4)
# oo+++x+
# +x+++xo
# +oxxxox
# +xoo+ox
# +x++o++
# x+++xo+
# +++oxoo
# 第 26 步： 玩家 1， 动作 (4, 3)
# oo+++x+
# +x+++xo
# +oxxxox
# +xoo+ox
# +x+oo++
# x+++xo+
# +++oxoo
# 第 27 步： 玩家 -1， 动作 (5, 2)
# oo+++x+
# +x+++xo
# +oxxxox
# +xoo+ox
# +x+oo++
# x+x+xo+
# +++oxoo
# 第 28 步： 玩家 1， 动作 (5, 6)
# oo+++x+
# +x+++xo
# +oxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# +++oxoo
# 第 29 步： 玩家 -1， 动作 (1, 0)
# oo+++x+
# xx+++xo
# +oxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# +++oxoo
# 第 30 步： 玩家 1， 动作 (2, 0)
# oo+++x+
# xx+++xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# +++oxoo
# 第 31 步： 玩家 -1， 动作 (6, 0)
# oo+++x+
# xx+++xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# x++oxoo
# 第 32 步： 玩家 1， 动作 (6, 1)
# oo+++x+
# xx+++xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# xo+oxoo
# 第 33 步： 玩家 -1， 动作 (1, 3)
# oo+++x+
# xx+x+xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+x+xoo
# xo+oxoo
# 第 34 步： 玩家 1， 动作 (5, 3)
# oo+++x+
# xx+x+xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+xoxoo
# xo+oxoo
# 第 35 步： 玩家 -1， 动作 (0, 4)
# oo++xx+
# xx+x+xo
# ooxxxox
# +xoo+ox
# +x+oo++
# x+xoxoo
# xo+oxoo
# 第 36 步： 玩家 1， 动作 (4, 5)
# oo++xx+
# xx+x+xo
# ooxxxox
# +xoo+ox
# +x+ooo+
# x+xoxoo
# xo+oxoo
# 赢家 1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# 第 1 步： 玩家 -1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# o++++++
# 第 2 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# +++++++
# +++x+++
# +++++++
# +++++++
# o++++++
# 第 3 步： 玩家 -1， 动作 (4, 2)
# +++++++
# +++o+++
# +++++++
# +++x+++
# ++x++++
# +++++++
# o++++++
# 第 4 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++o+++
# +++++++
# +++x+++
# ++x++++
# +++++++
# oo+++++
# 第 5 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++o+++
# +++++++
# +++x+++
# ++x++++
# +++++++
# oo+++++
# 第 6 步： 玩家 1， 动作 (3, 1)
# +x+++++
# +++o+++
# +++++++
# +o+x+++
# ++x++++
# +++++++
# oo+++++
# 第 7 步： 玩家 -1， 动作 (6, 6)
# +x+++++
# +++o+++
# +++++++
# +o+x+++
# ++x++++
# +++++++
# oo++++x
# 第 8 步： 玩家 1， 动作 (3, 0)
# +x+++++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++++++
# oo++++x
# 第 9 步： 玩家 -1， 动作 (5, 3)
# +x+++++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++x+++
# oo++++x
# 第 10 步： 玩家 1， 动作 (6, 3)
# +x+++++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++x+++
# oo+o++x
# 第 11 步： 玩家 -1， 动作 (0, 0)
# xx+++++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++x+++
# oo+o++x
# 第 12 步： 玩家 1， 动作 (6, 2)
# xx+++++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++x+++
# oooo++x
# 第 13 步： 玩家 -1， 动作 (0, 3)
# xx+x+++
# +++o+++
# +++++++
# oo+x+++
# ++x++++
# +++x+++
# oooo++x
# 第 14 步： 玩家 1， 动作 (4, 6)
# xx+x+++
# +++o+++
# +++++++
# oo+x+++
# ++x+++o
# +++x+++
# oooo++x
# 第 15 步： 玩家 -1， 动作 (0, 5)
# xx+x+x+
# +++o+++
# +++++++
# oo+x+++
# ++x+++o
# +++x+++
# oooo++x
# 第 16 步： 玩家 1， 动作 (1, 6)
# xx+x+x+
# +++o++o
# +++++++
# oo+x+++
# ++x+++o
# +++x+++
# oooo++x
# 第 17 步： 玩家 -1， 动作 (1, 1)
# xx+x+x+
# +x+o++o
# +++++++
# oo+x+++
# ++x+++o
# +++x+++
# oooo++x
# 第 18 步： 玩家 1， 动作 (2, 1)
# xx+x+x+
# +x+o++o
# +o+++++
# oo+x+++
# ++x+++o
# +++x+++
# oooo++x
# 第 19 步： 玩家 -1， 动作 (4, 4)
# xx+x+x+
# +x+o++o
# +o+++++
# oo+x+++
# ++x+x+o
# +++x+++
# oooo++x
# 第 20 步： 玩家 1， 动作 (6, 4)
# xx+x+x+
# +x+o++o
# +o+++++
# oo+x+++
# ++x+x+o
# +++x+++
# ooooo+x
# 赢家 1

# %% [markdown]
# ## 训练4 train_iterations = 10 从第49次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 49
iteration_old_save_model = 48
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 49 回合 0: 收集到 160 条经验
# 训练 49 回合 1: 收集到 192 条经验
# 训练 49 回合 2: 收集到 176 条经验
# 训练 49 回合 3: 收集到 248 条经验
# 训练 49 回合 4: 收集到 240 条经验
# 训练 49 回合 5: 收集到 248 条经验
# 训练 49 回合 6: 收集到 248 条经验
# 训练 49 回合 7: 收集到 248 条经验
# 训练 49 回合 8: 收集到 176 条经验
# 训练 49 回合 9: 收集到 264 条经验
# 训练 49 回合 10: 收集到 168 条经验
# 训练 49 回合 11: 收集到 184 条经验
# 训练 49 回合 12: 收集到 160 条经验
# 训练 49 回合 13: 收集到 200 条经验
# 训练 49 回合 14: 收集到 336 条经验
# 训练 49 回合 15: 收集到 224 条经验
# 训练 49 回合 16: 收集到 224 条经验
# 训练 49 回合 17: 收集到 168 条经验
# 训练 49 回合 18: 收集到 200 条经验
# 训练 49 回合 19: 收集到 344 条经验
# 训练 49：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0049/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 6)
# +++++++
# ++++++o
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x++o
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++x++o
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 3 步： 玩家 -1， 动作 (3, 5)
# +++++++
# +++x++o
# +++++++
# +++++x+
# +++++++
# +++++++
# +o+++++
# 第 4 步： 玩家 1， 动作 (6, 5)
# +++++++
# +++x++o
# +++++++
# +++++x+
# +++++++
# +++++++
# +o+++o+
# 第 5 步： 玩家 -1， 动作 (5, 6)
# +++++++
# +++x++o
# +++++++
# +++++x+
# +++++++
# ++++++x
# +o+++o+
# 第 6 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o++++++
# ++++++x
# +o+++o+
# 第 7 步： 玩家 -1， 动作 (4, 2)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o+x++++
# ++++++x
# +o+++o+
# 第 8 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o+x+o++
# ++++++x
# +o+++o+
# 第 9 步： 玩家 -1， 动作 (6, 4)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o+x+o++
# ++++++x
# +o++xo+
# 第 10 步： 玩家 1， 动作 (4, 5)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o+x+oo+
# ++++++x
# +o++xo+
# 第 11 步： 玩家 -1， 动作 (4, 6)
# +++++++
# +++x++o
# +++++++
# +++++x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 12 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++x++o
# +++++++
# +o+++x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 13 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++x++o
# ++x++++
# +o+++x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 14 步： 玩家 1， 动作 (0, 0)
# o++++++
# +++x++o
# ++x++++
# +o+++x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 15 步： 玩家 -1， 动作 (0, 1)
# ox+++++
# +++x++o
# ++x++++
# +o+++x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 16 步： 玩家 1， 动作 (3, 3)
# ox+++++
# +++x++o
# ++x++++
# +o+o+x+
# o+x+oox
# ++++++x
# +o++xo+
# 第 17 步： 玩家 -1， 动作 (6, 3)
# ox+++++
# +++x++o
# ++x++++
# +o+o+x+
# o+x+oox
# ++++++x
# +o+xxo+
# 第 18 步： 玩家 1， 动作 (4, 3)
# ox+++++
# +++x++o
# ++x++++
# +o+o+x+
# o+xooox
# ++++++x
# +o+xxo+
# 第 19 步： 玩家 -1， 动作 (1, 2)
# ox+++++
# ++xx++o
# ++x++++
# +o+o+x+
# o+xooox
# ++++++x
# +o+xxo+
# 第 20 步： 玩家 1， 动作 (6, 6)
# ox+++++
# ++xx++o
# ++x++++
# +o+o+x+
# o+xooox
# ++++++x
# +o+xxoo
# 第 21 步： 玩家 -1， 动作 (5, 5)
# ox+++++
# ++xx++o
# ++x++++
# +o+o+x+
# o+xooox
# +++++xx
# +o+xxoo
# 第 22 步： 玩家 1， 动作 (5, 4)
# ox+++++
# ++xx++o
# ++x++++
# +o+o+x+
# o+xooox
# ++++oxx
# +o+xxoo
# 第 23 步： 玩家 -1， 动作 (6, 0)
# ox+++++
# ++xx++o
# ++x++++
# +o+o+x+
# o+xooox
# ++++oxx
# xo+xxoo
# 第 24 步： 玩家 1， 动作 (3, 0)
# ox+++++
# ++xx++o
# ++x++++
# oo+o+x+
# o+xooox
# ++++oxx
# xo+xxoo
# 第 25 步： 玩家 -1， 动作 (2, 1)
# ox+++++
# ++xx++o
# +xx++++
# oo+o+x+
# o+xooox
# ++++oxx
# xo+xxoo
# 第 26 步： 玩家 1， 动作 (2, 6)
# ox+++++
# ++xx++o
# +xx+++o
# oo+o+x+
# o+xooox
# ++++oxx
# xo+xxoo
# 第 27 步： 玩家 -1， 动作 (0, 5)
# ox+++x+
# ++xx++o
# +xx+++o
# oo+o+x+
# o+xooox
# ++++oxx
# xo+xxoo
# 第 28 步： 玩家 1， 动作 (4, 1)
# ox+++x+
# ++xx++o
# +xx+++o
# oo+o+x+
# ooxooox
# ++++oxx
# xo+xxoo
# 第 29 步： 玩家 -1， 动作 (0, 2)
# oxx++x+
# ++xx++o
# +xx+++o
# oo+o+x+
# ooxooox
# ++++oxx
# xo+xxoo
# 第 30 步： 玩家 1， 动作 (2, 5)
# oxx++x+
# ++xx++o
# +xx++oo
# oo+o+x+
# ooxooox
# ++++oxx
# xo+xxoo
# 第 31 步： 玩家 -1， 动作 (3, 2)
# oxx++x+
# ++xx++o
# +xx++oo
# ooxo+x+
# ooxooox
# ++++oxx
# xo+xxoo
# 赢家 -1
# 训练 50 回合 0: 收集到 264 条经验
# 训练 50 回合 1: 收集到 224 条经验
# 训练 50 回合 2: 收集到 192 条经验
# 训练 50 回合 3: 收集到 344 条经验
# 训练 50 回合 4: 收集到 200 条经验
# 训练 50 回合 5: 收集到 200 条经验
# 训练 50 回合 6: 收集到 168 条经验
# 训练 50 回合 7: 收集到 176 条经验
# 训练 50 回合 8: 收集到 232 条经验
# 训练 50 回合 9: 收集到 136 条经验
# 训练 50 回合 10: 收集到 160 条经验
# 训练 50 回合 11: 收集到 240 条经验
# 训练 50 回合 12: 收集到 224 条经验
# 训练 50 回合 13: 收集到 176 条经验
# 训练 50 回合 14: 收集到 208 条经验
# 训练 50 回合 15: 收集到 184 条经验
# 训练 50 回合 16: 收集到 248 条经验
# 训练 50 回合 17: 收集到 192 条经验
# 训练 50 回合 18: 收集到 256 条经验
# 训练 50 回合 19: 收集到 224 条经验
# 训练 50：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0050/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 4)
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 6)
# ++++o++
# +++++++
# +++++++
# +++++++
# ++++++x
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 0)
# ++++o++
# o++++++
# +++++++
# +++++++
# ++++++x
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 4)
# ++++o++
# o++++++
# +++++++
# ++++x++
# ++++++x
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 3)
# ++++o++
# o++++++
# +++o+++
# ++++x++
# ++++++x
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 5)
# ++++o++
# o++++++
# +++o+++
# ++++x++
# +++++xx
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 1)
# ++++o++
# o++++++
# +++o+++
# ++++x++
# +o+++xx
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (5, 5)
# ++++o++
# o++++++
# +++o+++
# ++++x++
# +o+++xx
# +++++x+
# +++++++
# 第 8 步： 玩家 1， 动作 (6, 5)
# ++++o++
# o++++++
# +++o+++
# ++++x++
# +o+++xx
# +++++x+
# +++++o+
# 第 9 步： 玩家 -1， 动作 (1, 2)
# ++++o++
# o+x++++
# +++o+++
# ++++x++
# +o+++xx
# +++++x+
# +++++o+
# 第 10 步： 玩家 1， 动作 (3, 3)
# ++++o++
# o+x++++
# +++o+++
# +++ox++
# +o+++xx
# +++++x+
# +++++o+
# 第 11 步： 玩家 -1， 动作 (5, 2)
# ++++o++
# o+x++++
# +++o+++
# +++ox++
# +o+++xx
# ++x++x+
# +++++o+
# 第 12 步： 玩家 1， 动作 (2, 1)
# ++++o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# +++++o+
# 第 13 步： 玩家 -1， 动作 (6, 4)
# ++++o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# ++++xo+
# 第 14 步： 玩家 1， 动作 (6, 0)
# ++++o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# o+++xo+
# 第 15 步： 玩家 -1， 动作 (6, 6)
# ++++o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# o+++xox
# 第 16 步： 玩家 1， 动作 (0, 1)
# +o++o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# o+++xox
# 第 17 步： 玩家 -1， 动作 (0, 2)
# +ox+o++
# o+x++++
# +o+o+++
# +++ox++
# +o+++xx
# ++x++x+
# o+++xox
# 第 18 步： 玩家 1， 动作 (3, 6)
# +ox+o++
# o+x++++
# +o+o+++
# +++ox+o
# +o+++xx
# ++x++x+
# o+++xox
# 第 19 步： 玩家 -1， 动作 (2, 6)
# +ox+o++
# o+x++++
# +o+o++x
# +++ox+o
# +o+++xx
# ++x++x+
# o+++xox
# 第 20 步： 玩家 1， 动作 (2, 4)
# +ox+o++
# o+x++++
# +o+oo+x
# +++ox+o
# +o+++xx
# ++x++x+
# o+++xox
# 第 21 步： 玩家 -1， 动作 (0, 3)
# +oxxo++
# o+x++++
# +o+oo+x
# +++ox+o
# +o+++xx
# ++x++x+
# o+++xox
# 第 22 步： 玩家 1， 动作 (2, 5)
# +oxxo++
# o+x++++
# +o+ooox
# +++ox+o
# +o+++xx
# ++x++x+
# o+++xox
# 第 23 步： 玩家 -1， 动作 (3, 5)
# +oxxo++
# o+x++++
# +o+ooox
# +++oxxo
# +o+++xx
# ++x++x+
# o+++xox
# 第 24 步： 玩家 1， 动作 (4, 0)
# +oxxo++
# o+x++++
# +o+ooox
# +++oxxo
# oo+++xx
# ++x++x+
# o+++xox
# 第 25 步： 玩家 -1， 动作 (3, 2)
# +oxxo++
# o+x++++
# +o+ooox
# ++xoxxo
# oo+++xx
# ++x++x+
# o+++xox
# 第 26 步： 玩家 1， 动作 (1, 5)
# +oxxo++
# o+x++o+
# +o+ooox
# ++xoxxo
# oo+++xx
# ++x++x+
# o+++xox
# 第 27 步： 玩家 -1， 动作 (0, 6)
# +oxxo+x
# o+x++o+
# +o+ooox
# ++xoxxo
# oo+++xx
# ++x++x+
# o+++xox
# 第 28 步： 玩家 1， 动作 (0, 5)
# +oxxoox
# o+x++o+
# +o+ooox
# ++xoxxo
# oo+++xx
# ++x++x+
# o+++xox
# 第 29 步： 玩家 -1， 动作 (4, 2)
# +oxxoox
# o+x++o+
# +o+ooox
# ++xoxxo
# oox++xx
# ++x++x+
# o+++xox
# 第 30 步： 玩家 1， 动作 (4, 4)
# +oxxoox
# o+x++o+
# +o+ooox
# ++xoxxo
# oox+oxx
# ++x++x+
# o+++xox
# 第 31 步： 玩家 -1， 动作 (2, 2)
# +oxxoox
# o+x++o+
# +oxooox
# ++xoxxo
# oox+oxx
# ++x++x+
# o+++xox
# 赢家 -1
# 训练 51 回合 0: 收集到 264 条经验
# 训练 51 回合 1: 收集到 248 条经验
# 训练 51 回合 2: 收集到 224 条经验
# 训练 51 回合 3: 收集到 240 条经验
# 训练 51 回合 4: 收集到 376 条经验
# 训练 51 回合 5: 收集到 328 条经验
# 训练 51 回合 6: 收集到 264 条经验
# 训练 51 回合 7: 收集到 136 条经验
# 训练 51 回合 8: 收集到 320 条经验
# 训练 51 回合 9: 收集到 248 条经验
# 训练 51 回合 10: 收集到 288 条经验
# 训练 51 回合 11: 收集到 168 条经验
# 训练 51 回合 12: 收集到 184 条经验
# 训练 51 回合 13: 收集到 304 条经验
# 训练 51 回合 14: 收集到 224 条经验
# 训练 51 回合 15: 收集到 256 条经验
# 训练 51 回合 16: 收集到 248 条经验
# 训练 51 回合 17: 收集到 208 条经验
# 训练 51 回合 18: 收集到 256 条经验
# 训练 51 回合 19: 收集到 184 条经验
# 训练 51：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0051/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 6)
# +++++++
# +++++o+
# ++++++x
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++++o+
# ++++++x
# +++++++
# o++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++o+
# ++++x+x
# +++++++
# o++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++++o+
# ++++x+x
# +++++++
# o+++o++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 5)
# +++++x+
# +++++o+
# ++++x+x
# +++++++
# o+++o++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (5, 1)
# +++++x+
# +++++o+
# ++++x+x
# +++++++
# o+++o++
# +o+++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (0, 4)
# ++++xx+
# +++++o+
# ++++x+x
# +++++++
# o+++o++
# +o+++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 5)
# ++++xx+
# +++++o+
# ++++x+x
# +++++++
# o+++oo+
# +o+++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 0)
# ++++xx+
# +++++o+
# ++++x+x
# x++++++
# o+++oo+
# +o+++++
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 0)
# o+++xx+
# +++++o+
# ++++x+x
# x++++++
# o+++oo+
# +o+++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 3)
# o+++xx+
# +++++o+
# ++++x+x
# x++x+++
# o+++oo+
# +o+++++
# +++++++
# 第 12 步： 玩家 1， 动作 (4, 1)
# o+++xx+
# +++++o+
# ++++x+x
# x++x+++
# oo++oo+
# +o+++++
# +++++++
# 第 13 步： 玩家 -1， 动作 (5, 3)
# o+++xx+
# +++++o+
# ++++x+x
# x++x+++
# oo++oo+
# +o+x+++
# +++++++
# 第 14 步： 玩家 1， 动作 (6, 1)
# o+++xx+
# +++++o+
# ++++x+x
# x++x+++
# oo++oo+
# +o+x+++
# +o+++++
# 第 15 步： 玩家 -1， 动作 (4, 2)
# o+++xx+
# +++++o+
# ++++x+x
# x++x+++
# oox+oo+
# +o+x+++
# +o+++++
# 第 16 步： 玩家 1， 动作 (0, 3)
# o++oxx+
# +++++o+
# ++++x+x
# x++x+++
# oox+oo+
# +o+x+++
# +o+++++
# 第 17 步： 玩家 -1， 动作 (3, 5)
# o++oxx+
# +++++o+
# ++++x+x
# x++x+x+
# oox+oo+
# +o+x+++
# +o+++++
# 第 18 步： 玩家 1， 动作 (4, 6)
# o++oxx+
# +++++o+
# ++++x+x
# x++x+x+
# oox+ooo
# +o+x+++
# +o+++++
# 第 19 步： 玩家 -1， 动作 (6, 0)
# o++oxx+
# +++++o+
# ++++x+x
# x++x+x+
# oox+ooo
# +o+x+++
# xo+++++
# 第 20 步： 玩家 1， 动作 (3, 6)
# o++oxx+
# +++++o+
# ++++x+x
# x++x+xo
# oox+ooo
# +o+x+++
# xo+++++
# 第 21 步： 玩家 -1， 动作 (2, 5)
# o++oxx+
# +++++o+
# ++++xxx
# x++x+xo
# oox+ooo
# +o+x+++
# xo+++++
# 第 22 步： 玩家 1， 动作 (2, 1)
# o++oxx+
# +++++o+
# +o++xxx
# x++x+xo
# oox+ooo
# +o+x+++
# xo+++++
# 第 23 步： 玩家 -1， 动作 (2, 3)
# o++oxx+
# +++++o+
# +o+xxxx
# x++x+xo
# oox+ooo
# +o+x+++
# xo+++++
# 第 24 步： 玩家 1， 动作 (3, 1)
# o++oxx+
# +++++o+
# +o+xxxx
# xo+x+xo
# oox+ooo
# +o+x+++
# xo+++++
# 赢家 1
# 训练 52 回合 0: 收集到 136 条经验
# 训练 52 回合 1: 收集到 296 条经验
# 训练 52 回合 2: 收集到 176 条经验
# 训练 52 回合 3: 收集到 136 条经验
# 训练 52 回合 4: 收集到 144 条经验
# 训练 52 回合 5: 收集到 224 条经验
# 训练 52 回合 6: 收集到 136 条经验
# 训练 52 回合 7: 收集到 288 条经验
# 训练 52 回合 8: 收集到 120 条经验
# 训练 52 回合 9: 收集到 256 条经验
# 训练 52 回合 10: 收集到 288 条经验
# 训练 52 回合 11: 收集到 168 条经验
# 训练 52 回合 12: 收集到 288 条经验
# 训练 52 回合 13: 收集到 216 条经验
# 训练 52 回合 14: 收集到 296 条经验
# 训练 52 回合 15: 收集到 200 条经验
# 训练 52 回合 16: 收集到 280 条经验
# 训练 52 回合 17: 收集到 232 条经验
# 训练 52 回合 18: 收集到 176 条经验
# 训练 52 回合 19: 收集到 232 条经验
# 训练 52：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0052/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 0)
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# o+++++o
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++xx+++
# +++++++
# +++++++
# o+++++o
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 5)
# +++++++
# +++++++
# ++xx+++
# +++++++
# +++++++
# o+++++o
# +++++o+
# 第 5 步： 玩家 -1， 动作 (2, 0)
# +++++++
# +++++++
# x+xx+++
# +++++++
# +++++++
# o+++++o
# +++++o+
# 第 6 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++++
# x+xx+++
# +++++++
# +++++++
# o+++++o
# +o+++o+
# 第 7 步： 玩家 -1， 动作 (3, 0)
# +++++++
# +++++++
# x+xx+++
# x++++++
# +++++++
# o+++++o
# +o+++o+
# 第 8 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# x+xx++o
# x++++++
# +++++++
# o+++++o
# +o+++o+
# 第 9 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# x+xx++o
# x++++++
# +++++++
# o+x+++o
# +o+++o+
# 第 10 步： 玩家 1， 动作 (1, 1)
# +++++++
# +o+++++
# x+xx++o
# x++++++
# +++++++
# o+x+++o
# +o+++o+
# 第 11 步： 玩家 -1， 动作 (0, 2)
# ++x++++
# +o+++++
# x+xx++o
# x++++++
# +++++++
# o+x+++o
# +o+++o+
# 第 12 步： 玩家 1， 动作 (4, 5)
# ++x++++
# +o+++++
# x+xx++o
# x++++++
# +++++o+
# o+x+++o
# +o+++o+
# 第 13 步： 玩家 -1， 动作 (2, 1)
# ++x++++
# +o+++++
# xxxx++o
# x++++++
# +++++o+
# o+x+++o
# +o+++o+
# 第 14 步： 玩家 1， 动作 (0, 0)
# o+x++++
# +o+++++
# xxxx++o
# x++++++
# +++++o+
# o+x+++o
# +o+++o+
# 第 15 步： 玩家 -1， 动作 (2, 4)
# o+x++++
# +o+++++
# xxxxx+o
# x++++++
# +++++o+
# o+x+++o
# +o+++o+
# 赢家 -1
# 训练 53 回合 0: 收集到 136 条经验
# 训练 53 回合 1: 收集到 208 条经验
# 训练 53 回合 2: 收集到 176 条经验
# 训练 53 回合 3: 收集到 256 条经验
# 训练 53 回合 4: 收集到 248 条经验
# 训练 53 回合 5: 收集到 184 条经验
# 训练 53 回合 6: 收集到 240 条经验
# 训练 53 回合 7: 收集到 120 条经验
# 训练 53 回合 8: 收集到 112 条经验
# 训练 53 回合 9: 收集到 200 条经验
# 训练 53 回合 10: 收集到 312 条经验
# 训练 53 回合 11: 收集到 176 条经验
# 训练 53 回合 12: 收集到 272 条经验
# 训练 53 回合 13: 收集到 192 条经验
# 训练 53 回合 14: 收集到 248 条经验
# 训练 53 回合 15: 收集到 184 条经验
# 训练 53 回合 16: 收集到 144 条经验
# 训练 53 回合 17: 收集到 216 条经验
# 训练 53 回合 18: 收集到 280 条经验
# 训练 53 回合 19: 收集到 208 条经验
# 训练 53：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0053/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 2)
# ++x++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 3)
# ++x++++
# +++++++
# +++++++
# +++o+++
# ++++++o
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 6)
# ++x++++
# +++++++
# +++++++
# +++o++x
# ++++++o
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 5)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# ++++++o
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 1)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# ++++++o
# +x+++++
# +++++++
# 第 6 步： 玩家 1， 动作 (5, 5)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# ++++++o
# +x+++o+
# +++++++
# 第 7 步： 玩家 -1， 动作 (6, 3)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# ++++++o
# +x+++o+
# +++x+++
# 第 8 步： 玩家 1， 动作 (5, 6)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# ++++++o
# +x+++oo
# +++x+++
# 第 9 步： 玩家 -1， 动作 (4, 0)
# ++x++++
# +++++++
# +++++++
# +++o+ox
# x+++++o
# +x+++oo
# +++x+++
# 第 10 步： 玩家 1， 动作 (1, 0)
# ++x++++
# o++++++
# +++++++
# +++o+ox
# x+++++o
# +x+++oo
# +++x+++
# 第 11 步： 玩家 -1， 动作 (4, 5)
# ++x++++
# o++++++
# +++++++
# +++o+ox
# x++++xo
# +x+++oo
# +++x+++
# 第 12 步： 玩家 1， 动作 (5, 2)
# ++x++++
# o++++++
# +++++++
# +++o+ox
# x++++xo
# +xo++oo
# +++x+++
# 第 13 步： 玩家 -1， 动作 (1, 5)
# ++x++++
# o++++x+
# +++++++
# +++o+ox
# x++++xo
# +xo++oo
# +++x+++
# 第 14 步： 玩家 1， 动作 (2, 1)
# ++x++++
# o++++x+
# +o+++++
# +++o+ox
# x++++xo
# +xo++oo
# +++x+++
# 第 15 步： 玩家 -1， 动作 (2, 4)
# ++x++++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo++oo
# +++x+++
# 第 16 步： 玩家 1， 动作 (6, 6)
# ++x++++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo++oo
# +++x++o
# 第 17 步： 玩家 -1， 动作 (5, 4)
# ++x++++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo+xoo
# +++x++o
# 第 18 步： 玩家 1， 动作 (6, 4)
# ++x++++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo+xoo
# +++xo+o
# 第 19 步： 玩家 -1， 动作 (0, 4)
# ++x+x++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo+xoo
# +++xo+o
# 第 20 步： 玩家 1， 动作 (0, 0)
# o+x+x++
# o++++x+
# +o++x++
# +++o+ox
# x++++xo
# +xo+xoo
# +++xo+o
# 第 21 步： 玩家 -1， 动作 (4, 1)
# o+x+x++
# o++++x+
# +o++x++
# +++o+ox
# xx+++xo
# +xo+xoo
# +++xo+o
# 第 22 步： 玩家 1， 动作 (3, 0)
# o+x+x++
# o++++x+
# +o++x++
# o++o+ox
# xx+++xo
# +xo+xoo
# +++xo+o
# 第 23 步： 玩家 -1， 动作 (5, 0)
# o+x+x++
# o++++x+
# +o++x++
# o++o+ox
# xx+++xo
# xxo+xoo
# +++xo+o
# 第 24 步： 玩家 1， 动作 (4, 2)
# o+x+x++
# o++++x+
# +o++x++
# o++o+ox
# xxo++xo
# xxo+xoo
# +++xo+o
# 第 25 步： 玩家 -1， 动作 (4, 3)
# o+x+x++
# o++++x+
# +o++x++
# o++o+ox
# xxox+xo
# xxo+xoo
# +++xo+o
# 第 26 步： 玩家 1， 动作 (6, 5)
# o+x+x++
# o++++x+
# +o++x++
# o++o+ox
# xxox+xo
# xxo+xoo
# +++xooo
# 第 27 步： 玩家 -1， 动作 (0, 3)
# o+xxx++
# o++++x+
# +o++x++
# o++o+ox
# xxox+xo
# xxo+xoo
# +++xooo
# 第 28 步： 玩家 1， 动作 (4, 4)
# o+xxx++
# o++++x+
# +o++x++
# o++o+ox
# xxoxoxo
# xxo+xoo
# +++xooo
# 第 29 步： 玩家 -1， 动作 (3, 2)
# o+xxx++
# o++++x+
# +o++x++
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +++xooo
# 第 30 步： 玩家 1， 动作 (1, 4)
# o+xxx++
# o+++ox+
# +o++x++
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +++xooo
# 第 31 步： 玩家 -1， 动作 (6, 1)
# o+xxx++
# o+++ox+
# +o++x++
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +x+xooo
# 第 32 步： 玩家 1， 动作 (2, 5)
# o+xxx++
# o+++ox+
# +o++xo+
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +x+xooo
# 第 33 步： 玩家 -1， 动作 (0, 6)
# o+xxx+x
# o+++ox+
# +o++xo+
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +x+xooo
# 第 34 步： 玩家 1， 动作 (2, 2)
# o+xxx+x
# o+++ox+
# +oo+xo+
# o+xo+ox
# xxoxoxo
# xxo+xoo
# +x+xooo
# 赢家 1
# 训练 54 回合 0: 收集到 200 条经验
# 训练 54 回合 1: 收集到 288 条经验
# 训练 54 回合 2: 收集到 144 条经验
# 训练 54 回合 3: 收集到 216 条经验
# 训练 54 回合 4: 收集到 216 条经验
# 训练 54 回合 5: 收集到 312 条经验
# 训练 54 回合 6: 收集到 280 条经验
# 训练 54 回合 7: 收集到 224 条经验
# 训练 54 回合 8: 收集到 128 条经验
# 训练 54 回合 9: 收集到 224 条经验
# 训练 54 回合 10: 收集到 184 条经验
# 训练 54 回合 11: 收集到 200 条经验
# 训练 54 回合 12: 收集到 216 条经验
# 训练 54 回合 13: 收集到 176 条经验
# 训练 54 回合 14: 收集到 248 条经验
# 训练 54 回合 15: 收集到 160 条经验
# 训练 54 回合 16: 收集到 128 条经验
# 训练 54 回合 17: 收集到 248 条经验
# 训练 54 回合 18: 收集到 216 条经验
# 训练 54 回合 19: 收集到 248 条经验
# 训练 54：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0054/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 5)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++x+
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++o++++
# +++++++
# +++o+++
# +++++x+
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x+o++++
# +++++++
# +++o+++
# +++++x+
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 6)
# +++++++
# x+o++++
# +++++++
# +++o+++
# +++++x+
# +++++++
# ++++++o
# 第 5 步： 玩家 -1， 动作 (3, 2)
# +++++++
# x+o++++
# +++++++
# ++xo+++
# +++++x+
# +++++++
# ++++++o
# 第 6 步： 玩家 1， 动作 (0, 3)
# +++o+++
# x+o++++
# +++++++
# ++xo+++
# +++++x+
# +++++++
# ++++++o
# 第 7 步： 玩家 -1， 动作 (1, 4)
# +++o+++
# x+o+x++
# +++++++
# ++xo+++
# +++++x+
# +++++++
# ++++++o
# 第 8 步： 玩家 1， 动作 (5, 4)
# +++o+++
# x+o+x++
# +++++++
# ++xo+++
# +++++x+
# ++++o++
# ++++++o
# 第 9 步： 玩家 -1， 动作 (6, 4)
# +++o+++
# x+o+x++
# +++++++
# ++xo+++
# +++++x+
# ++++o++
# ++++x+o
# 第 10 步： 玩家 1， 动作 (1, 3)
# +++o+++
# x+oox++
# +++++++
# ++xo+++
# +++++x+
# ++++o++
# ++++x+o
# 第 11 步： 玩家 -1， 动作 (6, 0)
# +++o+++
# x+oox++
# +++++++
# ++xo+++
# +++++x+
# ++++o++
# x+++x+o
# 第 12 步： 玩家 1， 动作 (5, 5)
# +++o+++
# x+oox++
# +++++++
# ++xo+++
# +++++x+
# ++++oo+
# x+++x+o
# 第 13 步： 玩家 -1， 动作 (3, 4)
# +++o+++
# x+oox++
# +++++++
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 14 步： 玩家 1， 动作 (0, 4)
# +++oo++
# x+oox++
# +++++++
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 15 步： 玩家 -1， 动作 (2, 2)
# +++oo++
# x+oox++
# ++x++++
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 16 步： 玩家 1， 动作 (2, 5)
# +++oo++
# x+oox++
# ++x++o+
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 17 步： 玩家 -1， 动作 (0, 5)
# +++oox+
# x+oox++
# ++x++o+
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 18 步： 玩家 1， 动作 (2, 1)
# +++oox+
# x+oox++
# +ox++o+
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 19 步： 玩家 -1， 动作 (2, 4)
# +++oox+
# x+oox++
# +ox+xo+
# ++xox++
# +++++x+
# ++++oo+
# x+++x+o
# 第 20 步： 玩家 1， 动作 (4, 3)
# +++oox+
# x+oox++
# +ox+xo+
# ++xox++
# +++o+x+
# ++++oo+
# x+++x+o
# 第 21 步： 玩家 -1， 动作 (4, 4)
# +++oox+
# x+oox++
# +ox+xo+
# ++xox++
# +++oxx+
# ++++oo+
# x+++x+o
# 第 22 步： 玩家 1， 动作 (5, 2)
# +++oox+
# x+oox++
# +ox+xo+
# ++xox++
# +++oxx+
# ++o+oo+
# x+++x+o
# 第 23 步： 玩家 -1， 动作 (1, 1)
# +++oox+
# xxoox++
# +ox+xo+
# ++xox++
# +++oxx+
# ++o+oo+
# x+++x+o
# 第 24 步： 玩家 1， 动作 (2, 3)
# +++oox+
# xxoox++
# +oxoxo+
# ++xox++
# +++oxx+
# ++o+oo+
# x+++x+o
# 赢家 1
# 训练 55 回合 0: 收集到 208 条经验
# 训练 55 回合 1: 收集到 224 条经验
# 训练 55 回合 2: 收集到 256 条经验
# 训练 55 回合 3: 收集到 240 条经验
# 训练 55 回合 4: 收集到 256 条经验
# 训练 55 回合 5: 收集到 168 条经验
# 训练 55 回合 6: 收集到 216 条经验
# 训练 55 回合 7: 收集到 256 条经验
# 训练 55 回合 8: 收集到 224 条经验
# 训练 55 回合 9: 收集到 336 条经验
# 训练 55 回合 10: 收集到 312 条经验
# 训练 55 回合 11: 收集到 248 条经验
# 训练 55 回合 12: 收集到 272 条经验
# 训练 55 回合 13: 收集到 224 条经验
# 训练 55 回合 14: 收集到 216 条经验
# 训练 55 回合 15: 收集到 184 条经验
# 训练 55 回合 16: 收集到 104 条经验
# 训练 55 回合 17: 收集到 256 条经验
# 训练 55 回合 18: 收集到 272 条经验
# 训练 55 回合 19: 收集到 224 条经验
# 训练 55：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0055/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x+++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 1)
# +++++++
# +o+++++
# +x+++++
# +++o+++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 5)
# +++++++
# +o+++++
# +x+++++
# +++o+++
# +++++x+
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 0)
# +++++++
# +o+++++
# +x+++++
# +++o+++
# o++++x+
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 1)
# +++++++
# +o+++++
# +x+++++
# +x+o+++
# o++++x+
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +o+++++
# +x+++++
# +x+o+++
# o++++x+
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (4, 1)
# +++o+++
# +o+++++
# +x+++++
# +x+o+++
# ox+++x+
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 2)
# +++o+++
# +o+++++
# +x+++++
# +xoo+++
# ox+++x+
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (2, 4)
# +++o+++
# +o+++++
# +x++x++
# +xoo+++
# ox+++x+
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 6)
# +++o+++
# +o+++++
# +x++x++
# +xoo+++
# ox+++x+
# +++++++
# ++++++o
# 第 11 步： 玩家 -1， 动作 (4, 4)
# +++o+++
# +o+++++
# +x++x++
# +xoo+++
# ox++xx+
# +++++++
# ++++++o
# 第 12 步： 玩家 1， 动作 (6, 1)
# +++o+++
# +o+++++
# +x++x++
# +xoo+++
# ox++xx+
# +++++++
# +o++++o
# 第 13 步： 玩家 -1， 动作 (1, 6)
# +++o+++
# +o++++x
# +x++x++
# +xoo+++
# ox++xx+
# +++++++
# +o++++o
# 第 14 步： 玩家 1， 动作 (1, 5)
# +++o+++
# +o+++ox
# +x++x++
# +xoo+++
# ox++xx+
# +++++++
# +o++++o
# 第 15 步： 玩家 -1， 动作 (5, 5)
# +++o+++
# +o+++ox
# +x++x++
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 16 步： 玩家 1， 动作 (0, 2)
# ++oo+++
# +o+++ox
# +x++x++
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 17 步： 玩家 -1， 动作 (2, 5)
# ++oo+++
# +o+++ox
# +x++xx+
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 18 步： 玩家 1， 动作 (1, 3)
# ++oo+++
# +o+o+ox
# +x++xx+
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 19 步： 玩家 -1， 动作 (1, 2)
# ++oo+++
# +oxo+ox
# +x++xx+
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 20 步： 玩家 1， 动作 (2, 6)
# ++oo+++
# +oxo+ox
# +x++xxo
# +xoo+++
# ox++xx+
# +++++x+
# +o++++o
# 第 21 步： 玩家 -1， 动作 (5, 0)
# ++oo+++
# +oxo+ox
# +x++xxo
# +xoo+++
# ox++xx+
# x++++x+
# +o++++o
# 第 22 步： 玩家 1， 动作 (0, 1)
# +ooo+++
# +oxo+ox
# +x++xxo
# +xoo+++
# ox++xx+
# x++++x+
# +o++++o
# 第 23 步： 玩家 -1， 动作 (1, 0)
# +ooo+++
# xoxo+ox
# +x++xxo
# +xoo+++
# ox++xx+
# x++++x+
# +o++++o
# 第 24 步： 玩家 1， 动作 (0, 4)
# +oooo++
# xoxo+ox
# +x++xxo
# +xoo+++
# ox++xx+
# x++++x+
# +o++++o
# 第 25 步： 玩家 -1， 动作 (4, 6)
# +oooo++
# xoxo+ox
# +x++xxo
# +xoo+++
# ox++xxx
# x++++x+
# +o++++o
# 第 26 步： 玩家 1， 动作 (0, 5)
# +ooooo+
# xoxo+ox
# +x++xxo
# +xoo+++
# ox++xxx
# x++++x+
# +o++++o
# 赢家 1
# 训练 56 回合 0: 收集到 216 条经验
# 训练 56 回合 1: 收集到 272 条经验
# 训练 56 回合 2: 收集到 200 条经验
# 训练 56 回合 3: 收集到 152 条经验
# 训练 56 回合 4: 收集到 112 条经验
# 训练 56 回合 5: 收集到 320 条经验
# 训练 56 回合 6: 收集到 264 条经验
# 训练 56 回合 7: 收集到 136 条经验
# 训练 56 回合 8: 收集到 240 条经验
# 训练 56 回合 9: 收集到 200 条经验
# 训练 56 回合 10: 收集到 272 条经验
# 训练 56 回合 11: 收集到 240 条经验
# 训练 56 回合 12: 收集到 160 条经验
# 训练 56 回合 13: 收集到 128 条经验
# 训练 56 回合 14: 收集到 128 条经验
# 训练 56 回合 15: 收集到 256 条经验
# 训练 56 回合 16: 收集到 208 条经验
# 训练 56 回合 17: 收集到 168 条经验
# 训练 56 回合 18: 收集到 184 条经验
# 训练 56 回合 19: 收集到 232 条经验
# 训练 56：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0056/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# 第 1 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# x++++++
# +++o+++
# 第 2 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# x++++++
# +++o+++
# 第 3 步： 玩家 -1， 动作 (4, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++xo++
# x++++++
# +++o+++
# 第 4 步： 玩家 1， 动作 (3, 4)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++xo++
# x++++++
# +++o+++
# 第 5 步： 玩家 -1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++xo++
# x+++x++
# +++o+++
# 第 6 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++xo++
# x+++x++
# +++oo++
# 第 7 步： 玩家 -1， 动作 (4, 6)
# +++++++
# +++++++
# +++++++
# ++++o++
# +++xo+x
# x+++x++
# +++oo++
# 第 8 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# ++++o++
# +++xo+x
# x+++x++
# +++oo++
# 第 9 步： 玩家 -1， 动作 (4, 2)
# +++++++
# +++++++
# ++++o++
# ++++o++
# ++xxo+x
# x+++x++
# +++oo++
# 第 10 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# ++++o+o
# ++++o++
# ++xxo+x
# x+++x++
# +++oo++
# 第 11 步： 玩家 -1， 动作 (4, 0)
# +++++++
# +++++++
# ++++o+o
# ++++o++
# x+xxo+x
# x+++x++
# +++oo++
# 第 12 步： 玩家 1， 动作 (5, 5)
# +++++++
# +++++++
# ++++o+o
# ++++o++
# x+xxo+x
# x+++xo+
# +++oo++
# 第 13 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# ++++o+o
# ++++o++
# x+xxo+x
# x+++xo+
# +++oo++
# 第 14 步： 玩家 1， 动作 (3, 3)
# x++++++
# +++++++
# ++++o+o
# +++oo++
# x+xxo+x
# x+++xo+
# +++oo++
# 第 15 步： 玩家 -1， 动作 (5, 1)
# x++++++
# +++++++
# ++++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# +++oo++
# 第 16 步： 玩家 1， 动作 (6, 2)
# x++++++
# +++++++
# ++++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 17 步： 玩家 -1， 动作 (2, 0)
# x++++++
# +++++++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 18 步： 玩家 1， 动作 (0, 6)
# x+++++o
# +++++++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 19 步： 玩家 -1， 动作 (1, 3)
# x+++++o
# +++x+++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 20 步： 玩家 1， 动作 (1, 4)
# x+++++o
# +++xo++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 21 步： 玩家 -1， 动作 (0, 3)
# x++x++o
# +++xo++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 第 22 步： 玩家 1， 动作 (0, 4)
# x++xo+o
# +++xo++
# x+++o+o
# +++oo++
# x+xxo+x
# xx++xo+
# ++ooo++
# 赢家 1
# 训练 57 回合 0: 收集到 176 条经验
# 训练 57 回合 1: 收集到 200 条经验
# 训练 57 回合 2: 收集到 152 条经验
# 训练 57 回合 3: 收集到 232 条经验
# 训练 57 回合 4: 收集到 232 条经验
# 训练 57 回合 5: 收集到 192 条经验
# 训练 57 回合 6: 收集到 264 条经验
# 训练 57 回合 7: 收集到 160 条经验
# 训练 57 回合 8: 收集到 232 条经验
# 训练 57 回合 9: 收集到 328 条经验
# 训练 57 回合 10: 收集到 304 条经验
# 训练 57 回合 11: 收集到 136 条经验
# 训练 57 回合 12: 收集到 208 条经验
# 训练 57 回合 13: 收集到 176 条经验
# 训练 57 回合 14: 收集到 216 条经验
# 训练 57 回合 15: 收集到 264 条经验
# 训练 57 回合 16: 收集到 168 条经验
# 训练 57 回合 17: 收集到 152 条经验
# 训练 57 回合 18: 收集到 136 条经验
# 训练 57 回合 19: 收集到 272 条经验
# 训练 57：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0057/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 4)
# +++o+++
# +++++++
# +++++++
# ++++x++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 0)
# +++o+++
# +++++++
# +++++++
# ++++x++
# o++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 2)
# +++o+++
# +++++++
# +++++++
# ++x+x++
# o++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 3)
# +++o+++
# +++++++
# +++++++
# ++xox++
# o++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (2, 3)
# +++o+++
# +++++++
# +++x+++
# ++xox++
# o++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 5)
# +++o+++
# +++++++
# +++x+++
# ++xox++
# o++++++
# +++++++
# +++++o+
# 第 7 步： 玩家 -1， 动作 (5, 1)
# +++o+++
# +++++++
# +++x+++
# ++xox++
# o++++++
# +x+++++
# +++++o+
# 第 8 步： 玩家 1， 动作 (2, 4)
# +++o+++
# +++++++
# +++xo++
# ++xox++
# o++++++
# +x+++++
# +++++o+
# 第 9 步： 玩家 -1， 动作 (1, 3)
# +++o+++
# +++x+++
# +++xo++
# ++xox++
# o++++++
# +x+++++
# +++++o+
# 第 10 步： 玩家 1， 动作 (0, 2)
# ++oo+++
# +++x+++
# +++xo++
# ++xox++
# o++++++
# +x+++++
# +++++o+
# 第 11 步： 玩家 -1， 动作 (5, 4)
# ++oo+++
# +++x+++
# +++xo++
# ++xox++
# o++++++
# +x++x++
# +++++o+
# 第 12 步： 玩家 1， 动作 (2, 5)
# ++oo+++
# +++x+++
# +++xoo+
# ++xox++
# o++++++
# +x++x++
# +++++o+
# 第 13 步： 玩家 -1， 动作 (6, 2)
# ++oo+++
# +++x+++
# +++xoo+
# ++xox++
# o++++++
# +x++x++
# ++x++o+
# 第 14 步： 玩家 1， 动作 (2, 0)
# ++oo+++
# +++x+++
# o++xoo+
# ++xox++
# o++++++
# +x++x++
# ++x++o+
# 第 15 步： 玩家 -1， 动作 (2, 6)
# ++oo+++
# +++x+++
# o++xoox
# ++xox++
# o++++++
# +x++x++
# ++x++o+
# 第 16 步： 玩家 1， 动作 (1, 1)
# ++oo+++
# +o+x+++
# o++xoox
# ++xox++
# o++++++
# +x++x++
# ++x++o+
# 第 17 步： 玩家 -1， 动作 (1, 4)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox++
# o++++++
# +x++x++
# ++x++o+
# 第 18 步： 玩家 1， 动作 (5, 6)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox++
# o++++++
# +x++x+o
# ++x++o+
# 第 19 步： 玩家 -1， 动作 (4, 2)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox++
# o+x++++
# +x++x+o
# ++x++o+
# 第 20 步： 玩家 1， 动作 (3, 6)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox+o
# o+x++++
# +x++x+o
# ++x++o+
# 第 21 步： 玩家 -1， 动作 (5, 2)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox+o
# o+x++++
# +xx+x+o
# ++x++o+
# 第 22 步： 玩家 1， 动作 (6, 1)
# ++oo+++
# +o+xx++
# o++xoox
# ++xox+o
# o+x++++
# +xx+x+o
# +ox++o+
# 第 23 步： 玩家 -1， 动作 (1, 0)
# ++oo+++
# xo+xx++
# o++xoox
# ++xox+o
# o+x++++
# +xx+x+o
# +ox++o+
# 第 24 步： 玩家 1， 动作 (5, 0)
# ++oo+++
# xo+xx++
# o++xoox
# ++xox+o
# o+x++++
# oxx+x+o
# +ox++o+
# 第 25 步： 玩家 -1， 动作 (2, 2)
# ++oo+++
# xo+xx++
# o+xxoox
# ++xox+o
# o+x++++
# oxx+x+o
# +ox++o+
# 赢家 -1
# 训练 58 回合 0: 收集到 232 条经验
# 训练 58 回合 1: 收集到 168 条经验
# 训练 58 回合 2: 收集到 264 条经验
# 训练 58 回合 3: 收集到 248 条经验
# 训练 58 回合 4: 收集到 160 条经验
# 训练 58 回合 5: 收集到 208 条经验
# 训练 58 回合 6: 收集到 176 条经验
# 训练 58 回合 7: 收集到 136 条经验
# 训练 58 回合 8: 收集到 216 条经验
# 训练 58 回合 9: 收集到 288 条经验
# 训练 58 回合 10: 收集到 216 条经验
# 训练 58 回合 11: 收集到 168 条经验
# 训练 58 回合 12: 收集到 248 条经验
# 训练 58 回合 13: 收集到 152 条经验
# 训练 58 回合 14: 收集到 200 条经验
# 训练 58 回合 15: 收集到 168 条经验
# 训练 58 回合 16: 收集到 176 条经验
# 训练 58 回合 17: 收集到 272 条经验
# 训练 58 回合 18: 收集到 248 条经验
# 训练 58 回合 19: 收集到 256 条经验
# 训练 58：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0058/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# x++++++
# ++o++++
# +++++++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# x++++++
# ++o++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (6, 5)
# +++++++
# +++++++
# +++++++
# +++o+++
# x++++++
# ++o++++
# +++++x+
# 第 4 步： 玩家 1， 动作 (2, 0)
# +++++++
# +++++++
# o++++++
# +++o+++
# x++++++
# ++o++++
# +++++x+
# 第 5 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# o++++++
# +++o+++
# x++++++
# x+o++++
# +++++x+
# 第 6 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# o++++++
# +++o+++
# x++++++
# x+o++++
# o++++x+
# 第 7 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x++
# o++++++
# +++o+++
# x++++++
# x+o++++
# o++++x+
# 第 8 步： 玩家 1， 动作 (1, 5)
# +++++++
# ++++xo+
# o++++++
# +++o+++
# x++++++
# x+o++++
# o++++x+
# 第 9 步： 玩家 -1， 动作 (4, 1)
# +++++++
# ++++xo+
# o++++++
# +++o+++
# xx+++++
# x+o++++
# o++++x+
# 第 10 步： 玩家 1， 动作 (2, 1)
# +++++++
# ++++xo+
# oo+++++
# +++o+++
# xx+++++
# x+o++++
# o++++x+
# 第 11 步： 玩家 -1， 动作 (4, 5)
# +++++++
# ++++xo+
# oo+++++
# +++o+++
# xx+++x+
# x+o++++
# o++++x+
# 第 12 步： 玩家 1， 动作 (0, 0)
# o++++++
# ++++xo+
# oo+++++
# +++o+++
# xx+++x+
# x+o++++
# o++++x+
# 第 13 步： 玩家 -1， 动作 (3, 5)
# o++++++
# ++++xo+
# oo+++++
# +++o+x+
# xx+++x+
# x+o++++
# o++++x+
# 第 14 步： 玩家 1， 动作 (0, 2)
# o+o++++
# ++++xo+
# oo+++++
# +++o+x+
# xx+++x+
# x+o++++
# o++++x+
# 第 15 步： 玩家 -1， 动作 (5, 1)
# o+o++++
# ++++xo+
# oo+++++
# +++o+x+
# xx+++x+
# xxo++++
# o++++x+
# 第 16 步： 玩家 1， 动作 (1, 3)
# o+o++++
# +++oxo+
# oo+++++
# +++o+x+
# xx+++x+
# xxo++++
# o++++x+
# 第 17 步： 玩家 -1， 动作 (2, 2)
# o+o++++
# +++oxo+
# oox++++
# +++o+x+
# xx+++x+
# xxo++++
# o++++x+
# 第 18 步： 玩家 1， 动作 (5, 4)
# o+o++++
# +++oxo+
# oox++++
# +++o+x+
# xx+++x+
# xxo+o++
# o++++x+
# 第 19 步： 玩家 -1， 动作 (2, 4)
# o+o++++
# +++oxo+
# oox+x++
# +++o+x+
# xx+++x+
# xxo+o++
# o++++x+
# 第 20 步： 玩家 1， 动作 (4, 4)
# o+o++++
# +++oxo+
# oox+x++
# +++o+x+
# xx++ox+
# xxo+o++
# o++++x+
# 第 21 步： 玩家 -1， 动作 (1, 0)
# o+o++++
# x++oxo+
# oox+x++
# +++o+x+
# xx++ox+
# xxo+o++
# o++++x+
# 第 22 步： 玩家 1， 动作 (2, 5)
# o+o++++
# x++oxo+
# oox+xo+
# +++o+x+
# xx++ox+
# xxo+o++
# o++++x+
# 第 23 步： 玩家 -1， 动作 (2, 3)
# o+o++++
# x++oxo+
# ooxxxo+
# +++o+x+
# xx++ox+
# xxo+o++
# o++++x+
# 第 24 步： 玩家 1， 动作 (3, 2)
# o+o++++
# x++oxo+
# ooxxxo+
# ++oo+x+
# xx++ox+
# xxo+o++
# o++++x+
# 第 25 步： 玩家 -1， 动作 (4, 2)
# o+o++++
# x++oxo+
# ooxxxo+
# ++oo+x+
# xxx+ox+
# xxo+o++
# o++++x+
# 第 26 步： 玩家 1， 动作 (3, 1)
# o+o++++
# x++oxo+
# ooxxxo+
# +ooo+x+
# xxx+ox+
# xxo+o++
# o++++x+
# 第 27 步： 玩家 -1， 动作 (5, 6)
# o+o++++
# x++oxo+
# ooxxxo+
# +ooo+x+
# xxx+ox+
# xxo+o+x
# o++++x+
# 第 28 步： 玩家 1， 动作 (4, 3)
# o+o++++
# x++oxo+
# ooxxxo+
# +ooo+x+
# xxxoox+
# xxo+o+x
# o++++x+
# 第 29 步： 玩家 -1， 动作 (1, 6)
# o+o++++
# x++oxox
# ooxxxo+
# +ooo+x+
# xxxoox+
# xxo+o+x
# o++++x+
# 第 30 步： 玩家 1， 动作 (3, 0)
# o+o++++
# x++oxox
# ooxxxo+
# oooo+x+
# xxxoox+
# xxo+o+x
# o++++x+
# 第 31 步： 玩家 -1， 动作 (0, 6)
# o+o+++x
# x++oxox
# ooxxxo+
# oooo+x+
# xxxoox+
# xxo+o+x
# o++++x+
# 第 32 步： 玩家 1， 动作 (3, 4)
# o+o+++x
# x++oxox
# ooxxxo+
# ooooox+
# xxxoox+
# xxo+o+x
# o++++x+
# 赢家 1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# ++++x++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# ++++++o
# ++++x++
# 第 3 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+++
# +++++++
# +++o+++
# +++++++
# ++++++o
# ++++x++
# 第 4 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++x+++
# +++++++
# +++o+++
# ++o++++
# ++++++o
# ++++x++
# 第 5 步： 玩家 -1， 动作 (5, 5)
# +++++++
# +++x+++
# +++++++
# +++o+++
# ++o++++
# +++++xo
# ++++x++
# 第 6 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++x+++
# +++++++
# +++o+++
# o+o++++
# +++++xo
# ++++x++
# 第 7 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++x+++
# +++x+++
# +++o+++
# o+o++++
# +++++xo
# ++++x++
# 第 8 步： 玩家 1， 动作 (4, 6)
# +++++++
# +++x+++
# +++x+++
# +++o+++
# o+o+++o
# +++++xo
# ++++x++
# 第 9 步： 玩家 -1， 动作 (5, 3)
# +++++++
# +++x+++
# +++x+++
# +++o+++
# o+o+++o
# +++x+xo
# ++++x++
# 第 10 步： 玩家 1， 动作 (1, 0)
# +++++++
# o++x+++
# +++x+++
# +++o+++
# o+o+++o
# +++x+xo
# ++++x++
# 第 11 步： 玩家 -1， 动作 (2, 5)
# +++++++
# o++x+++
# +++x+x+
# +++o+++
# o+o+++o
# +++x+xo
# ++++x++
# 第 12 步： 玩家 1， 动作 (2, 0)
# +++++++
# o++x+++
# o++x+x+
# +++o+++
# o+o+++o
# +++x+xo
# ++++x++
# 第 13 步： 玩家 -1， 动作 (6, 1)
# +++++++
# o++x+++
# o++x+x+
# +++o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 14 步： 玩家 1， 动作 (3, 1)
# +++++++
# o++x+++
# o++x+x+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 15 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# o++x+++
# o++x+x+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 16 步： 玩家 1， 动作 (1, 5)
# ++++++x
# o++x+o+
# o++x+x+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 17 步： 玩家 -1， 动作 (2, 2)
# ++++++x
# o++x+o+
# o+xx+x+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 18 步： 玩家 1， 动作 (1, 1)
# ++++++x
# oo+x+o+
# o+xx+x+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 19 步： 玩家 -1， 动作 (2, 4)
# ++++++x
# oo+x+o+
# o+xxxx+
# +o+o+++
# o+o+++o
# +++x+xo
# +x++x++
# 第 20 步： 玩家 1， 动作 (3, 4)
# ++++++x
# oo+x+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++x++
# 第 21 步： 玩家 -1， 动作 (0, 3)
# +++x++x
# oo+x+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++x++
# 第 22 步： 玩家 1， 动作 (1, 2)
# +++x++x
# ooox+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++x++
# 第 23 步： 玩家 -1， 动作 (6, 6)
# +++x++x
# ooox+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++x+x
# 第 24 步： 玩家 1， 动作 (6, 5)
# +++x++x
# ooox+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++xox
# 第 25 步： 玩家 -1， 动作 (0, 5)
# +++x+xx
# ooox+o+
# o+xxxx+
# +o+oo++
# o+o+++o
# +++x+xo
# +x++xox
# 第 26 步： 玩家 1， 动作 (2, 6)
# +++x+xx
# ooox+o+
# o+xxxxo
# +o+oo++
# o+o+++o
# +++x+xo
# +x++xox
# 第 27 步： 玩家 -1， 动作 (0, 2)
# ++xx+xx
# ooox+o+
# o+xxxxo
# +o+oo++
# o+o+++o
# +++x+xo
# +x++xox
# 第 28 步： 玩家 1， 动作 (3, 2)
# ++xx+xx
# ooox+o+
# o+xxxxo
# +oooo++
# o+o+++o
# +++x+xo
# +x++xox
# 第 29 步： 玩家 -1， 动作 (2, 1)
# ++xx+xx
# ooox+o+
# oxxxxxo
# +oooo++
# o+o+++o
# +++x+xo
# +x++xox
# 赢家 -1

# %% [markdown]
# ## 训练5 train_iterations = 10 从第59次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 59
iteration_old_save_model = 58
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 59 回合 0: 收集到 216 条经验
# 训练 59 回合 1: 收集到 296 条经验
# 训练 59 回合 2: 收集到 200 条经验
# 训练 59 回合 3: 收集到 184 条经验
# 训练 59 回合 4: 收集到 208 条经验
# 训练 59 回合 5: 收集到 264 条经验
# 训练 59 回合 6: 收集到 248 条经验
# 训练 59 回合 7: 收集到 192 条经验
# 训练 59 回合 8: 收集到 120 条经验
# 训练 59 回合 9: 收集到 160 条经验
# 训练 59 回合 10: 收集到 168 条经验
# 训练 59 回合 11: 收集到 280 条经验
# 训练 59 回合 12: 收集到 240 条经验
# 训练 59 回合 13: 收集到 200 条经验
# 训练 59 回合 14: 收集到 168 条经验
# 训练 59 回合 15: 收集到 256 条经验
# 训练 59 回合 16: 收集到 184 条经验
# 训练 59 回合 17: 收集到 248 条经验
# 训练 59 回合 18: 收集到 280 条经验
# 训练 59 回合 19: 收集到 160 条经验
# 训练 59：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0059/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# ++++o++
# 第 2 步： 玩家 1， 动作 (4, 3)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++o+++
# +++++++
# ++++o++
# 第 3 步： 玩家 -1， 动作 (4, 5)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++o+x+
# +++++++
# ++++o++
# 第 4 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +x+++++
# +++++++
# +++o+x+
# +++++++
# ++++o++
# 第 5 步： 玩家 -1， 动作 (6, 3)
# +++o+++
# +++++++
# +x+++++
# +++++++
# +++o+x+
# +++++++
# +++xo++
# 第 6 步： 玩家 1， 动作 (4, 1)
# +++o+++
# +++++++
# +x+++++
# +++++++
# +o+o+x+
# +++++++
# +++xo++
# 第 7 步： 玩家 -1， 动作 (2, 3)
# +++o+++
# +++++++
# +x+x+++
# +++++++
# +o+o+x+
# +++++++
# +++xo++
# 第 8 步： 玩家 1， 动作 (4, 4)
# +++o+++
# +++++++
# +x+x+++
# +++++++
# +o+oox+
# +++++++
# +++xo++
# 第 9 步： 玩家 -1， 动作 (1, 0)
# +++o+++
# x++++++
# +x+x+++
# +++++++
# +o+oox+
# +++++++
# +++xo++
# 第 10 步： 玩家 1， 动作 (0, 2)
# ++oo+++
# x++++++
# +x+x+++
# +++++++
# +o+oox+
# +++++++
# +++xo++
# 第 11 步： 玩家 -1， 动作 (1, 6)
# ++oo+++
# x+++++x
# +x+x+++
# +++++++
# +o+oox+
# +++++++
# +++xo++
# 第 12 步： 玩家 1， 动作 (3, 5)
# ++oo+++
# x+++++x
# +x+x+++
# +++++o+
# +o+oox+
# +++++++
# +++xo++
# 第 13 步： 玩家 -1， 动作 (3, 4)
# ++oo+++
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# +++++++
# +++xo++
# 第 14 步： 玩家 1， 动作 (5, 5)
# ++oo+++
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# +++++o+
# +++xo++
# 第 15 步： 玩家 -1， 动作 (5, 2)
# ++oo+++
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# ++x++o+
# +++xo++
# 第 16 步： 玩家 1， 动作 (0, 5)
# ++oo+o+
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# ++x++o+
# +++xo++
# 第 17 步： 玩家 -1， 动作 (5, 4)
# ++oo+o+
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# ++x+xo+
# +++xo++
# 第 18 步： 玩家 1， 动作 (5, 6)
# ++oo+o+
# x+++++x
# +x+x+++
# ++++xo+
# +o+oox+
# ++x+xoo
# +++xo++
# 第 19 步： 玩家 -1， 动作 (4, 2)
# ++oo+o+
# x+++++x
# +x+x+++
# ++++xo+
# +oxoox+
# ++x+xoo
# +++xo++
# 第 20 步： 玩家 1， 动作 (2, 5)
# ++oo+o+
# x+++++x
# +x+x+o+
# ++++xo+
# +oxoox+
# ++x+xoo
# +++xo++
# 第 21 步： 玩家 -1， 动作 (6, 0)
# ++oo+o+
# x+++++x
# +x+x+o+
# ++++xo+
# +oxoox+
# ++x+xoo
# x++xo++
# 第 22 步： 玩家 1， 动作 (3, 6)
# ++oo+o+
# x+++++x
# +x+x+o+
# ++++xoo
# +oxoox+
# ++x+xoo
# x++xo++
# 第 23 步： 玩家 -1， 动作 (3, 2)
# ++oo+o+
# x+++++x
# +x+x+o+
# ++x+xoo
# +oxoox+
# ++x+xoo
# x++xo++
# 第 24 步： 玩家 1， 动作 (3, 0)
# ++oo+o+
# x+++++x
# +x+x+o+
# o+x+xoo
# +oxoox+
# ++x+xoo
# x++xo++
# 第 25 步： 玩家 -1， 动作 (1, 4)
# ++oo+o+
# x+++x+x
# +x+x+o+
# o+x+xoo
# +oxoox+
# ++x+xoo
# x++xo++
# 第 26 步： 玩家 1， 动作 (2, 6)
# ++oo+o+
# x+++x+x
# +x+x+oo
# o+x+xoo
# +oxoox+
# ++x+xoo
# x++xo++
# 第 27 步： 玩家 -1， 动作 (5, 0)
# ++oo+o+
# x+++x+x
# +x+x+oo
# o+x+xoo
# +oxoox+
# x+x+xoo
# x++xo++
# 第 28 步： 玩家 1， 动作 (6, 2)
# ++oo+o+
# x+++x+x
# +x+x+oo
# o+x+xoo
# +oxoox+
# x+x+xoo
# x+oxo++
# 第 29 步： 玩家 -1， 动作 (3, 3)
# ++oo+o+
# x+++x+x
# +x+x+oo
# o+xxxoo
# +oxoox+
# x+x+xoo
# x+oxo++
# 第 30 步： 玩家 1， 动作 (5, 3)
# ++oo+o+
# x+++x+x
# +x+x+oo
# o+xxxoo
# +oxoox+
# x+xoxoo
# x+oxo++
# 赢家 1
# 训练 60 回合 0: 收集到 200 条经验
# 训练 60 回合 1: 收集到 248 条经验
# 训练 60 回合 2: 收集到 240 条经验
# 训练 60 回合 3: 收集到 184 条经验
# 训练 60 回合 4: 收集到 184 条经验
# 训练 60 回合 5: 收集到 152 条经验
# 训练 60 回合 6: 收集到 296 条经验
# 训练 60 回合 7: 收集到 248 条经验
# 训练 60 回合 8: 收集到 168 条经验
# 训练 60 回合 9: 收集到 112 条经验
# 训练 60 回合 10: 收集到 160 条经验
# 训练 60 回合 11: 收集到 168 条经验
# 训练 60 回合 12: 收集到 320 条经验
# 训练 60 回合 13: 收集到 216 条经验
# 训练 60 回合 14: 收集到 264 条经验
# 训练 60 回合 15: 收集到 96 条经验
# 训练 60 回合 16: 收集到 200 条经验
# 训练 60 回合 17: 收集到 312 条经验
# 训练 60 回合 18: 收集到 216 条经验
# 训练 60 回合 19: 收集到 200 条经验
# 训练 60：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0060/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 2 步： 玩家 1， 动作 (0, 2)
# ++o++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 3 步： 玩家 -1， 动作 (6, 0)
# ++o++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# x+o++++
# 第 4 步： 玩家 1， 动作 (6, 6)
# ++o++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# x+o+++o
# 第 5 步： 玩家 -1， 动作 (4, 6)
# ++o++++
# +++++++
# +x+++++
# +++++++
# ++++++x
# +++++++
# x+o+++o
# 第 6 步： 玩家 1， 动作 (1, 4)
# ++o++++
# ++++o++
# +x+++++
# +++++++
# ++++++x
# +++++++
# x+o+++o
# 第 7 步： 玩家 -1， 动作 (4, 0)
# ++o++++
# ++++o++
# +x+++++
# +++++++
# x+++++x
# +++++++
# x+o+++o
# 第 8 步： 玩家 1， 动作 (3, 3)
# ++o++++
# ++++o++
# +x+++++
# +++o+++
# x+++++x
# +++++++
# x+o+++o
# 第 9 步： 玩家 -1， 动作 (4, 4)
# ++o++++
# ++++o++
# +x+++++
# +++o+++
# x+++x+x
# +++++++
# x+o+++o
# 第 10 步： 玩家 1， 动作 (3, 4)
# ++o++++
# ++++o++
# +x+++++
# +++oo++
# x+++x+x
# +++++++
# x+o+++o
# 第 11 步： 玩家 -1， 动作 (4, 5)
# ++o++++
# ++++o++
# +x+++++
# +++oo++
# x+++xxx
# +++++++
# x+o+++o
# 第 12 步： 玩家 1， 动作 (1, 5)
# ++o++++
# ++++oo+
# +x+++++
# +++oo++
# x+++xxx
# +++++++
# x+o+++o
# 第 13 步： 玩家 -1， 动作 (3, 2)
# ++o++++
# ++++oo+
# +x+++++
# ++xoo++
# x+++xxx
# +++++++
# x+o+++o
# 第 14 步： 玩家 1， 动作 (2, 4)
# ++o++++
# ++++oo+
# +x++o++
# ++xoo++
# x+++xxx
# +++++++
# x+o+++o
# 第 15 步： 玩家 -1， 动作 (5, 0)
# ++o++++
# ++++oo+
# +x++o++
# ++xoo++
# x+++xxx
# x++++++
# x+o+++o
# 第 16 步： 玩家 1， 动作 (4, 3)
# ++o++++
# ++++oo+
# +x++o++
# ++xoo++
# x++oxxx
# x++++++
# x+o+++o
# 第 17 步： 玩家 -1， 动作 (0, 5)
# ++o++x+
# ++++oo+
# +x++o++
# ++xoo++
# x++oxxx
# x++++++
# x+o+++o
# 第 18 步： 玩家 1， 动作 (1, 2)
# ++o++x+
# ++o+oo+
# +x++o++
# ++xoo++
# x++oxxx
# x++++++
# x+o+++o
# 第 19 步： 玩家 -1， 动作 (2, 0)
# ++o++x+
# ++o+oo+
# xx++o++
# ++xoo++
# x++oxxx
# x++++++
# x+o+++o
# 第 20 步： 玩家 1， 动作 (1, 3)
# ++o++x+
# ++oooo+
# xx++o++
# ++xoo++
# x++oxxx
# x++++++
# x+o+++o
# 第 21 步： 玩家 -1， 动作 (3, 0)
# ++o++x+
# ++oooo+
# xx++o++
# x+xoo++
# x++oxxx
# x++++++
# x+o+++o
# 赢家 -1
# 训练 61 回合 0: 收集到 216 条经验
# 训练 61 回合 1: 收集到 160 条经验
# 训练 61 回合 2: 收集到 192 条经验
# 训练 61 回合 3: 收集到 208 条经验
# 训练 61 回合 4: 收集到 200 条经验
# 训练 61 回合 5: 收集到 160 条经验
# 训练 61 回合 6: 收集到 184 条经验
# 训练 61 回合 7: 收集到 240 条经验
# 训练 61 回合 8: 收集到 232 条经验
# 训练 61 回合 9: 收集到 152 条经验
# 训练 61 回合 10: 收集到 200 条经验
# 训练 61 回合 11: 收集到 152 条经验
# 训练 61 回合 12: 收集到 136 条经验
# 训练 61 回合 13: 收集到 296 条经验
# 训练 61 回合 14: 收集到 176 条经验
# 训练 61 回合 15: 收集到 160 条经验
# 训练 61 回合 16: 收集到 216 条经验
# 训练 61 回合 17: 收集到 168 条经验
# 训练 61 回合 18: 收集到 152 条经验
# 训练 61 回合 19: 收集到 136 条经验
# 训练 61：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0061/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 1)
# +++++o+
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 0)
# +++++o+
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# o++++++
# 第 3 步： 玩家 -1， 动作 (2, 1)
# +++++o+
# +++++++
# +x+++++
# +x+++++
# +++++++
# +++++++
# o++++++
# 第 4 步： 玩家 1， 动作 (2, 6)
# +++++o+
# +++++++
# +x++++o
# +x+++++
# +++++++
# +++++++
# o++++++
# 第 5 步： 玩家 -1， 动作 (4, 2)
# +++++o+
# +++++++
# +x++++o
# +x+++++
# ++x++++
# +++++++
# o++++++
# 第 6 步： 玩家 1， 动作 (5, 2)
# +++++o+
# +++++++
# +x++++o
# +x+++++
# ++x++++
# ++o++++
# o++++++
# 第 7 步： 玩家 -1， 动作 (4, 3)
# +++++o+
# +++++++
# +x++++o
# +x+++++
# ++xx+++
# ++o++++
# o++++++
# 第 8 步： 玩家 1， 动作 (4, 4)
# +++++o+
# +++++++
# +x++++o
# +x+++++
# ++xxo++
# ++o++++
# o++++++
# 第 9 步： 玩家 -1， 动作 (1, 4)
# +++++o+
# ++++x++
# +x++++o
# +x+++++
# ++xxo++
# ++o++++
# o++++++
# 第 10 步： 玩家 1， 动作 (5, 6)
# +++++o+
# ++++x++
# +x++++o
# +x+++++
# ++xxo++
# ++o+++o
# o++++++
# 第 11 步： 玩家 -1， 动作 (2, 4)
# +++++o+
# ++++x++
# +x++x+o
# +x+++++
# ++xxo++
# ++o+++o
# o++++++
# 第 12 步： 玩家 1， 动作 (3, 0)
# +++++o+
# ++++x++
# +x++x+o
# ox+++++
# ++xxo++
# ++o+++o
# o++++++
# 第 13 步： 玩家 -1， 动作 (0, 0)
# x++++o+
# ++++x++
# +x++x+o
# ox+++++
# ++xxo++
# ++o+++o
# o++++++
# 第 14 步： 玩家 1， 动作 (2, 0)
# x++++o+
# ++++x++
# ox++x+o
# ox+++++
# ++xxo++
# ++o+++o
# o++++++
# 第 15 步： 玩家 -1， 动作 (5, 3)
# x++++o+
# ++++x++
# ox++x+o
# ox+++++
# ++xxo++
# ++ox++o
# o++++++
# 第 16 步： 玩家 1， 动作 (2, 3)
# x++++o+
# ++++x++
# ox+ox+o
# ox+++++
# ++xxo++
# ++ox++o
# o++++++
# 第 17 步： 玩家 -1， 动作 (0, 4)
# x+++xo+
# ++++x++
# ox+ox+o
# ox+++++
# ++xxo++
# ++ox++o
# o++++++
# 第 18 步： 玩家 1， 动作 (2, 2)
# x+++xo+
# ++++x++
# oxoox+o
# ox+++++
# ++xxo++
# ++ox++o
# o++++++
# 第 19 步： 玩家 -1， 动作 (4, 6)
# x+++xo+
# ++++x++
# oxoox+o
# ox+++++
# ++xxo+x
# ++ox++o
# o++++++
# 第 20 步： 玩家 1， 动作 (3, 2)
# x+++xo+
# ++++x++
# oxoox+o
# oxo++++
# ++xxo+x
# ++ox++o
# o++++++
# 第 21 步： 玩家 -1， 动作 (2, 5)
# x+++xo+
# ++++x++
# oxooxxo
# oxo++++
# ++xxo+x
# ++ox++o
# o++++++
# 第 22 步： 玩家 1， 动作 (0, 1)
# xo++xo+
# ++++x++
# oxooxxo
# oxo++++
# ++xxo+x
# ++ox++o
# o++++++
# 第 23 步： 玩家 -1， 动作 (1, 0)
# xo++xo+
# x+++x++
# oxooxxo
# oxo++++
# ++xxo+x
# ++ox++o
# o++++++
# 第 24 步： 玩家 1， 动作 (5, 5)
# xo++xo+
# x+++x++
# oxooxxo
# oxo++++
# ++xxo+x
# ++ox+oo
# o++++++
# 第 25 步： 玩家 -1， 动作 (4, 1)
# xo++xo+
# x+++x++
# oxooxxo
# oxo++++
# +xxxo+x
# ++ox+oo
# o++++++
# 第 26 步： 玩家 1， 动作 (1, 3)
# xo++xo+
# x++ox++
# oxooxxo
# oxo++++
# +xxxo+x
# ++ox+oo
# o++++++
# 第 27 步： 玩家 -1， 动作 (6, 4)
# xo++xo+
# x++ox++
# oxooxxo
# oxo++++
# +xxxo+x
# ++ox+oo
# o+++x++
# 第 28 步： 玩家 1， 动作 (6, 6)
# xo++xo+
# x++ox++
# oxooxxo
# oxo++++
# +xxxo+x
# ++ox+oo
# o+++x+o
# 第 29 步： 玩家 -1， 动作 (1, 1)
# xo++xo+
# xx+ox++
# oxooxxo
# oxo++++
# +xxxo+x
# ++ox+oo
# o+++x+o
# 第 30 步： 玩家 1， 动作 (5, 0)
# xo++xo+
# xx+ox++
# oxooxxo
# oxo++++
# +xxxo+x
# o+ox+oo
# o+++x+o
# 第 31 步： 玩家 -1， 动作 (5, 1)
# xo++xo+
# xx+ox++
# oxooxxo
# oxo++++
# +xxxo+x
# oxox+oo
# o+++x+o
# 赢家 -1
# 训练 62 回合 0: 收集到 312 条经验
# 训练 62 回合 1: 收集到 168 条经验
# 训练 62 回合 2: 收集到 224 条经验
# 训练 62 回合 3: 收集到 328 条经验
# 训练 62 回合 4: 收集到 224 条经验
# 训练 62 回合 5: 收集到 264 条经验
# 训练 62 回合 6: 收集到 296 条经验
# 训练 62 回合 7: 收集到 184 条经验
# 训练 62 回合 8: 收集到 144 条经验
# 训练 62 回合 9: 收集到 200 条经验
# 训练 62 回合 10: 收集到 336 条经验
# 训练 62 回合 11: 收集到 224 条经验
# 训练 62 回合 12: 收集到 256 条经验
# 训练 62 回合 13: 收集到 232 条经验
# 训练 62 回合 14: 收集到 208 条经验
# 训练 62 回合 15: 收集到 224 条经验
# 训练 62 回合 16: 收集到 192 条经验
# 训练 62 回合 17: 收集到 216 条经验
# 训练 62 回合 18: 收集到 232 条经验
# 训练 62 回合 19: 收集到 216 条经验
# 训练 62：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0062/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# ++x++++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# o++++++
# ++x++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+++
# ++++o++
# +++++++
# o++++++
# ++x++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++x+++
# +o++o++
# +++++++
# o++++++
# ++x++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (6, 2)
# +++++++
# +++x+++
# +o++o++
# +++++++
# o++++++
# ++x++++
# ++x++++
# 第 6 步： 玩家 1， 动作 (3, 1)
# +++++++
# +++x+++
# +o++o++
# +o+++++
# o++++++
# ++x++++
# ++x++++
# 第 7 步： 玩家 -1， 动作 (4, 2)
# +++++++
# +++x+++
# +o++o++
# +o+++++
# o+x++++
# ++x++++
# ++x++++
# 第 8 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++x+++
# +o++o++
# +o+++o+
# o+x++++
# ++x++++
# ++x++++
# 第 9 步： 玩家 -1， 动作 (4, 5)
# +++++++
# +++x+++
# +o++o++
# +o+++o+
# o+x++x+
# ++x++++
# ++x++++
# 第 10 步： 玩家 1， 动作 (5, 5)
# +++++++
# +++x+++
# +o++o++
# +o+++o+
# o+x++x+
# ++x++o+
# ++x++++
# 第 11 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++x+++
# +o++ox+
# +o+++o+
# o+x++x+
# ++x++o+
# ++x++++
# 第 12 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++x+++
# +o++ox+
# +o+o+o+
# o+x++x+
# ++x++o+
# ++x++++
# 第 13 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++x+++
# +o+xox+
# +o+o+o+
# o+x++x+
# ++x++o+
# ++x++++
# 第 14 步： 玩家 1， 动作 (4, 6)
# +++++++
# +++x+++
# +o+xox+
# +o+o+o+
# o+x++xo
# ++x++o+
# ++x++++
# 第 15 步： 玩家 -1， 动作 (5, 6)
# +++++++
# +++x+++
# +o+xox+
# +o+o+o+
# o+x++xo
# ++x++ox
# ++x++++
# 第 16 步： 玩家 1， 动作 (3, 0)
# +++++++
# +++x+++
# +o+xox+
# oo+o+o+
# o+x++xo
# ++x++ox
# ++x++++
# 第 17 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++x+++
# +oxxox+
# oo+o+o+
# o+x++xo
# ++x++ox
# ++x++++
# 第 18 步： 玩家 1， 动作 (0, 6)
# ++++++o
# +++x+++
# +oxxox+
# oo+o+o+
# o+x++xo
# ++x++ox
# ++x++++
# 第 19 步： 玩家 -1， 动作 (4, 4)
# ++++++o
# +++x+++
# +oxxox+
# oo+o+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 20 步： 玩家 1， 动作 (1, 2)
# ++++++o
# ++ox+++
# +oxxox+
# oo+o+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 21 步： 玩家 -1， 动作 (2, 6)
# ++++++o
# ++ox+++
# +oxxoxx
# oo+o+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 22 步： 玩家 1， 动作 (1, 4)
# ++++++o
# ++oxo++
# +oxxoxx
# oo+o+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 23 步： 玩家 -1， 动作 (1, 1)
# ++++++o
# +xoxo++
# +oxxoxx
# oo+o+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 24 步： 玩家 1， 动作 (3, 2)
# ++++++o
# +xoxo++
# +oxxoxx
# oooo+o+
# o+x+xxo
# ++x++ox
# ++x++++
# 第 25 步： 玩家 -1， 动作 (6, 3)
# ++++++o
# +xoxo++
# +oxxoxx
# oooo+o+
# o+x+xxo
# ++x++ox
# ++xx+++
# 第 26 步： 玩家 1， 动作 (6, 1)
# ++++++o
# +xoxo++
# +oxxoxx
# oooo+o+
# o+x+xxo
# ++x++ox
# +oxx+++
# 第 27 步： 玩家 -1， 动作 (4, 1)
# ++++++o
# +xoxo++
# +oxxoxx
# oooo+o+
# oxx+xxo
# ++x++ox
# +oxx+++
# 第 28 步： 玩家 1， 动作 (3, 4)
# ++++++o
# +xoxo++
# +oxxoxx
# oooooo+
# oxx+xxo
# ++x++ox
# +oxx+++
# 赢家 1
# 训练 63 回合 0: 收集到 184 条经验
# 训练 63 回合 1: 收集到 216 条经验
# 训练 63 回合 2: 收集到 208 条经验
# 训练 63 回合 3: 收集到 216 条经验
# 训练 63 回合 4: 收集到 232 条经验
# 训练 63 回合 5: 收集到 256 条经验
# 训练 63 回合 6: 收集到 176 条经验
# 训练 63 回合 7: 收集到 192 条经验
# 训练 63 回合 8: 收集到 296 条经验
# 训练 63 回合 9: 收集到 192 条经验
# 训练 63 回合 10: 收集到 312 条经验
# 训练 63 回合 11: 收集到 208 条经验
# 训练 63 回合 12: 收集到 176 条经验
# 训练 63 回合 13: 收集到 272 条经验
# 训练 63 回合 14: 收集到 272 条经验
# 训练 63 回合 15: 收集到 160 条经验
# 训练 63 回合 16: 收集到 144 条经验
# 训练 63 回合 17: 收集到 280 条经验
# 训练 63 回合 18: 收集到 240 条经验
# 训练 63 回合 19: 收集到 216 条经验
# 训练 63：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0063/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 4)
# +++++o+
# +++++++
# +++++++
# +++++++
# ++++x++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 4)
# +++++o+
# ++++o++
# +++++++
# +++++++
# ++++x++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++o+
# ++++o++
# ++++x++
# +++++++
# ++++x++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 6)
# +++++o+
# ++++o++
# ++++x++
# ++++++o
# ++++x++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 0)
# x++++o+
# ++++o++
# ++++x++
# ++++++o
# ++++x++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 1)
# x++++o+
# ++++o++
# ++++x++
# +o++++o
# ++++x++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 3)
# x++++o+
# ++++o++
# +++xx++
# +o++++o
# ++++x++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 2)
# x++++o+
# ++++o++
# +++xx++
# +oo+++o
# ++++x++
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 1)
# x++++o+
# +x++o++
# +++xx++
# +oo+++o
# ++++x++
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 2)
# x++++o+
# +x++o++
# +++xx++
# +oo+++o
# ++++x++
# +++++++
# ++o++++
# 第 11 步： 玩家 -1， 动作 (5, 5)
# x++++o+
# +x++o++
# +++xx++
# +oo+++o
# ++++x++
# +++++x+
# ++o++++
# 第 12 步： 玩家 1， 动作 (2, 6)
# x++++o+
# +x++o++
# +++xx+o
# +oo+++o
# ++++x++
# +++++x+
# ++o++++
# 第 13 步： 玩家 -1， 动作 (6, 1)
# x++++o+
# +x++o++
# +++xx+o
# +oo+++o
# ++++x++
# +++++x+
# +xo++++
# 第 14 步： 玩家 1， 动作 (3, 5)
# x++++o+
# +x++o++
# +++xx+o
# +oo++oo
# ++++x++
# +++++x+
# +xo++++
# 第 15 步： 玩家 -1， 动作 (1, 2)
# x++++o+
# +xx+o++
# +++xx+o
# +oo++oo
# ++++x++
# +++++x+
# +xo++++
# 第 16 步： 玩家 1， 动作 (1, 3)
# x++++o+
# +xxoo++
# +++xx+o
# +oo++oo
# ++++x++
# +++++x+
# +xo++++
# 第 17 步： 玩家 -1， 动作 (1, 6)
# x++++o+
# +xxoo+x
# +++xx+o
# +oo++oo
# ++++x++
# +++++x+
# +xo++++
# 第 18 步： 玩家 1， 动作 (6, 5)
# x++++o+
# +xxoo+x
# +++xx+o
# +oo++oo
# ++++x++
# +++++x+
# +xo++o+
# 第 19 步： 玩家 -1， 动作 (5, 1)
# x++++o+
# +xxoo+x
# +++xx+o
# +oo++oo
# ++++x++
# +x+++x+
# +xo++o+
# 第 20 步： 玩家 1， 动作 (3, 3)
# x++++o+
# +xxoo+x
# +++xx+o
# +ooo+oo
# ++++x++
# +x+++x+
# +xo++o+
# 第 21 步： 玩家 -1， 动作 (5, 4)
# x++++o+
# +xxoo+x
# +++xx+o
# +ooo+oo
# ++++x++
# +x++xx+
# +xo++o+
# 第 22 步： 玩家 1， 动作 (3, 4)
# x++++o+
# +xxoo+x
# +++xx+o
# +oooooo
# ++++x++
# +x++xx+
# +xo++o+
# 赢家 1
# 训练 64 回合 0: 收集到 296 条经验
# 训练 64 回合 1: 收集到 240 条经验
# 训练 64 回合 2: 收集到 216 条经验
# 训练 64 回合 3: 收集到 208 条经验
# 训练 64 回合 4: 收集到 304 条经验
# 训练 64 回合 5: 收集到 288 条经验
# 训练 64 回合 6: 收集到 232 条经验
# 训练 64 回合 7: 收集到 240 条经验
# 训练 64 回合 8: 收集到 160 条经验
# 训练 64 回合 9: 收集到 232 条经验
# 训练 64 回合 10: 收集到 200 条经验
# 训练 64 回合 11: 收集到 120 条经验
# 训练 64 回合 12: 收集到 144 条经验
# 训练 64 回合 13: 收集到 168 条经验
# 训练 64 回合 14: 收集到 336 条经验
# 训练 64 回合 15: 收集到 216 条经验
# 训练 64 回合 16: 收集到 224 条经验
# 训练 64 回合 17: 收集到 328 条经验
# 训练 64 回合 18: 收集到 192 条经验
# 训练 64 回合 19: 收集到 200 条经验
# 训练 64：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0064/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# x+o++++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 4)
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# x+o++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 6)
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# x+o+++x
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 4)
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# x+o+++x
# ++++o++
# 第 5 步： 玩家 -1， 动作 (4, 4)
# ++++o++
# +++++++
# +++++++
# +++++++
# ++++x++
# x+o+++x
# ++++o++
# 第 6 步： 玩家 1， 动作 (0, 2)
# ++o+o++
# +++++++
# +++++++
# +++++++
# ++++x++
# x+o+++x
# ++++o++
# 第 7 步： 玩家 -1， 动作 (2, 6)
# ++o+o++
# +++++++
# ++++++x
# +++++++
# ++++x++
# x+o+++x
# ++++o++
# 第 8 步： 玩家 1， 动作 (6, 2)
# ++o+o++
# +++++++
# ++++++x
# +++++++
# ++++x++
# x+o+++x
# ++o+o++
# 第 9 步： 玩家 -1， 动作 (3, 0)
# ++o+o++
# +++++++
# ++++++x
# x++++++
# ++++x++
# x+o+++x
# ++o+o++
# 第 10 步： 玩家 1， 动作 (5, 1)
# ++o+o++
# +++++++
# ++++++x
# x++++++
# ++++x++
# xoo+++x
# ++o+o++
# 第 11 步： 玩家 -1， 动作 (3, 4)
# ++o+o++
# +++++++
# ++++++x
# x+++x++
# ++++x++
# xoo+++x
# ++o+o++
# 第 12 步： 玩家 1， 动作 (2, 1)
# ++o+o++
# +++++++
# +o++++x
# x+++x++
# ++++x++
# xoo+++x
# ++o+o++
# 第 13 步： 玩家 -1， 动作 (6, 3)
# ++o+o++
# +++++++
# +o++++x
# x+++x++
# ++++x++
# xoo+++x
# ++oxo++
# 第 14 步： 玩家 1， 动作 (3, 2)
# ++o+o++
# +++++++
# +o++++x
# x+o+x++
# ++++x++
# xoo+++x
# ++oxo++
# 第 15 步： 玩家 -1， 动作 (2, 4)
# ++o+o++
# +++++++
# +o++x+x
# x+o+x++
# ++++x++
# xoo+++x
# ++oxo++
# 第 16 步： 玩家 1， 动作 (2, 0)
# ++o+o++
# +++++++
# oo++x+x
# x+o+x++
# ++++x++
# xoo+++x
# ++oxo++
# 第 17 步： 玩家 -1， 动作 (6, 6)
# ++o+o++
# +++++++
# oo++x+x
# x+o+x++
# ++++x++
# xoo+++x
# ++oxo+x
# 第 18 步： 玩家 1， 动作 (5, 3)
# ++o+o++
# +++++++
# oo++x+x
# x+o+x++
# ++++x++
# xooo++x
# ++oxo+x
# 第 19 步： 玩家 -1， 动作 (3, 1)
# ++o+o++
# +++++++
# oo++x+x
# xxo+x++
# ++++x++
# xooo++x
# ++oxo+x
# 第 20 步： 玩家 1， 动作 (1, 6)
# ++o+o++
# ++++++o
# oo++x+x
# xxo+x++
# ++++x++
# xooo++x
# ++oxo+x
# 第 21 步： 玩家 -1， 动作 (0, 0)
# x+o+o++
# ++++++o
# oo++x+x
# xxo+x++
# ++++x++
# xooo++x
# ++oxo+x
# 第 22 步： 玩家 1， 动作 (4, 5)
# x+o+o++
# ++++++o
# oo++x+x
# xxo+x++
# ++++xo+
# xooo++x
# ++oxo+x
# 第 23 步： 玩家 -1， 动作 (3, 5)
# x+o+o++
# ++++++o
# oo++x+x
# xxo+xx+
# ++++xo+
# xooo++x
# ++oxo+x
# 第 24 步： 玩家 1， 动作 (2, 3)
# x+o+o++
# ++++++o
# oo+ox+x
# xxo+xx+
# ++++xo+
# xooo++x
# ++oxo+x
# 第 25 步： 玩家 -1， 动作 (1, 1)
# x+o+o++
# +x++++o
# oo+ox+x
# xxo+xx+
# ++++xo+
# xooo++x
# ++oxo+x
# 第 26 步： 玩家 1， 动作 (6, 1)
# x+o+o++
# +x++++o
# oo+ox+x
# xxo+xx+
# ++++xo+
# xooo++x
# +ooxo+x
# 第 27 步： 玩家 -1， 动作 (5, 5)
# x+o+o++
# +x++++o
# oo+ox+x
# xxo+xx+
# ++++xo+
# xooo+xx
# +ooxo+x
# 第 28 步： 玩家 1， 动作 (3, 3)
# x+o+o++
# +x++++o
# oo+ox+x
# xxooxx+
# ++++xo+
# xooo+xx
# +ooxo+x
# 第 29 步： 玩家 -1， 动作 (2, 5)
# x+o+o++
# +x++++o
# oo+oxxx
# xxooxx+
# ++++xo+
# xooo+xx
# +ooxo+x
# 第 30 步： 玩家 1， 动作 (2, 2)
# x+o+o++
# +x++++o
# ooooxxx
# xxooxx+
# ++++xo+
# xooo+xx
# +ooxo+x
# 第 31 步： 玩家 -1， 动作 (0, 5)
# x+o+ox+
# +x++++o
# ooooxxx
# xxooxx+
# ++++xo+
# xooo+xx
# +ooxo+x
# 第 32 步： 玩家 1， 动作 (4, 2)
# x+o+ox+
# +x++++o
# ooooxxx
# xxooxx+
# ++o+xo+
# xooo+xx
# +ooxo+x
# 赢家 1
# 训练 65 回合 0: 收集到 232 条经验
# 训练 65 回合 1: 收集到 128 条经验
# 训练 65 回合 2: 收集到 320 条经验
# 训练 65 回合 3: 收集到 392 条经验
# 训练 65 回合 4: 收集到 192 条经验
# 训练 65 回合 5: 收集到 128 条经验
# 训练 65 回合 6: 收集到 200 条经验
# 训练 65 回合 7: 收集到 160 条经验
# 训练 65 回合 8: 收集到 200 条经验
# 训练 65 回合 9: 收集到 232 条经验
# 训练 65 回合 10: 收集到 184 条经验
# 训练 65 回合 11: 收集到 216 条经验
# 训练 65 回合 12: 收集到 112 条经验
# 训练 65 回合 13: 收集到 192 条经验
# 训练 65 回合 14: 收集到 136 条经验
# 训练 65 回合 15: 收集到 312 条经验
# 训练 65 回合 16: 收集到 168 条经验
# 训练 65 回合 17: 收集到 352 条经验
# 训练 65 回合 18: 收集到 168 条经验
# 训练 65 回合 19: 收集到 248 条经验
# 训练 65：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0065/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 2 步： 玩家 1， 动作 (6, 6)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# +o++++o
# 第 3 步： 玩家 -1， 动作 (4, 2)
# +++++++
# +++++++
# +x+++++
# +++++++
# ++x++++
# +++++++
# +o++++o
# 第 4 步： 玩家 1， 动作 (5, 5)
# +++++++
# +++++++
# +x+++++
# +++++++
# ++x++++
# +++++o+
# +o++++o
# 第 5 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++++++
# +x+++x+
# +++++++
# ++x++++
# +++++o+
# +o++++o
# 第 6 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +x+++x+
# +++++++
# ++x++++
# +++++o+
# +o++++o
# 第 7 步： 玩家 -1， 动作 (1, 5)
# +++o+++
# +++++x+
# +x+++x+
# +++++++
# ++x++++
# +++++o+
# +o++++o
# 第 8 步： 玩家 1， 动作 (3, 3)
# +++o+++
# +++++x+
# +x+++x+
# +++o+++
# ++x++++
# +++++o+
# +o++++o
# 第 9 步： 玩家 -1， 动作 (1, 4)
# +++o+++
# ++++xx+
# +x+++x+
# +++o+++
# ++x++++
# +++++o+
# +o++++o
# 第 10 步： 玩家 1， 动作 (3, 5)
# +++o+++
# ++++xx+
# +x+++x+
# +++o+o+
# ++x++++
# +++++o+
# +o++++o
# 第 11 步： 玩家 -1， 动作 (5, 2)
# +++o+++
# ++++xx+
# +x+++x+
# +++o+o+
# ++x++++
# ++x++o+
# +o++++o
# 第 12 步： 玩家 1， 动作 (5, 0)
# +++o+++
# ++++xx+
# +x+++x+
# +++o+o+
# ++x++++
# o+x++o+
# +o++++o
# 第 13 步： 玩家 -1， 动作 (2, 3)
# +++o+++
# ++++xx+
# +x+x+x+
# +++o+o+
# ++x++++
# o+x++o+
# +o++++o
# 第 14 步： 玩家 1， 动作 (4, 1)
# +++o+++
# ++++xx+
# +x+x+x+
# +++o+o+
# +ox++++
# o+x++o+
# +o++++o
# 第 15 步： 玩家 -1， 动作 (1, 6)
# +++o+++
# ++++xxx
# +x+x+x+
# +++o+o+
# +ox++++
# o+x++o+
# +o++++o
# 第 16 步： 玩家 1， 动作 (0, 6)
# +++o++o
# ++++xxx
# +x+x+x+
# +++o+o+
# +ox++++
# o+x++o+
# +o++++o
# 第 17 步： 玩家 -1， 动作 (6, 0)
# +++o++o
# ++++xxx
# +x+x+x+
# +++o+o+
# +ox++++
# o+x++o+
# xo++++o
# 第 18 步： 玩家 1， 动作 (3, 1)
# +++o++o
# ++++xxx
# +x+x+x+
# +o+o+o+
# +ox++++
# o+x++o+
# xo++++o
# 第 19 步： 玩家 -1， 动作 (2, 4)
# +++o++o
# ++++xxx
# +x+xxx+
# +o+o+o+
# +ox++++
# o+x++o+
# xo++++o
# 第 20 步： 玩家 1， 动作 (6, 4)
# +++o++o
# ++++xxx
# +x+xxx+
# +o+o+o+
# +ox++++
# o+x++o+
# xo++o+o
# 第 21 步： 玩家 -1， 动作 (2, 2)
# +++o++o
# ++++xxx
# +xxxxx+
# +o+o+o+
# +ox++++
# o+x++o+
# xo++o+o
# 赢家 -1
# 训练 66 回合 0: 收集到 232 条经验
# 训练 66 回合 1: 收集到 184 条经验
# 训练 66 回合 2: 收集到 168 条经验
# 训练 66 回合 3: 收集到 200 条经验
# 训练 66 回合 4: 收集到 248 条经验
# 训练 66 回合 5: 收集到 184 条经验
# 训练 66 回合 6: 收集到 192 条经验
# 训练 66 回合 7: 收集到 240 条经验
# 训练 66 回合 8: 收集到 120 条经验
# 训练 66 回合 9: 收集到 200 条经验
# 训练 66 回合 10: 收集到 152 条经验
# 训练 66 回合 11: 收集到 176 条经验
# 训练 66 回合 12: 收集到 104 条经验
# 训练 66 回合 13: 收集到 232 条经验
# 训练 66 回合 14: 收集到 280 条经验
# 训练 66 回合 15: 收集到 176 条经验
# 训练 66 回合 16: 收集到 272 条经验
# 训练 66 回合 17: 收集到 216 条经验
# 训练 66 回合 18: 收集到 232 条经验
# 训练 66 回合 19: 收集到 264 条经验
# 训练 66：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0066/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 6)
# ++++++o
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 3)
# ++++++o
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 6)
# ++++++o
# +++++++
# +++++++
# +++x+++
# +++++++
# ++++++o
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 2)
# ++++++o
# +++++++
# +++++++
# +++x+++
# ++x++++
# ++++++o
# +++++++
# 第 4 步： 玩家 1， 动作 (5, 0)
# ++++++o
# +++++++
# +++++++
# +++x+++
# ++x++++
# o+++++o
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 2)
# ++++++o
# ++x++++
# +++++++
# +++x+++
# ++x++++
# o+++++o
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 0)
# ++++++o
# ++x++++
# +++++++
# +++x+++
# o+x++++
# o+++++o
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 4)
# ++++++o
# ++x++++
# +++++++
# +++xx++
# o+x++++
# o+++++o
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 2)
# ++++++o
# ++x++++
# +++++++
# ++oxx++
# o+x++++
# o+++++o
# +++++++
# 第 9 步： 玩家 -1， 动作 (1, 3)
# ++++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x++++
# o+++++o
# +++++++
# 第 10 步： 玩家 1， 动作 (0, 0)
# o+++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x++++
# o+++++o
# +++++++
# 第 11 步： 玩家 -1， 动作 (0, 1)
# ox++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x++++
# o+++++o
# +++++++
# 第 12 步： 玩家 1， 动作 (5, 2)
# ox++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x++++
# o+o+++o
# +++++++
# 第 13 步： 玩家 -1， 动作 (4, 5)
# ox++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x++x+
# o+o+++o
# +++++++
# 第 14 步： 玩家 1， 动作 (4, 4)
# ox++++o
# ++xx+++
# +++++++
# ++oxx++
# o+x+ox+
# o+o+++o
# +++++++
# 第 15 步： 玩家 -1， 动作 (2, 3)
# ox++++o
# ++xx+++
# +++x+++
# ++oxx++
# o+x+ox+
# o+o+++o
# +++++++
# 赢家 -1
# 训练 67 回合 0: 收集到 336 条经验
# 训练 67 回合 1: 收集到 200 条经验
# 训练 67 回合 2: 收集到 152 条经验
# 训练 67 回合 3: 收集到 248 条经验
# 训练 67 回合 4: 收集到 184 条经验
# 训练 67 回合 5: 收集到 208 条经验
# 训练 67 回合 6: 收集到 264 条经验
# 训练 67 回合 7: 收集到 200 条经验
# 训练 67 回合 8: 收集到 200 条经验
# 训练 67 回合 9: 收集到 192 条经验
# 训练 67 回合 10: 收集到 312 条经验
# 训练 67 回合 11: 收集到 136 条经验
# 训练 67 回合 12: 收集到 136 条经验
# 训练 67 回合 13: 收集到 216 条经验
# 训练 67 回合 14: 收集到 320 条经验
# 训练 67 回合 15: 收集到 216 条经验
# 训练 67 回合 16: 收集到 216 条经验
# 训练 67 回合 17: 收集到 176 条经验
# 训练 67 回合 18: 收集到 240 条经验
# 训练 67 回合 19: 收集到 144 条经验
# 训练 67：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0067/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 6)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 4)
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++++o
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 5)
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++oo
# +++++++
# 第 3 步： 玩家 -1， 动作 (6, 4)
# ++++x++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++oo
# ++++x++
# 第 4 步： 玩家 1， 动作 (2, 3)
# ++++x++
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++oo
# ++++x++
# 第 5 步： 玩家 -1， 动作 (2, 1)
# ++++x++
# +++++++
# +x+o+++
# +++++++
# +++++++
# +++++oo
# ++++x++
# 第 6 步： 玩家 1， 动作 (3, 3)
# ++++x++
# +++++++
# +x+o+++
# +++o+++
# +++++++
# +++++oo
# ++++x++
# 第 7 步： 玩家 -1， 动作 (4, 0)
# ++++x++
# +++++++
# +x+o+++
# +++o+++
# x++++++
# +++++oo
# ++++x++
# 第 8 步： 玩家 1， 动作 (5, 3)
# ++++x++
# +++++++
# +x+o+++
# +++o+++
# x++++++
# +++o+oo
# ++++x++
# 第 9 步： 玩家 -1， 动作 (0, 2)
# ++x+x++
# +++++++
# +x+o+++
# +++o+++
# x++++++
# +++o+oo
# ++++x++
# 第 10 步： 玩家 1， 动作 (3, 1)
# ++x+x++
# +++++++
# +x+o+++
# +o+o+++
# x++++++
# +++o+oo
# ++++x++
# 第 11 步： 玩家 -1， 动作 (0, 1)
# +xx+x++
# +++++++
# +x+o+++
# +o+o+++
# x++++++
# +++o+oo
# ++++x++
# 第 12 步： 玩家 1， 动作 (2, 0)
# +xx+x++
# +++++++
# ox+o+++
# +o+o+++
# x++++++
# +++o+oo
# ++++x++
# 第 13 步： 玩家 -1， 动作 (5, 4)
# +xx+x++
# +++++++
# ox+o+++
# +o+o+++
# x++++++
# +++oxoo
# ++++x++
# 第 14 步： 玩家 1， 动作 (3, 6)
# +xx+x++
# +++++++
# ox+o+++
# +o+o++o
# x++++++
# +++oxoo
# ++++x++
# 第 15 步： 玩家 -1， 动作 (2, 2)
# +xx+x++
# +++++++
# oxxo+++
# +o+o++o
# x++++++
# +++oxoo
# ++++x++
# 第 16 步： 玩家 1， 动作 (6, 6)
# +xx+x++
# +++++++
# oxxo+++
# +o+o++o
# x++++++
# +++oxoo
# ++++x+o
# 第 17 步： 玩家 -1， 动作 (1, 6)
# +xx+x++
# ++++++x
# oxxo+++
# +o+o++o
# x++++++
# +++oxoo
# ++++x+o
# 第 18 步： 玩家 1， 动作 (4, 3)
# +xx+x++
# ++++++x
# oxxo+++
# +o+o++o
# x++o+++
# +++oxoo
# ++++x+o
# 第 19 步： 玩家 -1， 动作 (3, 4)
# +xx+x++
# ++++++x
# oxxo+++
# +o+ox+o
# x++o+++
# +++oxoo
# ++++x+o
# 第 20 步： 玩家 1， 动作 (2, 6)
# +xx+x++
# ++++++x
# oxxo++o
# +o+ox+o
# x++o+++
# +++oxoo
# ++++x+o
# 第 21 步： 玩家 -1， 动作 (4, 6)
# +xx+x++
# ++++++x
# oxxo++o
# +o+ox+o
# x++o++x
# +++oxoo
# ++++x+o
# 第 22 步： 玩家 1， 动作 (0, 3)
# +xxox++
# ++++++x
# oxxo++o
# +o+ox+o
# x++o++x
# +++oxoo
# ++++x+o
# 第 23 步： 玩家 -1， 动作 (4, 5)
# +xxox++
# ++++++x
# oxxo++o
# +o+ox+o
# x++o+xx
# +++oxoo
# ++++x+o
# 第 24 步： 玩家 1， 动作 (2, 4)
# +xxox++
# ++++++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +++oxoo
# ++++x+o
# 第 25 步： 玩家 -1， 动作 (0, 0)
# xxxox++
# ++++++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +++oxoo
# ++++x+o
# 第 26 步： 玩家 1， 动作 (5, 1)
# xxxox++
# ++++++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +o+oxoo
# ++++x+o
# 第 27 步： 玩家 -1， 动作 (1, 2)
# xxxox++
# ++x+++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +o+oxoo
# ++++x+o
# 第 28 步： 玩家 1， 动作 (1, 1)
# xxxox++
# +ox+++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +o+oxoo
# ++++x+o
# 第 29 步： 玩家 -1， 动作 (6, 5)
# xxxox++
# +ox+++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +o+oxoo
# ++++xxo
# 第 30 步： 玩家 1， 动作 (1, 0)
# xxxox++
# oox+++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +o+oxoo
# ++++xxo
# 第 31 步： 玩家 -1， 动作 (5, 2)
# xxxox++
# oox+++x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +oxoxoo
# ++++xxo
# 第 32 步： 玩家 1， 动作 (1, 4)
# xxxox++
# oox+o+x
# oxxoo+o
# +o+ox+o
# x++o+xx
# +oxoxoo
# ++++xxo
# 第 33 步： 玩家 -1， 动作 (2, 5)
# xxxox++
# oox+o+x
# oxxooxo
# +o+ox+o
# x++o+xx
# +oxoxoo
# ++++xxo
# 第 34 步： 玩家 1， 动作 (1, 3)
# xxxox++
# ooxoo+x
# oxxooxo
# +o+ox+o
# x++o+xx
# +oxoxoo
# ++++xxo
# 赢家 1
# 训练 68 回合 0: 收集到 208 条经验
# 训练 68 回合 1: 收集到 264 条经验
# 训练 68 回合 2: 收集到 312 条经验
# 训练 68 回合 3: 收集到 224 条经验
# 训练 68 回合 4: 收集到 120 条经验
# 训练 68 回合 5: 收集到 208 条经验
# 训练 68 回合 6: 收集到 216 条经验
# 训练 68 回合 7: 收集到 304 条经验
# 训练 68 回合 8: 收集到 160 条经验
# 训练 68 回合 9: 收集到 216 条经验
# 训练 68 回合 10: 收集到 128 条经验
# 训练 68 回合 11: 收集到 176 条经验
# 训练 68 回合 12: 收集到 264 条经验
# 训练 68 回合 13: 收集到 208 条经验
# 训练 68 回合 14: 收集到 248 条经验
# 训练 68 回合 15: 收集到 200 条经验
# 训练 68 回合 16: 收集到 216 条经验
# 训练 68 回合 17: 收集到 216 条经验
# 训练 68 回合 18: 收集到 112 条经验
# 训练 68 回合 19: 收集到 216 条经验
# 训练 68：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0068/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+o+
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 2)
# +++++++
# +++x+o+
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (1, 1)
# +++++++
# +x+x+o+
# ++o++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 4)
# +++++++
# +x+x+o+
# ++o+o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 4)
# +++++++
# +x+xxo+
# ++o+o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (4, 3)
# +++++++
# +x+xxo+
# ++o+o++
# +++++++
# +++o+++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (0, 3)
# +++x+++
# +x+xxo+
# ++o+o++
# +++++++
# +++o+++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (3, 2)
# +++x+++
# +x+xxo+
# ++o+o++
# ++o++++
# +++o+++
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 1)
# +++x+++
# +x+xxo+
# ++o+o++
# +xo++++
# +++o+++
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (3, 4)
# +++x+++
# +x+xxo+
# ++o+o++
# +xo+o++
# +++o+++
# +++++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (3, 0)
# +++x+++
# +x+xxo+
# ++o+o++
# xxo+o++
# +++o+++
# +++++++
# +++++++
# 第 12 步： 玩家 1， 动作 (4, 5)
# +++x+++
# +x+xxo+
# ++o+o++
# xxo+o++
# +++o+o+
# +++++++
# +++++++
# 第 13 步： 玩家 -1， 动作 (6, 0)
# +++x+++
# +x+xxo+
# ++o+o++
# xxo+o++
# +++o+o+
# +++++++
# x++++++
# 第 14 步： 玩家 1， 动作 (0, 0)
# o++x+++
# +x+xxo+
# ++o+o++
# xxo+o++
# +++o+o+
# +++++++
# x++++++
# 第 15 步： 玩家 -1， 动作 (2, 5)
# o++x+++
# +x+xxo+
# ++o+ox+
# xxo+o++
# +++o+o+
# +++++++
# x++++++
# 第 16 步： 玩家 1， 动作 (3, 5)
# o++x+++
# +x+xxo+
# ++o+ox+
# xxo+oo+
# +++o+o+
# +++++++
# x++++++
# 第 17 步： 玩家 -1， 动作 (1, 2)
# o++x+++
# +xxxxo+
# ++o+ox+
# xxo+oo+
# +++o+o+
# +++++++
# x++++++
# 第 18 步： 玩家 1， 动作 (5, 3)
# o++x+++
# +xxxxo+
# ++o+ox+
# xxo+oo+
# +++o+o+
# +++o+++
# x++++++
# 第 19 步： 玩家 -1， 动作 (1, 0)
# o++x+++
# xxxxxo+
# ++o+ox+
# xxo+oo+
# +++o+o+
# +++o+++
# x++++++
# 赢家 -1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# 第 1 步： 玩家 -1， 动作 (3, 0)
# +++++++
# +++++++
# +++++++
# x++++++
# +++++++
# +++++++
# o++++++
# 第 2 步： 玩家 1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# x++++++
# +++++++
# ++++o++
# o++++++
# 第 3 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# x++++++
# +++++++
# x+++o++
# o++++++
# 第 4 步： 玩家 1， 动作 (1, 0)
# +++++++
# o++++++
# +++++++
# x++++++
# +++++++
# x+++o++
# o++++++
# 第 5 步： 玩家 -1， 动作 (5, 3)
# +++++++
# o++++++
# +++++++
# x++++++
# +++++++
# x++xo++
# o++++++
# 第 6 步： 玩家 1， 动作 (1, 3)
# +++++++
# o++o+++
# +++++++
# x++++++
# +++++++
# x++xo++
# o++++++
# 第 7 步： 玩家 -1， 动作 (4, 0)
# +++++++
# o++o+++
# +++++++
# x++++++
# x++++++
# x++xo++
# o++++++
# 第 8 步： 玩家 1， 动作 (3, 3)
# +++++++
# o++o+++
# +++++++
# x++o+++
# x++++++
# x++xo++
# o++++++
# 第 9 步： 玩家 -1， 动作 (6, 2)
# +++++++
# o++o+++
# +++++++
# x++o+++
# x++++++
# x++xo++
# o+x++++
# 第 10 步： 玩家 1， 动作 (2, 2)
# +++++++
# o++o+++
# ++o++++
# x++o+++
# x++++++
# x++xo++
# o+x++++
# 第 11 步： 玩家 -1， 动作 (3, 2)
# +++++++
# o++o+++
# ++o++++
# x+xo+++
# x++++++
# x++xo++
# o+x++++
# 第 12 步： 玩家 1， 动作 (0, 2)
# ++o++++
# o++o+++
# ++o++++
# x+xo+++
# x++++++
# x++xo++
# o+x++++
# 第 13 步： 玩家 -1， 动作 (2, 4)
# ++o++++
# o++o+++
# ++o+x++
# x+xo+++
# x++++++
# x++xo++
# o+x++++
# 第 14 步： 玩家 1， 动作 (6, 6)
# ++o++++
# o++o+++
# ++o+x++
# x+xo+++
# x++++++
# x++xo++
# o+x+++o
# 第 15 步： 玩家 -1， 动作 (0, 3)
# ++ox+++
# o++o+++
# ++o+x++
# x+xo+++
# x++++++
# x++xo++
# o+x+++o
# 第 16 步： 玩家 1， 动作 (3, 1)
# ++ox+++
# o++o+++
# ++o+x++
# xoxo+++
# x++++++
# x++xo++
# o+x+++o
# 第 17 步： 玩家 -1， 动作 (2, 0)
# ++ox+++
# o++o+++
# x+o+x++
# xoxo+++
# x++++++
# x++xo++
# o+x+++o
# 第 18 步： 玩家 1， 动作 (0, 4)
# ++oxo++
# o++o+++
# x+o+x++
# xoxo+++
# x++++++
# x++xo++
# o+x+++o
# 第 19 步： 玩家 -1， 动作 (4, 1)
# ++oxo++
# o++o+++
# x+o+x++
# xoxo+++
# xx+++++
# x++xo++
# o+x+++o
# 第 20 步： 玩家 1， 动作 (6, 4)
# ++oxo++
# o++o+++
# x+o+x++
# xoxo+++
# xx+++++
# x++xo++
# o+x+o+o
# 第 21 步： 玩家 -1， 动作 (5, 5)
# ++oxo++
# o++o+++
# x+o+x++
# xoxo+++
# xx+++++
# x++xox+
# o+x+o+o
# 第 22 步： 玩家 1， 动作 (4, 4)
# ++oxo++
# o++o+++
# x+o+x++
# xoxo+++
# xx++o++
# x++xox+
# o+x+o+o
# 第 23 步： 玩家 -1， 动作 (3, 4)
# ++oxo++
# o++o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xox+
# o+x+o+o
# 第 24 步： 玩家 1， 动作 (0, 0)
# o+oxo++
# o++o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xox+
# o+x+o+o
# 第 25 步： 玩家 -1， 动作 (1, 1)
# o+oxo++
# ox+o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xox+
# o+x+o+o
# 第 26 步： 玩家 1， 动作 (6, 3)
# o+oxo++
# ox+o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xox+
# o+xoo+o
# 第 27 步： 玩家 -1， 动作 (5, 6)
# o+oxo++
# ox+o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xoxx
# o+xoo+o
# 第 28 步： 玩家 1， 动作 (6, 1)
# o+oxo++
# ox+o+++
# x+o+x++
# xoxox++
# xx++o++
# x++xoxx
# ooxoo+o
# 第 29 步： 玩家 -1， 动作 (1, 2)
# o+oxo++
# oxxo+++
# x+o+x++
# xoxox++
# xx++o++
# x++xoxx
# ooxoo+o
# 第 30 步： 玩家 1， 动作 (4, 3)
# o+oxo++
# oxxo+++
# x+o+x++
# xoxox++
# xx+oo++
# x++xoxx
# ooxoo+o
# 第 31 步： 玩家 -1， 动作 (4, 6)
# o+oxo++
# oxxo+++
# x+o+x++
# xoxox++
# xx+oo+x
# x++xoxx
# ooxoo+o
# 第 32 步： 玩家 1， 动作 (3, 6)
# o+oxo++
# oxxo+++
# x+o+x++
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoo+o
# 第 33 步： 玩家 -1， 动作 (0, 6)
# o+oxo+x
# oxxo+++
# x+o+x++
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoo+o
# 第 34 步： 玩家 1， 动作 (6, 5)
# o+oxo+x
# oxxo+++
# x+o+x++
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 第 35 步： 玩家 -1， 动作 (1, 4)
# o+oxo+x
# oxxox++
# x+o+x++
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 第 36 步： 玩家 1， 动作 (2, 5)
# o+oxo+x
# oxxox++
# x+o+xo+
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 第 37 步： 玩家 -1， 动作 (0, 5)
# o+oxoxx
# oxxox++
# x+o+xo+
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 第 38 步： 玩家 1， 动作 (1, 5)
# o+oxoxx
# oxxoxo+
# x+o+xo+
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 第 39 步： 玩家 -1， 动作 (2, 3)
# o+oxoxx
# oxxoxo+
# x+oxxo+
# xoxox+o
# xx+oo+x
# x++xoxx
# ooxoooo
# 赢家 -1

# %% [markdown]
# ## 训练6 train_iterations = 10 从第69次迭代训练¶

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 69
iteration_old_save_model = 68
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 69 回合 0: 收集到 152 条经验
# 训练 69 回合 1: 收集到 216 条经验
# 训练 69 回合 2: 收集到 184 条经验
# 训练 69 回合 3: 收集到 248 条经验
# 训练 69 回合 4: 收集到 240 条经验
# 训练 69 回合 5: 收集到 160 条经验
# 训练 69 回合 6: 收集到 304 条经验
# 训练 69 回合 7: 收集到 168 条经验
# 训练 69 回合 8: 收集到 184 条经验
# 训练 69 回合 9: 收集到 248 条经验
# 训练 69 回合 10: 收集到 184 条经验
# 训练 69 回合 11: 收集到 216 条经验
# 训练 69 回合 12: 收集到 160 条经验
# 训练 69 回合 13: 收集到 184 条经验
# 训练 69 回合 14: 收集到 392 条经验
# 训练 69 回合 15: 收集到 184 条经验
# 训练 69 回合 16: 收集到 272 条经验
# 训练 69 回合 17: 收集到 208 条经验
# 训练 69 回合 18: 收集到 216 条经验
# 训练 69 回合 19: 收集到 216 条经验
# 训练 69：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0069/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 0)
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 1)
# +++++++
# +++++++
# o++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++++++
# o++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 1)
# +x+++o+
# +++++++
# o++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 2)
# +x+++o+
# +++++++
# o++++++
# +++++++
# +xo++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 5)
# +x+++o+
# +++++++
# o++++++
# +++++++
# +xo++x+
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (1, 3)
# +x+++o+
# +++o+++
# o++++++
# +++++++
# +xo++x+
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (6, 0)
# +x+++o+
# +++o+++
# o++++++
# +++++++
# +xo++x+
# +++++++
# x++++++
# 第 8 步： 玩家 1， 动作 (2, 1)
# +x+++o+
# +++o+++
# oo+++++
# +++++++
# +xo++x+
# +++++++
# x++++++
# 第 9 步： 玩家 -1， 动作 (2, 3)
# +x+++o+
# +++o+++
# oo+x+++
# +++++++
# +xo++x+
# +++++++
# x++++++
# 第 10 步： 玩家 1， 动作 (6, 2)
# +x+++o+
# +++o+++
# oo+x+++
# +++++++
# +xo++x+
# +++++++
# x+o++++
# 第 11 步： 玩家 -1， 动作 (4, 3)
# +x+++o+
# +++o+++
# oo+x+++
# +++++++
# +xox+x+
# +++++++
# x+o++++
# 第 12 步： 玩家 1， 动作 (2, 5)
# +x+++o+
# +++o+++
# oo+x+o+
# +++++++
# +xox+x+
# +++++++
# x+o++++
# 第 13 步： 玩家 -1， 动作 (6, 3)
# +x+++o+
# +++o+++
# oo+x+o+
# +++++++
# +xox+x+
# +++++++
# x+ox+++
# 第 14 步： 玩家 1， 动作 (5, 5)
# +x+++o+
# +++o+++
# oo+x+o+
# +++++++
# +xox+x+
# +++++o+
# x+ox+++
# 第 15 步： 玩家 -1， 动作 (5, 0)
# +x+++o+
# +++o+++
# oo+x+o+
# +++++++
# +xox+x+
# x++++o+
# x+ox+++
# 第 16 步： 玩家 1， 动作 (5, 3)
# +x+++o+
# +++o+++
# oo+x+o+
# +++++++
# +xox+x+
# x++o+o+
# x+ox+++
# 第 17 步： 玩家 -1， 动作 (3, 4)
# +x+++o+
# +++o+++
# oo+x+o+
# ++++x++
# +xox+x+
# x++o+o+
# x+ox+++
# 第 18 步： 玩家 1， 动作 (3, 3)
# +x+++o+
# +++o+++
# oo+x+o+
# +++ox++
# +xox+x+
# x++o+o+
# x+ox+++
# 第 19 步： 玩家 -1， 动作 (1, 2)
# +x+++o+
# ++xo+++
# oo+x+o+
# +++ox++
# +xox+x+
# x++o+o+
# x+ox+++
# 赢家 -1
# 训练 70 回合 0: 收集到 200 条经验
# 训练 70 回合 1: 收集到 240 条经验
# 训练 70 回合 2: 收集到 176 条经验
# 训练 70 回合 3: 收集到 288 条经验
# 训练 70 回合 4: 收集到 208 条经验
# 训练 70 回合 5: 收集到 264 条经验
# 训练 70 回合 6: 收集到 208 条经验
# 训练 70 回合 7: 收集到 272 条经验
# 训练 70 回合 8: 收集到 160 条经验
# 训练 70 回合 9: 收集到 192 条经验
# 训练 70 回合 10: 收集到 216 条经验
# 训练 70 回合 11: 收集到 144 条经验
# 训练 70 回合 12: 收集到 184 条经验
# 训练 70 回合 13: 收集到 336 条经验
# 训练 70 回合 14: 收集到 216 条经验
# 训练 70 回合 15: 收集到 248 条经验
# 训练 70 回合 16: 收集到 184 条经验
# 训练 70 回合 17: 收集到 152 条经验
# 训练 70 回合 18: 收集到 304 条经验
# 训练 70 回合 19: 收集到 248 条经验
# 训练 70：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0070/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (5, 5)
# +x+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++++o+
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 3)
# +x+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# +++x+o+
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 5)
# +x+++o+
# +++++++
# +++++++
# +++++++
# ++o++++
# +++x+o+
# +++++++
# 第 5 步： 玩家 -1， 动作 (0, 4)
# +x++xo+
# +++++++
# +++++++
# +++++++
# ++o++++
# +++x+o+
# +++++++
# 第 6 步： 玩家 1， 动作 (2, 2)
# +x++xo+
# +++++++
# ++o++++
# +++++++
# ++o++++
# +++x+o+
# +++++++
# 第 7 步： 玩家 -1， 动作 (5, 1)
# +x++xo+
# +++++++
# ++o++++
# +++++++
# ++o++++
# +x+x+o+
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 0)
# +x++xo+
# +++++++
# ++o++++
# +++++++
# o+o++++
# +x+x+o+
# +++++++
# 第 9 步： 玩家 -1， 动作 (2, 4)
# +x++xo+
# +++++++
# ++o+x++
# +++++++
# o+o++++
# +x+x+o+
# +++++++
# 第 10 步： 玩家 1， 动作 (1, 2)
# +x++xo+
# ++o++++
# ++o+x++
# +++++++
# o+o++++
# +x+x+o+
# +++++++
# 第 11 步： 玩家 -1， 动作 (5, 6)
# +x++xo+
# ++o++++
# ++o+x++
# +++++++
# o+o++++
# +x+x+ox
# +++++++
# 第 12 步： 玩家 1， 动作 (3, 5)
# +x++xo+
# ++o++++
# ++o+x++
# +++++o+
# o+o++++
# +x+x+ox
# +++++++
# 第 13 步： 玩家 -1， 动作 (1, 1)
# +x++xo+
# +xo++++
# ++o+x++
# +++++o+
# o+o++++
# +x+x+ox
# +++++++
# 第 14 步： 玩家 1， 动作 (3, 3)
# +x++xo+
# +xo++++
# ++o+x++
# +++o+o+
# o+o++++
# +x+x+ox
# +++++++
# 第 15 步： 玩家 -1， 动作 (3, 4)
# +x++xo+
# +xo++++
# ++o+x++
# +++oxo+
# o+o++++
# +x+x+ox
# +++++++
# 第 16 步： 玩家 1， 动作 (4, 3)
# +x++xo+
# +xo++++
# ++o+x++
# +++oxo+
# o+oo+++
# +x+x+ox
# +++++++
# 第 17 步： 玩家 -1， 动作 (1, 3)
# +x++xo+
# +xox+++
# ++o+x++
# +++oxo+
# o+oo+++
# +x+x+ox
# +++++++
# 第 18 步： 玩家 1， 动作 (2, 3)
# +x++xo+
# +xox+++
# ++oox++
# +++oxo+
# o+oo+++
# +x+x+ox
# +++++++
# 第 19 步： 玩家 -1， 动作 (5, 2)
# +x++xo+
# +xox+++
# ++oox++
# +++oxo+
# o+oo+++
# +xxx+ox
# +++++++
# 第 20 步： 玩家 1， 动作 (4, 5)
# +x++xo+
# +xox+++
# ++oox++
# +++oxo+
# o+oo+o+
# +xxx+ox
# +++++++
# 第 21 步： 玩家 -1， 动作 (3, 2)
# +x++xo+
# +xox+++
# ++oox++
# ++xoxo+
# o+oo+o+
# +xxx+ox
# +++++++
# 第 22 步： 玩家 1， 动作 (2, 5)
# +x++xo+
# +xox+++
# ++ooxo+
# ++xoxo+
# o+oo+o+
# +xxx+ox
# +++++++
# 第 23 步： 玩家 -1， 动作 (4, 4)
# +x++xo+
# +xox+++
# ++ooxo+
# ++xoxo+
# o+ooxo+
# +xxx+ox
# +++++++
# 第 24 步： 玩家 1， 动作 (6, 6)
# +x++xo+
# +xox+++
# ++ooxo+
# ++xoxo+
# o+ooxo+
# +xxx+ox
# ++++++o
# 第 25 步： 玩家 -1， 动作 (1, 4)
# +x++xo+
# +xoxx++
# ++ooxo+
# ++xoxo+
# o+ooxo+
# +xxx+ox
# ++++++o
# 赢家 -1
# 训练 71 回合 0: 收集到 256 条经验
# 训练 71 回合 1: 收集到 248 条经验
# 训练 71 回合 2: 收集到 184 条经验
# 训练 71 回合 3: 收集到 216 条经验
# 训练 71 回合 4: 收集到 352 条经验
# 训练 71 回合 5: 收集到 136 条经验
# 训练 71 回合 6: 收集到 192 条经验
# 训练 71 回合 7: 收集到 216 条经验
# 训练 71 回合 8: 收集到 264 条经验
# 训练 71 回合 9: 收集到 352 条经验
# 训练 71 回合 10: 收集到 256 条经验
# 训练 71 回合 11: 收集到 264 条经验
# 训练 71 回合 12: 收集到 136 条经验
# 训练 71 回合 13: 收集到 392 条经验
# 训练 71 回合 14: 收集到 184 条经验
# 训练 71 回合 15: 收集到 216 条经验
# 训练 71 回合 16: 收集到 224 条经验
# 训练 71 回合 17: 收集到 104 条经验
# 训练 71 回合 18: 收集到 176 条经验
# 训练 71 回合 19: 收集到 248 条经验
# 训练 71：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0071/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 1 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 2 步： 玩家 1， 动作 (0, 4)
# ++++o++
# x++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 3 步： 玩家 -1， 动作 (2, 0)
# ++++o++
# x++++++
# x++++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 4 步： 玩家 1， 动作 (2, 1)
# ++++o++
# x++++++
# xo+++++
# +++++++
# +++++++
# +++++++
# ++o++++
# 第 5 步： 玩家 -1， 动作 (4, 5)
# ++++o++
# x++++++
# xo+++++
# +++++++
# +++++x+
# +++++++
# ++o++++
# 第 6 步： 玩家 1， 动作 (2, 3)
# ++++o++
# x++++++
# xo+o+++
# +++++++
# +++++x+
# +++++++
# ++o++++
# 第 7 步： 玩家 -1， 动作 (6, 4)
# ++++o++
# x++++++
# xo+o+++
# +++++++
# +++++x+
# +++++++
# ++o+x++
# 第 8 步： 玩家 1， 动作 (5, 4)
# ++++o++
# x++++++
# xo+o+++
# +++++++
# +++++x+
# ++++o++
# ++o+x++
# 第 9 步： 玩家 -1， 动作 (6, 0)
# ++++o++
# x++++++
# xo+o+++
# +++++++
# +++++x+
# ++++o++
# x+o+x++
# 第 10 步： 玩家 1， 动作 (0, 0)
# o+++o++
# x++++++
# xo+o+++
# +++++++
# +++++x+
# ++++o++
# x+o+x++
# 第 11 步： 玩家 -1， 动作 (2, 5)
# o+++o++
# x++++++
# xo+o+x+
# +++++++
# +++++x+
# ++++o++
# x+o+x++
# 第 12 步： 玩家 1， 动作 (5, 1)
# o+++o++
# x++++++
# xo+o+x+
# +++++++
# +++++x+
# +o++o++
# x+o+x++
# 第 13 步： 玩家 -1， 动作 (5, 0)
# o+++o++
# x++++++
# xo+o+x+
# +++++++
# +++++x+
# xo++o++
# x+o+x++
# 第 14 步： 玩家 1， 动作 (0, 2)
# o+o+o++
# x++++++
# xo+o+x+
# +++++++
# +++++x+
# xo++o++
# x+o+x++
# 第 15 步： 玩家 -1， 动作 (5, 6)
# o+o+o++
# x++++++
# xo+o+x+
# +++++++
# +++++x+
# xo++o+x
# x+o+x++
# 第 16 步： 玩家 1， 动作 (4, 2)
# o+o+o++
# x++++++
# xo+o+x+
# +++++++
# ++o++x+
# xo++o+x
# x+o+x++
# 第 17 步： 玩家 -1， 动作 (3, 0)
# o+o+o++
# x++++++
# xo+o+x+
# x++++++
# ++o++x+
# xo++o+x
# x+o+x++
# 第 18 步： 玩家 1， 动作 (3, 4)
# o+o+o++
# x++++++
# xo+o+x+
# x+++o++
# ++o++x+
# xo++o+x
# x+o+x++
# 第 19 步： 玩家 -1， 动作 (4, 0)
# o+o+o++
# x++++++
# xo+o+x+
# x+++o++
# x+o++x+
# xo++o+x
# x+o+x++
# 赢家 -1
# 训练 72 回合 0: 收集到 96 条经验
# 训练 72 回合 1: 收集到 232 条经验
# 训练 72 回合 2: 收集到 296 条经验
# 训练 72 回合 3: 收集到 128 条经验
# 训练 72 回合 4: 收集到 208 条经验
# 训练 72 回合 5: 收集到 392 条经验
# 训练 72 回合 6: 收集到 296 条经验
# 训练 72 回合 7: 收集到 320 条经验
# 训练 72 回合 8: 收集到 104 条经验
# 训练 72 回合 9: 收集到 120 条经验
# 训练 72 回合 10: 收集到 192 条经验
# 训练 72 回合 11: 收集到 240 条经验
# 训练 72 回合 12: 收集到 176 条经验
# 训练 72 回合 13: 收集到 200 条经验
# 训练 72 回合 14: 收集到 232 条经验
# 训练 72 回合 15: 收集到 248 条经验
# 训练 72 回合 16: 收集到 176 条经验
# 训练 72 回合 17: 收集到 304 条经验
# 训练 72 回合 18: 收集到 184 条经验
# 训练 72 回合 19: 收集到 160 条经验
# 训练 72：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0072/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# 第 1 步： 玩家 -1， 动作 (5, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# x++++++
# +++o+++
# 第 2 步： 玩家 1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# x++++++
# +++o+++
# 第 3 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+++
# +++++++
# +++o+++
# +++++++
# x++++++
# +++o+++
# 第 4 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++x+++
# +++++++
# +++o+o+
# +++++++
# x++++++
# +++o+++
# 第 5 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++++++
# x++++++
# +++o+++
# 第 6 步： 玩家 1， 动作 (4, 3)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++o+++
# x++++++
# +++o+++
# 第 7 步： 玩家 -1， 动作 (6, 6)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++o+++
# x++++++
# +++o++x
# 第 8 步： 玩家 1， 动作 (5, 3)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++o+++
# x++o+++
# +++o++x
# 第 9 步： 玩家 -1， 动作 (6, 2)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++o+++
# x++o+++
# ++xo++x
# 第 10 步： 玩家 1， 动作 (4, 6)
# +++++++
# x++x+++
# +++++++
# +++o+o+
# +++o++o
# x++o+++
# ++xo++x
# 第 11 步： 玩家 -1， 动作 (3, 0)
# +++++++
# x++x+++
# +++++++
# x++o+o+
# +++o++o
# x++o+++
# ++xo++x
# 第 12 步： 玩家 1， 动作 (6, 5)
# +++++++
# x++x+++
# +++++++
# x++o+o+
# +++o++o
# x++o+++
# ++xo+ox
# 第 13 步： 玩家 -1， 动作 (1, 2)
# +++++++
# x+xx+++
# +++++++
# x++o+o+
# +++o++o
# x++o+++
# ++xo+ox
# 第 14 步： 玩家 1， 动作 (2, 3)
# +++++++
# x+xx+++
# +++o+++
# x++o+o+
# +++o++o
# x++o+++
# ++xo+ox
# 赢家 1
# 训练 73 回合 0: 收集到 160 条经验
# 训练 73 回合 1: 收集到 232 条经验
# 训练 73 回合 2: 收集到 272 条经验
# 训练 73 回合 3: 收集到 200 条经验
# 训练 73 回合 4: 收集到 224 条经验
# 训练 73 回合 5: 收集到 176 条经验
# 训练 73 回合 6: 收集到 136 条经验
# 训练 73 回合 7: 收集到 208 条经验
# 训练 73 回合 8: 收集到 392 条经验
# 训练 73 回合 9: 收集到 216 条经验
# 训练 73 回合 10: 收集到 200 条经验
# 训练 73 回合 11: 收集到 208 条经验
# 训练 73 回合 12: 收集到 288 条经验
# 训练 73 回合 13: 收集到 248 条经验
# 训练 73 回合 14: 收集到 272 条经验
# 训练 73 回合 15: 收集到 256 条经验
# 训练 73 回合 16: 收集到 248 条经验
# 训练 73 回合 17: 收集到 192 条经验
# 训练 73 回合 18: 收集到 192 条经验
# 训练 73 回合 19: 收集到 312 条经验
# 训练 73：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0073/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 3)
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 2)
# +++o+++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 1)
# +++o+++
# +o+++++
# ++x++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 2)
# +++o+++
# +o+++++
# ++x++++
# +++++++
# ++x++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 2)
# +++o+++
# +o+++++
# ++x++++
# ++o++++
# ++x++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (4, 6)
# +++o+++
# +o+++++
# ++x++++
# ++o++++
# ++x+++x
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (2, 1)
# +++o+++
# +o+++++
# +ox++++
# ++o++++
# ++x+++x
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 1)
# +++o+++
# +o+++++
# +ox++++
# +xo++++
# ++x+++x
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (6, 3)
# +++o+++
# +o+++++
# +ox++++
# +xo++++
# ++x+++x
# +++++++
# +++o+++
# 第 9 步： 玩家 -1， 动作 (6, 4)
# +++o+++
# +o+++++
# +ox++++
# +xo++++
# ++x+++x
# +++++++
# +++ox++
# 第 10 步： 玩家 1， 动作 (5, 0)
# +++o+++
# +o+++++
# +ox++++
# +xo++++
# ++x+++x
# o++++++
# +++ox++
# 第 11 步： 玩家 -1， 动作 (3, 5)
# +++o+++
# +o+++++
# +ox++++
# +xo++x+
# ++x+++x
# o++++++
# +++ox++
# 第 12 步： 玩家 1， 动作 (1, 5)
# +++o+++
# +o+++o+
# +ox++++
# +xo++x+
# ++x+++x
# o++++++
# +++ox++
# 第 13 步： 玩家 -1， 动作 (3, 0)
# +++o+++
# +o+++o+
# +ox++++
# xxo++x+
# ++x+++x
# o++++++
# +++ox++
# 第 14 步： 玩家 1， 动作 (3, 4)
# +++o+++
# +o+++o+
# +ox++++
# xxo+ox+
# ++x+++x
# o++++++
# +++ox++
# 第 15 步： 玩家 -1， 动作 (2, 3)
# +++o+++
# +o+++o+
# +oxx+++
# xxo+ox+
# ++x+++x
# o++++++
# +++ox++
# 第 16 步： 玩家 1， 动作 (5, 5)
# +++o+++
# +o+++o+
# +oxx+++
# xxo+ox+
# ++x+++x
# o++++o+
# +++ox++
# 第 17 步： 玩家 -1， 动作 (3, 3)
# +++o+++
# +o+++o+
# +oxx+++
# xxoxox+
# ++x+++x
# o++++o+
# +++ox++
# 第 18 步： 玩家 1， 动作 (5, 6)
# +++o+++
# +o+++o+
# +oxx+++
# xxoxox+
# ++x+++x
# o++++oo
# +++ox++
# 第 19 步： 玩家 -1， 动作 (5, 4)
# +++o+++
# +o+++o+
# +oxx+++
# xxoxox+
# ++x+++x
# o+++xoo
# +++ox++
# 第 20 步： 玩家 1， 动作 (0, 2)
# ++oo+++
# +o+++o+
# +oxx+++
# xxoxox+
# ++x+++x
# o+++xoo
# +++ox++
# 第 21 步： 玩家 -1， 动作 (1, 3)
# ++oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+++x
# o+++xoo
# +++ox++
# 第 22 步： 玩家 1， 动作 (5, 2)
# ++oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+++x
# o+o+xoo
# +++ox++
# 第 23 步： 玩家 -1， 动作 (6, 6)
# ++oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+++x
# o+o+xoo
# +++ox+x
# 第 24 步： 玩家 1， 动作 (4, 4)
# ++oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+o+xoo
# +++ox+x
# 第 25 步： 玩家 -1， 动作 (0, 0)
# x+oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+o+xoo
# +++ox+x
# 第 26 步： 玩家 1， 动作 (5, 3)
# x+oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+ooxoo
# +++ox+x
# 第 27 步： 玩家 -1， 动作 (6, 1)
# x+oo+++
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 28 步： 玩家 1， 动作 (0, 6)
# x+oo++o
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 29 步： 玩家 -1， 动作 (0, 1)
# xxoo++o
# +o+x+o+
# +oxx+++
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 30 步： 玩家 1， 动作 (2, 6)
# xxoo++o
# +o+x+o+
# +oxx++o
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 31 步： 玩家 -1， 动作 (1, 6)
# xxoo++o
# +o+x+ox
# +oxx++o
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 32 步： 玩家 1， 动作 (0, 5)
# xxoo+oo
# +o+x+ox
# +oxx++o
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 33 步： 玩家 -1， 动作 (0, 4)
# xxooxoo
# +o+x+ox
# +oxx++o
# xxoxox+
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 34 步： 玩家 1， 动作 (3, 6)
# xxooxoo
# +o+x+ox
# +oxx++o
# xxoxoxo
# ++x+o+x
# o+ooxoo
# +x+ox+x
# 第 35 步： 玩家 -1， 动作 (4, 0)
# xxooxoo
# +o+x+ox
# +oxx++o
# xxoxoxo
# x+x+o+x
# o+ooxoo
# +x+ox+x
# 赢家 -1
# 训练 74 回合 0: 收集到 232 条经验
# 训练 74 回合 1: 收集到 136 条经验
# 训练 74 回合 2: 收集到 216 条经验
# 训练 74 回合 3: 收集到 216 条经验
# 训练 74 回合 4: 收集到 256 条经验
# 训练 74 回合 5: 收集到 192 条经验
# 训练 74 回合 6: 收集到 168 条经验
# 训练 74 回合 7: 收集到 152 条经验
# 训练 74 回合 8: 收集到 112 条经验
# 训练 74 回合 9: 收集到 168 条经验
# 训练 74 回合 10: 收集到 320 条经验
# 训练 74 回合 11: 收集到 216 条经验
# 训练 74 回合 12: 收集到 392 条经验
# 训练 74 回合 13: 收集到 168 条经验
# 训练 74 回合 14: 收集到 192 条经验
# 训练 74 回合 15: 收集到 224 条经验
# 训练 74 回合 16: 收集到 256 条经验
# 训练 74 回合 17: 收集到 168 条经验
# 训练 74 回合 18: 收集到 240 条经验
# 训练 74 回合 19: 收集到 240 条经验
# 训练 74：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0074/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 4)
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# ++xo+++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 1)
# +++++++
# ++++o++
# +++++++
# +x+++++
# +++++++
# ++xo+++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 0)
# +++++++
# ++++o++
# +++++++
# +x+++++
# o++++++
# ++xo+++
# +++++++
# 第 5 步： 玩家 -1， 动作 (6, 3)
# +++++++
# ++++o++
# +++++++
# +x+++++
# o++++++
# ++xo+++
# +++x+++
# 第 6 步： 玩家 1， 动作 (1, 6)
# +++++++
# ++++o+o
# +++++++
# +x+++++
# o++++++
# ++xo+++
# +++x+++
# 第 7 步： 玩家 -1， 动作 (4, 6)
# +++++++
# ++++o+o
# +++++++
# +x+++++
# o+++++x
# ++xo+++
# +++x+++
# 第 8 步： 玩家 1， 动作 (5, 0)
# +++++++
# ++++o+o
# +++++++
# +x+++++
# o+++++x
# o+xo+++
# +++x+++
# 第 9 步： 玩家 -1， 动作 (4, 3)
# +++++++
# ++++o+o
# +++++++
# +x+++++
# o++x++x
# o+xo+++
# +++x+++
# 第 10 步： 玩家 1， 动作 (2, 3)
# +++++++
# ++++o+o
# +++o+++
# +x+++++
# o++x++x
# o+xo+++
# +++x+++
# 第 11 步： 玩家 -1， 动作 (2, 4)
# +++++++
# ++++o+o
# +++ox++
# +x+++++
# o++x++x
# o+xo+++
# +++x+++
# 第 12 步： 玩家 1， 动作 (1, 1)
# +++++++
# +o++o+o
# +++ox++
# +x+++++
# o++x++x
# o+xo+++
# +++x+++
# 第 13 步： 玩家 -1， 动作 (1, 5)
# +++++++
# +o++oxo
# +++ox++
# +x+++++
# o++x++x
# o+xo+++
# +++x+++
# 第 14 步： 玩家 1， 动作 (5, 4)
# +++++++
# +o++oxo
# +++ox++
# +x+++++
# o++x++x
# o+xoo++
# +++x+++
# 第 15 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +o++oxo
# ++xox++
# +x+++++
# o++x++x
# o+xoo++
# +++x+++
# 第 16 步： 玩家 1， 动作 (3, 5)
# +++++++
# +o++oxo
# ++xox++
# +x+++o+
# o++x++x
# o+xoo++
# +++x+++
# 第 17 步： 玩家 -1， 动作 (6, 6)
# +++++++
# +o++oxo
# ++xox++
# +x+++o+
# o++x++x
# o+xoo++
# +++x++x
# 第 18 步： 玩家 1， 动作 (3, 3)
# +++++++
# +o++oxo
# ++xox++
# +x+o+o+
# o++x++x
# o+xoo++
# +++x++x
# 第 19 步： 玩家 -1， 动作 (6, 2)
# +++++++
# +o++oxo
# ++xox++
# +x+o+o+
# o++x++x
# o+xoo++
# ++xx++x
# 第 20 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +o++oxo
# ++xox++
# +x+o+o+
# o++x++x
# o+xoo++
# ++xx++x
# 第 21 步： 玩家 -1， 动作 (2, 0)
# +++++o+
# +o++oxo
# x+xox++
# +x+o+o+
# o++x++x
# o+xoo++
# ++xx++x
# 第 22 步： 玩家 1， 动作 (5, 1)
# +++++o+
# +o++oxo
# x+xox++
# +x+o+o+
# o++x++x
# ooxoo++
# ++xx++x
# 第 23 步： 玩家 -1， 动作 (3, 6)
# +++++o+
# +o++oxo
# x+xox++
# +x+o+ox
# o++x++x
# ooxoo++
# ++xx++x
# 第 24 步： 玩家 1， 动作 (6, 4)
# +++++o+
# +o++oxo
# x+xox++
# +x+o+ox
# o++x++x
# ooxoo++
# ++xxo+x
# 第 25 步： 玩家 -1， 动作 (4, 2)
# +++++o+
# +o++oxo
# x+xox++
# +x+o+ox
# o+xx++x
# ooxoo++
# ++xxo+x
# 第 26 步： 玩家 1， 动作 (0, 0)
# o++++o+
# +o++oxo
# x+xox++
# +x+o+ox
# o+xx++x
# ooxoo++
# ++xxo+x
# 第 27 步： 玩家 -1， 动作 (3, 2)
# o++++o+
# +o++oxo
# x+xox++
# +xxo+ox
# o+xx++x
# ooxoo++
# ++xxo+x
# 赢家 -1
# 训练 75 回合 0: 收集到 152 条经验
# 训练 75 回合 1: 收集到 312 条经验
# 训练 75 回合 2: 收集到 192 条经验
# 训练 75 回合 3: 收集到 184 条经验
# 训练 75 回合 4: 收集到 144 条经验
# 训练 75 回合 5: 收集到 200 条经验
# 训练 75 回合 6: 收集到 232 条经验
# 训练 75 回合 7: 收集到 120 条经验
# 训练 75 回合 8: 收集到 256 条经验
# 训练 75 回合 9: 收集到 168 条经验
# 训练 75 回合 10: 收集到 128 条经验
# 训练 75 回合 11: 收集到 136 条经验
# 训练 75 回合 12: 收集到 392 条经验
# 训练 75 回合 13: 收集到 176 条经验
# 训练 75 回合 14: 收集到 200 条经验
# 训练 75 回合 15: 收集到 224 条经验
# 训练 75 回合 16: 收集到 272 条经验
# 训练 75 回合 17: 收集到 200 条经验
# 训练 75 回合 18: 收集到 192 条经验
# 训练 75 回合 19: 收集到 232 条经验
# 训练 75：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0075/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +++++++
# +++++o+
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++x+o+
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 4)
# +++++++
# +++++++
# +++++++
# +++x+o+
# +++++++
# +++++++
# ++++o++
# 第 3 步： 玩家 -1， 动作 (6, 1)
# +++++++
# +++++++
# +++++++
# +++x+o+
# +++++++
# +++++++
# +x++o++
# 第 4 步： 玩家 1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++x+o+
# +++++++
# +++++++
# +x+oo++
# 第 5 步： 玩家 -1， 动作 (2, 3)
# +++++++
# +++++++
# +++x+++
# +++x+o+
# +++++++
# +++++++
# +x+oo++
# 第 6 步： 玩家 1， 动作 (4, 3)
# +++++++
# +++++++
# +++x+++
# +++x+o+
# +++o+++
# +++++++
# +x+oo++
# 第 7 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# +++x+++
# +++x+o+
# +++o+++
# ++x++++
# +x+oo++
# 第 8 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# +++x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 9 步： 玩家 -1， 动作 (1, 3)
# +++++++
# +++x+++
# +++x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 10 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++x+++
# +o+x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 11 步： 玩家 -1， 动作 (0, 4)
# ++++x++
# +++x+++
# +o+x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 12 步： 玩家 1， 动作 (1, 2)
# ++++x++
# ++ox+++
# +o+x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 13 步： 玩家 -1， 动作 (2, 0)
# ++++x++
# ++ox+++
# xo+x+++
# +++x+o+
# +++o+++
# ++xo+++
# +x+oo++
# 第 14 步： 玩家 1， 动作 (4, 2)
# ++++x++
# ++ox+++
# xo+x+++
# +++x+o+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 15 步： 玩家 -1， 动作 (2, 2)
# ++++x++
# ++ox+++
# xoxx+++
# +++x+o+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 16 步： 玩家 1， 动作 (2, 5)
# ++++x++
# ++ox+++
# xoxx+o+
# +++x+o+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 17 步： 玩家 -1， 动作 (3, 1)
# ++++x++
# ++ox+++
# xoxx+o+
# +x+x+o+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 18 步： 玩家 1， 动作 (0, 0)
# o+++x++
# ++ox+++
# xoxx+o+
# +x+x+o+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 19 步： 玩家 -1， 动作 (3, 4)
# o+++x++
# ++ox+++
# xoxx+o+
# +x+xxo+
# ++oo+++
# ++xo+++
# +x+oo++
# 第 20 步： 玩家 1， 动作 (4, 4)
# o+++x++
# ++ox+++
# xoxx+o+
# +x+xxo+
# ++ooo++
# ++xo+++
# +x+oo++
# 第 21 步： 玩家 -1， 动作 (4, 0)
# o+++x++
# ++ox+++
# xoxx+o+
# +x+xxo+
# x+ooo++
# ++xo+++
# +x+oo++
# 赢家 -1
# 训练 76 回合 0: 收集到 224 条经验
# 训练 76 回合 1: 收集到 208 条经验
# 训练 76 回合 2: 收集到 104 条经验
# 训练 76 回合 3: 收集到 224 条经验
# 训练 76 回合 4: 收集到 256 条经验
# 训练 76 回合 5: 收集到 144 条经验
# 训练 76 回合 6: 收集到 176 条经验
# 训练 76 回合 7: 收集到 152 条经验
# 训练 76 回合 8: 收集到 240 条经验
# 训练 76 回合 9: 收集到 88 条经验
# 训练 76 回合 10: 收集到 192 条经验
# 训练 76 回合 11: 收集到 248 条经验
# 训练 76 回合 12: 收集到 392 条经验
# 训练 76 回合 13: 收集到 192 条经验
# 训练 76 回合 14: 收集到 192 条经验
# 训练 76 回合 15: 收集到 184 条经验
# 训练 76 回合 16: 收集到 144 条经验
# 训练 76 回合 17: 收集到 184 条经验
# 训练 76 回合 18: 收集到 152 条经验
# 训练 76 回合 19: 收集到 256 条经验
# 训练 76：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0076/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# ++++++o
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 0)
# +++++++
# +++++++
# ++++++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (0, 4)
# ++++o++
# +++++++
# ++++++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (0, 2)
# ++x+o++
# +++++++
# ++++++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 3)
# ++x+o++
# +++++++
# +++o++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 5)
# ++x+o++
# +++++x+
# +++o++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (1, 0)
# ++x+o++
# o++++x+
# +++o++o
# +++++++
# x++++++
# +++++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (3, 1)
# ++x+o++
# o++++x+
# +++o++o
# +x+++++
# x++++++
# +++++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 6)
# ++x+o++
# o++++x+
# +++o++o
# +x+++++
# x+++++o
# +++++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (3, 3)
# ++x+o++
# o++++x+
# +++o++o
# +x+x+++
# x+++++o
# +++++++
# +++++++
# 第 10 步： 玩家 1， 动作 (2, 4)
# ++x+o++
# o++++x+
# +++oo+o
# +x+x+++
# x+++++o
# +++++++
# +++++++
# 第 11 步： 玩家 -1， 动作 (4, 5)
# ++x+o++
# o++++x+
# +++oo+o
# +x+x+++
# x++++xo
# +++++++
# +++++++
# 第 12 步： 玩家 1， 动作 (5, 3)
# ++x+o++
# o++++x+
# +++oo+o
# +x+x+++
# x++++xo
# +++o+++
# +++++++
# 第 13 步： 玩家 -1， 动作 (6, 2)
# ++x+o++
# o++++x+
# +++oo+o
# +x+x+++
# x++++xo
# +++o+++
# ++x++++
# 第 14 步： 玩家 1， 动作 (4, 2)
# ++x+o++
# o++++x+
# +++oo+o
# +x+x+++
# x+o++xo
# +++o+++
# ++x++++
# 第 15 步： 玩家 -1， 动作 (1, 2)
# ++x+o++
# o+x++x+
# +++oo+o
# +x+x+++
# x+o++xo
# +++o+++
# ++x++++
# 第 16 步： 玩家 1， 动作 (2, 1)
# ++x+o++
# o+x++x+
# +o+oo+o
# +x+x+++
# x+o++xo
# +++o+++
# ++x++++
# 第 17 步： 玩家 -1， 动作 (4, 3)
# ++x+o++
# o+x++x+
# +o+oo+o
# +x+x+++
# x+ox+xo
# +++o+++
# ++x++++
# 第 18 步： 玩家 1， 动作 (3, 2)
# ++x+o++
# o+x++x+
# +o+oo+o
# +xox+++
# x+ox+xo
# +++o+++
# ++x++++
# 第 19 步： 玩家 -1， 动作 (5, 0)
# ++x+o++
# o+x++x+
# +o+oo+o
# +xox+++
# x+ox+xo
# x++o+++
# ++x++++
# 第 20 步： 玩家 1， 动作 (4, 1)
# ++x+o++
# o+x++x+
# +o+oo+o
# +xox+++
# xoox+xo
# x++o+++
# ++x++++
# 第 21 步： 玩家 -1， 动作 (5, 5)
# ++x+o++
# o+x++x+
# +o+oo+o
# +xox+++
# xoox+xo
# x++o+x+
# ++x++++
# 第 22 步： 玩家 1， 动作 (5, 6)
# ++x+o++
# o+x++x+
# +o+oo+o
# +xox+++
# xoox+xo
# x++o+xo
# ++x++++
# 第 23 步： 玩家 -1， 动作 (1, 1)
# ++x+o++
# oxx++x+
# +o+oo+o
# +xox+++
# xoox+xo
# x++o+xo
# ++x++++
# 第 24 步： 玩家 1， 动作 (1, 4)
# ++x+o++
# oxx+ox+
# +o+oo+o
# +xox+++
# xoox+xo
# x++o+xo
# ++x++++
# 第 25 步： 玩家 -1， 动作 (3, 4)
# ++x+o++
# oxx+ox+
# +o+oo+o
# +xoxx++
# xoox+xo
# x++o+xo
# ++x++++
# 第 26 步： 玩家 1， 动作 (0, 1)
# +ox+o++
# oxx+ox+
# +o+oo+o
# +xoxx++
# xoox+xo
# x++o+xo
# ++x++++
# 第 27 步： 玩家 -1， 动作 (5, 2)
# +ox+o++
# oxx+ox+
# +o+oo+o
# +xoxx++
# xoox+xo
# x+xo+xo
# ++x++++
# 第 28 步： 玩家 1， 动作 (3, 0)
# +ox+o++
# oxx+ox+
# +o+oo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# ++x++++
# 第 29 步： 玩家 -1， 动作 (2, 0)
# +ox+o++
# oxx+ox+
# xo+oo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# ++x++++
# 第 30 步： 玩家 1， 动作 (6, 3)
# +ox+o++
# oxx+ox+
# xo+oo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# ++xo+++
# 第 31 步： 玩家 -1， 动作 (6, 5)
# +ox+o++
# oxx+ox+
# xo+oo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# ++xo+x+
# 第 32 步： 玩家 1， 动作 (2, 2)
# +ox+o++
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# ++xo+x+
# 第 33 步： 玩家 -1， 动作 (6, 0)
# +ox+o++
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# x+xo+xo
# x+xo+x+
# 第 34 步： 玩家 1， 动作 (5, 1)
# +ox+o++
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# x+xo+x+
# 第 35 步： 玩家 -1， 动作 (0, 5)
# +ox+ox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# x+xo+x+
# 第 36 步： 玩家 1， 动作 (0, 0)
# oox+ox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# x+xo+x+
# 第 37 步： 玩家 -1， 动作 (6, 6)
# oox+ox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# x+xo+xx
# 第 38 步： 玩家 1， 动作 (6, 4)
# oox+ox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# x+xooxx
# 第 39 步： 玩家 -1， 动作 (6, 1)
# oox+ox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# xxxooxx
# 第 40 步： 玩家 1， 动作 (0, 3)
# ooxoox+
# oxx+ox+
# xoooo+o
# oxoxx++
# xoox+xo
# xoxo+xo
# xxxooxx
# 第 41 步： 玩家 -1， 动作 (2, 5)
# ooxoox+
# oxx+ox+
# xooooxo
# oxoxx++
# xoox+xo
# xoxo+xo
# xxxooxx
# 赢家 -1
# 训练 77 回合 0: 收集到 224 条经验
# 训练 77 回合 1: 收集到 256 条经验
# 训练 77 回合 2: 收集到 232 条经验
# 训练 77 回合 3: 收集到 152 条经验
# 训练 77 回合 4: 收集到 264 条经验
# 训练 77 回合 5: 收集到 248 条经验
# 训练 77 回合 6: 收集到 256 条经验
# 训练 77 回合 7: 收集到 224 条经验
# 训练 77 回合 8: 收集到 272 条经验
# 训练 77 回合 9: 收集到 144 条经验
# 训练 77 回合 10: 收集到 184 条经验
# 训练 77 回合 11: 收集到 208 条经验
# 训练 77 回合 12: 收集到 128 条经验
# 训练 77 回合 13: 收集到 296 条经验
# 训练 77 回合 14: 收集到 200 条经验
# 训练 77 回合 15: 收集到 256 条经验
# 训练 77 回合 16: 收集到 224 条经验
# 训练 77 回合 17: 收集到 288 条经验
# 训练 77 回合 18: 收集到 224 条经验
# 训练 77 回合 19: 收集到 184 条经验
# 训练 77：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0077/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++o+++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 6)
# +++++++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# ++++++o
# 第 3 步： 玩家 -1， 动作 (1, 0)
# +++++++
# x++++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# ++++++o
# 第 4 步： 玩家 1， 动作 (1, 1)
# +++++++
# xo+++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# ++++++o
# 第 5 步： 玩家 -1， 动作 (6, 4)
# +++++++
# xo+++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# ++++x+o
# 第 6 步： 玩家 1， 动作 (6, 1)
# +++++++
# xo+++++
# ++x++++
# +++++++
# +++++++
# +++o+++
# +o++x+o
# 第 7 步： 玩家 -1， 动作 (4, 4)
# +++++++
# xo+++++
# ++x++++
# +++++++
# ++++x++
# +++o+++
# +o++x+o
# 第 8 步： 玩家 1， 动作 (5, 4)
# +++++++
# xo+++++
# ++x++++
# +++++++
# ++++x++
# +++oo++
# +o++x+o
# 第 9 步： 玩家 -1， 动作 (4, 2)
# +++++++
# xo+++++
# ++x++++
# +++++++
# ++x+x++
# +++oo++
# +o++x+o
# 第 10 步： 玩家 1， 动作 (3, 5)
# +++++++
# xo+++++
# ++x++++
# +++++o+
# ++x+x++
# +++oo++
# +o++x+o
# 第 11 步： 玩家 -1， 动作 (0, 3)
# +++x+++
# xo+++++
# ++x++++
# +++++o+
# ++x+x++
# +++oo++
# +o++x+o
# 第 12 步： 玩家 1， 动作 (2, 6)
# +++x+++
# xo+++++
# ++x+++o
# +++++o+
# ++x+x++
# +++oo++
# +o++x+o
# 第 13 步： 玩家 -1， 动作 (1, 5)
# +++x+++
# xo+++x+
# ++x+++o
# +++++o+
# ++x+x++
# +++oo++
# +o++x+o
# 第 14 步： 玩家 1， 动作 (2, 3)
# +++x+++
# xo+++x+
# ++xo++o
# +++++o+
# ++x+x++
# +++oo++
# +o++x+o
# 第 15 步： 玩家 -1， 动作 (4, 6)
# +++x+++
# xo+++x+
# ++xo++o
# +++++o+
# ++x+x+x
# +++oo++
# +o++x+o
# 第 16 步： 玩家 1， 动作 (6, 0)
# +++x+++
# xo+++x+
# ++xo++o
# +++++o+
# ++x+x+x
# +++oo++
# oo++x+o
# 第 17 步： 玩家 -1， 动作 (2, 5)
# +++x+++
# xo+++x+
# ++xo+xo
# +++++o+
# ++x+x+x
# +++oo++
# oo++x+o
# 第 18 步： 玩家 1， 动作 (1, 3)
# +++x+++
# xo+o+x+
# ++xo+xo
# +++++o+
# ++x+x+x
# +++oo++
# oo++x+o
# 第 19 步： 玩家 -1， 动作 (4, 5)
# +++x+++
# xo+o+x+
# ++xo+xo
# +++++o+
# ++x+xxx
# +++oo++
# oo++x+o
# 第 20 步： 玩家 1， 动作 (4, 3)
# +++x+++
# xo+o+x+
# ++xo+xo
# +++++o+
# ++xoxxx
# +++oo++
# oo++x+o
# 第 21 步： 玩家 -1， 动作 (3, 3)
# +++x+++
# xo+o+x+
# ++xo+xo
# +++x+o+
# ++xoxxx
# +++oo++
# oo++x+o
# 第 22 步： 玩家 1， 动作 (3, 2)
# +++x+++
# xo+o+x+
# ++xo+xo
# ++ox+o+
# ++xoxxx
# +++oo++
# oo++x+o
# 第 23 步： 玩家 -1， 动作 (2, 4)
# +++x+++
# xo+o+x+
# ++xoxxo
# ++ox+o+
# ++xoxxx
# +++oo++
# oo++x+o
# 第 24 步： 玩家 1， 动作 (5, 2)
# +++x+++
# xo+o+x+
# ++xoxxo
# ++ox+o+
# ++xoxxx
# ++ooo++
# oo++x+o
# 第 25 步： 玩家 -1， 动作 (3, 6)
# +++x+++
# xo+o+x+
# ++xoxxo
# ++ox+ox
# ++xoxxx
# ++ooo++
# oo++x+o
# 第 26 步： 玩家 1， 动作 (3, 1)
# +++x+++
# xo+o+x+
# ++xoxxo
# +oox+ox
# ++xoxxx
# ++ooo++
# oo++x+o
# 第 27 步： 玩家 -1， 动作 (0, 6)
# +++x++x
# xo+o+x+
# ++xoxxo
# +oox+ox
# ++xoxxx
# ++ooo++
# oo++x+o
# 赢家 -1
# 训练 78 回合 0: 收集到 120 条经验
# 训练 78 回合 1: 收集到 192 条经验
# 训练 78 回合 2: 收集到 304 条经验
# 训练 78 回合 3: 收集到 264 条经验
# 训练 78 回合 4: 收集到 128 条经验
# 训练 78 回合 5: 收集到 208 条经验
# 训练 78 回合 6: 收集到 184 条经验
# 训练 78 回合 7: 收集到 256 条经验
# 训练 78 回合 8: 收集到 168 条经验
# 训练 78 回合 9: 收集到 216 条经验
# 训练 78 回合 10: 收集到 336 条经验
# 训练 78 回合 11: 收集到 256 条经验
# 训练 78 回合 12: 收集到 176 条经验
# 训练 78 回合 13: 收集到 144 条经验
# 训练 78 回合 14: 收集到 192 条经验
# 训练 78 回合 15: 收集到 208 条经验
# 训练 78 回合 16: 收集到 176 条经验
# 训练 78 回合 17: 收集到 200 条经验
# 训练 78 回合 18: 收集到 256 条经验
# 训练 78 回合 19: 收集到 256 条经验
# 训练 78：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0078/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 1 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 2)
# +x+++++
# +++++++
# ++o++++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 3)
# +x+++++
# +++++++
# ++ox+++
# +++++++
# +++++++
# ++++o++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 6)
# +x+++++
# +++++++
# ++ox+++
# +++++++
# ++++++o
# ++++o++
# +++++++
# 第 5 步： 玩家 -1， 动作 (3, 5)
# +x+++++
# +++++++
# ++ox+++
# +++++x+
# ++++++o
# ++++o++
# +++++++
# 第 6 步： 玩家 1， 动作 (3, 3)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# ++++++o
# ++++o++
# +++++++
# 第 7 步： 玩家 -1， 动作 (6, 1)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# ++++++o
# ++++o++
# +x+++++
# 第 8 步： 玩家 1， 动作 (5, 6)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# ++++++o
# ++++o+o
# +x+++++
# 第 9 步： 玩家 -1， 动作 (4, 1)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# +x++++o
# ++++o+o
# +x+++++
# 第 10 步： 玩家 1， 动作 (4, 3)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# +x+o++o
# ++++o+o
# +x+++++
# 第 11 步： 玩家 -1， 动作 (5, 5)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# +x+o++o
# ++++oxo
# +x+++++
# 第 12 步： 玩家 1， 动作 (4, 2)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# +xoo++o
# ++++oxo
# +x+++++
# 第 13 步： 玩家 -1， 动作 (6, 6)
# +x+++++
# +++++++
# ++ox+++
# +++o+x+
# +xoo++o
# ++++oxo
# +x++++x
# 第 14 步： 玩家 1， 动作 (0, 2)
# +xo++++
# +++++++
# ++ox+++
# +++o+x+
# +xoo++o
# ++++oxo
# +x++++x
# 第 15 步： 玩家 -1， 动作 (1, 6)
# +xo++++
# ++++++x
# ++ox+++
# +++o+x+
# +xoo++o
# ++++oxo
# +x++++x
# 第 16 步： 玩家 1， 动作 (3, 0)
# +xo++++
# ++++++x
# ++ox+++
# o++o+x+
# +xoo++o
# ++++oxo
# +x++++x
# 第 17 步： 玩家 -1， 动作 (3, 1)
# +xo++++
# ++++++x
# ++ox+++
# ox+o+x+
# +xoo++o
# ++++oxo
# +x++++x
# 第 18 步： 玩家 1， 动作 (5, 0)
# +xo++++
# ++++++x
# ++ox+++
# ox+o+x+
# +xoo++o
# o+++oxo
# +x++++x
# 第 19 步： 玩家 -1， 动作 (6, 2)
# +xo++++
# ++++++x
# ++ox+++
# ox+o+x+
# +xoo++o
# o+++oxo
# +xx+++x
# 第 20 步： 玩家 1， 动作 (1, 2)
# +xo++++
# ++o+++x
# ++ox+++
# ox+o+x+
# +xoo++o
# o+++oxo
# +xx+++x
# 第 21 步： 玩家 -1， 动作 (1, 5)
# +xo++++
# ++o++xx
# ++ox+++
# ox+o+x+
# +xoo++o
# o+++oxo
# +xx+++x
# 第 22 步： 玩家 1， 动作 (3, 2)
# +xo++++
# ++o++xx
# ++ox+++
# oxoo+x+
# +xoo++o
# o+++oxo
# +xx+++x
# 赢家 1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# 第 1 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++++++
# +++++x+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 2 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 3 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++++x++
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 4 步： 玩家 1， 动作 (1, 5)
# +++++++
# ++++xo+
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 5 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++++xox
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++++
# 第 6 步： 玩家 1， 动作 (6, 5)
# +++++++
# ++++xox
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++o+
# 第 7 步： 玩家 -1， 动作 (1, 2)
# +++++++
# ++x+xox
# ++++ox+
# +++++++
# +++++++
# +++++++
# o++++o+
# 第 8 步： 玩家 1， 动作 (6, 2)
# +++++++
# ++x+xox
# ++++ox+
# +++++++
# +++++++
# +++++++
# o+o++o+
# 第 9 步： 玩家 -1， 动作 (0, 5)
# +++++x+
# ++x+xox
# ++++ox+
# +++++++
# +++++++
# +++++++
# o+o++o+
# 第 10 步： 玩家 1， 动作 (4, 1)
# +++++x+
# ++x+xox
# ++++ox+
# +++++++
# +o+++++
# +++++++
# o+o++o+
# 第 11 步： 玩家 -1， 动作 (2, 3)
# +++++x+
# ++x+xox
# +++xox+
# +++++++
# +o+++++
# +++++++
# o+o++o+
# 第 12 步： 玩家 1， 动作 (6, 1)
# +++++x+
# ++x+xox
# +++xox+
# +++++++
# +o+++++
# +++++++
# ooo++o+
# 第 13 步： 玩家 -1， 动作 (6, 3)
# +++++x+
# ++x+xox
# +++xox+
# +++++++
# +o+++++
# +++++++
# ooox+o+
# 第 14 步： 玩家 1， 动作 (3, 4)
# +++++x+
# ++x+xox
# +++xox+
# ++++o++
# +o+++++
# +++++++
# ooox+o+
# 第 15 步： 玩家 -1， 动作 (2, 6)
# +++++x+
# ++x+xox
# +++xoxx
# ++++o++
# +o+++++
# +++++++
# ooox+o+
# 第 16 步： 玩家 1， 动作 (6, 6)
# +++++x+
# ++x+xox
# +++xoxx
# ++++o++
# +o+++++
# +++++++
# ooox+oo
# 第 17 步： 玩家 -1， 动作 (4, 4)
# +++++x+
# ++x+xox
# +++xoxx
# ++++o++
# +o++x++
# +++++++
# ooox+oo
# 第 18 步： 玩家 1， 动作 (0, 4)
# ++++ox+
# ++x+xox
# +++xoxx
# ++++o++
# +o++x++
# +++++++
# ooox+oo
# 第 19 步： 玩家 -1， 动作 (4, 5)
# ++++ox+
# ++x+xox
# +++xoxx
# ++++o++
# +o++xx+
# +++++++
# ooox+oo
# 第 20 步： 玩家 1， 动作 (3, 3)
# ++++ox+
# ++x+xox
# +++xoxx
# +++oo++
# +o++xx+
# +++++++
# ooox+oo
# 第 21 步： 玩家 -1， 动作 (2, 2)
# ++++ox+
# ++x+xox
# ++xxoxx
# +++oo++
# +o++xx+
# +++++++
# ooox+oo
# 第 22 步： 玩家 1， 动作 (4, 6)
# ++++ox+
# ++x+xox
# ++xxoxx
# +++oo++
# +o++xxo
# +++++++
# ooox+oo
# 第 23 步： 玩家 -1， 动作 (5, 6)
# ++++ox+
# ++x+xox
# ++xxoxx
# +++oo++
# +o++xxo
# ++++++x
# ooox+oo
# 第 24 步： 玩家 1， 动作 (0, 2)
# ++o+ox+
# ++x+xox
# ++xxoxx
# +++oo++
# +o++xxo
# ++++++x
# ooox+oo
# 第 25 步： 玩家 -1， 动作 (4, 0)
# ++o+ox+
# ++x+xox
# ++xxoxx
# +++oo++
# xo++xxo
# ++++++x
# ooox+oo
# 第 26 步： 玩家 1， 动作 (4, 3)
# ++o+ox+
# ++x+xox
# ++xxoxx
# +++oo++
# xo+oxxo
# ++++++x
# ooox+oo
# 第 27 步： 玩家 -1， 动作 (3, 2)
# ++o+ox+
# ++x+xox
# ++xxoxx
# ++xoo++
# xo+oxxo
# ++++++x
# ooox+oo
# 第 28 步： 玩家 1， 动作 (5, 4)
# ++o+ox+
# ++x+xox
# ++xxoxx
# ++xoo++
# xo+oxxo
# ++++o+x
# ooox+oo
# 第 29 步： 玩家 -1， 动作 (6, 4)
# ++o+ox+
# ++x+xox
# ++xxoxx
# ++xoo++
# xo+oxxo
# ++++o+x
# oooxxoo
# 第 30 步： 玩家 1， 动作 (2, 1)
# ++o+ox+
# ++x+xox
# +oxxoxx
# ++xoo++
# xo+oxxo
# ++++o+x
# oooxxoo
# 第 31 步： 玩家 -1， 动作 (5, 3)
# ++o+ox+
# ++x+xox
# +oxxoxx
# ++xoo++
# xo+oxxo
# +++xo+x
# oooxxoo
# 第 32 步： 玩家 1， 动作 (4, 2)
# ++o+ox+
# ++x+xox
# +oxxoxx
# ++xoo++
# xoooxxo
# +++xo+x
# oooxxoo
# 第 33 步： 玩家 -1， 动作 (2, 0)
# ++o+ox+
# ++x+xox
# xoxxoxx
# ++xoo++
# xoooxxo
# +++xo+x
# oooxxoo
# 第 34 步： 玩家 1， 动作 (0, 6)
# ++o+oxo
# ++x+xox
# xoxxoxx
# ++xoo++
# xoooxxo
# +++xo+x
# oooxxoo
# 赢家 1

# %% [markdown]
# ## 训练7 train_iterations = 10 从第79次迭代训练

# %%
def env_reset(verbose:bool) -> Tuple[np.ndarray, np.ndarray]:
    
    board, player = env.reset()
    return (np.array(board, np.int32), np.array(player, np.int32))

def tf_env_reset(verbose:tf.bool) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_reset, inp=[verbose],
                            Tout=[tf.int32, tf.int32])

def env_step(action:np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    
    board, player, winner, done = env.step(action)
    return (board, np.array(player,np.int32),
            np.array(winner, np.int32),
            np.array(done, np.int32))

def tf_env_step(action:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(env_step, [action],
                            [tf.int32, tf.int32 , tf.int32, tf.int32])

def agent_decide(board:np.ndarray, player:int) -> Tuple[np.ndarray, np.ndarray]:
    
    observation = board, player
    action, prob = agent.decide(observation)
    return (np.array(action,dtype=np.int32),
            np.array(prob, dtype=np.float32))

def tf_agent_decide(board:tf.Tensor, player:tf.Tensor) -> List[tf.Tensor]:
    
    return tf.numpy_function(agent_decide, [board, player],
                            [tf.int32, tf.float32])

@tf.function
def self_play(env:object, agent:object) -> List[tf.Tensor]:
    
    players = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    boards = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    probs = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
    winners = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
    board, player = tf_env_reset(False)
    
    # 15 * 15 = 225
    t = 0
    for step in tf.range(240):
        
        action, prob = tf_agent_decide(board, player)
        board,player,winner,done = tf_env_step(action)
        boards_stack = extend_board(board)
        
        for i in range(8):
            players = players.write(t, player)
            boards = boards.write(t, boards_stack[i])
            probs = probs.write(t, prob)
            t += 1
        
        if tf.cast(done, tf.bool): 
            winners=winners.write(0, winner)
            break
    
    winners = winners.stack()
    players = players.stack()
    boards = boards.stack()
    probs = probs.stack()
    return players, boards, probs, winners

def self_play_eval(env:object, agent:object):
    
    board, player = env.reset()
    
    # 15 * 15 = 225    
    for step in range(240):
        
        observation = board, player
        action, prob = agent.decide(observation)
        
        print(strfboard(board))
        print('第 {} 步： 玩家 {}， 动作 {}'.format(step,player,action))
        
        board,player,winner,done = env.step(action)
        
        if done:
            print(strfboard(board))
            print('赢家 {}'.format(winner)) 
            break

@tf.function
def preprocess(trajectory:dict) -> List[tf.Tensor]:
    
    player = trajectory["player"]
    board = trajectory["board"]
    prob = trajectory["prob"]
    winner = trajectory["winner"]
    
    cononical_boards = board * player
    vs = (player * winner)
    return cononical_boards, (prob, vs)

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

"""
小规模参数， 用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 10
train_episodes_per_iteration = 20
epoches = 10
batch_size = 64
sim_count = 200
shuffle_buffer_size = 512
iteration_old = 79
iteration_old_save_model = 78
current_model_path = os.path.join(H5_PATH, f"model_{iteration_old_save_model:04}iterations.h5")

agent = AlphaZeroAgent(env=env, load=current_model_path, sim_count=sim_count,
                       epoches=epoches)

for iteration in range(train_iterations):
    
    # 自我对弈
    trajectorys = {}
    ls_players = []
    ls_boards = []
    ls_probs = []
    ls_winners = []
    
    for episode in range(train_episodes_per_iteration):
        
        players, boards, probs, winners = self_play(env, agent)
        
        print('训练 {} 回合 {}: 收集到 {} 条经验'.format(
            iteration + iteration_old, episode, len(players)))
        
        ls_players.append(players)
        ls_boards.append(boards)
        ls_probs.append(probs)
        winners = tf.concat([winners]*len(players), 0)
        ls_winners.append(winners)
        
    # 利用经验进行学习
    trajectorys["player"] = tf.concat(ls_players, 0)
    trajectorys["board"] = tf.concat(ls_boards, 0)
    trajectorys["prob"] = tf.concat(ls_probs, 0)
    trajectorys["winner"] = tf.concat(ls_winners, 0)
    
    dataset = tf.data.Dataset.from_tensor_slices(trajectorys)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(shuffle_buffer_size,reshuffle_each_iteration=True)
    dataset = dataset.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    agent.learn(dataset)
    print('训练 {}：学习完成'.format(iteration + iteration_old))
    
    current_model_path = os.path.join(H5_PATH, f"model_{iteration + iteration_old:04}iterations.h5")
    agent.net.save(current_model_path)
    tf.saved_model.save(agent.net, os.path.join(SavedModel_PATH, f"{iteration + iteration_old:04}"))
    
    # 演示训练结果
    self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# 训练 79 回合 0: 收集到 200 条经验
# 训练 79 回合 1: 收集到 224 条经验
# 训练 79 回合 2: 收集到 120 条经验
# 训练 79 回合 3: 收集到 232 条经验
# 训练 79 回合 4: 收集到 136 条经验
# 训练 79 回合 5: 收集到 224 条经验
# 训练 79 回合 6: 收集到 200 条经验
# 训练 79 回合 7: 收集到 232 条经验
# 训练 79 回合 8: 收集到 320 条经验
# 训练 79 回合 9: 收集到 184 条经验
# 训练 79 回合 10: 收集到 128 条经验
# 训练 79 回合 11: 收集到 248 条经验
# 训练 79 回合 12: 收集到 224 条经验
# 训练 79 回合 13: 收集到 248 条经验
# 训练 79 回合 14: 收集到 232 条经验
# 训练 79 回合 15: 收集到 304 条经验
# 训练 79 回合 16: 收集到 256 条经验
# 训练 79 回合 17: 收集到 240 条经验
# 训练 79 回合 18: 收集到 160 条经验
# 训练 79 回合 19: 收集到 320 条经验
# 训练 79：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0079/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 2 步： 玩家 1， 动作 (0, 2)
# ++o++++
# +++++++
# +x+++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 3 步： 玩家 -1， 动作 (3, 6)
# ++o++++
# +++++++
# +x+++++
# ++++++x
# +++++++
# +++++++
# +o+++++
# 第 4 步： 玩家 1， 动作 (4, 3)
# ++o++++
# +++++++
# +x+++++
# ++++++x
# +++o+++
# +++++++
# +o+++++
# 第 5 步： 玩家 -1， 动作 (5, 4)
# ++o++++
# +++++++
# +x+++++
# ++++++x
# +++o+++
# ++++x++
# +o+++++
# 第 6 步： 玩家 1， 动作 (3, 3)
# ++o++++
# +++++++
# +x+++++
# +++o++x
# +++o+++
# ++++x++
# +o+++++
# 第 7 步： 玩家 -1， 动作 (4, 5)
# ++o++++
# +++++++
# +x+++++
# +++o++x
# +++o+x+
# ++++x++
# +o+++++
# 第 8 步： 玩家 1， 动作 (2, 4)
# ++o++++
# +++++++
# +x++o++
# +++o++x
# +++o+x+
# ++++x++
# +o+++++
# 第 9 步： 玩家 -1， 动作 (5, 5)
# ++o++++
# +++++++
# +x++o++
# +++o++x
# +++o+x+
# ++++xx+
# +o+++++
# 第 10 步： 玩家 1， 动作 (0, 3)
# ++oo+++
# +++++++
# +x++o++
# +++o++x
# +++o+x+
# ++++xx+
# +o+++++
# 第 11 步： 玩家 -1， 动作 (4, 0)
# ++oo+++
# +++++++
# +x++o++
# +++o++x
# x++o+x+
# ++++xx+
# +o+++++
# 第 12 步： 玩家 1， 动作 (4, 1)
# ++oo+++
# +++++++
# +x++o++
# +++o++x
# xo+o+x+
# ++++xx+
# +o+++++
# 第 13 步： 玩家 -1， 动作 (2, 6)
# ++oo+++
# +++++++
# +x++o+x
# +++o++x
# xo+o+x+
# ++++xx+
# +o+++++
# 第 14 步： 玩家 1， 动作 (4, 6)
# ++oo+++
# +++++++
# +x++o+x
# +++o++x
# xo+o+xo
# ++++xx+
# +o+++++
# 第 15 步： 玩家 -1， 动作 (6, 2)
# ++oo+++
# +++++++
# +x++o+x
# +++o++x
# xo+o+xo
# ++++xx+
# +ox++++
# 第 16 步： 玩家 1， 动作 (6, 5)
# ++oo+++
# +++++++
# +x++o+x
# +++o++x
# xo+o+xo
# ++++xx+
# +ox++o+
# 第 17 步： 玩家 -1， 动作 (1, 5)
# ++oo+++
# +++++x+
# +x++o+x
# +++o++x
# xo+o+xo
# ++++xx+
# +ox++o+
# 第 18 步： 玩家 1， 动作 (4, 4)
# ++oo+++
# +++++x+
# +x++o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +ox++o+
# 第 19 步： 玩家 -1， 动作 (0, 5)
# ++oo+x+
# +++++x+
# +x++o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +ox++o+
# 第 20 步： 玩家 1， 动作 (6, 6)
# ++oo+x+
# +++++x+
# +x++o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +ox++oo
# 第 21 步： 玩家 -1， 动作 (2, 2)
# ++oo+x+
# +++++x+
# +xx+o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +ox++oo
# 第 22 步： 玩家 1， 动作 (1, 2)
# ++oo+x+
# ++o++x+
# +xx+o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +ox++oo
# 第 23 步： 玩家 -1， 动作 (6, 3)
# ++oo+x+
# ++o++x+
# +xx+o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +oxx+oo
# 第 24 步： 玩家 1， 动作 (1, 6)
# ++oo+x+
# ++o++xo
# +xx+o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +oxx+oo
# 第 25 步： 玩家 -1， 动作 (0, 0)
# x+oo+x+
# ++o++xo
# +xx+o+x
# +++o++x
# xo+ooxo
# ++++xx+
# +oxx+oo
# 第 26 步： 玩家 1， 动作 (5, 2)
# x+oo+x+
# ++o++xo
# +xx+o+x
# +++o++x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 27 步： 玩家 -1， 动作 (3, 2)
# x+oo+x+
# ++o++xo
# +xx+o+x
# ++xo++x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 28 步： 玩家 1， 动作 (1, 0)
# x+oo+x+
# o+o++xo
# +xx+o+x
# ++xo++x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 29 步： 玩家 -1， 动作 (1, 4)
# x+oo+x+
# o+o+xxo
# +xx+o+x
# ++xo++x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 30 步： 玩家 1， 动作 (3, 4)
# x+oo+x+
# o+o+xxo
# +xx+o+x
# ++xoo+x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 31 步： 玩家 -1， 动作 (2, 5)
# x+oo+x+
# o+o+xxo
# +xx+oxx
# ++xoo+x
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 32 步： 玩家 1， 动作 (3, 5)
# x+oo+x+
# o+o+xxo
# +xx+oxx
# ++xooox
# xo+ooxo
# ++o+xx+
# +oxx+oo
# 第 33 步： 玩家 -1， 动作 (5, 0)
# x+oo+x+
# o+o+xxo
# +xx+oxx
# ++xooox
# xo+ooxo
# x+o+xx+
# +oxx+oo
# 第 34 步： 玩家 1， 动作 (1, 3)
# x+oo+x+
# o+ooxxo
# +xx+oxx
# ++xooox
# xo+ooxo
# x+o+xx+
# +oxx+oo
# 赢家 1
# 训练 80 回合 0: 收集到 256 条经验
# 训练 80 回合 1: 收集到 152 条经验
# 训练 80 回合 2: 收集到 192 条经验
# 训练 80 回合 3: 收集到 240 条经验
# 训练 80 回合 4: 收集到 152 条经验
# 训练 80 回合 5: 收集到 184 条经验
# 训练 80 回合 6: 收集到 352 条经验
# 训练 80 回合 7: 收集到 128 条经验
# 训练 80 回合 8: 收集到 192 条经验
# 训练 80 回合 9: 收集到 320 条经验
# 训练 80 回合 10: 收集到 128 条经验
# 训练 80 回合 11: 收集到 280 条经验
# 训练 80 回合 12: 收集到 112 条经验
# 训练 80 回合 13: 收集到 216 条经验
# 训练 80 回合 14: 收集到 176 条经验
# 训练 80 回合 15: 收集到 256 条经验
# 训练 80 回合 16: 收集到 208 条经验
# 训练 80 回合 17: 收集到 240 条经验
# 训练 80 回合 18: 收集到 224 条经验
# 训练 80 回合 19: 收集到 256 条经验
# 训练 80：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0080/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 4)
# +++++++
# +++++++
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 3)
# +++++++
# +++++++
# +++++++
# +++x+++
# ++++o++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++++++
# +o+++++
# +++x+++
# ++++o++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++++++
# +o++x++
# +++x+++
# ++++o++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (3, 0)
# +++++++
# +++++++
# +o++x++
# o++x+++
# ++++o++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 5)
# +++++++
# +++++++
# +o++x++
# o++x+++
# ++++o++
# +++++x+
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 0)
# +++++++
# +++++++
# +o++x++
# o++x+++
# ++++o++
# +++++x+
# o++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++++++
# +o++xx+
# o++x+++
# ++++o++
# +++++x+
# o++++++
# 第 8 步： 玩家 1， 动作 (2, 6)
# +++++++
# +++++++
# +o++xxo
# o++x+++
# ++++o++
# +++++x+
# o++++++
# 第 9 步： 玩家 -1， 动作 (0, 0)
# x++++++
# +++++++
# +o++xxo
# o++x+++
# ++++o++
# +++++x+
# o++++++
# 第 10 步： 玩家 1， 动作 (4, 2)
# x++++++
# +++++++
# +o++xxo
# o++x+++
# ++o+o++
# +++++x+
# o++++++
# 第 11 步： 玩家 -1， 动作 (5, 0)
# x++++++
# +++++++
# +o++xxo
# o++x+++
# ++o+o++
# x++++x+
# o++++++
# 第 12 步： 玩家 1， 动作 (0, 3)
# x++o+++
# +++++++
# +o++xxo
# o++x+++
# ++o+o++
# x++++x+
# o++++++
# 第 13 步： 玩家 -1， 动作 (4, 0)
# x++o+++
# +++++++
# +o++xxo
# o++x+++
# x+o+o++
# x++++x+
# o++++++
# 第 14 步： 玩家 1， 动作 (2, 0)
# x++o+++
# +++++++
# oo++xxo
# o++x+++
# x+o+o++
# x++++x+
# o++++++
# 第 15 步： 玩家 -1， 动作 (1, 1)
# x++o+++
# +x+++++
# oo++xxo
# o++x+++
# x+o+o++
# x++++x+
# o++++++
# 第 16 步： 玩家 1， 动作 (6, 5)
# x++o+++
# +x+++++
# oo++xxo
# o++x+++
# x+o+o++
# x++++x+
# o++++o+
# 第 17 步： 玩家 -1， 动作 (5, 4)
# x++o+++
# +x+++++
# oo++xxo
# o++x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 18 步： 玩家 1， 动作 (3, 1)
# x++o+++
# +x+++++
# oo++xxo
# oo+x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 19 步： 玩家 -1， 动作 (2, 3)
# x++o+++
# +x+++++
# oo+xxxo
# oo+x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 20 步： 玩家 1， 动作 (0, 6)
# x++o++o
# +x+++++
# oo+xxxo
# oo+x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 21 步： 玩家 -1， 动作 (1, 3)
# x++o++o
# +x+x+++
# oo+xxxo
# oo+x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 22 步： 玩家 1， 动作 (0, 1)
# xo+o++o
# +x+x+++
# oo+xxxo
# oo+x+++
# x+o+o++
# x+++xx+
# o++++o+
# 第 23 步： 玩家 -1， 动作 (5, 6)
# xo+o++o
# +x+x+++
# oo+xxxo
# oo+x+++
# x+o+o++
# x+++xxx
# o++++o+
# 第 24 步： 玩家 1， 动作 (5, 1)
# xo+o++o
# +x+x+++
# oo+xxxo
# oo+x+++
# x+o+o++
# xo++xxx
# o++++o+
# 第 25 步： 玩家 -1， 动作 (3, 4)
# xo+o++o
# +x+x+++
# oo+xxxo
# oo+xx++
# x+o+o++
# xo++xxx
# o++++o+
# 第 26 步： 玩家 1， 动作 (1, 0)
# xo+o++o
# ox+x+++
# oo+xxxo
# oo+xx++
# x+o+o++
# xo++xxx
# o++++o+
# 第 27 步： 玩家 -1， 动作 (4, 3)
# xo+o++o
# ox+x+++
# oo+xxxo
# oo+xx++
# x+oxo++
# xo++xxx
# o++++o+
# 第 28 步： 玩家 1， 动作 (0, 4)
# xo+oo+o
# ox+x+++
# oo+xxxo
# oo+xx++
# x+oxo++
# xo++xxx
# o++++o+
# 第 29 步： 玩家 -1， 动作 (5, 3)
# xo+oo+o
# ox+x+++
# oo+xxxo
# oo+xx++
# x+oxo++
# xo+xxxx
# o++++o+
# 赢家 -1
# 训练 81 回合 0: 收集到 176 条经验
# 训练 81 回合 1: 收集到 224 条经验
# 训练 81 回合 2: 收集到 248 条经验
# 训练 81 回合 3: 收集到 224 条经验
# 训练 81 回合 4: 收集到 160 条经验
# 训练 81 回合 5: 收集到 144 条经验
# 训练 81 回合 6: 收集到 200 条经验
# 训练 81 回合 7: 收集到 256 条经验
# 训练 81 回合 8: 收集到 200 条经验
# 训练 81 回合 9: 收集到 184 条经验
# 训练 81 回合 10: 收集到 176 条经验
# 训练 81 回合 11: 收集到 264 条经验
# 训练 81 回合 12: 收集到 224 条经验
# 训练 81 回合 13: 收集到 272 条经验
# 训练 81 回合 14: 收集到 208 条经验
# 训练 81 回合 15: 收集到 216 条经验
# 训练 81 回合 16: 收集到 208 条经验
# 训练 81 回合 17: 收集到 200 条经验
# 训练 81 回合 18: 收集到 320 条经验
# 训练 81 回合 19: 收集到 208 条经验
# 训练 81：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0081/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (2, 4)
# +++++++
# +++++++
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (1, 6)
# +++++++
# ++++++x
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 5)
# +++++++
# +++++ox
# ++++o++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 4)
# +++++++
# +++++ox
# ++++o++
# +++++++
# +++++++
# ++++x++
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++ox
# ++++o++
# +++++++
# +++++++
# ++++x++
# +o+++++
# 第 5 步： 玩家 -1， 动作 (0, 6)
# ++++++x
# +++++ox
# ++++o++
# +++++++
# +++++++
# ++++x++
# +o+++++
# 第 6 步： 玩家 1， 动作 (0, 0)
# o+++++x
# +++++ox
# ++++o++
# +++++++
# +++++++
# ++++x++
# +o+++++
# 第 7 步： 玩家 -1， 动作 (3, 2)
# o+++++x
# +++++ox
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +o+++++
# 第 8 步： 玩家 1， 动作 (0, 3)
# o++o++x
# +++++ox
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +o+++++
# 第 9 步： 玩家 -1， 动作 (0, 4)
# o++ox+x
# +++++ox
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +o+++++
# 第 10 步： 玩家 1， 动作 (1, 3)
# o++ox+x
# +++o+ox
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +o+++++
# 第 11 步： 玩家 -1， 动作 (6, 3)
# o++ox+x
# +++o+ox
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +o+x+++
# 第 12 步： 玩家 1， 动作 (5, 6)
# o++ox+x
# +++o+ox
# ++++o++
# ++x++++
# +++++++
# ++++x+o
# +o+x+++
# 第 13 步： 玩家 -1， 动作 (3, 3)
# o++ox+x
# +++o+ox
# ++++o++
# ++xx+++
# +++++++
# ++++x+o
# +o+x+++
# 第 14 步： 玩家 1， 动作 (6, 4)
# o++ox+x
# +++o+ox
# ++++o++
# ++xx+++
# +++++++
# ++++x+o
# +o+xo++
# 第 15 步： 玩家 -1， 动作 (0, 2)
# o+xox+x
# +++o+ox
# ++++o++
# ++xx+++
# +++++++
# ++++x+o
# +o+xo++
# 第 16 步： 玩家 1， 动作 (2, 0)
# o+xox+x
# +++o+ox
# o+++o++
# ++xx+++
# +++++++
# ++++x+o
# +o+xo++
# 第 17 步： 玩家 -1， 动作 (5, 0)
# o+xox+x
# +++o+ox
# o+++o++
# ++xx+++
# +++++++
# x+++x+o
# +o+xo++
# 第 18 步： 玩家 1， 动作 (5, 1)
# o+xox+x
# +++o+ox
# o+++o++
# ++xx+++
# +++++++
# xo++x+o
# +o+xo++
# 第 19 步： 玩家 -1， 动作 (3, 6)
# o+xox+x
# +++o+ox
# o+++o++
# ++xx++x
# +++++++
# xo++x+o
# +o+xo++
# 第 20 步： 玩家 1， 动作 (4, 0)
# o+xox+x
# +++o+ox
# o+++o++
# ++xx++x
# o++++++
# xo++x+o
# +o+xo++
# 第 21 步： 玩家 -1， 动作 (1, 4)
# o+xox+x
# +++oxox
# o+++o++
# ++xx++x
# o++++++
# xo++x+o
# +o+xo++
# 第 22 步： 玩家 1， 动作 (4, 2)
# o+xox+x
# +++oxox
# o+++o++
# ++xx++x
# o+o++++
# xo++x+o
# +o+xo++
# 第 23 步： 玩家 -1， 动作 (0, 1)
# oxxox+x
# +++oxox
# o+++o++
# ++xx++x
# o+o++++
# xo++x+o
# +o+xo++
# 第 24 步： 玩家 1， 动作 (3, 4)
# oxxox+x
# +++oxox
# o+++o++
# ++xxo+x
# o+o++++
# xo++x+o
# +o+xo++
# 第 25 步： 玩家 -1， 动作 (4, 6)
# oxxox+x
# +++oxox
# o+++o++
# ++xxo+x
# o+o+++x
# xo++x+o
# +o+xo++
# 第 26 步： 玩家 1， 动作 (2, 3)
# oxxox+x
# +++oxox
# o++oo++
# ++xxo+x
# o+o+++x
# xo++x+o
# +o+xo++
# 第 27 步： 玩家 -1， 动作 (2, 6)
# oxxox+x
# +++oxox
# o++oo+x
# ++xxo+x
# o+o+++x
# xo++x+o
# +o+xo++
# 赢家 -1
# 训练 82 回合 0: 收集到 200 条经验
# 训练 82 回合 1: 收集到 296 条经验
# 训练 82 回合 2: 收集到 392 条经验
# 训练 82 回合 3: 收集到 240 条经验
# 训练 82 回合 4: 收集到 168 条经验
# 训练 82 回合 5: 收集到 320 条经验
# 训练 82 回合 6: 收集到 272 条经验
# 训练 82 回合 7: 收集到 176 条经验
# 训练 82 回合 8: 收集到 184 条经验
# 训练 82 回合 9: 收集到 200 条经验
# 训练 82 回合 10: 收集到 192 条经验
# 训练 82 回合 11: 收集到 104 条经验
# 训练 82 回合 12: 收集到 176 条经验
# 训练 82 回合 13: 收集到 352 条经验
# 训练 82 回合 14: 收集到 224 条经验
# 训练 82 回合 15: 收集到 280 条经验
# 训练 82 回合 16: 收集到 160 条经验
# 训练 82 回合 17: 收集到 184 条经验
# 训练 82 回合 18: 收集到 184 条经验
# 训练 82 回合 19: 收集到 152 条经验
# 训练 82：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0082/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 2)
# +++++++
# +++o+++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++oo+++
# +++++++
# ++x++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (5, 4)
# +++++++
# ++oo+++
# +++++++
# ++x++++
# +++++++
# ++++x++
# +++++++
# 第 4 步： 玩家 1， 动作 (6, 3)
# +++++++
# ++oo+++
# +++++++
# ++x++++
# +++++++
# ++++x++
# +++o+++
# 第 5 步： 玩家 -1， 动作 (0, 2)
# ++x++++
# ++oo+++
# +++++++
# ++x++++
# +++++++
# ++++x++
# +++o+++
# 第 6 步： 玩家 1， 动作 (2, 4)
# ++x++++
# ++oo+++
# ++++o++
# ++x++++
# +++++++
# ++++x++
# +++o+++
# 第 7 步： 玩家 -1， 动作 (5, 0)
# ++x++++
# ++oo+++
# ++++o++
# ++x++++
# +++++++
# x+++x++
# +++o+++
# 第 8 步： 玩家 1， 动作 (1, 0)
# ++x++++
# o+oo+++
# ++++o++
# ++x++++
# +++++++
# x+++x++
# +++o+++
# 第 9 步： 玩家 -1， 动作 (4, 4)
# ++x++++
# o+oo+++
# ++++o++
# ++x++++
# ++++x++
# x+++x++
# +++o+++
# 第 10 步： 玩家 1， 动作 (0, 5)
# ++x++o+
# o+oo+++
# ++++o++
# ++x++++
# ++++x++
# x+++x++
# +++o+++
# 第 11 步： 玩家 -1， 动作 (0, 4)
# ++x+xo+
# o+oo+++
# ++++o++
# ++x++++
# ++++x++
# x+++x++
# +++o+++
# 第 12 步： 玩家 1， 动作 (1, 5)
# ++x+xo+
# o+oo+o+
# ++++o++
# ++x++++
# ++++x++
# x+++x++
# +++o+++
# 第 13 步： 玩家 -1， 动作 (3, 3)
# ++x+xo+
# o+oo+o+
# ++++o++
# ++xx+++
# ++++x++
# x+++x++
# +++o+++
# 第 14 步： 玩家 1， 动作 (2, 5)
# ++x+xo+
# o+oo+o+
# ++++oo+
# ++xx+++
# ++++x++
# x+++x++
# +++o+++
# 第 15 步： 玩家 -1， 动作 (5, 3)
# ++x+xo+
# o+oo+o+
# ++++oo+
# ++xx+++
# ++++x++
# x++xx++
# +++o+++
# 第 16 步： 玩家 1， 动作 (2, 2)
# ++x+xo+
# o+oo+o+
# ++o+oo+
# ++xx+++
# ++++x++
# x++xx++
# +++o+++
# 第 17 步： 玩家 -1， 动作 (6, 4)
# ++x+xo+
# o+oo+o+
# ++o+oo+
# ++xx+++
# ++++x++
# x++xx++
# +++ox++
# 第 18 步： 玩家 1， 动作 (1, 1)
# ++x+xo+
# oooo+o+
# ++o+oo+
# ++xx+++
# ++++x++
# x++xx++
# +++ox++
# 第 19 步： 玩家 -1， 动作 (2, 6)
# ++x+xo+
# oooo+o+
# ++o+oox
# ++xx+++
# ++++x++
# x++xx++
# +++ox++
# 第 20 步： 玩家 1， 动作 (5, 1)
# ++x+xo+
# oooo+o+
# ++o+oox
# ++xx+++
# ++++x++
# xo+xx++
# +++ox++
# 第 21 步： 玩家 -1， 动作 (4, 5)
# ++x+xo+
# oooo+o+
# ++o+oox
# ++xx+++
# ++++xx+
# xo+xx++
# +++ox++
# 第 22 步： 玩家 1， 动作 (6, 2)
# ++x+xo+
# oooo+o+
# ++o+oox
# ++xx+++
# ++++xx+
# xo+xx++
# ++oox++
# 第 23 步： 玩家 -1， 动作 (1, 6)
# ++x+xo+
# oooo+ox
# ++o+oox
# ++xx+++
# ++++xx+
# xo+xx++
# ++oox++
# 第 24 步： 玩家 1， 动作 (1, 4)
# ++x+xo+
# oooooox
# ++o+oox
# ++xx+++
# ++++xx+
# xo+xx++
# ++oox++
# 赢家 1
# 训练 83 回合 0: 收集到 224 条经验
# 训练 83 回合 1: 收集到 232 条经验
# 训练 83 回合 2: 收集到 312 条经验
# 训练 83 回合 3: 收集到 280 条经验
# 训练 83 回合 4: 收集到 200 条经验
# 训练 83 回合 5: 收集到 184 条经验
# 训练 83 回合 6: 收集到 208 条经验
# 训练 83 回合 7: 收集到 264 条经验
# 训练 83 回合 8: 收集到 120 条经验
# 训练 83 回合 9: 收集到 352 条经验
# 训练 83 回合 10: 收集到 208 条经验
# 训练 83 回合 11: 收集到 232 条经验
# 训练 83 回合 12: 收集到 224 条经验
# 训练 83 回合 13: 收集到 328 条经验
# 训练 83 回合 14: 收集到 152 条经验
# 训练 83 回合 15: 收集到 200 条经验
# 训练 83 回合 16: 收集到 184 条经验
# 训练 83 回合 17: 收集到 160 条经验
# 训练 83 回合 18: 收集到 224 条经验
# 训练 83 回合 19: 收集到 240 条经验
# 训练 83：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0083/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (5, 2)
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# ++x++++
# +++++++
# 第 2 步： 玩家 1， 动作 (4, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# o++o+++
# ++x++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +++++++
# +++++++
# ++++x++
# o++o+++
# ++x++++
# +++++++
# 第 4 步： 玩家 1， 动作 (0, 2)
# ++o++++
# +++++++
# +++++++
# ++++x++
# o++o+++
# ++x++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (6, 6)
# ++o++++
# +++++++
# +++++++
# ++++x++
# o++o+++
# ++x++++
# ++++++x
# 第 6 步： 玩家 1， 动作 (0, 3)
# ++oo+++
# +++++++
# +++++++
# ++++x++
# o++o+++
# ++x++++
# ++++++x
# 第 7 步： 玩家 -1， 动作 (5, 5)
# ++oo+++
# +++++++
# +++++++
# ++++x++
# o++o+++
# ++x++x+
# ++++++x
# 第 8 步： 玩家 1， 动作 (4, 5)
# ++oo+++
# +++++++
# +++++++
# ++++x++
# o++o+o+
# ++x++x+
# ++++++x
# 第 9 步： 玩家 -1， 动作 (2, 4)
# ++oo+++
# +++++++
# ++++x++
# ++++x++
# o++o+o+
# ++x++x+
# ++++++x
# 第 10 步： 玩家 1， 动作 (6, 3)
# ++oo+++
# +++++++
# ++++x++
# ++++x++
# o++o+o+
# ++x++x+
# +++o++x
# 第 11 步： 玩家 -1， 动作 (6, 4)
# ++oo+++
# +++++++
# ++++x++
# ++++x++
# o++o+o+
# ++x++x+
# +++ox+x
# 第 12 步： 玩家 1， 动作 (2, 5)
# ++oo+++
# +++++++
# ++++xo+
# ++++x++
# o++o+o+
# ++x++x+
# +++ox+x
# 第 13 步： 玩家 -1， 动作 (4, 6)
# ++oo+++
# +++++++
# ++++xo+
# ++++x++
# o++o+ox
# ++x++x+
# +++ox+x
# 第 14 步： 玩家 1， 动作 (0, 5)
# ++oo+o+
# +++++++
# ++++xo+
# ++++x++
# o++o+ox
# ++x++x+
# +++ox+x
# 第 15 步： 玩家 -1， 动作 (1, 1)
# ++oo+o+
# +x+++++
# ++++xo+
# ++++x++
# o++o+ox
# ++x++x+
# +++ox+x
# 第 16 步： 玩家 1， 动作 (6, 0)
# ++oo+o+
# +x+++++
# ++++xo+
# ++++x++
# o++o+ox
# ++x++x+
# o++ox+x
# 第 17 步： 玩家 -1， 动作 (5, 3)
# ++oo+o+
# +x+++++
# ++++xo+
# ++++x++
# o++o+ox
# ++xx+x+
# o++ox+x
# 第 18 步： 玩家 1， 动作 (4, 4)
# ++oo+o+
# +x+++++
# ++++xo+
# ++++x++
# o++ooox
# ++xx+x+
# o++ox+x
# 第 19 步： 玩家 -1， 动作 (1, 6)
# ++oo+o+
# +x++++x
# ++++xo+
# ++++x++
# o++ooox
# ++xx+x+
# o++ox+x
# 第 20 步： 玩家 1， 动作 (1, 3)
# ++oo+o+
# +x+o++x
# ++++xo+
# ++++x++
# o++ooox
# ++xx+x+
# o++ox+x
# 第 21 步： 玩家 -1， 动作 (1, 2)
# ++oo+o+
# +xxo++x
# ++++xo+
# ++++x++
# o++ooox
# ++xx+x+
# o++ox+x
# 第 22 步： 玩家 1， 动作 (0, 6)
# ++oo+oo
# +xxo++x
# ++++xo+
# ++++x++
# o++ooox
# ++xx+x+
# o++ox+x
# 第 23 步： 玩家 -1， 动作 (5, 0)
# ++oo+oo
# +xxo++x
# ++++xo+
# ++++x++
# o++ooox
# x+xx+x+
# o++ox+x
# 第 24 步： 玩家 1， 动作 (2, 0)
# ++oo+oo
# +xxo++x
# o+++xo+
# ++++x++
# o++ooox
# x+xx+x+
# o++ox+x
# 第 25 步： 玩家 -1， 动作 (1, 4)
# ++oo+oo
# +xxox+x
# o+++xo+
# ++++x++
# o++ooox
# x+xx+x+
# o++ox+x
# 第 26 步： 玩家 1， 动作 (0, 4)
# ++ooooo
# +xxox+x
# o+++xo+
# ++++x++
# o++ooox
# x+xx+x+
# o++ox+x
# 赢家 1
# 训练 84 回合 0: 收集到 232 条经验
# 训练 84 回合 1: 收集到 256 条经验
# 训练 84 回合 2: 收集到 144 条经验
# 训练 84 回合 3: 收集到 256 条经验
# 训练 84 回合 4: 收集到 208 条经验
# 训练 84 回合 5: 收集到 216 条经验
# 训练 84 回合 6: 收集到 208 条经验
# 训练 84 回合 7: 收集到 152 条经验
# 训练 84 回合 8: 收集到 336 条经验
# 训练 84 回合 9: 收集到 232 条经验
# 训练 84 回合 10: 收集到 200 条经验
# 训练 84 回合 11: 收集到 168 条经验
# 训练 84 回合 12: 收集到 184 条经验
# 训练 84 回合 13: 收集到 232 条经验
# 训练 84 回合 14: 收集到 208 条经验
# 训练 84 回合 15: 收集到 248 条经验
# 训练 84 回合 16: 收集到 120 条经验
# 训练 84 回合 17: 收集到 104 条经验
# 训练 84 回合 18: 收集到 160 条经验
# 训练 84 回合 19: 收集到 288 条经验
# 训练 84：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0084/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 1)
# +++++++
# +++o+++
# +x+++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 2)
# +++++++
# ++oo+++
# +x+++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 3)
# +++++++
# ++oo+++
# +x+x+++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (4, 1)
# +++++++
# ++oo+++
# +x+x+++
# +++++++
# +o+++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 4)
# +++++++
# ++oox++
# +x+x+++
# +++++++
# +o+++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (6, 0)
# +++++++
# ++oox++
# +x+x+++
# +++++++
# +o+++++
# +++++++
# o++++++
# 第 7 步： 玩家 -1， 动作 (4, 5)
# +++++++
# ++oox++
# +x+x+++
# +++++++
# +o+++x+
# +++++++
# o++++++
# 第 8 步： 玩家 1， 动作 (5, 3)
# +++++++
# ++oox++
# +x+x+++
# +++++++
# +o+++x+
# +++o+++
# o++++++
# 第 9 步： 玩家 -1， 动作 (5, 0)
# +++++++
# ++oox++
# +x+x+++
# +++++++
# +o+++x+
# x++o+++
# o++++++
# 第 10 步： 玩家 1， 动作 (3, 3)
# +++++++
# ++oox++
# +x+x+++
# +++o+++
# +o+++x+
# x++o+++
# o++++++
# 第 11 步： 玩家 -1， 动作 (4, 2)
# +++++++
# ++oox++
# +x+x+++
# +++o+++
# +ox++x+
# x++o+++
# o++++++
# 第 12 步： 玩家 1， 动作 (5, 5)
# +++++++
# ++oox++
# +x+x+++
# +++o+++
# +ox++x+
# x++o+o+
# o++++++
# 第 13 步： 玩家 -1， 动作 (4, 4)
# +++++++
# ++oox++
# +x+x+++
# +++o+++
# +ox+xx+
# x++o+o+
# o++++++
# 第 14 步： 玩家 1， 动作 (4, 3)
# +++++++
# ++oox++
# +x+x+++
# +++o+++
# +oxoxx+
# x++o+o+
# o++++++
# 第 15 步： 玩家 -1， 动作 (0, 5)
# +++++x+
# ++oox++
# +x+x+++
# +++o+++
# +oxoxx+
# x++o+o+
# o++++++
# 第 16 步： 玩家 1， 动作 (1, 6)
# +++++x+
# ++oox+o
# +x+x+++
# +++o+++
# +oxoxx+
# x++o+o+
# o++++++
# 第 17 步： 玩家 -1， 动作 (6, 1)
# +++++x+
# ++oox+o
# +x+x+++
# +++o+++
# +oxoxx+
# x++o+o+
# ox+++++
# 第 18 步： 玩家 1， 动作 (0, 4)
# ++++ox+
# ++oox+o
# +x+x+++
# +++o+++
# +oxoxx+
# x++o+o+
# ox+++++
# 第 19 步： 玩家 -1， 动作 (4, 0)
# ++++ox+
# ++oox+o
# +x+x+++
# +++o+++
# xoxoxx+
# x++o+o+
# ox+++++
# 第 20 步： 玩家 1， 动作 (0, 1)
# +o++ox+
# ++oox+o
# +x+x+++
# +++o+++
# xoxoxx+
# x++o+o+
# ox+++++
# 第 21 步： 玩家 -1， 动作 (3, 0)
# +o++ox+
# ++oox+o
# +x+x+++
# x++o+++
# xoxoxx+
# x++o+o+
# ox+++++
# 第 22 步： 玩家 1， 动作 (6, 2)
# +o++ox+
# ++oox+o
# +x+x+++
# x++o+++
# xoxoxx+
# x++o+o+
# oxo++++
# 第 23 步： 玩家 -1， 动作 (3, 4)
# +o++ox+
# ++oox+o
# +x+x+++
# x++ox++
# xoxoxx+
# x++o+o+
# oxo++++
# 第 24 步： 玩家 1， 动作 (2, 0)
# +o++ox+
# ++oox+o
# ox+x+++
# x++ox++
# xoxoxx+
# x++o+o+
# oxo++++
# 第 25 步： 玩家 -1， 动作 (3, 2)
# +o++ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxx+
# x++o+o+
# oxo++++
# 第 26 步： 玩家 1， 动作 (5, 6)
# +o++ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxx+
# x++o+oo
# oxo++++
# 第 27 步： 玩家 -1， 动作 (4, 6)
# +o++ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxxx
# x++o+oo
# oxo++++
# 第 28 步： 玩家 1， 动作 (6, 5)
# +o++ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxxx
# x++o+oo
# oxo++o+
# 第 29 步： 玩家 -1， 动作 (5, 4)
# +o++ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxxx
# x++oxoo
# oxo++o+
# 第 30 步： 玩家 1， 动作 (0, 2)
# +oo+ox+
# ++oox+o
# ox+x+++
# x+xox++
# xoxoxxx
# x++oxoo
# oxo++o+
# 第 31 步： 玩家 -1， 动作 (2, 4)
# +oo+ox+
# ++oox+o
# ox+xx++
# x+xox++
# xoxoxxx
# x++oxoo
# oxo++o+
# 赢家 -1
# 训练 85 回合 0: 收集到 248 条经验
# 训练 85 回合 1: 收集到 352 条经验
# 训练 85 回合 2: 收集到 224 条经验
# 训练 85 回合 3: 收集到 168 条经验
# 训练 85 回合 4: 收集到 232 条经验
# 训练 85 回合 5: 收集到 200 条经验
# 训练 85 回合 6: 收集到 144 条经验
# 训练 85 回合 7: 收集到 176 条经验
# 训练 85 回合 8: 收集到 208 条经验
# 训练 85 回合 9: 收集到 176 条经验
# 训练 85 回合 10: 收集到 232 条经验
# 训练 85 回合 11: 收集到 216 条经验
# 训练 85 回合 12: 收集到 248 条经验
# 训练 85 回合 13: 收集到 272 条经验
# 训练 85 回合 14: 收集到 200 条经验
# 训练 85 回合 15: 收集到 128 条经验
# 训练 85 回合 16: 收集到 136 条经验
# 训练 85 回合 17: 收集到 200 条经验
# 训练 85 回合 18: 收集到 184 条经验
# 训练 85 回合 19: 收集到 224 条经验
# 训练 85：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0085/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (1, 0)
# +++++++
# o++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (4, 3)
# +++++++
# o++++++
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 3)
# +++++++
# o++o+++
# +++++++
# +++++++
# +++x+++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (4, 4)
# +++++++
# o++o+++
# +++++++
# +++++++
# +++xx++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (2, 6)
# +++++++
# o++o+++
# ++++++o
# +++++++
# +++xx++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (5, 4)
# +++++++
# o++o+++
# ++++++o
# +++++++
# +++xx++
# ++++x++
# +++++++
# 第 6 步： 玩家 1， 动作 (2, 3)
# +++++++
# o++o+++
# +++o++o
# +++++++
# +++xx++
# ++++x++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 0)
# +++++++
# o++o+++
# x++o++o
# +++++++
# +++xx++
# ++++x++
# +++++++
# 第 8 步： 玩家 1， 动作 (0, 1)
# +o+++++
# o++o+++
# x++o++o
# +++++++
# +++xx++
# ++++x++
# +++++++
# 第 9 步： 玩家 -1， 动作 (4, 2)
# +o+++++
# o++o+++
# x++o++o
# +++++++
# ++xxx++
# ++++x++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 0)
# +o+++++
# o++o+++
# x++o++o
# +++++++
# ++xxx++
# ++++x++
# o++++++
# 第 11 步： 玩家 -1， 动作 (1, 4)
# +o+++++
# o++ox++
# x++o++o
# +++++++
# ++xxx++
# ++++x++
# o++++++
# 第 12 步： 玩家 1， 动作 (3, 2)
# +o+++++
# o++ox++
# x++o++o
# ++o++++
# ++xxx++
# ++++x++
# o++++++
# 第 13 步： 玩家 -1， 动作 (1, 6)
# +o+++++
# o++ox+x
# x++o++o
# ++o++++
# ++xxx++
# ++++x++
# o++++++
# 第 14 步： 玩家 1， 动作 (1, 1)
# +o+++++
# oo+ox+x
# x++o++o
# ++o++++
# ++xxx++
# ++++x++
# o++++++
# 第 15 步： 玩家 -1， 动作 (2, 4)
# +o+++++
# oo+ox+x
# x++ox+o
# ++o++++
# ++xxx++
# ++++x++
# o++++++
# 第 16 步： 玩家 1， 动作 (3, 4)
# +o+++++
# oo+ox+x
# x++ox+o
# ++o+o++
# ++xxx++
# ++++x++
# o++++++
# 第 17 步： 玩家 -1， 动作 (5, 6)
# +o+++++
# oo+ox+x
# x++ox+o
# ++o+o++
# ++xxx++
# ++++x+x
# o++++++
# 第 18 步： 玩家 1， 动作 (4, 5)
# +o+++++
# oo+ox+x
# x++ox+o
# ++o+o++
# ++xxxo+
# ++++x+x
# o++++++
# 第 19 步： 玩家 -1， 动作 (3, 0)
# +o+++++
# oo+ox+x
# x++ox+o
# x+o+o++
# ++xxxo+
# ++++x+x
# o++++++
# 第 20 步： 玩家 1， 动作 (1, 2)
# +o+++++
# oooox+x
# x++ox+o
# x+o+o++
# ++xxxo+
# ++++x+x
# o++++++
# 赢家 1
# 训练 86 回合 0: 收集到 232 条经验
# 训练 86 回合 1: 收集到 240 条经验
# 训练 86 回合 2: 收集到 224 条经验
# 训练 86 回合 3: 收集到 224 条经验
# 训练 86 回合 4: 收集到 232 条经验
# 训练 86 回合 5: 收集到 200 条经验
# 训练 86 回合 6: 收集到 280 条经验
# 训练 86 回合 7: 收集到 232 条经验
# 训练 86 回合 8: 收集到 272 条经验
# 训练 86 回合 9: 收集到 192 条经验
# 训练 86 回合 10: 收集到 200 条经验
# 训练 86 回合 11: 收集到 176 条经验
# 训练 86 回合 12: 收集到 280 条经验
# 训练 86 回合 13: 收集到 224 条经验
# 训练 86 回合 14: 收集到 320 条经验
# 训练 86 回合 15: 收集到 152 条经验
# 训练 86 回合 16: 收集到 192 条经验
# 训练 86 回合 17: 收集到 224 条经验
# 训练 86 回合 18: 收集到 288 条经验
# 训练 86 回合 19: 收集到 120 条经验
# 训练 86：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0086/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (0, 1)
# +o+++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (2, 3)
# +o+++++
# +++++++
# +++x+++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (6, 5)
# +o+++++
# +++++++
# +++x+++
# +++++++
# +++++++
# +++++++
# +++++o+
# 第 3 步： 玩家 -1， 动作 (4, 5)
# +o+++++
# +++++++
# +++x+++
# +++++++
# +++++x+
# +++++++
# +++++o+
# 第 4 步： 玩家 1， 动作 (5, 4)
# +o+++++
# +++++++
# +++x+++
# +++++++
# +++++x+
# ++++o++
# +++++o+
# 第 5 步： 玩家 -1， 动作 (5, 2)
# +o+++++
# +++++++
# +++x+++
# +++++++
# +++++x+
# ++x+o++
# +++++o+
# 第 6 步： 玩家 1， 动作 (1, 2)
# +o+++++
# ++o++++
# +++x+++
# +++++++
# +++++x+
# ++x+o++
# +++++o+
# 第 7 步： 玩家 -1， 动作 (6, 6)
# +o+++++
# ++o++++
# +++x+++
# +++++++
# +++++x+
# ++x+o++
# +++++ox
# 第 8 步： 玩家 1， 动作 (1, 0)
# +o+++++
# o+o++++
# +++x+++
# +++++++
# +++++x+
# ++x+o++
# +++++ox
# 第 9 步： 玩家 -1， 动作 (2, 1)
# +o+++++
# o+o++++
# +x+x+++
# +++++++
# +++++x+
# ++x+o++
# +++++ox
# 第 10 步： 玩家 1， 动作 (4, 0)
# +o+++++
# o+o++++
# +x+x+++
# +++++++
# o++++x+
# ++x+o++
# +++++ox
# 第 11 步： 玩家 -1， 动作 (6, 1)
# +o+++++
# o+o++++
# +x+x+++
# +++++++
# o++++x+
# ++x+o++
# +x+++ox
# 第 12 步： 玩家 1， 动作 (3, 2)
# +o+++++
# o+o++++
# +x+x+++
# ++o++++
# o++++x+
# ++x+o++
# +x+++ox
# 第 13 步： 玩家 -1， 动作 (0, 6)
# +o++++x
# o+o++++
# +x+x+++
# ++o++++
# o++++x+
# ++x+o++
# +x+++ox
# 第 14 步： 玩家 1， 动作 (4, 3)
# +o++++x
# o+o++++
# +x+x+++
# ++o++++
# o++o+x+
# ++x+o++
# +x+++ox
# 第 15 步： 玩家 -1， 动作 (0, 5)
# +o+++xx
# o+o++++
# +x+x+++
# ++o++++
# o++o+x+
# ++x+o++
# +x+++ox
# 第 16 步： 玩家 1， 动作 (0, 3)
# +o+o+xx
# o+o++++
# +x+x+++
# ++o++++
# o++o+x+
# ++x+o++
# +x+++ox
# 第 17 步： 玩家 -1， 动作 (3, 4)
# +o+o+xx
# o+o++++
# +x+x+++
# ++o+x++
# o++o+x+
# ++x+o++
# +x+++ox
# 第 18 步： 玩家 1， 动作 (4, 6)
# +o+o+xx
# o+o++++
# +x+x+++
# ++o+x++
# o++o+xo
# ++x+o++
# +x+++ox
# 第 19 步： 玩家 -1， 动作 (2, 5)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x++
# o++o+xo
# ++x+o++
# +x+++ox
# 第 20 步： 玩家 1， 动作 (4, 1)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x++
# oo+o+xo
# ++x+o++
# +x+++ox
# 第 21 步： 玩家 -1， 动作 (6, 4)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x++
# oo+o+xo
# ++x+o++
# +x++xox
# 第 22 步： 玩家 1， 动作 (5, 5)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x++
# oo+o+xo
# ++x+oo+
# +x++xox
# 第 23 步： 玩家 -1， 动作 (3, 6)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x+x
# oo+o+xo
# ++x+oo+
# +x++xox
# 第 24 步： 玩家 1， 动作 (5, 6)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+x+x
# oo+o+xo
# ++x+ooo
# +x++xox
# 第 25 步： 玩家 -1， 动作 (3, 5)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+xxx
# oo+o+xo
# ++x+ooo
# +x++xox
# 第 26 步： 玩家 1， 动作 (5, 3)
# +o+o+xx
# o+o++++
# +x+x+x+
# ++o+xxx
# oo+o+xo
# ++xoooo
# +x++xox
# 第 27 步： 玩家 -1， 动作 (1, 5)
# +o+o+xx
# o+o++x+
# +x+x+x+
# ++o+xxx
# oo+o+xo
# ++xoooo
# +x++xox
# 赢家 -1
# 训练 87 回合 0: 收集到 152 条经验
# 训练 87 回合 1: 收集到 216 条经验
# 训练 87 回合 2: 收集到 128 条经验
# 训练 87 回合 3: 收集到 216 条经验
# 训练 87 回合 4: 收集到 184 条经验
# 训练 87 回合 5: 收集到 184 条经验
# 训练 87 回合 6: 收集到 264 条经验
# 训练 87 回合 7: 收集到 232 条经验
# 训练 87 回合 8: 收集到 232 条经验
# 训练 87 回合 9: 收集到 296 条经验
# 训练 87 回合 10: 收集到 200 条经验
# 训练 87 回合 11: 收集到 192 条经验
# 训练 87 回合 12: 收集到 208 条经验
# 训练 87 回合 13: 收集到 160 条经验
# 训练 87 回合 14: 收集到 208 条经验
# 训练 87 回合 15: 收集到 288 条经验
# 训练 87 回合 16: 收集到 176 条经验
# 训练 87 回合 17: 收集到 336 条经验
# 训练 87 回合 18: 收集到 104 条经验
# 训练 87 回合 19: 收集到 192 条经验
# 训练 87：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0087/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (4, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# o++++++
# +++++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (3, 0)
# +++++++
# +++++++
# +++++++
# x++++++
# o++++++
# +++++++
# +++++++
# 第 2 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# +++++++
# x++++++
# o++++++
# +++++++
# +++++++
# 第 3 步： 玩家 -1， 动作 (2, 4)
# +++++++
# +++o+++
# ++++x++
# x++++++
# o++++++
# +++++++
# +++++++
# 第 4 步： 玩家 1， 动作 (1, 4)
# +++++++
# +++oo++
# ++++x++
# x++++++
# o++++++
# +++++++
# +++++++
# 第 5 步： 玩家 -1， 动作 (1, 6)
# +++++++
# +++oo+x
# ++++x++
# x++++++
# o++++++
# +++++++
# +++++++
# 第 6 步： 玩家 1， 动作 (5, 1)
# +++++++
# +++oo+x
# ++++x++
# x++++++
# o++++++
# +o+++++
# +++++++
# 第 7 步： 玩家 -1， 动作 (2, 5)
# +++++++
# +++oo+x
# ++++xx+
# x++++++
# o++++++
# +o+++++
# +++++++
# 第 8 步： 玩家 1， 动作 (4, 2)
# +++++++
# +++oo+x
# ++++xx+
# x++++++
# o+o++++
# +o+++++
# +++++++
# 第 9 步： 玩家 -1， 动作 (0, 4)
# ++++x++
# +++oo+x
# ++++xx+
# x++++++
# o+o++++
# +o+++++
# +++++++
# 第 10 步： 玩家 1， 动作 (6, 1)
# ++++x++
# +++oo+x
# ++++xx+
# x++++++
# o+o++++
# +o+++++
# +o+++++
# 第 11 步： 玩家 -1， 动作 (3, 4)
# ++++x++
# +++oo+x
# ++++xx+
# x+++x++
# o+o++++
# +o+++++
# +o+++++
# 第 12 步： 玩家 1， 动作 (5, 5)
# ++++x++
# +++oo+x
# ++++xx+
# x+++x++
# o+o++++
# +o+++o+
# +o+++++
# 第 13 步： 玩家 -1， 动作 (4, 1)
# ++++x++
# +++oo+x
# ++++xx+
# x+++x++
# oxo++++
# +o+++o+
# +o+++++
# 第 14 步： 玩家 1， 动作 (0, 3)
# +++ox++
# +++oo+x
# ++++xx+
# x+++x++
# oxo++++
# +o+++o+
# +o+++++
# 第 15 步： 玩家 -1， 动作 (1, 2)
# +++ox++
# ++xoo+x
# ++++xx+
# x+++x++
# oxo++++
# +o+++o+
# +o+++++
# 第 16 步： 玩家 1， 动作 (0, 6)
# +++ox+o
# ++xoo+x
# ++++xx+
# x+++x++
# oxo++++
# +o+++o+
# +o+++++
# 第 17 步： 玩家 -1， 动作 (2, 6)
# +++ox+o
# ++xoo+x
# ++++xxx
# x+++x++
# oxo++++
# +o+++o+
# +o+++++
# 第 18 步： 玩家 1， 动作 (5, 6)
# +++ox+o
# ++xoo+x
# ++++xxx
# x+++x++
# oxo++++
# +o+++oo
# +o+++++
# 第 19 步： 玩家 -1， 动作 (5, 2)
# +++ox+o
# ++xoo+x
# ++++xxx
# x+++x++
# oxo++++
# +ox++oo
# +o+++++
# 第 20 步： 玩家 1， 动作 (4, 3)
# +++ox+o
# ++xoo+x
# ++++xxx
# x+++x++
# oxoo+++
# +ox++oo
# +o+++++
# 第 21 步： 玩家 -1， 动作 (3, 6)
# +++ox+o
# ++xoo+x
# ++++xxx
# x+++x+x
# oxoo+++
# +ox++oo
# +o+++++
# 第 22 步： 玩家 1， 动作 (2, 3)
# +++ox+o
# ++xoo+x
# +++oxxx
# x+++x+x
# oxoo+++
# +ox++oo
# +o+++++
# 第 23 步： 玩家 -1， 动作 (5, 0)
# +++ox+o
# ++xoo+x
# +++oxxx
# x+++x+x
# oxoo+++
# xox++oo
# +o+++++
# 第 24 步： 玩家 1， 动作 (3, 3)
# +++ox+o
# ++xoo+x
# +++oxxx
# x++ox+x
# oxoo+++
# xox++oo
# +o+++++
# 赢家 1
# 训练 88 回合 0: 收集到 216 条经验
# 训练 88 回合 1: 收集到 208 条经验
# 训练 88 回合 2: 收集到 248 条经验
# 训练 88 回合 3: 收集到 192 条经验
# 训练 88 回合 4: 收集到 176 条经验
# 训练 88 回合 5: 收集到 312 条经验
# 训练 88 回合 6: 收集到 392 条经验
# 训练 88 回合 7: 收集到 200 条经验
# 训练 88 回合 8: 收集到 336 条经验
# 训练 88 回合 9: 收集到 152 条经验
# 训练 88 回合 10: 收集到 272 条经验
# 训练 88 回合 11: 收集到 176 条经验
# 训练 88 回合 12: 收集到 176 条经验
# 训练 88 回合 13: 收集到 144 条经验
# 训练 88 回合 14: 收集到 232 条经验
# 训练 88 回合 15: 收集到 232 条经验
# 训练 88 回合 16: 收集到 224 条经验
# 训练 88 回合 17: 收集到 392 条经验
# 训练 88 回合 18: 收集到 184 条经验
# 训练 88 回合 19: 收集到 248 条经验
# 训练 88：学习完成
# INFO:tensorflow:Assets written to: ./saved_model/Gomoku-v0_tf_21/0088/assets
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (5, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# +++++++
# 第 1 步： 玩家 -1， 动作 (6, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# x++++++
# 第 2 步： 玩家 1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 3 步： 玩家 -1， 动作 (2, 6)
# +++++++
# +++++++
# ++++++x
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 4 步： 玩家 1， 动作 (2, 1)
# +++++++
# +++++++
# +o++++x
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 5 步： 玩家 -1， 动作 (0, 1)
# +x+++++
# +++++++
# +o++++x
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 6 步： 玩家 1， 动作 (2, 3)
# +x+++++
# +++++++
# +o+o++x
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 7 步： 玩家 -1， 动作 (1, 4)
# +x+++++
# ++++x++
# +o+o++x
# +++++++
# +o+++++
# +o+++++
# x++++++
# 第 8 步： 玩家 1， 动作 (4, 0)
# +x+++++
# ++++x++
# +o+o++x
# +++++++
# oo+++++
# +o+++++
# x++++++
# 第 9 步： 玩家 -1， 动作 (3, 2)
# +x+++++
# ++++x++
# +o+o++x
# ++x++++
# oo+++++
# +o+++++
# x++++++
# 第 10 步： 玩家 1， 动作 (4, 4)
# +x+++++
# ++++x++
# +o+o++x
# ++x++++
# oo++o++
# +o+++++
# x++++++
# 第 11 步： 玩家 -1， 动作 (3, 6)
# +x+++++
# ++++x++
# +o+o++x
# ++x+++x
# oo++o++
# +o+++++
# x++++++
# 第 12 步： 玩家 1， 动作 (3, 1)
# +x+++++
# ++++x++
# +o+o++x
# +ox+++x
# oo++o++
# +o+++++
# x++++++
# 第 13 步： 玩家 -1， 动作 (5, 6)
# +x+++++
# ++++x++
# +o+o++x
# +ox+++x
# oo++o++
# +o++++x
# x++++++
# 第 14 步： 玩家 1， 动作 (4, 2)
# +x+++++
# ++++x++
# +o+o++x
# +ox+++x
# ooo+o++
# +o++++x
# x++++++
# 第 15 步： 玩家 -1， 动作 (3, 3)
# +x+++++
# ++++x++
# +o+o++x
# +oxx++x
# ooo+o++
# +o++++x
# x++++++
# 第 16 步： 玩家 1， 动作 (1, 1)
# +x+++++
# +o++x++
# +o+o++x
# +oxx++x
# ooo+o++
# +o++++x
# x++++++
# 赢家 1

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#env = KInARowEnv(3,3)
env = KInARowEnv(7,5)

def categorical_crossentropy_2d(y_true:tf.Tensor,
                                y_pred:tf.Tensor) -> tf.keras.losses.Loss:
    labels = tf.reshape(y_true, [-1, env.board.size])
    preds = tf.reshape(y_pred, [-1,env.board.size])
    return tf.keras.losses.categorical_crossentropy(labels, preds)

#current_model_path = os.path.join(H5_PATH, f"model_{28:04}iterations.h5")
agent = AlphaZeroAgent(env=env, load=current_model_path)

self_play_eval(env, agent)
# Out:
# INFO:tensorflow:ParameterServerStrategy (CentralStorageStrategy if you are using a single machine) with compute_devices = ['/job:localhost/replica:0/task:0/device:CPU:0'], variable_device = '/job:localhost/replica:0/task:0/device:CPU:0'
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# 第 0 步： 玩家 1， 动作 (6, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +++++++
# +o+++++
# 第 1 步： 玩家 -1， 动作 (4, 0)
# +++++++
# +++++++
# +++++++
# +++++++
# x++++++
# +++++++
# +o+++++
# 第 2 步： 玩家 1， 动作 (4, 1)
# +++++++
# +++++++
# +++++++
# +++++++
# xo+++++
# +++++++
# +o+++++
# 第 3 步： 玩家 -1， 动作 (6, 3)
# +++++++
# +++++++
# +++++++
# +++++++
# xo+++++
# +++++++
# +o+x+++
# 第 4 步： 玩家 1， 动作 (3, 5)
# +++++++
# +++++++
# +++++++
# +++++o+
# xo+++++
# +++++++
# +o+x+++
# 第 5 步： 玩家 -1， 动作 (2, 2)
# +++++++
# +++++++
# ++x++++
# +++++o+
# xo+++++
# +++++++
# +o+x+++
# 第 6 步： 玩家 1， 动作 (5, 4)
# +++++++
# +++++++
# ++x++++
# +++++o+
# xo+++++
# ++++o++
# +o+x+++
# 第 7 步： 玩家 -1， 动作 (3, 4)
# +++++++
# +++++++
# ++x++++
# ++++xo+
# xo+++++
# ++++o++
# +o+x+++
# 第 8 步： 玩家 1， 动作 (1, 3)
# +++++++
# +++o+++
# ++x++++
# ++++xo+
# xo+++++
# ++++o++
# +o+x+++
# 第 9 步： 玩家 -1， 动作 (4, 3)
# +++++++
# +++o+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 10 步： 玩家 1， 动作 (0, 5)
# +++++o+
# +++o+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 11 步： 玩家 -1， 动作 (1, 0)
# +++++o+
# x++o+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 12 步： 玩家 1， 动作 (1, 2)
# +++++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 13 步： 玩家 -1， 动作 (0, 2)
# ++x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 14 步： 玩家 1， 动作 (0, 0)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x+++
# ++++o++
# +o+x+++
# 第 15 步： 玩家 -1， 动作 (4, 6)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++++o++
# +o+x+++
# 第 16 步： 玩家 1， 动作 (5, 2)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++o+o++
# +o+x+++
# 第 17 步： 玩家 -1， 动作 (6, 2)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++o+o++
# +oxx+++
# 第 18 步： 玩家 1， 动作 (6, 0)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++o+o++
# ooxx+++
# 第 19 步： 玩家 -1， 动作 (6, 4)
# o+x++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++o+o++
# ooxxx++
# 第 20 步： 玩家 1， 动作 (0, 1)
# oox++o+
# x+oo+++
# ++x++++
# ++++xo+
# xo+x++x
# ++o+o++
# ooxxx++
# 第 21 步： 玩家 -1， 动作 (3, 2)
# oox++o+
# x+oo+++
# ++x++++
# ++x+xo+
# xo+x++x
# ++o+o++
# ooxxx++
# 第 22 步： 玩家 1， 动作 (2, 3)
# oox++o+
# x+oo+++
# ++xo+++
# ++x+xo+
# xo+x++x
# ++o+o++
# ooxxx++
# 第 23 步： 玩家 -1， 动作 (4, 2)
# oox++o+
# x+oo+++
# ++xo+++
# ++x+xo+
# xoxx++x
# ++o+o++
# ooxxx++
# 第 24 步： 玩家 1， 动作 (6, 5)
# oox++o+
# x+oo+++
# ++xo+++
# ++x+xo+
# xoxx++x
# ++o+o++
# ooxxxo+
# 第 25 步： 玩家 -1， 动作 (1, 4)
# oox++o+
# x+oox++
# ++xo+++
# ++x+xo+
# xoxx++x
# ++o+o++
# ooxxxo+
# 第 26 步： 玩家 1， 动作 (2, 1)
# oox++o+
# x+oox++
# +oxo+++
# ++x+xo+
# xoxx++x
# ++o+o++
# ooxxxo+
# 第 27 步： 玩家 -1， 动作 (6, 6)
# oox++o+
# x+oox++
# +oxo+++
# ++x+xo+
# xoxx++x
# ++o+o++
# ooxxxox
# 第 28 步： 玩家 1， 动作 (5, 1)
# oox++o+
# x+oox++
# +oxo+++
# ++x+xo+
# xoxx++x
# +oo+o++
# ooxxxox
# 第 29 步： 玩家 -1， 动作 (3, 0)
# oox++o+
# x+oox++
# +oxo+++
# x+x+xo+
# xoxx++x
# +oo+o++
# ooxxxox
# 第 30 步： 玩家 1， 动作 (3, 1)
# oox++o+
# x+oox++
# +oxo+++
# xox+xo+
# xoxx++x
# +oo+o++
# ooxxxox
# 赢家 1
